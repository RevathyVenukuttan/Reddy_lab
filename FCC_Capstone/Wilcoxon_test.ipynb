# %%
# %%writefile /data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/wilcoxon_rank_test.py

import numpy as np
from scipy.stats import ranksums
from deeptools import heatmapper 

hm=heatmapper.heatmapper()
hm.read_matrix_file('/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/enhancer_call_comparison/10032022/ASTARR_LentiMPRA_wgSTARR.GC_content.random5000.V6.refpoint.mat.gz')


for ii in range(len(hm.__dict__['parameters']['sample_labels'])):
    if hm.__dict__['parameters']['sample_labels'][ii]=='EP300':
        p300_active=np.nanmean(hm.matrix.matrix[9995:14993, (ii)*400:(ii+1)*400], axis=0)
        p300_inactive=np.nanmean(hm.matrix.matrix[14993:19991, (ii)*400:(ii+1)*400], axis=0)
        
    if hm.__dict__['parameters']['sample_labels'][ii]=='YY1':
        yy1_active=np.nanmean(hm.matrix.matrix[9995:14993, (ii)*400:(ii+1)*400], axis=0)
        yy1_inactive=np.nanmean(hm.matrix.matrix[14993:19991, (ii)*400:(ii+1)*400], axis=0)
        
    if hm.__dict__['parameters']['sample_labels'][ii]=='JUN':
        jun_active=np.nanmean(hm.matrix.matrix[9995:14993, (ii)*400:(ii+1)*400], axis=0)
        jun_inactive=np.nanmean(hm.matrix.matrix[14993:19991, (ii)*400:(ii+1)*400], axis=0)
        
    if hm.__dict__['parameters']['sample_labels'][ii]=='ATF1':
        atf_active=np.nanmean(hm.matrix.matrix[9995:14993, (ii)*400:(ii+1)*400], axis=0)
        atf_inactive=np.nanmean(hm.matrix.matrix[14993:19991, (ii)*400:(ii+1)*400], axis=0)
        
#     if hm.__dict__['parameters']['sample_labels'][ii]=='H3K4me3':
#         h3k4me3_active=np.nanmean(hm.matrix.matrix[:5000, (ii)*400:(ii+1)*400], axis=0)
#         h3k4me3_inactive=np.nanmean(hm.matrix.matrix[5000:9995, (ii)*400:(ii+1)*400], axis=0)
        
#     if hm.__dict__['parameters']['sample_labels'][ii]=='H3K27ac':
#         h3k27ac_active=np.nanmean(hm.matrix.matrix[:5000, (ii)*400:(ii+1)*400], axis=0)
#         h3k27ac_inactive=np.nanmean(hm.matrix.matrix[5000:9995, (ii)*400:(ii+1)*400], axis=0)
        

print(ranksums(p300_active, p300_inactive))
print(ranksums(yy1_active, yy1_inactive))
print(ranksums(jun_active, jun_inactive))
print(ranksums(atf_active, atf_inactive))
# print(ranksums(h3k4me3_active, h3k4me3_inactive))
# print(ranksums(h3k27ac_active, h3k27ac_inactive))
# Out:
# Overwriting /data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/wilcoxon_rank_test.py

# %%
9995:14993:19991

# %%
# %%bash
# source /data/reddylab/software/miniconda3/bin/activate revathy_py3
# sbatch \
#     --exclude=dl-01 \
#     --mem=16G \
#     -o /data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/logs/wilcoxon_rank_test.out \
#     --cpus-per-task=1 \
#     <<'EOF'
# #!/bin/bash
# python /data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/wilcoxon_rank_test.py
# EOF
# Out:
# Submitted batch job 30691731

# %%
# !squeue -u rv103
# Out:
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
#           30691719       all spawner-    rv103  R    1:03:31      1 x3-05-4
#           30691731       all   sbatch    rv103  R       0:01      1 x3-04-4

# %%
# !cat /data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/logs/wilcoxon_rank_test.out
# Out:
# RanksumsResult(statistic=-7.484332455427857, pvalue=7.191170798658462e-14)
# RanksumsResult(statistic=-7.644367856474048, pvalue=2.0997432253144888e-14)
# RanksumsResult(statistic=-6.677729554552604, pvalue=2.426723221568881e-11)
# RanksumsResult(statistic=-6.556555522402907, pvalue=5.506482351919189e-11)
# RanksumsResult(statistic=-5.819107498461571, pvalue=5.916267721612858e-09)
# RanksumsResult(statistic=1.5382370192336499, pvalue=0.12399067260002145)

# %%
import numpy as np

for ii in range(len(hm.__dict__['parameters']['sample_labels'])):
    print(hm.__dict__['parameters']['sample_labels'][ii])
    print(np.nanmean(hm.matrix.matrix[:5000, (ii)*400:(ii+1)*400], axis=0))
# Out:
# POLR2A
# [20.03813524 20.07080112 20.05554263 20.00324751 19.82324319 19.5970871
#  19.47098034 19.33405262 19.11818149 18.92152297 18.73973291 18.64214826
#  18.6285331  18.54249782 18.53208666 18.59915532 18.68430315 18.78573763
#  18.83831523 18.9457604  19.14994573 19.41257166 19.6679578  19.91053159
#  20.06014183 20.29313095 20.49954112 20.65111893 20.80741959 20.8691231
#  20.85752089 20.87196343 20.84148932 20.68274536 20.43456287 20.16626029
#  19.80108951 19.41496172 19.05756968 18.60119474 18.16357019 17.6691715
#  17.16663011 16.67109985 16.16105548 15.67149328 15.20980872 14.71857102
#  14.17027061 13.77930985 13.43420648 13.12519181 12.86633824 12.61403638
#  12.37716062 12.21396869 12.08823833 11.98613737 11.92531867 11.8820567
#  11.85451522 11.81757989 11.78294073 11.77492147 11.76296412 11.77613924
#  11.78203031 11.77945501 11.76362752 11.75936531 11.77679316 11.76972267
#  11.72850345 11.72809375 11.75655922 11.77784916 11.80109164 11.87651296
# ...

# %%
import numpy as np
from scipy.stats import ranksums

for ii in range(len(hm.__dict__['parameters']['sample_labels'])):
    if hm.__dict__['parameters']['sample_labels'][ii]=='EP300':
        p300_active=np.nanmean(hm.matrix.matrix[:5000, (ii)*400:(ii+1)*400], axis=0)
        p300_inactive=np.nanmean(hm.matrix.matrix[5000:9995, (ii)*400:(ii+1)*400], axis=0)
        
    if hm.__dict__['parameters']['sample_labels'][ii]=='YY1':
        yy1_active=np.nanmean(hm.matrix.matrix[:5000, (ii)*400:(ii+1)*400], axis=0)
        yy1_inactive=np.nanmean(hm.matrix.matrix[5000:9995, (ii)*400:(ii+1)*400], axis=0)
        
    if hm.__dict__['parameters']['sample_labels'][ii]=='JUN':
        jun_active=np.nanmean(hm.matrix.matrix[:5000, (ii)*400:(ii+1)*400], axis=0)
        jun_inactive=np.nanmean(hm.matrix.matrix[5000:9995, (ii)*400:(ii+1)*400], axis=0)
        
    if hm.__dict__['parameters']['sample_labels'][ii]=='ATF1':
        atf_active=np.nanmean(hm.matrix.matrix[:5000, (ii)*400:(ii+1)*400], axis=0)
        atf_inactive=np.nanmean(hm.matrix.matrix[5000:9995, (ii)*400:(ii+1)*400], axis=0)
        
    if hm.__dict__['parameters']['sample_labels'][ii]=='H3K4me3':
        h3k4me3_active=np.nanmean(hm.matrix.matrix[:5000, (ii)*400:(ii+1)*400], axis=0)
        h3k4me3_inactive=np.nanmean(hm.matrix.matrix[5000:9995, (ii)*400:(ii+1)*400], axis=0)
        
    if hm.__dict__['parameters']['sample_labels'][ii]=='H3K27ac':
        h3k27ac_active=np.nanmean(hm.matrix.matrix[:5000, (ii)*400:(ii+1)*400], axis=0)
        h3k27ac_inactive=np.nanmean(hm.matrix.matrix[5000:9995, (ii)*400:(ii+1)*400], axis=0)
        

print(ranksums(p300_active, p300_inactive))
print(ranksums(yy1_active, yy1_inactive))
print(ranksums(jun_active, jun_inactive))
print(ranksums(atf_active, atf_inactive))
print(ranksums(h3k4me3_active, h3k4me3_inactive))
print(ranksums(h3k27ac_active, h3k27ac_inactive))
# Out:
# RanksumsResult(statistic=-7.484332455427857, pvalue=7.191170798658462e-14)
# RanksumsResult(statistic=-7.644367856474048, pvalue=2.0997432253144888e-14)
# RanksumsResult(statistic=-6.677729554552604, pvalue=2.426723221568881e-11)
# RanksumsResult(statistic=-6.556555522402907, pvalue=5.506482351919189e-11)

# %%
import numpy as np
from scipy.stats import ranksums

for ii in range(len(hm.__dict__['parameters']['sample_labels'])):
    if hm.__dict__['parameters']['sample_labels'][ii]=='H3K4me3':
        h3k4me3_active=np.nanmean(hm.matrix.matrix[:5000, (ii)*400:(ii+1)*400], axis=0)
        h3k4me3_inactive=np.nanmean(hm.matrix.matrix[5000:9995, (ii)*400:(ii+1)*400], axis=0)
        
    if hm.__dict__['parameters']['sample_labels'][ii]=='H3K27ac':
        h3k27ac_active=np.nanmean(hm.matrix.matrix[:5000, (ii)*400:(ii+1)*400], axis=0)
        h3k27ac_inactive=np.nanmean(hm.matrix.matrix[5000:9995, (ii)*400:(ii+1)*400], axis=0)
        




print(ranksums(h3k4me3_active, h3k4me3_inactive))
print(ranksums(h3k27ac_active, h3k27ac_inactive))

# %%
hm.matrix.matrix[:5000, 0:400][0]
# Out:
# masked_array(data=[6.537600e-02, 6.079000e-02, 6.079000e-02, 7.172000e-02,
#                    3.869600e-02, 8.075000e-02, 6.698100e-02, 4.840600e-02,
#                    8.059600e-02, 1.335120e-01, 1.514320e-01, 1.801660e-01,
#                    2.279100e-01, 1.311180e-01, 2.356360e-01, 2.923400e-01,
#                    2.062590e-01, 2.138300e-01, 1.369990e-01, 1.141600e-01,
#                    1.141600e-01, 1.221980e-01, 1.342550e-01, 1.543500e-01,
#                    1.543500e-01, 9.146600e-02, 1.568620e-01, 1.068620e-01,
#                    1.194330e-01, 1.769580e-01, 1.903240e-01, 1.915300e-01,
#                    1.369360e-01, 8.418200e-02, 5.734000e-02, 5.734000e-02,
#                    3.340100e-02, 2.066200e-02, 2.080600e-02, 2.041400e-02,
#                    1.837000e-02, 1.876200e-02, 1.982600e-02, 1.246800e-02,
#                    7.040000e-03, 6.675000e-03, 7.072000e-03, 8.016000e-03,
# ...

# %%
hm.__dict__['parameters']['sample_labels']
# Out:
# ['POLR2A',
#  'JUN',
#  'CTCF',
#  'SP1',
#  'ELK1',
#  'NRF1',
#  'TAL1',
#  'GATA1',
#  'NFE2',
#  'KLF10',
#  'KLF16',
#  'YY1',
#  'ATF1',
#  'EP300',
#  'REST',
#  'ZEB2',
#  'H3K27ac',
#  'H3K4me3',
#  'H3K4me1',
#  'ATACseq',
#  'ASTARR_log2',
#  'WG_STARR',
#  'WG_STARR_log2',
#  'CRISPRi_sloped400bp']

# %%
hm.__dict__['parameters']['group_boundaries']
# Out:
# [0, 5000, 9995, 14993, 19991, 24991, 29990]

# %%
for ii in range(len(hm.__dict__['parameters']['sample_labels'])):
    print(hm.matrix.matrix[:5000, (ii)*400:(ii+1)*400])
