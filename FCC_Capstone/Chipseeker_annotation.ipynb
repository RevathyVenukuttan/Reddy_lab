# %% [markdown]
# ### Annotate peaks for:
# * `/data/reddylab/Alex/encode4_duke/ipynbs/jamborees/20220706_fcc_capstone/data/tewhey_mpra_orientation_dep_call_all.merged.bed`
# * `/data/reddylab/Alex/encode4_duke/ipynbs/jamborees/20220706_fcc_capstone/data/lenti_mpra_orientation_dep_call_all.merged.bed`
# * `/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/Junke_enhancer_calls_5Oct/processed/merged_peak/merged_sig_up_in_each_orientation.bed`
# * `/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/K562_wgSTARR_active_cradle_peaks.txt`
# * CRISPR_HCRFlowFISH: `/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/encode_data/CRISPR/K562.merged_peaks_from_HCRFF_SabetiLab.peakwise.bed`
# * CRISPR_CERES_screen: `/data/reddylab/Alex/collab/20181203_Tyler/data/allen_order_beta_test/k562-wgCERES-discovery.dhs_allen_test_v2_df.bnd_3.fdr_0.05.hg38.bed`

# %%
suppressMessages(suppressWarnings(library(TxDb.Hsapiens.UCSC.hg38.knownGene)))
suppressMessages(suppressWarnings(library(ChIPseeker)))

txdb <- TxDb.Hsapiens.UCSC.hg38.knownGene


set_plot_dimensions <- function(width_choice, height_choice) {
        options(repr.plot.width=width_choice, repr.plot.height=height_choice)
        }

files <- list("/data/reddylab/Alex/encode4_duke/ipynbs/jamborees/20220706_fcc_capstone/data/tewhey_mpra_orientation_dep_call_all.merged.bed",
              "/data/reddylab/Alex/encode4_duke/ipynbs/jamborees/20220706_fcc_capstone/data/lenti_mpra_orientation_dep_call_all.merged.bed",
              "/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/Junke_enhancer_calls_5Oct/processed/merged_peak/merged_sig_up_in_each_orientation.bed",
              "/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/K562_wgSTARR_active_cradle_peaks.txt",
              "/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/encode_data/CRISPR/K562_merged_peaks_from_HCRFF_SabetiLab.cut.peakwise.bed",
              "/data/reddylab/Alex/collab/20181203_Tyler/data/allen_order_beta_test/k562-wgCERES-discovery.dhs_allen_test_v2_df.bnd_3.fdr_0.05.hg38.bed")

for (file in files){
    filename <- sub('\\..*$', '', basename(file))
    print(filename)
    peakAnnoEnrich <- annotatePeak(file, tssRegion=c(-2000, 2000),
                                TxDb=txdb, annoDb="org.Hs.eg.db")
    print(peakAnnoEnrich)
    foo <- as.data.frame(peakAnnoEnrich)
    write.table(foo, 
             file=paste0('/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/enhancer_call_annotation/',filename, '.annotated.txt'), 
            quote=F, sep='\t')
    
}
# Out:
# [1] "tewhey_mpra_orientation_dep_call_all"
# >> loading peak file...				 2022-11-02 11:38:30 PM
# >> preparing features information...		 2022-11-02 11:38:30 PM
# >> identifying nearest features...		 2022-11-02 11:38:30 PM
# >> calculating distance from peak to TSS...	 2022-11-02 11:38:30 PM
# >> assigning genomic annotation...		 2022-11-02 11:38:30 PM
# >> adding gene annotation...			 2022-11-02 11:38:37 PM
# 'select()' returned 1:1 mapping between keys and columns
# >> assigning chromosome lengths			 2022-11-02 11:38:37 PM
# >> done...					 2022-11-02 11:38:37 PM
# Annotated peaks generated by ChIPseeker
# 4004/4004  peaks were annotated
# Genomic Annotation Summary:
#               Feature  Frequency
# 9    Promoter (<=1kb) 11.4885115
# 10   Promoter (1-2kb)  7.2677323
# 4              5' UTR  0.1248751
# 3              3' UTR  1.8231768
# 1            1st Exon  0.9740260
# 7          Other Exon  4.9700300
# 2          1st Intron  7.7672328
# 8        Other Intron 36.0139860
# ...

# %% [markdown]
# ### Promoter/Non-promoter annotations for the random 5k hits used for the heatmaps

# %% [markdown]
# data:
#
# `/data/reddylab/Alex/encode4_duke/ipynbs/jamborees/20220706_fcc_capstone/data/tewhey_mpra_orientation_dep_call_all.merged.bed`
#         `/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/lenti_mpra_orientation_dep_call_all.merged.random5000.bed`
#         `/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/Junke_ASTARR.30bp_bin.merged_sig_up_in_each_orientation.random5000.bed`
#         `/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/K562_wgSTARR_active_cradle_peaks.random5000.bed `
#        `/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/k562_wgCERES_dhsHits_all_HCRFF_Sabeti_Lab.random5000.bed`

# %%
suppressMessages(suppressWarnings(library(TxDb.Hsapiens.UCSC.hg38.knownGene)))
suppressMessages(suppressWarnings(library(ChIPseeker)))

txdb <- TxDb.Hsapiens.UCSC.hg38.knownGene


set_plot_dimensions <- function(width_choice, height_choice) {
        options(repr.plot.width=width_choice, repr.plot.height=height_choice)
        }

files <- list(
              "/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/lenti_mpra_orientation_dep_call_all.merged.random5000.bed",
              "/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/Junke_ASTARR.30bp_bin.merged_sig_up_in_each_orientation.random5000.bed",
              "/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/K562_wgSTARR_active_cradle_peaks.random5000.bed",
              "/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/k562_wgCERES_dhsHits_all_HCRFF_Sabeti_Lab.random5000.bed"
)

for (file in files){
    filename <- sub('\\..*$', '', basename(file))
    print(filename)
    peakAnnoEnrich <- annotatePeak(file, tssRegion=c(-2000, 2000),
                                TxDb=txdb, annoDb="org.Hs.eg.db")
    print(peakAnnoEnrich)
    foo <- as.data.frame(peakAnnoEnrich)
    write.table(foo, 
             file=paste0('/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/enhancer_call_annotation/',filename, '.random5k.annotated.txt'), 
            quote=F, sep='\t')
    
}
# Out:
# [1] "lenti_mpra_orientation_dep_call_all"
# >> loading peak file...				 2022-11-09 01:54:21 PM
# >> preparing features information...		 2022-11-09 01:54:21 PM
# >> identifying nearest features...		 2022-11-09 01:54:25 PM
# >> calculating distance from peak to TSS...	 2022-11-09 01:54:27 PM
# >> assigning genomic annotation...		 2022-11-09 01:54:27 PM
# >> adding gene annotation...			 2022-11-09 01:55:13 PM
# Loading required package: org.Hs.eg.db
#
# 'select()' returned 1:many mapping between keys and columns
# >> assigning chromosome lengths			 2022-11-09 01:55:14 PM
# >> done...					 2022-11-09 01:55:14 PM
# Annotated peaks generated by ChIPseeker
# 5000/5000  peaks were annotated
# Genomic Annotation Summary:
#               Feature Frequency
# 9    Promoter (<=1kb)     42.72
# 10   Promoter (1-2kb)      1.96
# 4              5' UTR      0.22
# 3              3' UTR      1.30
# 1            1st Exon      1.76
# 7          Other Exon      1.26
# 2          1st Intron      9.48
# ...

# %% [markdown]
# ### Annotations for active_vs_inactive peaks
#
# DATA:
# * LentiMPRA:
# `/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/lenti_mpra_orientation_dep_call_all.merged.random5000.bed`
# `/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/New_enhancer_call/lentiMPRA/lenti_mpra_tested_element_all.unique_peaks.random5k.bed`
#
#
# * ASTARR:
# `/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/Junke_ASTARR.30bp_bin.merged_sig_up_in_each_orientation.random5000.bed`
# `/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/Junke_enhancer_calls_5Oct/processed/bin_level/inactive_bins_with_raw_count.merged.random5k.bed`
#
#
# * wgSTARR:
# `/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/Junke_wgSTARR.30bp_10bp_bin.sig_up.random5000.bed`
# `/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/Junke_enhancer_calls_5Oct/wgSTARR/processed/bin_level/inactive_bins_with_raw_count.merged.random5000.bed`

# %%
suppressMessages(suppressWarnings(library(TxDb.Hsapiens.UCSC.hg38.knownGene)))
suppressMessages(suppressWarnings(library(ChIPseeker)))

txdb <- TxDb.Hsapiens.UCSC.hg38.knownGene


set_plot_dimensions <- function(width_choice, height_choice) {
        options(repr.plot.width=width_choice, repr.plot.height=height_choice)
        }

files <- list(
              "/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/lenti_mpra_orientation_dep_call_all.merged.random5000.bed",
              "/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/New_enhancer_call/lentiMPRA/lenti_mpra_tested_element_all.unique_peaks.random5k.bed",
              "/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/Junke_ASTARR.30bp_bin.merged_sig_up_in_each_orientation.random5000.bed", 
              "/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/Junke_enhancer_calls_5Oct/processed/bin_level/inactive_bins_with_raw_count.merged.random5k.bed",
              "/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/Junke_wgSTARR.30bp_10bp_bin.sig_up.random5000.bed",
              "/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/Junke_enhancer_calls_5Oct/wgSTARR/processed/bin_level/wgSTARR_inactive_bins_with_raw_count.merged.random5000.bed"
)

for (file in files){
    filename <- sub('\\..*$', '', basename(file))
    print(filename)
    peakAnnoEnrich <- annotatePeak(file, tssRegion=c(-1000, 1000),
                                TxDb=txdb, annoDb="org.Hs.eg.db")
    print(peakAnnoEnrich)
    foo <- as.data.frame(peakAnnoEnrich)
    write.table(foo, 
             file=paste0('/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/enhancer_call_annotation/new/',filename, '.random5k.annotated.txt'), 
            quote=F, sep='\t')
    
}
# Out:
# [1] "lenti_mpra_orientation_dep_call_all"
# >> loading peak file...				 2023-02-14 01:04:47 AM
# >> preparing features information...		 2023-02-14 01:04:47 AM
# >> identifying nearest features...		 2023-02-14 01:04:47 AM
# >> calculating distance from peak to TSS...	 2023-02-14 01:04:48 AM
# >> assigning genomic annotation...		 2023-02-14 01:04:48 AM
# >> adding gene annotation...			 2023-02-14 01:04:55 AM
# 'select()' returned 1:many mapping between keys and columns
# >> assigning chromosome lengths			 2023-02-14 01:04:56 AM
# >> done...					 2023-02-14 01:04:56 AM
# Annotated peaks generated by ChIPseeker
# 5000/5000  peaks were annotated
# Genomic Annotation Summary:
#              Feature Frequency
# 9           Promoter     42.72
# 4             5' UTR      0.22
# 3             3' UTR      1.36
# 1           1st Exon      1.78
# 7         Other Exon      1.38
# 2         1st Intron      9.96
# 8       Other Intron     18.04
# 6 Downstream (<=300)      0.90
# ...

# %%
suppressMessages(suppressWarnings(library(TxDb.Hsapiens.UCSC.hg38.knownGene)))
suppressMessages(suppressWarnings(library(ChIPseeker)))

txdb <- TxDb.Hsapiens.UCSC.hg38.knownGene


set_plot_dimensions <- function(width_choice, height_choice) {
        options(repr.plot.width=width_choice, repr.plot.height=height_choice)
        }

files <- list(
#               "/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/Junke_enhancer_calls_5Oct/z_score_processed/ASTARR/merged_peak/ASTARR_merged_enhancer_peak_orientation_independent.summits.bed",
#               "/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/Junke_enhancer_calls_5Oct/z_score_processed/wgSTARR/merged_peak/merged_enhancer_peak_orientation_independent.summits.random5000.bed",
                "/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/Junke_enhancer_calls_5Oct/z_score_processed/lentiMPRA/merged_peak/lentiMPRA_merged_enhancer_peak_orientation_independent.summits.random5000.bed",
                "/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/inputs/intersections/ASTARR_wgSTARR_LentiMPRA_100%_intersected.100bp_bins.logFC_filtered.with_ATAC_peaks.merged.random5000.bed"
)

for (file in files){
    filename <- sub('[.][^.]+$', '', basename(file))
    print(filename)
    peakAnnoEnrich <- annotatePeak(file, tssRegion=c(-1000, 1000),
                                TxDb=txdb, annoDb="org.Hs.eg.db")
    print(peakAnnoEnrich)
    foo <- as.data.frame(peakAnnoEnrich)
    write.table(foo, 
             file=paste0('/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/enhancer_call_annotation/new/',filename, '.annotated.txt'), 
            quote=F, sep='\t')
    
}
# Out:
# [1] "lentiMPRA_merged_enhancer_peak_orientation_independent.summits.random5000"
# >> loading peak file...				 2023-05-03 10:00:23 PM
# >> preparing features information...		 2023-05-03 10:00:23 PM
# >> identifying nearest features...		 2023-05-03 10:00:25 PM
# >> calculating distance from peak to TSS...	 2023-05-03 10:00:27 PM
# >> assigning genomic annotation...		 2023-05-03 10:00:27 PM
# >> adding gene annotation...			 2023-05-03 10:01:11 PM
# Loading required package: org.Hs.eg.db
#
# 'select()' returned 1:many mapping between keys and columns
# >> assigning chromosome lengths			 2023-05-03 10:01:12 PM
# >> done...					 2023-05-03 10:01:12 PM
# Annotated peaks generated by ChIPseeker
# 5000/5000  peaks were annotated
# Genomic Annotation Summary:
#              Feature Frequency
# 9           Promoter     31.82
# 4             5' UTR      0.20
# 3             3' UTR      1.84
# 1           1st Exon      1.50
# 7         Other Exon      2.14
# 2         1st Intron     12.28
# ...

# %% [markdown]
# ## Annotate all ASTARR, LentiMPRA, wgSTARR and common background peaks into promoter and distal -- V5

# %% [markdown]
#    `/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/Junke_enhancer_calls_5Oct/z_score_processed/ASTARR/merged_peak/merged_enhancer_peaks_in_each_orientation.summits.random5000.bed`
#    `/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/Junke_enhancer_calls_5Oct/z_score_processed/lentiMPRA/merged_peak/merged_enhancer_peaks_in_either_orientation.summits.random5000.bed`
#    `/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/Junke_enhancer_calls_5Oct/z_score_processed/wgSTARR/merged_peak/merged_enhancer_peaks_in_each_orientation.summits.random5000.bed`
#    `/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/inputs/intersections/ASTARR_wgSTARR_LentiMPRA_100%_intersected.100bp_bins.logFC_filtered.with_ATAC_peaks.merged.random5000.bed`

# %%
suppressMessages(suppressWarnings(library(TxDb.Hsapiens.UCSC.hg38.knownGene)))
suppressMessages(suppressWarnings(library(ChIPseeker)))

txdb <- TxDb.Hsapiens.UCSC.hg38.knownGene


set_plot_dimensions <- function(width_choice, height_choice) {
        options(repr.plot.width=width_choice, repr.plot.height=height_choice)
        }

files <- list("/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/Junke_enhancer_calls_5Oct/z_score_processed/ASTARR/merged_peak/ASTARR_merged_enhancer_peaks_in_each_orientation.summits.random5000.bed",
              "/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/Junke_enhancer_calls_5Oct/z_score_processed/lentiMPRA/merged_peak/lentiMPRA_merged_enhancer_peaks_in_either_orientation.summits.random5000.bed",
              "/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/Junke_enhancer_calls_5Oct/z_score_processed/wgSTARR/merged_peak/wgSTARR_merged_enhancer_peaks_in_each_orientation.summits.random5000.bed",
              "/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/inputs/intersections/ASTARR_wgSTARR_LentiMPRA_100%_intersected.100bp_bins.logFC_filtered.with_ATAC_peaks.merged.random5000.bed"
)

for (file in files){
    filename <- sub('[.][^.]+$', '', basename(file))
    print(filename)
    peakAnnoEnrich <- annotatePeak(file, tssRegion=c(-1000, 1000),
                                TxDb=txdb, annoDb="org.Hs.eg.db")
    print(peakAnnoEnrich)
    foo <- as.data.frame(peakAnnoEnrich)
    write.table(foo, 
             file=paste0('/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/enhancer_call_annotation/V2/',filename, '.annotated.txt'), 
            quote=F, sep='\t')
    
}
# Out:
# [1] "ASTARR_merged_enhancer_peaks_in_each_orientation.summits.random5000"
# >> loading peak file...				 2023-06-13 12:03:05 PM
# >> preparing features information...		 2023-06-13 12:03:05 PM
# >> identifying nearest features...		 2023-06-13 12:03:05 PM
# >> calculating distance from peak to TSS...	 2023-06-13 12:03:06 PM
# >> assigning genomic annotation...		 2023-06-13 12:03:06 PM
# >> adding gene annotation...			 2023-06-13 12:03:12 PM
# 'select()' returned 1:many mapping between keys and columns
# >> assigning chromosome lengths			 2023-06-13 12:03:12 PM
# >> done...					 2023-06-13 12:03:12 PM
# Annotated peaks generated by ChIPseeker
# 5000/5000  peaks were annotated
# Genomic Annotation Summary:
#              Feature Frequency
# 9           Promoter     28.80
# 4             5' UTR      0.14
# 3             3' UTR      1.28
# 1           1st Exon      1.48
# 7         Other Exon      1.90
# 2         1st Intron     15.90
# 8       Other Intron     24.72
# ...

# %% [markdown]
# ## Annotate ASTARR, LentiMPRA, wgSTARR specific inactive/background peaks into promoter and distal -- V6

# %% [markdown]
# `/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/Junke_enhancer_calls_5Oct/z_score_processed/ASTARR/bin_level/ASTARR_bin_level_all_result.inactive.merged.random5000.bed`
# `/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/Junke_enhancer_calls_5Oct/z_score_processed/lentiMPRA/element_level/lentiMPRA_element_level_all_result.inactive.merged.random5000.bed`
# `/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/Junke_enhancer_calls_5Oct/z_score_processed/wgSTARR/bin_level/wgSTARR_bin_level_all_result.inactive.merged.random5000.bed`

# %%
suppressMessages(suppressWarnings(library(TxDb.Hsapiens.UCSC.hg38.knownGene)))
suppressMessages(suppressWarnings(library(ChIPseeker)))

txdb <- TxDb.Hsapiens.UCSC.hg38.knownGene


set_plot_dimensions <- function(width_choice, height_choice) {
        options(repr.plot.width=width_choice, repr.plot.height=height_choice)
        }

files <- list("/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/Junke_enhancer_calls_5Oct/z_score_processed/ASTARR/bin_level/ASTARR_bin_level_all_result.inactive.merged.random5000.bed",
              "/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/Junke_enhancer_calls_5Oct/z_score_processed/lentiMPRA/element_level/lentiMPRA_element_level_all_result.inactive.merged.random5000.bed",
              "/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/Junke_enhancer_calls_5Oct/z_score_processed/wgSTARR/bin_level/wgSTARR_bin_level_all_result.inactive.merged.random5000.bed"
)

for (file in files){
    filename <- sub('[.][^.]+$', '', basename(file))
    print(filename)
    peakAnnoEnrich <- annotatePeak(file, tssRegion=c(-1000, 1000),
                                TxDb=txdb, annoDb="org.Hs.eg.db")
    print(peakAnnoEnrich)
    foo <- as.data.frame(peakAnnoEnrich)
    write.table(foo, 
             file=paste0('/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/enhancer_call_annotation/V2/',filename, '.annotated.txt'), 
            quote=F, sep='\t')
    
}
# Out:
# [1] "ASTARR_bin_level_all_result.inactive.merged.random5000"
# >> loading peak file...				 2023-06-22 03:41:03 PM
# >> preparing features information...		 2023-06-22 03:41:03 PM
# >> identifying nearest features...		 2023-06-22 03:41:07 PM
# >> calculating distance from peak to TSS...	 2023-06-22 03:41:08 PM
# >> assigning genomic annotation...		 2023-06-22 03:41:08 PM
# >> adding gene annotation...			 2023-06-22 03:41:46 PM
# Loading required package: org.Hs.eg.db
#
# 'select()' returned 1:many mapping between keys and columns
# >> assigning chromosome lengths			 2023-06-22 03:41:46 PM
# >> done...					 2023-06-22 03:41:46 PM
# Annotated peaks generated by ChIPseeker
# 4995/4995  peaks were annotated
# Genomic Annotation Summary:
#              Feature  Frequency
# 9           Promoter 34.5745746
# 4             5' UTR  0.2602603
# 3             3' UTR  3.3033033
# 1           1st Exon  1.5015015
# 7         Other Exon  4.0640641
# 2         1st Intron 14.9549550
# ...

# %% [markdown]
# ## Annotate Repressed Peaks:
# #### ASTARR, LentiMPRA, wgSTARR specific active and inactive peaks into promoter and distal -- V2

# %%
suppressMessages(suppressWarnings(library(TxDb.Hsapiens.UCSC.hg38.knownGene)))
suppressMessages(suppressWarnings(library(ChIPseeker)))

txdb <- TxDb.Hsapiens.UCSC.hg38.knownGene


set_plot_dimensions <- function(width_choice, height_choice) {
        options(repr.plot.width=width_choice, repr.plot.height=height_choice)
        }

files <- list("/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/Junke_enhancer_calls_5Oct/z_score_processed/ASTARR/merged_peak/ASTARR_merged_repressor_peaks_in_each_orientation.random5000.bed",
              "/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/Junke_enhancer_calls_5Oct/z_score_processed/ASTARR/bin_level/ASTARR_bin_level_all_result.inactive_repressed_GC_content_matched.random5000.bed",
              "/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/Junke_enhancer_calls_5Oct/z_score_processed/lentiMPRA/merged_peak/merged_repressor_peaks_in_either_orientation.bed",
              "/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/Junke_enhancer_calls_5Oct/z_score_processed/lentiMPRA/lentiMPRA_element_level_all_result.inactive_repressed_GC_content_matched.random1700.bed",
              "/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/Junke_enhancer_calls_5Oct/z_score_processed/wgSTARR/merged_peak/wgSTARR_merged_repressor_peaks_in_each_orientation.random5000.bed",
              "/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/Junke_enhancer_calls_5Oct/z_score_processed/wgSTARR/bin_level/wgSTARR_bin_level_all_result.inactive_repressed_GC_content_matched.random5000.bed"
)

for (file in files){
    filename <- sub('[.][^.]+$', '', basename(file))
    print(filename)
    peakAnnoEnrich <- annotatePeak(file, tssRegion=c(-1000, 1000),
                                TxDb=txdb, annoDb="org.Hs.eg.db")
    print(peakAnnoEnrich)
    foo <- as.data.frame(peakAnnoEnrich)
    write.table(foo, 
             file=paste0('/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/enhancer_call_annotation/V3_repressed/',filename, '.annotated.txt'), 
            quote=F, sep='\t')
    
}
# Out:
# [1] "ASTARR_merged_repressor_peaks_in_each_orientation.random5000"
# >> loading peak file...				 2023-08-01 01:05:45 PM
# >> preparing features information...		 2023-08-01 01:05:45 PM
# >> identifying nearest features...		 2023-08-01 01:05:48 PM
# >> calculating distance from peak to TSS...	 2023-08-01 01:05:50 PM
# >> assigning genomic annotation...		 2023-08-01 01:05:50 PM
# >> adding gene annotation...			 2023-08-01 01:06:31 PM
# Loading required package: org.Hs.eg.db
#
# 'select()' returned 1:many mapping between keys and columns
# >> assigning chromosome lengths			 2023-08-01 01:06:32 PM
# >> done...					 2023-08-01 01:06:32 PM
# Annotated peaks generated by ChIPseeker
# 4923/5000  peaks were annotated
# Genomic Annotation Summary:
#              Feature  Frequency
# 9           Promoter 77.9199675
# 4             5' UTR  0.1828154
# 3             3' UTR  1.2390819
# 1           1st Exon  1.3609588
# 7         Other Exon  1.8687792
# 2         1st Intron  4.0828763
# ...

# %%
suppressMessages(suppressWarnings(library(TxDb.Hsapiens.UCSC.hg38.knownGene)))
suppressMessages(suppressWarnings(library(ChIPseeker)))

txdb <- TxDb.Hsapiens.UCSC.hg38.knownGene


set_plot_dimensions <- function(width_choice, height_choice) {
        options(repr.plot.width=width_choice, repr.plot.height=height_choice)
        }

files <- list("/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/Junke_enhancer_calls_5Oct/z_score_processed/intersected/ASTARR_LentiMPRA_wgSTARR_merged_enhancer_peak_in_each_orientation.filtered.bed",
              "/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/Junke_enhancer_calls_5Oct/z_score_processed/intersected/ASTARR_LentiMPRA_wgSTARR_common_background_with_ATAC.max_bw_signal.sloped_100bp.random2000.bed"
)

for (file in files){
    filename <- sub('[.][^.]+$', '', basename(file))
    print(filename)
    peakAnnoEnrich <- annotatePeak(file, tssRegion=c(-1000, 1000),
                                TxDb=txdb, annoDb="org.Hs.eg.db")
    print(peakAnnoEnrich)
    foo <- as.data.frame(peakAnnoEnrich)
    write.table(foo, 
             file=paste0('/data/reddylab/Revathy/collabs/Jamborees/fcc_capstone/data/enhancer_call_annotation/V2/',filename, '.annotated.txt'), 
            quote=F, sep='\t')
    
}
# Out:
# [1] "ASTARR_LentiMPRA_wgSTARR_merged_enhancer_peak_in_each_orientation.filtered"
# >> loading peak file...				 2023-11-28 12:41:35 PM
# >> preparing features information...		 2023-11-28 12:41:35 PM
# >> identifying nearest features...		 2023-11-28 12:41:38 PM
# >> calculating distance from peak to TSS...	 2023-11-28 12:41:40 PM
# >> assigning genomic annotation...		 2023-11-28 12:41:40 PM
# >> adding gene annotation...			 2023-11-28 12:42:33 PM
# Loading required package: org.Hs.eg.db
#
#
#
# 'select()' returned 1:many mapping between keys and columns
# >> assigning chromosome lengths			 2023-11-28 12:42:34 PM
# >> done...					 2023-11-28 12:42:34 PM
# Annotated peaks generated by ChIPseeker
# 2066/2066  peaks were annotated
# Genomic Annotation Summary:
#              Feature  Frequency
# 9           Promoter 28.3155857
# 4             5' UTR  0.1452081
# 3             3' UTR  1.5972894
# 1           1st Exon  1.2584705
# 7         Other Exon  2.3233301
# ...

# %%
if (!require("BiocManager", quietly = TRUE))
    install.packages("BiocManager")

BiocManager::install("AnnotationDbi")
# Out:
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.r-project.org
#
# Bioconductor version 3.18 (BiocManager 1.30.22), R 4.3.1 (2023-06-16)
#
# Installing package(s) 'AnnotationDbi'
#
# Warning message in install.packages(...):
# “installation of package ‘AnnotationDbi’ had non-zero exit status”
# Old packages: 'AnnotationDbi', 'chromVAR', 'CNEr', 'DelayedArray', 'DT',
#   'GenomicAlignments', 'GenomicRanges', 'gert', 'ggrepel', 'GO.db',
#   'htmlwidgets', 'KEGGREST', 'motifmatchr', 'plotly', 'prodlim', 'ragg',
#   'recipes', 'rmarkdown', 'Rsamtools', 'rtracklayer', 'sctransform', 'Seurat',
#   'spatstat.explore', 'spatstat.random', 'SummarizedExperiment', 'systemfonts',
#   'textshaping', 'TFBSTools', 'XML'

# %%
if (!require("BiocManager", quietly = TRUE))
    install.packages("BiocManager")

BiocManager::install(["BiocIO", "Biostrings", "BSgenome"])

# %%
getOption("repos")
# Out:
#                         CRAN
# "https://cran.r-project.org"
# attr(,"irkernel")
# [1] TRUE

# %%
BiocManager::repositories(version="3.18")
# Out:
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.r-project.org
#                                                 BioCsoft
#            "https://bioconductor.org/packages/3.18/bioc"
#                                                  BioCann
# "https://bioconductor.org/packages/3.18/data/annotation"
#                                                  BioCexp
# "https://bioconductor.org/packages/3.18/data/experiment"
#                                            BioCworkflows
#       "https://bioconductor.org/packages/3.18/workflows"
#                                                BioCbooks
#           "https://bioconductor.org/packages/3.18/books"
#                                                     CRAN
#                             "https://cran.r-project.org"

# %%
sessionInfo()
# Out:
# R version 4.3.1 (2023-06-16)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: CentOS Linux 7 (Core)
#
# Matrix products: default
# BLAS/LAPACK: /gpfs/fs1/home/rv103/miniconda3/envs/r_env/lib/libopenblasp-r0.3.23.so;  LAPACK version 3.11.0
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# time zone: America/New_York
# tzcode source: system (glibc)
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
# [1] BiocManager_1.30.21.1
#
# loaded via a namespace (and not attached):
#  [1] digest_0.6.33       IRdisplay_1.1       utf8_1.2.3
#  [4] base64enc_0.1-3     fastmap_1.1.1       glue_1.6.2
# ...

# %%
library(ChIPseeker)
# Out:
# Error in library(ChIPseeker): there is no package called ‘ChIPseeker’
# Traceback:
#
# 1. library(ChIPseeker)
