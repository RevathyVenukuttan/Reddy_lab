# %%
# !zcat /data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/fragment_files/syn52118183_syn52120091_GerminalCenter10xATAC_GSM5051505.atac.filter.fragments.hg38.tsv.gz/GerminalCenter10xATAC_GSM5051505.atac.filter.fragments.hg38.tsv.gz | head
# Out:
# chr1	10004	10253	ATCCTCGGTACGAGAC_GerminalCenter10xATAC_GSM5051505	1
# chr1	10005	10120	GCGCCAAAGTATACCC_GerminalCenter10xATAC_GSM5051505	1
# chr1	10006	10114	ACTTCCGTCGCTTGAA_GerminalCenter10xATAC_GSM5051505	1
# chr1	10007	10267	TGCACCTAGCGGACTA_GerminalCenter10xATAC_GSM5051505	1
# chr1	10007	10405	AGCCAGCAGGCTTCGC_GerminalCenter10xATAC_GSM5051505	1
# chr1	10012	10198	AGTCAACTCAGTGTAC_GerminalCenter10xATAC_GSM5051505	1
# chr1	10019	10162	GGCATTAGTATTGTCG_GerminalCenter10xATAC_GSM5051505	1
# chr1	10019	10192	GGCGAAATCCAAGAGG_GerminalCenter10xATAC_GSM5051505	1
# chr1	10025	10169	CGTTCCATCCGAATTG_GerminalCenter10xATAC_GSM5051505	1
# chr1	10025	10178	TAGCGGCGTGCGTTTA_GerminalCenter10xATAC_GSM5051505	1
#
# gzip: stdout: Broken pipe

# %%
# %%bash
# wc -l /data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/fragment_files/syn52118183_syn52120091_GerminalCenter10xATAC_GSM5051505.atac.filter.fragments.hg38.tsv.gz/GerminalCenter10xATAC_GSM5051505.atac.filter.fragments.hg38.tsv.gz
# Out:
# 7549435 /data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/fragment_files/syn52118183_syn52120091_GerminalCenter10xATAC_GSM5051505.atac.filter.fragments.hg38.tsv.gz/GerminalCenter10xATAC_GSM5051505.atac.filter.fragments.hg38.tsv.gz

# %%
# !pwd
# Out:
# /gpfs/fs1/data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks

# %%
import pandas as pd

celltypes = pd.read_csv('/data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/GerminalCenter_10x_Tonsil_scATAC_metadata_celltypes.tsv', sep='\t')
celltypes[['id','gsm','barcodes-num']]=celltypes['barcode'].str.split('_', expand=True)
celltypes[['barcodes','num']] = celltypes['barcodes-num'].str.split('-', expand=True)
celltypes['cell_id']=celltypes['id']+'_'+celltypes['barcodes']
celltypes = celltypes[['cell_id','Annotation','Sample']]
celltypes['membership_score']='NA'
celltypes.rename(columns={'Annotation':'cell_type_id','Sample':'cell_type_name'}, inplace=True)
celltypes.to_csv('/data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/GerminalCenter10xATAC_celltypes.tsv', sep='\t', index=False)

# %%
celltypes
# Out:
#                                       cell_id cell_type_id cell_type_name  \
# 0      GerminalCenter10xATAC_CACTGAACAGGGTAAC   MBC FCRL4+       Tonsil1a
# 1      GerminalCenter10xATAC_TGACTCCAGTGAACCG      Naive B       Tonsil1a
# 2      GerminalCenter10xATAC_CGTTCCAGTCATAGAA      Naive B       Tonsil1a
# 3      GerminalCenter10xATAC_CTAACTTAGTGCTAGG      Naive B       Tonsil1a
# 4      GerminalCenter10xATAC_ATAGTCGGTTTAGACC      Naive B       Tonsil1a
# 5      GerminalCenter10xATAC_AGCCGCAAGAATCAAC      Naive B       Tonsil1a
# 6      GerminalCenter10xATAC_TCGAGCGGTGATGCTT      Naive B       Tonsil1a
# 7      GerminalCenter10xATAC_GTCACGGAGGTTGACG      Naive B       Tonsil1a
# 8      GerminalCenter10xATAC_ATCCAGATCGATATGC      Naive B       Tonsil1a
# 9      GerminalCenter10xATAC_GGGTTATGTCAACGGA      Naive B       Tonsil1a
# 10     GerminalCenter10xATAC_CGTTCCAGTCAACGGA      Naive B       Tonsil1a
# 11     GerminalCenter10xATAC_AAATGAGGTTGGCTTA      Naive B       Tonsil1a
# 12     GerminalCenter10xATAC_GCGCCAAAGTCGAGCA      Myeloid       Tonsil1a
# 13     GerminalCenter10xATAC_AATGGAATCTGAACGT      Naive B       Tonsil1a
# 14     GerminalCenter10xATAC_TGCTCGTCAAGGAGGG      Naive B       Tonsil1a
# 15     GerminalCenter10xATAC_AGCCGCAGTTAACTCG      Naive B       Tonsil1a
# 16     GerminalCenter10xATAC_TGGACATCATGGCCTG  Activated B       Tonsil1a
# 17     GerminalCenter10xATAC_GTGCACGGTCAGAGTG      Naive B       Tonsil1a
# 18     GerminalCenter10xATAC_GTAGGAGCACCGAATT      Naive B       Tonsil1a
# 19     GerminalCenter10xATAC_GAGACTTTCAGTTGAC      Myeloid       Tonsil1a
# 20     GerminalCenter10xATAC_TCAGCTCGTGCTGAAG      Naive B       Tonsil1a
# 21     GerminalCenter10xATAC_TAGCTTTTCATCGCCT      Naive B       Tonsil1a
# 22     GerminalCenter10xATAC_CCTTAATTCGGAGTTT      Naive B       Tonsil1a
# 23     GerminalCenter10xATAC_CCTATTATCACTTACT      Naive B       Tonsil1a
# 24     GerminalCenter10xATAC_CCAGATAGTACATGGG      Myeloid       Tonsil1a
# 25     GerminalCenter10xATAC_GCGATTATCTAGTCGA      Naive B       Tonsil1a
# 26     GerminalCenter10xATAC_GAGGATGGTGAGGGTT      Naive B       Tonsil1a
# 27     GerminalCenter10xATAC_CCAATGATCCTCCATG      Myeloid       Tonsil1a
# 28     GerminalCenter10xATAC_TTACCGCCACACACCG      Naive B       Tonsil1a
# 29     GerminalCenter10xATAC_ACAGACTGTCCCTTTG        DZ GC       Tonsil1a
# ...                                       ...          ...            ...
# 33493  GerminalCenter10xATAC_GCATTCCTCGAGAACG        DZ GC         BCP006
# 33494  GerminalCenter10xATAC_TCGATTTGTGATCAGG         Treg         BCP006
# 33495  GerminalCenter10xATAC_GGAACCCTCTCCACTG          Tfh         BCP006
# 33496  GerminalCenter10xATAC_GAACGTTCATGGCCCA      Naive B         BCP006
# 33497  GerminalCenter10xATAC_CTGTTCGCAACTCCCT      Naive B         BCP006
# 33498  GerminalCenter10xATAC_TACCTCGTCGGAGTTT      Naive B         BCP006
# 33499  GerminalCenter10xATAC_CCTTGGTAGGCGTCCT      Naive T         BCP006
# 33500  GerminalCenter10xATAC_GCTCACTAGCATACCT        LZ GC         BCP006
# 33501  GerminalCenter10xATAC_TTGTTCAAGAAGGGCG        DZ GC         BCP006
# 33502  GerminalCenter10xATAC_GCTCACTAGGTTTCTG        DZ GC         BCP006
# 33503  GerminalCenter10xATAC_TATCGAGAGCTACGTT  Activated B         BCP006
# 33504  GerminalCenter10xATAC_TTGCTTATCAGTCAAC        DZ GC         BCP006
# 33505  GerminalCenter10xATAC_TTGGTCCTCCCGTAGG      Naive T         BCP006
# 33506  GerminalCenter10xATAC_CGATGATGTCAGACGA      Naive B         BCP006
# 33507  GerminalCenter10xATAC_GGAATCTAGGGTATCG        LZ GC         BCP006
# 33508  GerminalCenter10xATAC_TTGTTCAAGGATCCTT      Naive B         BCP006
# 33509  GerminalCenter10xATAC_CCCTAACTCGGGAAAC   MBC FCRL4+         BCP006
# 33510  GerminalCenter10xATAC_AGCTGATAGCGAGAAA        LZ GC         BCP006
# 33511  GerminalCenter10xATAC_ATGTCGAAGGCACCTC        DZ GC         BCP006
# 33512  GerminalCenter10xATAC_CGCTAGGAGTTATGAG      Naive B         BCP006
# 33513  GerminalCenter10xATAC_CCTGCTATCTCGCGTT   MBC FCRL4+         BCP006
# 33514  GerminalCenter10xATAC_TAATCGGCAAGTCTGT      Naive T         BCP006
# 33515  GerminalCenter10xATAC_GTCACGGTCACTCGGG      Naive T         BCP006
# 33516  GerminalCenter10xATAC_AGTTTGGGTACGCCCA      Naive T         BCP006
# 33517  GerminalCenter10xATAC_GAGAACGTCAGTCAAC   MBC FCRL4+         BCP006
# 33518  GerminalCenter10xATAC_TGAGCCGTCGATTACG      Naive B         BCP006
# 33519  GerminalCenter10xATAC_GGAACTTCAGCAGGTA          CTL         BCP006
# 33520  GerminalCenter10xATAC_AGTGCCGCAGAACAGC      Naive B         BCP006
# 33521  GerminalCenter10xATAC_GTGACATCATCGTACA      Naive T         BCP006
# 33522  GerminalCenter10xATAC_TAATCGGAGGATCCTT      Naive B         BCP006
#
#       membership_score
# 0                   NA
# 1                   NA
# 2                   NA
# 3                   NA
# 4                   NA
# 5                   NA
# 6                   NA
# 7                   NA
# 8                   NA
# 9                   NA
# 10                  NA
# 11                  NA
# 12                  NA
# 13                  NA
# 14                  NA
# 15                  NA
# 16                  NA
# 17                  NA
# 18                  NA
# 19                  NA
# 20                  NA
# 21                  NA
# 22                  NA
# 23                  NA
# 24                  NA
# 25                  NA
# 26                  NA
# 27                  NA
# 28                  NA
# 29                  NA
# ...                ...
# 33493               NA
# 33494               NA
# 33495               NA
# 33496               NA
# 33497               NA
# 33498               NA
# 33499               NA
# 33500               NA
# 33501               NA
# 33502               NA
# 33503               NA
# 33504               NA
# 33505               NA
# 33506               NA
# 33507               NA
# 33508               NA
# 33509               NA
# 33510               NA
# 33511               NA
# 33512               NA
# 33513               NA
# 33514               NA
# 33515               NA
# 33516               NA
# 33517               NA
# 33518               NA
# 33519               NA
# 33520               NA
# 33521               NA
# 33522               NA
#
# [33523 rows x 4 columns]

# %%
# !gzip /data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/GerminalCenter10xATAC_celltypes.tsv

# %% [markdown]
# ### tagAlign creation script

# %%
# !ls /data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/fragment_files/*Germinal*
# Out:
# /data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/fragment_files/syn52118183_syn52120076_GerminalCenter10xATAC_GSM5051500.atac.filter.fragments.hg38.tsv.gz:
# GerminalCenter10xATAC_GSM5051500.atac.filter.fragments.hg38.tsv.gz
#
# /data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/fragment_files/syn52118183_syn52120078_GerminalCenter10xATAC_GSM5051499.atac.filter.fragments.hg38.tsv.gz:
# GerminalCenter10xATAC_GSM5051499.atac.filter.fragments.hg38.tsv.gz
#
# /data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/fragment_files/syn52118183_syn52120079_GerminalCenter10xATAC_GSM5051501.atac.filter.fragments.hg38.tsv.gz:
# GerminalCenter10xATAC_GSM5051501.atac.filter.fragments.hg38.tsv.gz
#
# /data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/fragment_files/syn52118183_syn52120086_GerminalCenter10xATAC_GSM5051506.atac.filter.fragments.hg38.tsv.gz:
# GerminalCenter10xATAC_GSM5051506.atac.filter.fragments.hg38.tsv.gz
#
# /data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/fragment_files/syn52118183_syn52120089_GerminalCenter10xATAC_GSM5051508.atac.filter.fragments.hg38.tsv.gz:
# GerminalCenter10xATAC_GSM5051508.atac.filter.fragments.hg38.tsv.gz
#
# /data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/fragment_files/syn52118183_syn52120090_GerminalCenter10xATAC_GSM5051507.atac.filter.fragments.hg38.tsv.gz:
# GerminalCenter10xATAC_GSM5051507.atac.filter.fragments.hg38.tsv.gz
#
# /data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/fragment_files/syn52118183_syn52120091_GerminalCenter10xATAC_GSM5051505.atac.filter.fragments.hg38.tsv.gz:
# GerminalCenter10xATAC_GSM5051505.atac.filter.fragments.hg38.tsv.gz

# %%
[("/data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/fragment_files/syn52118183_syn52120076_GerminalCenter10xATAC_GSM5051500.atac.filter.fragments.hg38.tsv.gz/GerminalCenter10xATAC_GSM5051500.atac.filter.fragments.hg38.tsv.gz",
  "/data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/fragment_files/syn52118183_syn52120078_GerminalCenter10xATAC_GSM5051499.atac.filter.fragments.hg38.tsv.gz/GerminalCenter10xATAC_GSM5051499.atac.filter.fragments.hg38.tsv.gz",
                                        "/data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/fragment_files/syn52118183_syn52120079_GerminalCenter10xATAC_GSM5051501.atac.filter.fragments.hg38.tsv.gz/GerminalCenter10xATAC_GSM5051501.atac.filter.fragments.hg38.tsv.gz",
                                        "/data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/fragment_files/syn52118183_syn52120086_GerminalCenter10xATAC_GSM5051506.atac.filter.fragments.hg38.tsv.gz/GerminalCenter10xATAC_GSM5051506.atac.filter.fragments.hg38.tsv.gz",
                                        "/data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/fragment_files/syn52118183_syn52120089_GerminalCenter10xATAC_GSM5051508.atac.filter.fragments.hg38.tsv.gz/GerminalCenter10xATAC_GSM5051508.atac.filter.fragments.hg38.tsv.gz",
                                        "/data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/fragment_files/syn52118183_syn52120090_GerminalCenter10xATAC_GSM5051507.atac.filter.fragments.hg38.tsv.gz/GerminalCenter10xATAC_GSM5051507.atac.filter.fragments.hg38.tsv.gz",
                                        "/data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/fragment_files/syn52118183_syn52120090_GerminalCenter10xATAC_GSM5051507.atac.filter.fragments.hg38.tsv.gz/GerminalCenter10xATAC_GSM5051507.atac.filter.fragments.hg38.tsv.gz",
                                        "/data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/GerminalCenter10xATAC_celltypes.tsv.gz")]

# %%
# %%writefile /data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/tagAlign_script_GerminalCenter10xATAC.py
#!/usr/bin/env python
import os
import pandas as pd
import argparse
parser = argparse.ArgumentParser(formatter_class=argparse.RawTextHelpFormatter, \
description="""

tagAlign_script_GerminalCenter10xATAC.py

Create tagAlign files for the given fragment and cell type annotation files

""")

#### required arguments ####

parser.add_argument("-f", "--fragment_file", help="""fragment file .tsv.gz""", required=True)
parser.add_argument("-c", "--cell_types_annot", help="""cell types annotation file .tsv.gz""", required=True)
args = parser.parse_args()

full_fragments_and_cell_type_labels = [(args.fragment_file, args.cell_types_annot)]

local_clusters_fld = os.path.join(os.getcwd(),"clusters")
os.makedirs(local_clusters_fld, exist_ok=True)
local_path_to_download = os.path.join(os.getcwd(),"fragment_files")

def remove_file(filename):
    print("remove_file method: {}".format(filename))
    if os.path.exists(filename):
        os.remove(filename)
        
import gzip
import pandas as pd

def read_tsv_gz_to_dataframe_skipping_comments_and_empty_lines(tsv_gz_file, comment_character='#'):
    # Open the compressed file using gzip
    print("tsv_gz_file is {}".format(tsv_gz_file))
    with gzip.open(tsv_gz_file, 'rt') as file:
        # Skip comment lines and empty lines, and load the remaining data into a DataFrame
        df = pd.read_csv(file, delimiter='\t', comment=comment_character, skip_blank_lines=True)

    return df

# # Specify the path to the TSV.gz file
# tsv_gz_file = '/path/to/file.tsv.gz'

# # Read the TSV.gz file and create a DataFrame
# dataframe = read_tsv_gz_to_dataframe(tsv_gz_file)

# # Display the DataFrame
# print(dataframe)

    
def split_fragment_line_string(string):
    # Remove newline characters
    string = string.replace("\n", "")

    # Splitting by tab character
    split_list = string.split("\t")

    # Splitting the word before the last one by underscore
    last_word = split_list[-2]
    split_word = last_word.split("_")

    # Inserting the split word before the last one in the list
    split_list.insert(-1, split_word[0])
    split_list.insert(-1, split_word[1])

    # Concatenating values at index 5 and index 4 with underscore
    concatenated_value = split_list[5] + "_" + split_list[4]
    split_list.append(concatenated_value)

    return split_list

def convert_fragment_line_to_tagAlign(r):
#     chr1	10007	10175	ENCSR023FME_GAAGGTTCAAAGTGTCAGTCAA	1
    rows_str = ""
    r_list = r.split("\t")
    # print("r_list is {}".format(r_list))
    row1 = []
    row2 = []

    row1.append(r_list[0])
    row1.append(r_list[1])
    row1.append(str(int(r_list[1]) + 1))
    row1.append(r_list[3])
    row1.append('1')
    row1.append('+')
    # print("convert_to_tagAlign: row 1 is: {}".format(row1))

    row2.append(r_list[0])
    row2.append(str(int(r_list[2]) - 1))
    row2.append(r_list[2])
    row2.append(r_list[3])
    row2.append('1')
    row2.append('-')
    # print("convert_to_tagAlign: row 2 is: {}".format(row2))
    
    rows_str = "\t".join(row1)+"\n"+"\t".join(row2)+"\n"
    # print("rows_str is {}".format(rows_str))
    return rows_str


for local_file_tuple in full_fragments_and_cell_type_labels:

    # Dictionary to store the output file handles with names
    output_handles = {}
    local_fragment_file = local_file_tuple[0]
    full_cell_types_annotation_file_path = local_file_tuple[1]
    print("!!!!!local_fragment_file is {}".format(local_fragment_file))
    file_atac_dataset_id = local_fragment_file.split("/")[10].split('.')[0]
    print("file_atac_dataset_id is {}".format(file_atac_dataset_id))
 
    # This full_cell_types_annotation_file_path was given as an input
    df_cell_types_for_atac_dataset = read_tsv_gz_to_dataframe_skipping_comments_and_empty_lines(full_cell_types_annotation_file_path)
    cell_type_id_names_for_atac_dataset = list(set(df_cell_types_for_atac_dataset['cell_type_id']))
    print("number of cell_type_id_names_for_atac_dataset is {}".format(len(cell_type_id_names_for_atac_dataset)))
    # List of output text files with corresponding names
    # [("output1.txt", "file_1"), ("output2.txt", "file_2"), ("output3.txt", "file_3")]
    output_tagAlign_files_with_names = [(os.path.join(local_clusters_fld,file_atac_dataset_id,"tagAlign_{}_{}.tsv".format(file_atac_dataset_id,cell_type_name_id)),
                                        cell_type_name_id) for cell_type_name_id in cell_type_id_names_for_atac_dataset]


    # this will make sure that we will not run the same tagAlign twice.
    tagAlign_exists = [os.path.exists(output_tagAlign_file[0]) for output_tagAlign_file in output_tagAlign_files_with_names]
    print("tagAlign_exists is {}".format(tagAlign_exists))
#     if sum(tagAlign_exists) >0:
#         print("output_tagAlign_files_with_names {} is at work or was already downloaded. continue".format(output_tagAlign_files_with_names))
#         continue # either started by annother process or already was processed
#     else:
    print("!!!output_tagAlign_files_with_names {}. open files".format(output_tagAlign_files_with_names))
    for tag_file_path, tag_file_cell_type_name in output_tagAlign_files_with_names:
#         print("tag_file_path is {}".format(tag_file_path))
#         print("os.path.dirname(tag_file_path) is {}".format(os.path.dirname(tag_file_path)))
        os.makedirs(os.path.dirname(tag_file_path), exist_ok=True)
        output_handles[tag_file_cell_type_name] = open(tag_file_path, "w")

    # print("!!!output_tagAlign_files_with_names {}".format(output_tagAlign_files_with_names))
    print("open local_fragment_file {}".format(local_fragment_file))
    with gzip.open(local_fragment_file, "rt") as infile:
        missing_bc = 0
        # Open the output files and store their handles in the list
        num_of_lines_written=0
        for line_number, line in enumerate(infile, start=1):
            # debug
#             if line_number > 10:
#                 continue 

            # here cases where bc_datasetId or datasetId_bc are being mixed between the fragments and the
            # cell type are being address. you can select the righ out_list for your experiment
            out_list = split_fragment_line_string(line)
            bc = out_list[-1]
#             print(out_list)


#             Austin output: chrom, start, end, bc, rem = line.rstrip('\n').split('\t', 5)
            out_line_to_print = "{}\t{}\t{}\t{}\t{}\n".format(out_list[0],out_list[1],out_list[2],bc,out_list[-2])
# #             chr1	10007	10175	ENCSR023FME#ENCSR023FME_GAAGGTTCAAAGTGTCAGTCAA	1
            num_of_lines_written +=1
            returnTagAlign = convert_fragment_line_to_tagAlign(out_line_to_print)

            # write to the relevant cell type file
            # print("df_cell_types_for_atac_dataset[cell_id][0:5] is {}".format(df_cell_types_for_atac_dataset['cell_id'][0:5]))
            bc_exists_in_cell_type_atac_dataset = df_cell_types_for_atac_dataset[df_cell_types_for_atac_dataset['cell_id']==bc]
            print("len(bc_exists_in_cell_type_atac_dataset) is {} for bc {}".format(len(bc_exists_in_cell_type_atac_dataset),bc))
            if len(bc_exists_in_cell_type_atac_dataset) ==1:
                tag_file_cell_type_id = df_cell_types_for_atac_dataset.loc[df_cell_types_for_atac_dataset['cell_id'] == bc, 'cell_type_id'].iloc[0]
                # print("tag_file_cell_type_id is {}".format(tag_file_cell_type_id))
                output_handles[tag_file_cell_type_id].write(returnTagAlign)
            else:
                missing_bc+=1

        for tag_file_path, tag_file_cell_type_name in output_tagAlign_files_with_names:
            print("tag_file_path is {}".format(tag_file_path))
            output_handles[tag_file_cell_type_name].close()    
        print("finished clustering local_fragment_file {} by cell type. for types {}".format(local_fragment_file, cell_type_id_names_for_atac_dataset))
        print("total missing bc are {}".format(missing_bc))
# Out:
# Overwriting /data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/tagAlign_script_GerminalCenter10xATAC.py

# %%
# %%bash
# python /data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/tagAlign_script_GerminalCenter10xATAC.py -h
# Out:
# usage: tagAlign_script_GerminalCenter10xATAC.py [-h] -f FRAGMENT_FILE -c
#                                                 CELL_TYPES_ANNOT
#
# tagAlign_script_GerminalCenter10xATAC.py
#
# Create tagAlign files for the given fragment and cell type annotation files
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -f FRAGMENT_FILE, --fragment_file FRAGMENT_FILE
#                         fragment file .tsv.gz
#   -c CELL_TYPES_ANNOT, --cell_types_annot CELL_TYPES_ANNOT
#                         cell types annotation file .tsv.gz

# %%
# %%bash
# mkdir -p /data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/logs
# sbatch -p all \
#     --cpus-per-task 16 \
#     --exclude=dl-01 \
#     --array=0-7 \
#     --mem 64G \
#     -o /data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/logs/tagAlign_GerminalCenter10x.%a.out \
#     <<'EOF'
# #!/bin/bash
# fragments=( \
# syn52118183_syn52120076_GerminalCenter10xATAC_GSM5051500.atac.filter.fragments.hg38.tsv.gz/GerminalCenter10xATAC_GSM5051500.atac.filter.fragments.hg38.tsv.gz \
# syn52118183_syn52120078_GerminalCenter10xATAC_GSM5051499.atac.filter.fragments.hg38.tsv.gz/GerminalCenter10xATAC_GSM5051499.atac.filter.fragments.hg38.tsv.gz \
# syn52118183_syn52120079_GerminalCenter10xATAC_GSM5051501.atac.filter.fragments.hg38.tsv.gz/GerminalCenter10xATAC_GSM5051501.atac.filter.fragments.hg38.tsv.gz \
# syn52118183_syn52120086_GerminalCenter10xATAC_GSM5051506.atac.filter.fragments.hg38.tsv.gz/GerminalCenter10xATAC_GSM5051506.atac.filter.fragments.hg38.tsv.gz \
# syn52118183_syn52120089_GerminalCenter10xATAC_GSM5051508.atac.filter.fragments.hg38.tsv.gz/GerminalCenter10xATAC_GSM5051508.atac.filter.fragments.hg38.tsv.gz \
# syn52118183_syn52120090_GerminalCenter10xATAC_GSM5051507.atac.filter.fragments.hg38.tsv.gz/GerminalCenter10xATAC_GSM5051507.atac.filter.fragments.hg38.tsv.gz \
# syn52118183_syn52120090_GerminalCenter10xATAC_GSM5051507.atac.filter.fragments.hg38.tsv.gz/GerminalCenter10xATAC_GSM5051507.atac.filter.fragments.hg38.tsv.gz \
#   )
# fragment=${fragments[${SLURM_ARRAY_TASK_ID}]}
# python /data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/tagAlign_script_GerminalCenter10xATAC.py \
# -f /data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/fragment_files/${fragment} \
# -c /data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/GerminalCenter10xATAC_celltypes.tsv.gz \
# EOF
# Out:
# Submitted batch job 30172602

# %%
local_fragment_file.split("/")[10].split('.')[0]
# Out:
# 'GerminalCenter10xATAC_GSM5051500'

# %%
tsv_gz_file
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-87f0d7662e3a> in <module>()
# ----> 1 tsv_gz_file
#
# NameError: name 'tsv_gz_file' is not defined
