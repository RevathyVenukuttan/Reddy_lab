# %% [markdown]
# install synapse client
# - conda install -c bioconda synapseclient
# if import fires error, install
# - pip install synapseclient

# %%
import os
# https://python-docs.synapse.org/build/html/Credentials.html#use-synapseconfig
os.environ['SYNAPSE_AUTH_TOKEN']='eyJ0eXAiOiJKV1QiLCJraWQiOiJXN05OOldMSlQ6SjVSSzpMN1RMOlQ3TDc6M1ZYNjpKRU9VOjY0NFI6VTNJWDo1S1oyOjdaQ0s6RlBUSCIsImFsZyI6IlJTMjU2In0..DXooWvrEDivGIv3tHTdXP6EGgsCLHMcoV1nqdTRv1_2_nThWYAvheuBABhkN1OZic8U0713yGA-QIp4wCAHNSa3zOibDvhSJ58pxgtGVuuUc4nzD5hF5r4vVwH__TcfCAAjVQeCWGizC8b_4CkhoCBuT-yThtBOhok8fI_vn1ut3E6ZgTutSGW4jgSww8r404Wwf3I_2zfQqrg8Sjab9H6wZQg6Kn7L1vZUu2MNZyw4QDerOledKCz1HXFFeKwwbuVFcL-4evALSN0i-IQCevWtey8S-ag9eKytwYa0hWnHd7CzS3SYos3B5HAsXrZ7-c057mpT3p0XGtRygpXmiBQ'

# %%
import synapseclient
import synapseutils
import os
import csv

# token = os.environ.get('SYNAPSE_AUTH_TOKEN')

import synapseclient
syn = synapseclient.login("revathy", "Spirometer420$")
# Out:
# Welcome, revathy!
# UPGRADE AVAILABLE
#
# A more recent version of the Synapse Client (2.7.2) is available. Your version (1.9.4) can be upgraded by typing:
#     pip install --upgrade synapseclient
#
# Python Synapse Client version 2.7.2 release notes
#
# https://python-docs.synapse.org/build/html/news.html

# %% [markdown]
# ### PLEASE CHANGE THE DATASETS IDS, ONCE YOU HAVE THEM. IT IS IN THE END OF THE URL IN THE C COLUMN

# %%
# Specify the list of dataset IDs

dataset_ids = list(set(["syn52118183"]))
print(len(dataset_ids))

print(dataset_ids)

# Specity the string to find in the file name and what is not the relevant file:
str_in = "filter.fragments.hg38.tsv.gz"
str_not_in = "filter.fragments.hg38.tsv.gz.tbi"

# print(dataset_ids)
# print(len(dataset_ids))
# Out:
# 1
# ['syn52118183']

# %%
# Initialize the list to store file data from all datasets
all_file_data = []

# Process each dataset
for dataset_id in dataset_ids:
    print("***dataset_id is",dataset_id)
    # Get the list of files in the dataset
    files = syn.getChildren(dataset_id)
    print("***files for dataset_id is {} are {}".format(dataset_id,files))
    # Extract the file names and other information for the current dataset
    file_data = []
    for file in files:
        print('file is ',file)
        file_name = file['name']
        # str_in = "filter.fragments.hg38.tsv.gz"
        # str_not_in = "filter.fragments.hg38.tsv.gz.tbi"
        print("(str_in in file_name) is {}".format((str_in in file_name)))
        print("(str_not_in in file_name) is {}".format((str_not_in in file_name)))
        if (str_in in file_name) and (str_not_in not in file_name):
            file_id = file['id']
            file_version = file['versionNumber']
            file_data.append([dataset_id,file_name, file_id, file_version])
        else:
            continue
    
    
    print("***file_data for dataset_id is {} are {}".format(dataset_id,file_data))
    # Append the file data from the current dataset to the consolidated list
    print("add dataset data ",dataset_id)
    all_file_data.extend(file_data)
# Out:
# ***dataset_id is syn52118183
# ***files for dataset_id is syn52118183 are <generator object Synapse.getChildren at 0x2b49abf23e08>
# file is  {'name': 'GM12878_10XMultiome.Aligned.sortedByCoord.out.bam', 'id': 'syn52128717', 'createdBy': '3330650', 'versionLabel': '1', 'isLatestVersion': True, 'modifiedOn': '2023-07-21T14
z', 'modifiedBy': '3330650', 'versionNumber': 1}
# (str_in in file_name) is False
# (str_not_in in file_name) is False
# file is  {'name': 'HealthyBrain_scATAC_GSM4441828_SRR11442506.atac.filter.fragments.hg38.tsv.gz', 'id': 'syn52128868', 'createdBy': '3330650', 'versionLabel': '1', 'isLatestVersion': True, 'modifiedOn': '2023-07-21T14:46:12.034Z', 'type': 'org.sagebionetworks.repo.model.FileEntity', 'benefactorId': 52117441, 'createdOn': '2023-07-21T14:46:11.762Z', 'modifiedBy': '3330650', 'versionNumber': 1}
# (str_in in file_name) is True
# (str_not_in in file_name) is False
# file is  {'name': 'HealthyBrain_scATAC_GSM4441828_SRR11442506.atac.filter.fragments.hg38.tsv.gz.tbi', 'id': 'syn52128755', 'createdBy': '3330650', 'versionLabel': '1', 'isLatestVersion': True, 'modifiedOn': '2023-07-21T14:44:03.659Z', 'type': 'org.sagebionetworks.repo.model.FileEntity', 'benefactorId': 52117441, 'createdOn': '2023-07-21T14:44:03.379Z', 'modifiedBy': '3330650', 'versionNumber': 1}
# (str_in in file_name) is True
# (str_not_in in file_name) is True
# file is  {'name': 'HealthyBrain_scATAC_GSM4441828_SRR11442506.atac.qc.hg38.metadata.tsv', 'id': 'syn52129149', 'createdBy': '3330650', 'versionLabel': '1', 'isLatestVersion': True, 'modifiedOn': '2023-07-21T14:50:49.802Z', 'type': 'org.sagebionetworks.repo.model.FileEntity', 'benefactorId': 52117441, 'createdOn': '2023-07-21T14:50:49.524Z', 'modifiedBy': '3330650', 'versionNumber': 1}
# (str_in in file_name) is False
# (str_not_in in file_name) is False
# file is  {'name': 'HealthyBrain_scATAC_GSM4441828_SRR11442506.html', 'id': 'syn52128733', 'createdBy': '3330650', 'versionLabel': '1', 'isLatestVersion': True, 'modifiedOn': '2023-07-21T14:44:01.883Z', 'type': 'org.sagebionetworks.repo.model.FileEntity', 'benefactorId': 52117441, 'createdOn': '2023-07-21T14:44:01.609Z', 'modifiedBy': '3330650', 'versionNumber': 1}
# (str_in in file_name) is False
# (str_not_in in file_name) is False
# file is  {'name': 'HealthyBrain_scATAC_GSM4441829_SRR11442507.atac.filter.fragments.hg38.tsv.gz', 'id': 'syn52128861', 'createdBy': '3330650', 'versionLabel': '1', 'isLatestVersion': True, 'modifiedOn': '2023-07-21T14:45:42.993Z', 'type': 'org.sagebionetworks.repo.model.FileEntity', 'benefactorId': 52117441, 'createdOn': '2023-07-21T14:45:42.708Z', 'modifiedBy': '3330650', 'versionNumber': 1}
# (str_in in file_name) is True
# (str_not_in in file_name) is False
# file is  {'name': 'HealthyBrain_scATAC_GSM4441829_SRR11442507.atac.filter.fragments.hg38.tsv.gz.tbi', 'id': 'syn52128883', 'createdBy': '3330650', 'versionLabel': '1', 'isLatestVersion': True, 'modifiedOn': '2023-07-21T14:46:43.846Z', 'type': 'org.sagebionetworks.repo.model.FileEntity', 'benefactorId': 52117441, 'createdOn': '2023-07-21T14:46:43.588Z', 'modifiedBy': '3330650', 'versionNumber': 1}
# (str_in in file_name) is True
# (str_not_in in file_name) is True
# file is  {'name': 'HealthyBrain_scATAC_GSM4441829_SRR11442507.atac.qc.hg38.metadata.tsv', 'id': 'syn52129150', 'createdBy': '3330650', 'versionLabel': '1', 'isLatestVersion': True, 'modifiedOn': '2023-07-21T14:50:51.180Z', 'type': 'org.sagebionetworks.repo.model.FileEntity', 'benefactorId': 52117441, 'createdOn': '2023-07-21T14:50:50.908Z', 'modifiedBy': '3330650', 'versionNumber': 1}
# (str_in in file_name) is False
# (str_not_in in file_name) is False
# file is  {'name': 'HealthyBrain_scATAC_GSM4441829_SRR11442507.html', 'id': 'syn52128776', 'createdBy': '3330650', 'versionLabel': '1', 'isLatestVersion': True, 'modifiedOn': '2023-07-21T14:44:05.545Z', 'type': 'org.sagebionetworks.repo.model.FileEntity', 'benefactorId': 52117441, 'createdOn': '2023-07-21T14:44:05.290Z', 'modifiedBy': '3330650', 'versionNumber': 1}
# (str_in in file_name) is False
# (str_not_in in file_name) is False
# file is  {'name': 'K562_ERR9847049_Multiome.Aligned.sortedByCoord.out.bam', 'id': 'syn52129716', 'createdBy': '3330650', 'versionLabel': '1', 'isLatestVersion': True, 'modifiedOn': '2023-07-21T15:11:12.365Z', 'type': 'org.sagebionetworks.repo.model.FileEntity', 'benefactorId': 52117441, 'createdOn': '2023-07-21T15:11:11.889Z', 'modifiedBy': '3330650', 'versionNumber': 1}
# (str_in in file_name) is False
# (str_not_in in file_name) is False
# file is  {'name': 'K562_ERR9847049_Multiome.atac.filter.fragments.hg38.tsv.gz', 'id': 'syn52128968', 'createdBy': '3330650', 'versionLabel': '1', 'isLatestVersion': True, 'modifiedOn': '2023-07-21T14:48:27.541Z', 'type': 'org.sagebionetworks.repo.model.FileEntity', 'benefactorId': 52117441, 'createdOn': '2023-07-21T14:48:27.295Z', 'modifiedBy': '3330650', 'versionNumber': 1}
# (str_in in file_name) is True
# (str_not_in in file_name) is False
# file is  {'name': 'K562_ERR9847049_Multiome.atac.filter.fragments.hg38.tsv.gz.tbi', 'id': 'syn52128885', 'createdBy': '3330650', 'versionLabel': '1', 'isLatestVersion': True, 'modifiedOn': '2023-07-21T14:46:46.227Z', 'type': 'org.sagebionetworks.repo.model.FileEntity', 'benefactorId': 52117441, 'createdOn': '2023-07-21T14:46:45.973Z', 'modifiedBy': '3330650', 'versionNumber': 1}
# (str_in in file_name) is True
# (str_not_in in file_name) is True
# file is  {'name': 'K562_ERR9847049_Multiome.atac.qc.hg38.metadata.tsv', 'id': 'syn52129151', 'createdBy': '3330650', 'versionLabel': '1', 'isLatestVersion': True, 'modifiedOn': '2023-07-21T14:50:52.164Z', 'type': 'org.sagebionetworks.repo.model.FileEntity', 'benefactorId': 52117441, 'createdOn': '2023-07-21T14:50:51.912Z', 'modifiedBy': '3330650', 'versionNumber': 1}
# (str_in in file_name) is False
# (str_not_in in file_name) is False
# file is  {'name': 'K562_ERR9847049_Multiome.hg38.rna.h5', 'id': 'syn52129166', 'createdBy': '3330650', 'versionLabel': '1', 'isLatestVersion': True, 'modifiedOn': '2023-07-21T14:51:17.302Z', 'type': 'org.sagebionetworks.repo.model.FileEntity', 'benefactorId': 52117441, 'createdOn': '2023-07-21T14:51:17.022Z', 'modifiedBy': '3330650', 'versionNumber': 1}
# (str_in in file_name) is False
# (str_not_in in file_name) is False
# file is  {'name': 'K562_ERR9847049_Multiome.html', 'id': 'syn52129158', 'createdBy': '3330650', 'versionLabel': '1', 'isLatestVersion': True, 'modifiedOn': '2023-07-21T14:50:59.849Z', 'type': 'org.sagebionetworks.repo.model.FileEntity', 'benefactorId': 52117441, 'createdOn': '2023-07-21T14:50:59.598Z', 'modifiedBy': '3330650', 'versionNumber': 1}
# (str_in in file_name) is False
# (str_not_in in file_name) is False
# file is  {'name': 'K562_ERR9847049_Multiome.joint.barcode.metadata.hg38.csv', 'id': 'syn52129157', 'createdBy': '3330650', 'versionLabel': '1', 'isLatestVersion': True, 'modifiedOn': '2023-07-21T14:50:57.600Z', 'type': 'org.sagebionetworks.repo.model.FileEntity', 'benefactorId': 52117441, 'createdOn': '2023-07-21T14:50:57.329Z', 'modifiedBy': '3330650', 'versionNumber': 1}
# (str_in in file_name) is False
# (str_not_in in file_name) is False
# file is  {'name': 'K562_ERR9847049_Multiome.qc.rna.hg38.barcode.metadata.tsv', 'id': 'syn52129152', 'createdBy': '3330650', 'versionLabel': '1', 'isLatestVersion': True, 'modifiedOn': '2023-07-21T14:50:53.115Z', 'type': 'org.sagebionetworks.repo.model.FileEntity', 'benefactorId': 52117441, 'createdOn': '2023-07-21T14:50:52.854Z', 'modifiedBy': '3330650', 'versionNumber': 1}
# (str_in in file_name) is False
# (str_not_in in file_name) is False
# file is  {'name': 'K562_ERR9847049_Multiome.raw.tar.gz', 'id': 'syn52128902', 'createdBy': '3330650', 'versionLabel': '1', 'isLatestVersion': True, 'modifiedOn': '2023-07-21T14:47:10.724Z', 'type': 'org.sagebionetworks.repo.model.FileEntity', 'benefactorId': 52117441, 'createdOn': '2023-07-21T14:47:10.414Z', 'modifiedBy': '3330650', 'versionNumber': 1}
# (str_in in file_name) is False
# (str_not_in in file_name) is False
# ***file_data for dataset_id is syn52118183 are [['syn52118183', 'GM12878_10XMultiome.atac.filter.fragments.hg38.tsv.gz', 'syn52128237', 1], ['syn52118183', 'GSE175621_clint_miller_GSM5342787_SRR14664735.atac.filter.fragments.hg38.tsv.gz', 'syn52127497', 1], ['syn52118183', 'GSE175621_clint_miller_GSM5342787_SRR14664736.atac.filter.fragments.hg38.tsv.gz', 'syn52127499', 1], ['syn52118183', 'GSE175621_clint_miller_GSM5342788_SRR14664737.atac.filter.fragments.hg38.tsv.gz', 'syn52127498', 1], ['syn52118183', 'GSE175621_clint_miller_GSM5342788_SRR14664738.atac.filter.fragments.hg38.tsv.gz', 'syn52127502', 1], ['syn52118183', 'GSE175621_clint_miller_GSM5342789_SRR14664739.atac.filter.fragments.hg38.tsv.gz', 'syn52127515', 1], ['syn52118183', 'GSE175621_clint_miller_GSM5342789_SRR14664740.atac.filter.fragments.hg38.tsv.gz', 'syn52127509', 1], ['syn52118183', 'GSE175621_clint_miller_GSM5342790_SRR14664741.atac.filter.fragments.hg38.tsv.gz', 'syn52127510', 1], ['syn52118183', 'GSE175621_clint_miller_GSM5342790_SRR14664742.atac.filter.fragments.hg38.tsv.gz', 'syn52127518', 1], ['syn52118183', 'GSE175621_clint_miller_GSM5342791_SRR14664655.atac.filter.fragments.hg38.tsv.gz', 'syn52127531', 1], ['syn52118183', 'GSE175621_clint_miller_GSM5342791_SRR14664656.atac.filter.fragments.hg38.tsv.gz', 'syn52127535', 1], ['syn52118183', 'GSE175621_clint_miller_GSM5342792_SRR14664657.atac.filter.fragments.hg38.tsv.gz', 'syn52127534', 1], ['syn52118183', 'GSE175621_clint_miller_GSM5342792_SRR14664658.atac.filter.fragments.hg38.tsv.gz', 'syn52127532', 1], ['syn52118183', 'GSE175621_clint_miller_GSM5342793_SRR14664659.atac.filter.fragments.hg38.tsv.gz', 'syn52127544', 1], ['syn52118183', 'GSE175621_clint_miller_GSM5342793_SRR14664660.atac.filter.fragments.hg38.tsv.gz', 'syn52127545', 1], ['syn52118183', 'GSE175621_clint_miller_GSM5342794_SRR14664661.atac.filter.fragments.hg38.tsv.gz', 'syn52127546', 1], ['syn52118183', 'GSE175621_clint_miller_GSM5342794_SRR14664662.atac.filter.fragments.hg38.tsv.gz', 'syn52127553', 1], ['syn52118183', 'GSE175621_clint_miller_GSM5342795_SRR14664663.atac.filter.fragments.hg38.tsv.gz', 'syn52127563', 1], ['syn52118183', 'GSE175621_clint_miller_GSM5342795_SRR14664664.atac.filter.fragments.hg38.tsv.gz', 'syn52127554', 1], ['syn52118183', 'GSE175621_clint_miller_GSM5342796_SRR14664665.atac.filter.fragments.hg38.tsv.gz', 'syn52127567', 1], ['syn52118183', 'GSE175621_clint_miller_GSM5342796_SRR14664666.atac.filter.fragments.hg38.tsv.gz', 'syn52127581', 1], ['syn52118183', 'GSE175621_clint_miller_GSM5342797_SRR14664667.atac.filter.fragments.hg38.tsv.gz', 'syn52127579', 1], ['syn52118183', 'GSE175621_clint_miller_GSM5342797_SRR14664668.atac.filter.fragments.hg38.tsv.gz', 'syn52127580', 1], ['syn52118183', 'GSE175621_clint_miller_GSM5342798_SRR14664669.atac.filter.fragments.hg38.tsv.gz', 'syn52127587', 1], ['syn52118183', 'GSE175621_clint_miller_GSM5342798_SRR14664670.atac.filter.fragments.hg38.tsv.gz', 'syn52127586', 1], ['syn52118183', 'GSE175621_clint_miller_GSM5342799_SRR14664671.atac.filter.fragments.hg38.tsv.gz', 'syn52127597', 1], ['syn52118183', 'GSE175621_clint_miller_GSM5342799_SRR14664672.atac.filter.fragments.hg38.tsv.gz', 'syn52127596', 1], ['syn52118183', 'GSE175621_clint_miller_GSM5342800_SRR14664673.atac.filter.fragments.hg38.tsv.gz', 'syn52127598', 1], ['syn52118183', 'GSE175621_clint_miller_GSM5342800_SRR14664674.atac.filter.fragments.hg38.tsv.gz', 'syn52127601', 1], ['syn52118183', 'GSE175621_clint_miller_GSM5342801_SRR14664675.atac.filter.fragments.hg38.tsv.gz', 'syn52127676', 1], ['syn52118183', 'GSE175621_clint_miller_GSM5342801_SRR14664676.atac.filter.fragments.hg38.tsv.gz', 'syn52127679', 1], ['syn52118183', 'GSE175621_clint_miller_GSM5342802_SRR14664677.atac.filter.fragments.hg38.tsv.gz', 'syn52127677', 1], ['syn52118183', 'GSE175621_clint_miller_GSM5342802_SRR14664678.atac.filter.fragments.hg38.tsv.gz', 'syn52127678', 1], ['syn52118183', 'GSE175621_clint_miller_GSM5342803_SRR14664679.atac.filter.fragments ...
# add dataset data  syn52118183

# %%
file_prefix="_".join(dataset_ids)
file_prefix
# Out:
# 'syn52118183'

# %%
# Define the path and name of the TSV file
tsv_file_path = "{}_synpase_files.tsv".format(file_prefix)

if os.path.exists(tsv_file_path):
    print("removing {}".format(tsv_file_path))
    os.remove(tsv_file_path) # creates a new one everytime
else:
    print("nothing to remove. creating a new file. {}".format(tsv_file_path))

# Write the consolidated file data to the TSV file
with open(tsv_file_path, 'w', newline='') as tsv_file:
    writer = csv.writer(tsv_file, delimiter='\t')
    writer.writerow(['Dataset Id','File Name', 'File ID', 'File Version'])
    writer.writerows(all_file_data)

print("TSV file created successfully. {}".format(tsv_file_path))
# Out:
# nothing to remove. creating a new file. syn52118183_synpase_files.tsv
# TSV file created successfully. syn52118183_synpase_files.tsv

# %%
tsv_file_path
# Out:
# 'syn52118183_synpase_files.tsv'

# %%
# !head $tsv_file_path | wc -l
# Out:
# 10
