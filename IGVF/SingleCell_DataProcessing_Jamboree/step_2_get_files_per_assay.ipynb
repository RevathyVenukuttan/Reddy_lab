# %% [markdown]
# install synapse client
# - conda install -c bioconda synapseclient
# if import fires error, install
# - pip install synapseclient

# %%
# import os
# # https://python-docs.synapse.org/build/html/Credentials.html#use-synapseconfig
# os.environ['SYNAPSE_AUTH_TOKEN']='eyJ0eXAiOiJKV1QiLCJraWQiOiJXN05OOldMSlQ6SjVSSzpMN1RMOlQ3TDc6M1ZYNjpKRU9VOjY0NFI6VTNJWDo1S1oyOjdaQ0s6RlBUSCIsImFsZyI6IlJTMjU2In0..DXooWvrEDivGIv3tHTdXP6EGgsCLHMcoV1nqdTRv1_2_nThWYAvheuBABhkN1OZic8U0713yGA-QIp4wCAHNSa3zOibDvhSJ58pxgtGVuuUc4nzD5hF5r4vVwH__TcfCAAjVQeCWGizC8b_4CkhoCBuT-yThtBOhok8fI_vn1ut3E6ZgTutSGW4jgSww8r404Wwf3I_2zfQqrg8Sjab9H6wZQg6Kn7L1vZUu2MNZyw4QDerOledKCz1HXFFeKwwbuVFcL-4evALSN0i-IQCevWtey8S-ag9eKytwYa0hWnHd7CzS3SYos3B5HAsXrZ7-c057mpT3p0XGtRygpXmiBQ'

# %%
import synapseclient
import synapseutils
import os
import csv
import pandas as pd
# token = os.environ.get('SYNAPSE_AUTH_TOKEN')

import synapseclient
syn = synapseclient.login("revathy", "Spirometer420$")
# Out:
# Welcome, revathy!
# UPGRADE AVAILABLE
#
# A more recent version of the Synapse Client (2.7.2) is available. Your version (1.9.4) can be upgraded by typing:
#     pip install --upgrade synapseclient
#
# Python Synapse Client version 2.7.2 release notes
#
# https://python-docs.synapse.org/build/html/news.html

# %%
#TOOD
# Define the path and name of the TSV file. Take from step1
tsv_file_path = "syn52118183_synpase_files_RV.tsv"
local_path_to_download = os.path.join(os.getcwd(),"fragment_files")
os.makedirs(local_path_to_download,exist_ok=True)

# %%
tsv_dataframe = pd.read_csv(tsv_file_path, sep="\t")

print(tsv_dataframe.head(2))
# Out:
#     Dataset Id                                          File Name  \
# 0  syn52118183  GM12878_10XMultiome.atac.filter.fragments.hg38...
# 1  syn52118183  GerminalCenter10xATAC_GSM5051499.atac.filter.f...
#
#        File ID  File Version
# 0  syn52128237             1
# 1  syn52120078             1

# %%
local_fragment_file_path=list()
for index, row in tsv_dataframe.iterrows():
    print("index is {}".format(index))
    print("row is {}".format(row))
    # if index != 0:
    #     continue # debug only
    file_id = row["File ID"]
    file_name = row["File Name"]
    dataset_id = row["Dataset Id"]
    local_fragment_file_path = os.path.join(local_path_to_download,"{}_{}_{}".format(dataset_id,file_id,file_name))
    if os.path.exists(local_fragment_file_path) == False:
        local_fragment_file_synHandle = syn.get(entity=file_id,downloadLocation=local_fragment_file_path) 
        print('local_fragment_file_synHandle is {}'.format(local_fragment_file_synHandle))
        full_local_fragment_file_synHandle = local_fragment_file_synHandle.path
        print('full_local_fragment_file_synHandle is {}'.format(full_local_fragment_file_synHandle))
    else:
        print("local_fragment_file_path exists. {} ".format(local_fragment_file_path))
# print(local_fragment_file_path[0:4])
# print(len(local_fragment_file_path))
# Out:
# index is 0
# row is Dataset Id                                            syn52118183
# File Name       GM12878_10XMultiome.atac.filter.fragments.hg38...
# File ID                                               syn52128237
# File Version                                                    1
# Name: 0, dtype: object
# local_fragment_file_synHandle is File: GM12878_10XMultiome.atac.filter.fragments.hg38.tsv.gz (syn52128237)
#   md5=a6f535cb550483a99d582769e72205f9
#   fileSize=834338757
#   contentType=text/tab-separated-values
#   externalURL=None
#   cacheDir=/gpfs/fs1/data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/fragment_files/syn52118183_syn52128237_GM12878_10XMultiome.atac.filter.fragments.hg38.tsv.gz
#   files=['GM12878_10XMultiome.atac.filter.fragments.hg38.tsv.gz']
#   path=/gpfs/fs1/data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/fragment_files/syn52118183_syn52128237_GM12878_10XMultiome.atac.filter.fragments.hg38.tsv.gz/GM12878_10XMultiome.atac.filter.fragments.hg38.tsv.gz
#   synapseStore=True
# properties:
#   concreteType=org.sagebionetworks.repo.model.FileEntity
#   createdBy=3330650
#   createdOn=2023-07-21T14:30:46.709Z
#   dataFileHandleId=127236791
#   etag=4adca868-ec1b-4771-a55f-13247a29b471
#   id=syn52128237
#   isLatestVersion=True
#   modifiedBy=3330650
#   modifiedOn=2023-07-21T14:30:46.986Z
#   name=GM12878_10XMultiome.atac.filter.fragments.hg38.tsv.gz
#   parentId=syn52118183
#   versionLabel=1
#   versionNumber=1
# annotations:
#   md5_google=['pvU1y1UEg6mdWCdp5yIF+Q==']
#   subpool=['GM12878_10XMultiome']
#
# full_local_fragment_file_synHandle is /gpfs/fs1/data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/fragment_files/syn52118183_syn52128237_GM12878_10XMultiome.atac.filter.fragments.hg38.tsv.gz/GM12878_10XMultiome.atac.filter.fragments.hg38.tsv.gz
# index is 1
# row is Dataset Id                                            syn52118183
# File Name       GerminalCenter10xATAC_GSM5051499.atac.filter.f...
# File ID                                               syn52120078
# File Version                                                    1
# Name: 1, dtype: object
# local_fragment_file_synHandle is File: GerminalCenter10xATAC_GSM5051499.atac.filter.fragments.hg38.tsv.gz (syn52120078)
#   md5=db986b50c37e89ec9a16852de635fb6d
#   fileSize=492213746
#   contentType=text/tab-separated-values
#   externalURL=None
#   cacheDir=/gpfs/fs1/data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/fragment_files/syn52118183_syn52120078_GerminalCenter10xATAC_GSM5051499.atac.filter.fragments.hg38.tsv.gz
#   files=['GerminalCenter10xATAC_GSM5051499.atac.filter.fragments.hg38.tsv.gz']
#   path=/gpfs/fs1/data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/fragment_files/syn52118183_syn52120078_GerminalCenter10xATAC_GSM5051499.atac.filter.fragments.hg38.tsv.gz/GerminalCenter10xATAC_GSM5051499.atac.filter.fragments.hg38.tsv.gz
#   synapseStore=True
# properties:
#   concreteType=org.sagebionetworks.repo.model.FileEntity
#   createdBy=3330650
#   createdOn=2023-07-20T13:38:55.468Z
#   dataFileHandleId=127201708
#   etag=b76a95dc-8cfc-4999-b2f9-c4ff5b4bf13b
#   id=syn52120078
#   isLatestVersion=True
#   modifiedBy=3330650
#   modifiedOn=2023-07-20T13:38:55.730Z
#   name=GerminalCenter10xATAC_GSM5051499.atac.filter.fragments.hg38.tsv.gz
#   parentId=syn52118183
#   versionLabel=1
#   versionNumber=1
# annotations:
#   md5_google=['25hrUMN+ieyaFoUt5jX7bQ==']
#   subpool=['GerminalCenter10xATAC_GSM5051499']
#
# full_local_fragment_file_synHandle is /gpfs/fs1/data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/fragment_files/syn52118183_syn52120078_GerminalCenter10xATAC_GSM5051499.atac.filter.fragments.hg38.tsv.gz/GerminalCenter10xATAC_GSM5051499.atac.filter.fragments.hg38.tsv.gz
# index is 2
# row is Dataset Id                                            syn52118183
# File Name       GerminalCenter10xATAC_GSM5051500.atac.filter.f...
# File ID                                               syn52120076
# File Version                                                    1
# Name: 2, dtype: object
# local_fragment_file_synHandle is File: GerminalCenter10xATAC_GSM5051500.atac.filter.fragments.hg38.tsv.gz (syn52120076)
#   md5=d1f3993ba575cf5edc09293e31044f43
#   fileSize=465479907
#   contentType=text/tab-separated-values
#   externalURL=None
#   cacheDir=/gpfs/fs1/data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/fragment_files/syn52118183_syn52120076_GerminalCenter10xATAC_GSM5051500.atac.filter.fragments.hg38.tsv.gz
#   files=['GerminalCenter10xATAC_GSM5051500.atac.filter.fragments.hg38.tsv.gz']
#   path=/gpfs/fs1/data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/fragment_files/syn52118183_syn52120076_GerminalCenter10xATAC_GSM5051500.atac.filter.fragments.hg38.tsv.gz/GerminalCenter10xATAC_GSM5051500.atac.filter.fragments.hg38.tsv.gz
#   synapseStore=True
# properties:
#   concreteType=org.sagebionetworks.repo.model.FileEntity
#   createdBy=3330650
#   createdOn=2023-07-20T13:38:45.536Z
#   dataFileHandleId=127201705
#   etag=ea59008e-5e70-4091-aa23-530dfc2de353
#   id=syn52120076
#   isLatestVersion=True
#   modifiedBy=3330650
#   modifiedOn=2023-07-20T13:38:45.767Z
#   name=GerminalCenter10xATAC_GSM5051500.atac.filter.fragments.hg38.tsv.gz
#   parentId=syn52118183
#   versionLabel=1
#   versionNumber=1
# annotations:
#   md5_google=['0fOZO6V1z17cCSk+MQRPQw==']
#   subpool=['GerminalCenter10xATAC_GSM5051500']
#
# full_local_fragment_file_synHandle is /gpfs/fs1/data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/fragment_files/syn52118183_syn52120076_GerminalCenter10xATAC_GSM5051500.atac.filter.fragments.hg38.tsv.gz/GerminalCenter10xATAC_GSM5051500.atac.filter.fragments.hg38.tsv.gz
# index is 3
# row is Dataset Id                                            syn52118183
# File Name       GerminalCenter10xATAC_GSM5051501.atac.filter.f...
# File ID                                               syn52120079
# File Version                                                    1
# Name: 3, dtype: object
# local_fragment_file_synHandle is File: GerminalCenter10xATAC_GSM5051501.atac.filter.fragments.hg38.tsv.gz (syn52120079)
#   md5=8fb498172fa4e4188ad1692f2aedaf06
#   fileSize=1401683776
#   contentType=text/tab-separated-values
#   externalURL=None
#   cacheDir=/gpfs/fs1/data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/fragment_files/syn52118183_syn52120079_GerminalCenter10xATAC_GSM5051501.atac.filter.fragments.hg38.tsv.gz
#   files=['GerminalCenter10xATAC_GSM5051501.atac.filter.fragments.hg38.tsv.gz']
#   path=/gpfs/fs1/data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/fragment_files/syn52118183_syn52120079_GerminalCenter10xATAC_GSM5051501.atac.filter.fragments.hg38.tsv.gz/GerminalCenter10xATAC_GSM5051501.atac.filter.fragments.hg38.tsv.gz
#   synapseStore=True
# properties:
#   concreteType=org.sagebionetworks.repo.model.FileEntity
#   createdBy=3330650
#   createdOn=2023-07-20T13:39:12.583Z
#   dataFileHandleId=127201711
#   etag=2184465d-e39b-4d03-bedd-306496c2890f
#   id=syn52120079
#   isLatestVersion=True
#   modifiedBy=3330650
#   modifiedOn=2023-07-20T13:39:12.869Z
#   name=GerminalCenter10xATAC_GSM5051501.atac.filter.fragments.hg38.tsv.gz
#   parentId=syn52118183
#   versionLabel=1
#   versionNumber=1
# annotations:
#   md5_google=['j7SYFy+k5BiK0WkvKu2vBg==']
#   subpool=['GerminalCenter10xATAC_GSM5051501']
#
# full_local_fragment_file_synHandle is /gpfs/fs1/data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/fragment_files/syn52118183_syn52120079_GerminalCenter10xATAC_GSM5051501.atac.filter.fragments.hg38.tsv.gz/GerminalCenter10xATAC_GSM5051501.atac.filter.fragments.hg38.tsv.gz
# index is 4
# row is Dataset Id                                            syn52118183
# File Name       GerminalCenter10xATAC_GSM5051505.atac.filter.f...
# File ID                                               syn52120091
# File Version                                                    1
# Name: 4, dtype: object
# local_fragment_file_synHandle is File: GerminalCenter10xATAC_GSM5051505.atac.filter.fragments.hg38.tsv.gz (syn52120091)
#   md5=b4f0f8e6790998b97eeb7e1d5ac10d23
#   fileSize=2054370595
#   contentType=text/tab-separated-values
#   externalURL=None
#   cacheDir=/gpfs/fs1/data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/fragment_files/syn52118183_syn52120091_GerminalCenter10xATAC_GSM5051505.atac.filter.fragments.hg38.tsv.gz
#   files=['GerminalCenter10xATAC_GSM5051505.atac.filter.fragments.hg38.tsv.gz']
#   path=/gpfs/fs1/data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/fragment_files/syn52118183_syn52120091_GerminalCenter10xATAC_GSM5051505.atac.filter.fragments.hg38.tsv.gz/GerminalCenter10xATAC_GSM5051505.atac.filter.fragments.hg38.tsv.gz
#   synapseStore=True
# properties:
#   concreteType=org.sagebionetworks.repo.model.FileEntity
#   createdBy=3330650
#   createdOn=2023-07-20T13:41:08.717Z
#   dataFileHandleId=127201776
#   etag=e8c0dd1e-6a14-448e-98cb-f61958392487
#   id=syn52120091
#   isLatestVersion=True
#   modifiedBy=3330650
#   modifiedOn=2023-07-20T13:41:08.991Z
#   name=GerminalCenter10xATAC_GSM5051505.atac.filter.fragments.hg38.tsv.gz
#   parentId=syn52118183
#   versionLabel=1
#   versionNumber=1
# annotations:
#   md5_google=['tPD45nkJmLl+634dWsENIw==']
#   subpool=['GerminalCenter10xATAC_GSM5051505']
#
# full_local_fragment_file_synHandle is /gpfs/fs1/data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/fragment_files/syn52118183_syn52120091_GerminalCenter10xATAC_GSM5051505.atac.filter.fragments.hg38.tsv.gz/GerminalCenter10xATAC_GSM5051505.atac.filter.fragments.hg38.tsv.gz
# index is 5
# row is Dataset Id                                            syn52118183
# File Name       GerminalCenter10xATAC_GSM5051506.atac.filter.f...
# File ID                                               syn52120086
# File Version                                                    1
# Name: 5, dtype: object
# local_fragment_file_synHandle is File: GerminalCenter10xATAC_GSM5051506.atac.filter.fragments.hg38.tsv.gz (syn52120086)
#   md5=8c9aa0b161ca0a3ee975f759cb94681e
#   fileSize=871255830
#   contentType=text/tab-separated-values
#   externalURL=None
#   cacheDir=/gpfs/fs1/data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/fragment_files/syn52118183_syn52120086_GerminalCenter10xATAC_GSM5051506.atac.filter.fragments.hg38.tsv.gz
#   files=['GerminalCenter10xATAC_GSM5051506.atac.filter.fragments.hg38.tsv.gz']
#   path=/gpfs/fs1/data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/fragment_files/syn52118183_syn52120086_GerminalCenter10xATAC_GSM5051506.atac.filter.fragments.hg38.tsv.gz/GerminalCenter10xATAC_GSM5051506.atac.filter.fragments.hg38.tsv.gz
#   synapseStore=True
# properties:
#   concreteType=org.sagebionetworks.repo.model.FileEntity
#   createdBy=3330650
#   createdOn=2023-07-20T13:39:39.261Z
#   dataFileHandleId=127201722
#   etag=68dce32b-a2c3-45d0-82a8-ea941cc2950b
#   id=syn52120086
#   isLatestVersion=True
#   modifiedBy=3330650
#   modifiedOn=2023-07-20T13:39:39.539Z
#   name=GerminalCenter10xATAC_GSM5051506.atac.filter.fragments.hg38.tsv.gz
#   parentId=syn52118183
#   versionLabel=1
#   versionNumber=1
# annotations:
#   md5_google=['jJqgsWHKCj7pdfdZy5RoHg==']
#   subpool=['GerminalCenter10xATAC_GSM5051506']
#
# full_local_fragment_file_synHandle is /gpfs/fs1/data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/fragment_files/syn52118183_syn52120086_GerminalCenter10xATAC_GSM5051506.atac.filter.fragments.hg38.tsv.gz/GerminalCenter10xATAC_GSM5051506.atac.filter.fragments.hg38.tsv.gz
# index is 6
# row is Dataset Id                                            syn52118183
# File Name       GerminalCenter10xATAC_GSM5051507.atac.filter.f...
# File ID                                               syn52120090
# File Version                                                    1
# Name: 6, dtype: object
# local_fragment_file_synHandle is File: GerminalCenter10xATAC_GSM5051507.atac.filter.fragments.hg38.tsv.gz (syn52120090)
#   md5=824fb64100827a615db3de635ab5c7ab
#   fileSize=1894293841
#   contentType=text/tab-separated-values
#   externalURL=None
#   cacheDir=/gpfs/fs1/data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/fragment_files/syn52118183_syn52120090_GerminalCenter10xATAC_GSM5051507.atac.filter.fragments.hg38.tsv.gz
#   files=['GerminalCenter10xATAC_GSM5051507.atac.filter.fragments.hg38.tsv.gz']
#   path=/gpfs/fs1/data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/fragment_files/syn52118183_syn52120090_GerminalCenter10xATAC_GSM5051507.atac.filter.fragments.hg38.tsv.gz/GerminalCenter10xATAC_GSM5051507.atac.filter.fragments.hg38.tsv.gz
#   synapseStore=True
# properties:
#   concreteType=org.sagebionetworks.repo.model.FileEntity
#   createdBy=3330650
#   createdOn=2023-07-20T13:40:40.958Z
#   dataFileHandleId=127201753
#   etag=bd81e899-4e56-4051-8103-a7f290f90fae
#   id=syn52120090
#   isLatestVersion=True
#   modifiedBy=3330650
#   modifiedOn=2023-07-20T13:40:41.208Z
#   name=GerminalCenter10xATAC_GSM5051507.atac.filter.fragments.hg38.tsv.gz
#   parentId=syn52118183
#   versionLabel=1
#   versionNumber=1
# annotations:
#   md5_google=['gk+2QQCCemFds95jWrXHqw==']
#   subpool=['GerminalCenter10xATAC_GSM5051507']
#
# full_local_fragment_file_synHandle is /gpfs/fs1/data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/fragment_files/syn52118183_syn52120090_GerminalCenter10xATAC_GSM5051507.atac.filter.fragments.hg38.tsv.gz/GerminalCenter10xATAC_GSM5051507.atac.filter.fragments.hg38.tsv.gz
# index is 7
# row is Dataset Id                                            syn52118183
# File Name       GerminalCenter10xATAC_GSM5051508.atac.filter.f...
# File ID                                               syn52120089
# File Version                                                    1
# Name: 7, dtype: object
# local_fragment_file_synHandle is File: GerminalCenter10xATAC_GSM5051508.atac.filter.fragments.hg38.tsv.gz (syn52120089)
#   md5=82b78ec6db6db6ed91e847167a10e101
#   fileSize=1597859810
#   contentType=text/tab-separated-values
#   externalURL=None
#   cacheDir=/gpfs/fs1/data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/fragment_files/syn52118183_syn52120089_GerminalCenter10xATAC_GSM5051508.atac.filter.fragments.hg38.tsv.gz
#   files=['GerminalCenter10xATAC_GSM5051508.atac.filter.fragments.hg38.tsv.gz']
#   path=/gpfs/fs1/data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/fragment_files/syn52118183_syn52120089_GerminalCenter10xATAC_GSM5051508.atac.filter.fragments.hg38.tsv.gz/GerminalCenter10xATAC_GSM5051508.atac.filter.fragments.hg38.tsv.gz
#   synapseStore=True
# properties:
#   concreteType=org.sagebionetworks.repo.model.FileEntity
#   createdBy=3330650
#   createdOn=2023-07-20T13:40:12.098Z
#   dataFileHandleId=127201732
#   etag=91e7210b-8464-4419-b962-c13cb69fa137
#   id=syn52120089
#   isLatestVersion=True
#   modifiedBy=3330650
#   modifiedOn=2023-07-20T13:40:12.337Z
#   name=GerminalCenter10xATAC_GSM5051508.atac.filter.fragments.hg38.tsv.gz
#   parentId=syn52118183
#   versionLabel=1
#   versionNumber=1
# annotations:
#   md5_google=['greOxttttu2R6EcWehDhAQ==']
#   subpool=['GerminalCenter10xATAC_GSM5051508']
#
# full_local_fragment_file_synHandle is /gpfs/fs1/data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/fragment_files/syn52118183_syn52120089_GerminalCenter10xATAC_GSM5051508.atac.filter.fragments.hg38.tsv.gz/GerminalCenter10xATAC_GSM5051508.atac.filter.fragments.hg38.tsv.gz

# %%
# !ls -lt /Users/eilaarich-landkof-stanford/Documents/Code/git_kundaje_genomics/DNA/ATAC/single-cell/fragments-file-manipulation/synapse_in_out/fragment_files/
