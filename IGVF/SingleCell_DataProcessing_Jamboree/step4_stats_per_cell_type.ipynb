# %%
# step 4: stats file within each dataset.

# %%
def getManualAnnotationLabel(file):
    print("file is {}".format(file))
    Cell=file.split(subdir+"_")[-1].split(".tsv")[-2]
    print("Cell is {}".format(Cell))
    return(Cell)

# %%
def getCellClusterID(file,subdir):
    ClusterID="Cluster{}".format(index+1)
    print("ClusterID is {}".format(ClusterID))
    CellClusterID = subdir+"_"+ClusterID
    print("CellClusterID is {}".format(CellClusterID))
    return(CellClusterID)

# %%
def getMeanRNAUMIsPerCell():
    return()

# %%
# !pwd
# Out:
# /gpfs/fs1/data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks

# %%
# %%writefile /data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/tagAlign_stats.py
#!/usr/bin/env python
import os
import pandas as pd

def getManualAnnotationLabel(file):
    print("file is {}".format(file))
    Cell=file.split(subdir+"_")[-1].split(".tsv")[-2]
    print("Cell is {}".format(Cell))
    return(Cell)

def getCellClusterID(file,subdir):
    ClusterID="Cluster{}".format(index+1)
    print("ClusterID is {}".format(ClusterID))
    CellClusterID = subdir+"_"+ClusterID
    print("CellClusterID is {}".format(CellClusterID))
    return(CellClusterID)

def getMeanRNAUMIsPerCell():
    return()


clusters_folder_path = "/data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/clusters/"

# List all subdirectories under the "clusters" folder
subdirectories = [name for name in os.listdir(clusters_folder_path) if os.path.isdir(os.path.join(clusters_folder_path, name))]
# print(subdirectories)
# Create an empty dictionary to store the files for each subdirectory
subdir_files_dict = {}

# List all files under each subdirectory and store in the dictionary
# for subdir in subdirectories[0:1]:  # for debug
for subdir in subdirectories:  # all files
    subdir_path = os.path.join(clusters_folder_path, subdir)
    files = [file for file in os.listdir(subdir_path) if os.path.isfile(os.path.join(subdir_path, file))]
    subdir_files_dict[subdir] = files
# print(subdir_files_dict)
# Display the files for each subdirectory
for subdir, files in subdir_files_dict.items():
    print("Subdirectory: {}".format(subdir))
    stats_output_file = os.path.join(clusters_folder_path,subdir,'{}_ClusterMetadata.tsv'.format(subdir))
    print("stats_output_file is {}".format(stats_output_file))
    if os.path.exists(stats_output_file):
        print("stats_output_file {} exists".format(stats_output_file))
        continue
        
    print("Files:")
    print(files)
    files_in_subdir = len(files)
    print("files_in_subdir {} is {}".format(subdir,files_in_subdir))
    # Define the headers of the stats TSV file
    headers = ['tagAlignFile','CellClusterID','ManualAnnotationLabel','nCells','MeanRNAUMIsPerCell','MeanATACFragmentsPerCell']
    # Create an empty DataFrame with the headers
    df_stats = pd.DataFrame(columns=headers)
    # for index, file in enumerate(files[0:1]): # debug
    for index, file in enumerate(files): # all files
        # Read the TSV file into a pandas DataFrame
        df = pd.read_csv(os.path.join(clusters_folder_path,subdir,file), delimiter='\t', \
                         names = ['chr','start','stop','cell_id','reads','strand'])
        # Now you can work with the DataFrame 'df'
        print(df.head(2))  # Example: display the first few rows of the DataFrame
        print("number of rows (+/-) is {}".format(df.shape[0]))
        # Filter out rows with "-" in the last column
        df_positive_strand = df[~(df.iloc[:, -1] == '-')]
        # Now you can work with the filtered DataFrame 'df_filtered'
        print(df_positive_strand.head(2))  # Example: display the first few rows of the filtered DataFrame
        number_of_fragments = df_positive_strand.shape[0]
        print("number_of_fragments = number of rows (+) is {}".format(number_of_fragments))
        # CellClusterID	ManualAnnotationLabel	nCells	MeanRNAUMIsPerCell	MeanATACFragmentsPerCell
        # Xu2020_Cluster1	CD4+ T cell		152	3500			5000
        CellClusterID = getCellClusterID(file,subdir)
        print("CellClusterID is {}".format(CellClusterID))
        ManualAnnotationLabel = getManualAnnotationLabel(file)
        print("ManualAnnotationLabel is {}".format(ManualAnnotationLabel))
        nCells = df_positive_strand['cell_id'].nunique()
        print("nCells is {}".format(nCells))
        MeanRNAUMIsPerCell = getMeanRNAUMIsPerCell()
        MeanATACFragmentsPerCell = number_of_fragments // nCells
        print("MeanATACFragmentsPerCell is {}".format(MeanATACFragmentsPerCell))
        data_to_Add = [[CellClusterID,ManualAnnotationLabel,nCells,"",MeanATACFragmentsPerCell]]
        # Row to add as a dictionary
        new_row = {'tagAlignFile': file,
                   'CellClusterID': CellClusterID, 
                   'ManualAnnotationLabel': ManualAnnotationLabel,
                   'nCells':nCells, 
                   'MeanRNAUMIsPerCell':MeanRNAUMIsPerCell,
                   'MeanATACFragmentsPerCell':MeanATACFragmentsPerCell}
        # Add the new row using loc
        df_stats.loc[len(df_stats)] = new_row
        print(df_stats.head())
    # Save the DataFrame to a TSV file for each dataset
    df_stats.to_csv(stats_output_file, sep='\t', index=False)
# Out:
# Overwriting /data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/tagAlign_stats.py

# %%
# %%bash
# sbatch -p all \
#     --cpus-per-task 16 \
#     --exclude=dl-01 \
#     --mem 64G \
#     -o /data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/logs/tagAlign_stats.out \
#     <<'EOF'
# #!/bin/bash
# python /data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/tagAlign_stats.py
# EOF
# Out:
# Submitted batch job 30187436

# %%
# !squeue -u rv103
# Out:
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
#           30187429       all spawner-    rv103  R      18:31      1 dl-01

# %%
# !cat /data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/logs/tagAlign_stats.out
# Out:
# sys:1: DtypeWarning: Columns (1,2,4) have mixed types. Specify dtype option on import or set low_memory=False.
# Subdirectory: GerminalCenter10xATAC_GSM5051499
# stats_output_file is /data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/clusters/GerminalCenter10xATAC_GSM5051499/GerminalCenter10xATAC_GSM5051499_ClusterMetadata.tsv
# stats_output_file /data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/clusters/GerminalCenter10xATAC_GSM5051499/GerminalCenter10xATAC_GSM5051499_ClusterMetadata.tsv exists
# Subdirectory: GerminalCenter10xATAC_GSM5051506
# stats_output_file is /data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/clusters/GerminalCenter10xATAC_GSM5051506/GerminalCenter10xATAC_GSM5051506_ClusterMetadata.tsv
# stats_output_file /data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/clusters/GerminalCenter10xATAC_GSM5051506/GerminalCenter10xATAC_GSM5051506_ClusterMetadata.tsv exists
# Subdirectory: GerminalCenter10xATAC_GSM5051508
# stats_output_file is /data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/clusters/GerminalCenter10xATAC_GSM5051508/GerminalCenter10xATAC_GSM5051508_ClusterMetadata.tsv
# stats_output_file /data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/clusters/GerminalCenter10xATAC_GSM5051508/GerminalCenter10xATAC_GSM5051508_ClusterMetadata.tsv exists
# Subdirectory: GM12878_10XMultiome
# stats_output_file is /data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/clusters/GM12878_10XMultiome/GM12878_10XMultiome_ClusterMetadata.tsv
# stats_output_file /data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/clusters/GM12878_10XMultiome/GM12878_10XMultiome_ClusterMetadata.tsv exists
# Subdirectory: GerminalCenter10xATAC_GSM5051500
# stats_output_file is /data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/clusters/GerminalCenter10xATAC_GSM5051500/GerminalCenter10xATAC_GSM5051500_ClusterMetadata.tsv
# stats_output_file /data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/clusters/GerminalCenter10xATAC_GSM5051500/GerminalCenter10xATAC_GSM5051500_ClusterMetadata.tsv exists
# Subdirectory: GerminalCenter10xATAC_GSM5051501
# stats_output_file is /data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/clusters/GerminalCenter10xATAC_GSM5051501/GerminalCenter10xATAC_GSM5051501_ClusterMetadata.tsv
# stats_output_file /data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/clusters/GerminalCenter10xATAC_GSM5051501/GerminalCenter10xATAC_GSM5051501_ClusterMetadata.tsv exists
# Subdirectory: GerminalCenter10xATAC_GSM5051507
# stats_output_file is /data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/clusters/GerminalCenter10xATAC_GSM5051507/GerminalCenter10xATAC_GSM5051507_ClusterMetadata.tsv
# stats_output_file /data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/clusters/GerminalCenter10xATAC_GSM5051507/GerminalCenter10xATAC_GSM5051507_ClusterMetadata.tsv exists
# Subdirectory: GerminalCenter10xATAC_combined
# stats_output_file is /data/gersbachlab/Revathy/IGVF/Jamboree/SingleCellData/notebooks/clusters/GerminalCenter10xATAC_combined/GerminalCenter10xATAC_combined_ClusterMetadata.tsv
# Files:
# ['tagAlign_GerminalCenter10xATAC_Tcm_CD8.tsv', 'tagAlign_GerminalCenter10xATAC_DZ_GC.tsv', 'tagAlign_GerminalCenter10xATAC_Activated_B.tsv', 'tagAlign_GerminalCenter10xATAC_Dendritic.tsv', 'tagAlign_GerminalCenter10xATAC_Plasmablasts.tsv', 'tagAlign_GerminalCenter10xATAC_MBC.tsv', 'tagAlign_GerminalCenter10xATAC_Tcm_CD4.tsv', 'tagAlign_GerminalCenter10xATAC_Myeloid.tsv', 'tagAlign_GerminalCenter10xATAC_CTL.tsv', 'tagAlign_GerminalCenter10xATAC_Treg.tsv', 'tagAlign_GerminalCenter10xATAC_LZ_GC.tsv', 'tagAlign_GerminalCenter10xATAC_Naive_T.tsv', 'tagAlign_GerminalCenter10xATAC_Naive_B.tsv', 'tagAlign_GerminalCenter10xATAC_Tfh.tsv']
# files_in_subdir GerminalCenter10xATAC_combined is 14
#     chr  start   stop                                 cell_id  reads strand
# 0  chr1  10096  10097  GerminalCenter10xATAC_CTCTCGAAGCAATAAC      1      +
# 1  chr1  10461  10462  GerminalCenter10xATAC_CTCTCGAAGCAATAAC      1      -
# number of rows (+/-) is 1800004
#     chr  start   stop                                 cell_id  reads strand
# 0  chr1  10096  10097  GerminalCenter10xATAC_CTCTCGAAGCAATAAC      1      +
# 2  chr1  10480  10481  GerminalCenter10xATAC_TGATTTCGTGCTAGTT      1      +
# number_of_fragments = number of rows (+) is 900002
# ClusterID is Cluster1
# CellClusterID is GerminalCenter10xATAC_combined_Cluster1
# CellClusterID is GerminalCenter10xATAC_combined_Cluster1
# file is tagAlign_GerminalCenter10xATAC_Tcm_CD8.tsv
# Cell is tagAlign_GerminalCenter10xATAC_Tcm_CD8
# ManualAnnotationLabel is tagAlign_GerminalCenter10xATAC_Tcm_CD8
# nCells is 225
# MeanATACFragmentsPerCell is 4000
#                                  tagAlignFile  ... MeanATACFragmentsPerCell
# 0  tagAlign_GerminalCenter10xATAC_Tcm_CD8.tsv  ...                     4000
#
# [1 rows x 6 columns]
#     chr  start   stop                                 cell_id  reads strand
# 0  chr1  10007  10008  GerminalCenter10xATAC_GAAATGATCGATGTAC      1      +
# 1  chr1  10119  10120  GerminalCenter10xATAC_GAAATGATCGATGTAC      1      -
# number of rows (+/-) is 53967276
#     chr  start   stop                                 cell_id  reads strand
# 0  chr1  10007  10008  GerminalCenter10xATAC_GAAATGATCGATGTAC      1      +
# 2  chr1  10043  10044  GerminalCenter10xATAC_CAACGTATCGGGAATG      1      +
# number_of_fragments = number of rows (+) is 26983638
# ClusterID is Cluster2
# CellClusterID is GerminalCenter10xATAC_combined_Cluster2
# CellClusterID is GerminalCenter10xATAC_combined_Cluster2
# file is tagAlign_GerminalCenter10xATAC_DZ_GC.tsv
# Cell is tagAlign_GerminalCenter10xATAC_DZ_GC
# ManualAnnotationLabel is tagAlign_GerminalCenter10xATAC_DZ_GC
# nCells is 2176
# MeanATACFragmentsPerCell is 12400
#                                  tagAlignFile  ... MeanATACFragmentsPerCell
# 0  tagAlign_GerminalCenter10xATAC_Tcm_CD8.tsv  ...                     4000
# 1    tagAlign_GerminalCenter10xATAC_DZ_GC.tsv  ...                    12400
#
# [2 rows x 6 columns]
#     chr  start   stop                                 cell_id reads strand
# 0  chr1  10019  10020  GerminalCenter10xATAC_CCAGATACATCAGAAA     1      +
# 1  chr1  10185  10186  GerminalCenter10xATAC_CCAGATACATCAGAAA     1      -
# number of rows (+/-) is 18333275
#     chr  start   stop                                 cell_id reads strand
# 0  chr1  10019  10020  GerminalCenter10xATAC_CCAGATACATCAGAAA     1      +
# 2  chr1  10019  10020  GerminalCenter10xATAC_ACATGGTTCGAGCGCT     1      +
# number_of_fragments = number of rows (+) is 9166643
# ClusterID is Cluster3
# CellClusterID is GerminalCenter10xATAC_combined_Cluster3
# CellClusterID is GerminalCenter10xATAC_combined_Cluster3
# file is tagAlign_GerminalCenter10xATAC_Activated_B.tsv
# Cell is tagAlign_GerminalCenter10xATAC_Activated_B
# ManualAnnotationLabel is tagAlign_GerminalCenter10xATAC_Activated_B
# nCells is 3158
# MeanATACFragmentsPerCell is 2902
#                                      tagAlignFile  ... MeanATACFragmentsPerCell
# 0      tagAlign_GerminalCenter10xATAC_Tcm_CD8.tsv  ...                     4000
# 1        tagAlign_GerminalCenter10xATAC_DZ_GC.tsv  ...                    12400
# 2  tagAlign_GerminalCenter10xATAC_Activated_B.tsv  ...                     2902
#
# [3 rows x 6 columns]
#     chr  start   stop                                 cell_id  reads strand
# 0  chr1  12252  12253  GerminalCenter10xATAC_AGGCGAATCGCCACTT      1      +
# 1  chr1  12399  12400  GerminalCenter10xATAC_AGGCGAATCGCCACTT      1      -
# number of rows (+/-) is 338546
#     chr  start   stop                                 cell_id  reads strand
# 0  chr1  12252  12253  GerminalCenter10xATAC_AGGCGAATCGCCACTT      1      +
# 2  chr1  29467  29468  GerminalCenter10xATAC_GGAGAACGTCACTCTC      1      +
# number_of_fragments = number of rows (+) is 169273
# ClusterID is Cluster4
# CellClusterID is GerminalCenter10xATAC_combined_Cluster4
# CellClusterID is GerminalCenter10xATAC_combined_Cluster4
# file is tagAlign_GerminalCenter10xATAC_Dendritic.tsv
# Cell is tagAlign_GerminalCenter10xATAC_Dendritic
# ManualAnnotationLabel is tagAlign_GerminalCenter10xATAC_Dendritic
# nCells is 36
# MeanATACFragmentsPerCell is 4702
#                                      tagAlignFile  ... MeanATACFragmentsPerCell
# 0      tagAlign_GerminalCenter10xATAC_Tcm_CD8.tsv  ...                     4000
# 1        tagAlign_GerminalCenter10xATAC_DZ_GC.tsv  ...                    12400
# 2  tagAlign_GerminalCenter10xATAC_Activated_B.tsv  ...                     2902
# 3    tagAlign_GerminalCenter10xATAC_Dendritic.tsv  ...                     4702
#
# [4 rows x 6 columns]
#     chr  start   stop                                 cell_id  reads strand
# 0  chr1  10037  10038  GerminalCenter10xATAC_AGATAGAAGGAGGCGA      1      +
# 1  chr1  10191  10192  GerminalCenter10xATAC_AGATAGAAGGAGGCGA      1      -
# number of rows (+/-) is 4478400
#     chr  start   stop                                 cell_id  reads strand
# 0  chr1  10037  10038  GerminalCenter10xATAC_AGATAGAAGGAGGCGA      1      +
# 2  chr1  10061  10062  GerminalCenter10xATAC_ATCCAGAGTTTCGACA      1      +
# number_of_fragments = number of rows (+) is 2239200
# ClusterID is Cluster5
# CellClusterID is GerminalCenter10xATAC_combined_Cluster5
# CellClusterID is GerminalCenter10xATAC_combined_Cluster5
# file is tagAlign_GerminalCenter10xATAC_Plasmablasts.tsv
# Cell is tagAlign_GerminalCenter10xATAC_Plasmablasts
# ManualAnnotationLabel is tagAlign_GerminalCenter10xATAC_Plasmablasts
# nCells is 484
# MeanATACFragmentsPerCell is 4626
#                                       tagAlignFile  ... MeanATACFragmentsPerCell
# 0       tagAlign_GerminalCenter10xATAC_Tcm_CD8.tsv  ...                     4000
# 1         tagAlign_GerminalCenter10xATAC_DZ_GC.tsv  ...                    12400
# 2   tagAlign_GerminalCenter10xATAC_Activated_B.tsv  ...                     2902
# 3     tagAlign_GerminalCenter10xATAC_Dendritic.tsv  ...                     4702
# 4  tagAlign_GerminalCenter10xATAC_Plasmablasts.tsv  ...                     4626
#
# [5 rows x 6 columns]
#     chr  start   stop                                 cell_id  reads strand
# 0  chr1  10098  10099  GerminalCenter10xATAC_GAAAGTACATGGAGGT      1      +
# 1  chr1  10143  10144  GerminalCenter10xATAC_GAAAGTACATGGAGGT      1      -
# number of rows (+/-) is 7463306
#     chr  start   stop                                 cell_id  reads strand
# 0  chr1  10098  10099  GerminalCenter10xATAC_GAAAGTACATGGAGGT      1      +
# 2  chr1  10156  10157  GerminalCenter10xATAC_TATCTGTTCCACGGCA      1      +
# number_of_fragments = number of rows (+) is 3731653
# ClusterID is Cluster6
# CellClusterID is GerminalCenter10xATAC_combined_Cluster6
# CellClusterID is GerminalCenter10xATAC_combined_Cluster6
# file is tagAlign_GerminalCenter10xATAC_MBC.tsv
# Cell is tagAlign_GerminalCenter10xATAC_MBC
# ManualAnnotationLabel is tagAlign_GerminalCenter10xATAC_MBC
# nCells is 1285
# MeanATACFragmentsPerCell is 2904
#                                       tagAlignFile  ... MeanATACFragmentsPerCell
# 0       tagAlign_GerminalCenter10xATAC_Tcm_CD8.tsv  ...                     4000
# 1         tagAlign_GerminalCenter10xATAC_DZ_GC.tsv  ...                    12400
# 2   tagAlign_GerminalCenter10xATAC_Activated_B.tsv  ...                     2902
# 3     tagAlign_GerminalCenter10xATAC_Dendritic.tsv  ...                     4702
# 4  tagAlign_GerminalCenter10xATAC_Plasmablasts.tsv  ...                     4626
#
# [5 rows x 6 columns]
#     chr  start   stop                                 cell_id  reads strand
# 0  chr1  15346  15347  GerminalCenter10xATAC_TCCATCGAGATGAGGA      1      +
# 1  chr1  15547  15548  GerminalCenter10xATAC_TCCATCGAGATGAGGA      1      -
# number of rows (+/-) is 1113396
#     chr  start   stop                                 cell_id  reads strand
# 0  chr1  15346  15347  GerminalCenter10xATAC_TCCATCGAGATGAGGA      1      +
# 2  chr1  21239  21240  GerminalCenter10xATAC_CCGAAGCTCGTCTAGA      1      +
# number_of_fragments = number of rows (+) is 556698
# ClusterID is Cluster7
# CellClusterID is GerminalCenter10xATAC_combined_Cluster7
# CellClusterID is GerminalCenter10xATAC_combined_Cluster7
# file is tagAlign_GerminalCenter10xATAC_Tcm_CD4.tsv
# Cell is tagAlign_GerminalCenter10xATAC_Tcm_CD4
# ManualAnnotationLabel is tagAlign_GerminalCenter10xATAC_Tcm_CD4
# nCells is 370
# MeanATACFragmentsPerCell is 1504
#                                       tagAlignFile  ... MeanATACFragmentsPerCell
# 0       tagAlign_GerminalCenter10xATAC_Tcm_CD8.tsv  ...                     4000
# 1         tagAlign_GerminalCenter10xATAC_DZ_GC.tsv  ...                    12400
# 2   tagAlign_GerminalCenter10xATAC_Activated_B.tsv  ...                     2902
# 3     tagAlign_GerminalCenter10xATAC_Dendritic.tsv  ...                     4702
# 4  tagAlign_GerminalCenter10xATAC_Plasmablasts.tsv  ...                     4626
#
# [5 rows x 6 columns]
#     chr  start   stop                                 cell_id  reads strand
# 0  chr1  11235  11236  GerminalCenter10xATAC_ATAGGCTAGCTCGTTA      1      +
# 1  chr1  11392  11393  GerminalCenter10xATAC_ATAGGCTAGCTCGTTA      1      -
# number of rows (+/-) is 786988
#     chr  start   stop                                 cell_id  reads strand
# 0  chr1  11235  11236  GerminalCenter10xATAC_ATAGGCTAGCTCGTTA      1      +
# 2  chr1  11467  11468  GerminalCenter10xATAC_TTATGTCTCTAAACGC      1      +
# number_of_fragments = number of rows (+) is 393494
# ClusterID is Cluster8
# CellClusterID is GerminalCenter10xATAC_combined_Cluster8
# CellClusterID is GerminalCenter10xATAC_combined_Cluster8
# file is tagAlign_GerminalCenter10xATAC_Myeloid.tsv
# Cell is tagAlign_GerminalCenter10xATAC_Myeloid
# ManualAnnotationLabel is tagAlign_GerminalCenter10xATAC_Myeloid
# nCells is 251
# MeanATACFragmentsPerCell is 1567
#                                       tagAlignFile  ... MeanATACFragmentsPerCell
# 0       tagAlign_GerminalCenter10xATAC_Tcm_CD8.tsv  ...                     4000
# 1         tagAlign_GerminalCenter10xATAC_DZ_GC.tsv  ...                    12400
# 2   tagAlign_GerminalCenter10xATAC_Activated_B.tsv  ...                     2902
# 3     tagAlign_GerminalCenter10xATAC_Dendritic.tsv  ...                     4702
# 4  tagAlign_GerminalCenter10xATAC_Plasmablasts.tsv  ...                     4626
#
# [5 rows x 6 columns]
#     chr  start   stop                                 cell_id  reads strand
# 0  chr1  10151  10152  GerminalCenter10xATAC_AGCTATGCACAGTTCA      1      +
# 1  chr1  10191  10192  GerminalCenter10xATAC_AGCTATGCACAGTTCA      1      -
# number of rows (+/-) is 2890442
#     chr  start   stop                                 cell_id  reads strand
# 0  chr1  10151  10152  GerminalCenter10xATAC_AGCTATGCACAGTTCA      1      +
# 2  chr1  10202  10203  GerminalCenter10xATAC_AGCGATTCAAGTTGCT      1      +
# number_of_fragments = number of rows (+) is 1445221
# ClusterID is Cluster9
# CellClusterID is GerminalCenter10xATAC_combined_Cluster9
# CellClusterID is GerminalCenter10xATAC_combined_Cluster9
# file is tagAlign_GerminalCenter10xATAC_CTL.tsv
# Cell is tagAlign_GerminalCenter10xATAC_CTL
# ManualAnnotationLabel is tagAlign_GerminalCenter10xATAC_CTL
# nCells is 421
# MeanATACFragmentsPerCell is 3432
#                                       tagAlignFile  ... MeanATACFragmentsPerCell
# 0       tagAlign_GerminalCenter10xATAC_Tcm_CD8.tsv  ...                     4000
# 1         tagAlign_GerminalCenter10xATAC_DZ_GC.tsv  ...                    12400
# 2   tagAlign_GerminalCenter10xATAC_Activated_B.tsv  ...                     2902
# 3     tagAlign_GerminalCenter10xATAC_Dendritic.tsv  ...                     4702
# 4  tagAlign_GerminalCenter10xATAC_Plasmablasts.tsv  ...                     4626
#
# [5 rows x 6 columns]
#     chr  start   stop                                 cell_id  reads strand
# 0  chr1  10085  10086  GerminalCenter10xATAC_GTGTCCTTCGAGGTCC      1      +
# 1  chr1  10142  10143  GerminalCenter10xATAC_GTGTCCTTCGAGGTCC      1      -
# number of rows (+/-) is 3999594
#     chr  start   stop                                 cell_id  reads strand
# 0  chr1  10085  10086  GerminalCenter10xATAC_GTGTCCTTCGAGGTCC      1      +
# 2  chr1  10097  10098  GerminalCenter10xATAC_CGTAAACTCTTCCACG      1      +
# number_of_fragments = number of rows (+) is 1999797
# ClusterID is Cluster10
# CellClusterID is GerminalCenter10xATAC_combined_Cluster10
# CellClusterID is GerminalCenter10xATAC_combined_Cluster10
# file is tagAlign_GerminalCenter10xATAC_Treg.tsv
# Cell is tagAlign_GerminalCenter10xATAC_Treg
# ManualAnnotationLabel is tagAlign_GerminalCenter10xATAC_Treg
# nCells is 322
# MeanATACFragmentsPerCell is 6210
#                                       tagAlignFile  ... MeanATACFragmentsPerCell
# 0       tagAlign_GerminalCenter10xATAC_Tcm_CD8.tsv  ...                     4000
# 1         tagAlign_GerminalCenter10xATAC_DZ_GC.tsv  ...                    12400
# 2   tagAlign_GerminalCenter10xATAC_Activated_B.tsv  ...                     2902
# 3     tagAlign_GerminalCenter10xATAC_Dendritic.tsv  ...                     4702
# 4  tagAlign_GerminalCenter10xATAC_Plasmablasts.tsv  ...                     4626
#
# [5 rows x 6 columns]
#     chr  start   stop                                 cell_id  reads strand
# 0  chr1  10043  10044  GerminalCenter10xATAC_AAAGGGCTCAGCACTA      1      +
# 1  chr1  10318  10319  GerminalCenter10xATAC_AAAGGGCTCAGCACTA      1      -
# number of rows (+/-) is 12501448
#     chr  start   stop                                 cell_id  reads strand
# 0  chr1  10043  10044  GerminalCenter10xATAC_AAAGGGCTCAGCACTA      1      +
# 2  chr1  10162  10163  GerminalCenter10xATAC_ATGTACGCAATGGTCT      1      +
# number_of_fragments = number of rows (+) is 6250724
# ClusterID is Cluster11
# CellClusterID is GerminalCenter10xATAC_combined_Cluster11
# CellClusterID is GerminalCenter10xATAC_combined_Cluster11
# file is tagAlign_GerminalCenter10xATAC_LZ_GC.tsv
# Cell is tagAlign_GerminalCenter10xATAC_LZ_GC
# ManualAnnotationLabel is tagAlign_GerminalCenter10xATAC_LZ_GC
# nCells is 1093
# MeanATACFragmentsPerCell is 5718
#                                       tagAlignFile  ... MeanATACFragmentsPerCell
# 0       tagAlign_GerminalCenter10xATAC_Tcm_CD8.tsv  ...                     4000
# 1         tagAlign_GerminalCenter10xATAC_DZ_GC.tsv  ...                    12400
# 2   tagAlign_GerminalCenter10xATAC_Activated_B.tsv  ...                     2902
# 3     tagAlign_GerminalCenter10xATAC_Dendritic.tsv  ...                     4702
# 4  tagAlign_GerminalCenter10xATAC_Plasmablasts.tsv  ...                     4626
#
# [5 rows x 6 columns]
#     chr  start   stop                                 cell_id  reads strand
# 0  chr1  10131  10132  GerminalCenter10xATAC_CACGTTCAGTACCCAT      1      +
# 1  chr1  10162  10163  GerminalCenter10xATAC_CACGTTCAGTACCCAT      1      -
# number of rows (+/-) is 2934232
#     chr  start   stop                                 cell_id  reads strand
# 0  chr1  10131  10132  GerminalCenter10xATAC_CACGTTCAGTACCCAT      1      +
# 2  chr1  10131  10132  GerminalCenter10xATAC_CACGTTCAGTACCCAT      1      +
# number_of_fragments = number of rows (+) is 1467116
# ClusterID is Cluster12
# CellClusterID is GerminalCenter10xATAC_combined_Cluster12
# CellClusterID is GerminalCenter10xATAC_combined_Cluster12
# file is tagAlign_GerminalCenter10xATAC_Naive_T.tsv
# Cell is tagAlign_GerminalCenter10xATAC_Naive_T
# ManualAnnotationLabel is tagAlign_GerminalCenter10xATAC_Naive_T
# nCells is 542
# MeanATACFragmentsPerCell is 2706
#                                       tagAlignFile  ... MeanATACFragmentsPerCell
# 0       tagAlign_GerminalCenter10xATAC_Tcm_CD8.tsv  ...                     4000
# 1         tagAlign_GerminalCenter10xATAC_DZ_GC.tsv  ...                    12400
# 2   tagAlign_GerminalCenter10xATAC_Activated_B.tsv  ...                     2902
# 3     tagAlign_GerminalCenter10xATAC_Dendritic.tsv  ...                     4702
# 4  tagAlign_GerminalCenter10xATAC_Plasmablasts.tsv  ...                     4626
#
# [5 rows x 6 columns]
#     chr  start   stop                                 cell_id  reads strand
# 0  chr1  10007  10008  GerminalCenter10xATAC_CGTACAATCACAACAC      1      +
# 1  chr1  10119  10120  GerminalCenter10xATAC_CGTACAATCACAACAC      1      -
# number of rows (+/-) is 5305914
#     chr  start   stop                                 cell_id  reads strand
# 0  chr1  10007  10008  GerminalCenter10xATAC_CGTACAATCACAACAC      1      +
# 2  chr1  10007  10008  GerminalCenter10xATAC_ACTAACGCAGATAAGT      1      +
# number_of_fragments = number of rows (+) is 2652957
# ClusterID is Cluster13
# CellClusterID is GerminalCenter10xATAC_combined_Cluster13
# CellClusterID is GerminalCenter10xATAC_combined_Cluster13
# file is tagAlign_GerminalCenter10xATAC_Naive_B.tsv
# Cell is tagAlign_GerminalCenter10xATAC_Naive_B
# ManualAnnotationLabel is tagAlign_GerminalCenter10xATAC_Naive_B
# nCells is 3137
# MeanATACFragmentsPerCell is 845
#                                       tagAlignFile  ... MeanATACFragmentsPerCell
# 0       tagAlign_GerminalCenter10xATAC_Tcm_CD8.tsv  ...                     4000
# 1         tagAlign_GerminalCenter10xATAC_DZ_GC.tsv  ...                    12400
# 2   tagAlign_GerminalCenter10xATAC_Activated_B.tsv  ...                     2902
# 3     tagAlign_GerminalCenter10xATAC_Dendritic.tsv  ...                     4702
# 4  tagAlign_GerminalCenter10xATAC_Plasmablasts.tsv  ...                     4626
#
# [5 rows x 6 columns]
#     chr  start   stop                                 cell_id  reads strand
# 0  chr1  10395  10396  GerminalCenter10xATAC_CCTCCCTGTGGAGTGT      1      +
# 1  chr1  10436  10437  GerminalCenter10xATAC_CCTCCCTGTGGAGTGT      1      -
# number of rows (+/-) is 6720844
#     chr  start   stop                                 cell_id  reads strand
# 0  chr1  10395  10396  GerminalCenter10xATAC_CCTCCCTGTGGAGTGT      1      +
# 2  chr1  10553  10554  GerminalCenter10xATAC_TTACCCGTCCAAACCA      1      +
# number_of_fragments = number of rows (+) is 3360422
# ClusterID is Cluster14
# CellClusterID is GerminalCenter10xATAC_combined_Cluster14
# CellClusterID is GerminalCenter10xATAC_combined_Cluster14
# file is tagAlign_GerminalCenter10xATAC_Tfh.tsv
# Cell is tagAlign_GerminalCenter10xATAC_Tfh
# ManualAnnotationLabel is tagAlign_GerminalCenter10xATAC_Tfh
# nCells is 889
# MeanATACFragmentsPerCell is 3780
#                                       tagAlignFile  ... MeanATACFragmentsPerCell
# 0       tagAlign_GerminalCenter10xATAC_Tcm_CD8.tsv  ...                     4000
# 1         tagAlign_GerminalCenter10xATAC_DZ_GC.tsv  ...                    12400
# 2   tagAlign_GerminalCenter10xATAC_Activated_B.tsv  ...                     2902
# 3     tagAlign_GerminalCenter10xATAC_Dendritic.tsv  ...                     4702
# 4  tagAlign_GerminalCenter10xATAC_Plasmablasts.tsv  ...                     4626
#
# [5 rows x 6 columns]

# %%
# CellClusterID	ManualAnnotationLabel	nCells	MeanRNAUMIsPerCell	MeanATACFragmentsPerCell
# Xu2020_Cluster1	CD4+ T cell		152	3500			5000
# Xu2020_Cluster2	CD4+ T cell		357	5000			6000
