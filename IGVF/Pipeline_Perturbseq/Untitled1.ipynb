# %% [markdown]
# /data/gersbachlab/Ruhi/pipeline_perturbseq_like/perturbseq_OUT_exp_1/f8/94dc5f70664ccfa5251f139844f30d/processed_mudata_guide_and_transcripts.h5mu
# /data/gersbachlab/Ruhi/pipeline_perturbseq_like/perturbseq_OUT_exp_1/d1/bae35e828fe8f38294b061bf38480b/processed_mudata_guide_and_transcripts.h5mu
# /data/gersbachlab/Ruhi/pipeline_perturbseq_like/perturbseq_OUT_exp_1/21/ee748bb883c8acbce23cdfff78a1c8/processed_mudata_guide_and_transcripts.h5mu
# /data/gersbachlab/Ruhi/pipeline_perturbseq_like/perturbseq_OUT_exp_1/88/c8a88f1de1d9554775f9368339a785/processed_mudata_guide_and_transcripts.h5mu

# %%
suppressPackageStartupMessages(library(SeuratData))
suppressPackageStartupMessages(library(MuDataSeurat))

# %%
tst1 <- ReadH5MU("/data/gersbachlab/Ruhi/pipeline_perturbseq_like/perturbseq_OUT_exp_1/95/e1f674f73336c9fa186399da3abb9a/raw_mudata_guide_and_transcripts.h5mu")
# tst2 <- ReadH5MU("/data/gersbachlab/Ruhi/pipeline_perturbseq_like/perturbseq_OUT_exp_1/d1/bae35e828fe8f38294b061bf38480b/processed_mudata_guide_and_transcripts.h5mu")
# tst3 <- ReadH5MU("/data/gersbachlab/Ruhi/pipeline_perturbseq_like/perturbseq_OUT_exp_1/21/ee748bb883c8acbce23cdfff78a1c8/processed_mudata_guide_and_transcripts.h5mu")
# tst4 <- ReadH5MU("/data/gersbachlab/Ruhi/pipeline_perturbseq_like/perturbseq_OUT_exp_1/88/c8a88f1de1d9554775f9368339a785/processed_mudata_guide_and_transcripts.h5mu")
# Out:
# Warning message in missing_on_read("/var", paste0("global variables metadata (", :
# “Missing on read: /var. Seurat does not support global variables metadata (feature_name).”
# Warning message in read_layers_to_assay(h5[["mod"]][[mod]], mod):
# “The var_names from modality guides have been renamed as feature names cannot contain '_'. E.g. BROX|1_sgrna_chr1:222712600:222712620 -> BROX|1-sgrna-chr1:222712600:222712620.”
# Warning message:
# “Feature names cannot have pipe characters ('|'), replacing with dashes ('-')”
# Warning message in missing_on_read(paste0("/mod", mod, "/varp"), "pairwise annotation of variables"):
# “Missing on read: /modguides/varp. Seurat does not support pairwise annotation of variables.”
# Warning message in missing_on_read(paste0("/mod", mod, "/varp"), "pairwise annotation of variables"):
# “Missing on read: /modscRNA/varp. Seurat does not support pairwise annotation of variables.”
# Warning message:
# ...

# %%
tst5 <- read_h5ad('/data/gersbachlab/Ruhi/pipeline_perturbseq_like/perturbseq_OUT_exp_1/f4/05c1fb327cdd10557e0834c4cd49a8/adata.h5ad')
# Out:
# Error in read_h5ad("/data/gersbachlab/Ruhi/pipeline_perturbseq_like/perturbseq_OUT_exp_1/f4/05c1fb327cdd10557e0834c4cd49a8/adata.h5ad"): could not find function "read_h5ad"
# Traceback:

# %%
tst1.var
# Out:
# Error in eval(expr, envir, enclos): object 'tst1.var' not found
# Traceback:

# %%
tst1@meta.data
# Out:
#                  orig.ident    nCount_guides nFeature_guides nCount_scRNA
# AAACCTGAGCGAGAAA SeuratProject 19            3                733
# AAACCTGAGCTGTCTA SeuratProject 25            2                566
# AAACCTGAGTTATCGC SeuratProject 22            1                982
# AAACCTGCAAATACAG SeuratProject  4            2                509
# AAACCTGCACTCGACG SeuratProject  1            1                435
# AAACCTGCAGTCTTCC SeuratProject 11            1                480
# AAACGGGAGAGTACCG SeuratProject  2            2                908
# AAACGGGAGCACGCCT SeuratProject 15            1               1182
# AAACGGGAGCAGACTG SeuratProject  2            2               2137
# AAACGGGCACAGCCCA SeuratProject 30            1               1073
# AAACGGGCACAGGAGT SeuratProject 74            1               1785
# AAACGGGCACTAGTAC SeuratProject 51            2               2531
# AAACGGGCATCCCATC SeuratProject 56            1               1297
# ...

# %%
median(tst1@meta.data$nFeature_scRNA)
# Out:
# [1] 608

# %%
median(tst1@meta.data$nCount_scRNA)
# Out:
# [1] 922
