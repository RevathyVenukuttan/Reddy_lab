# %%
# %%bash
# cd /data/reddylab/Flowcells/gjohnson/wgss/wgss3/wgss3_output_fastqs/TFX2/NovaSeq_Run1_fastqs/
# ls *_R1_*.fastq.gz *_R2_*.fastq.gz
# Out:
# TFX2_AZD2906_TechRep2_S38_L003_R1_001_NovaSeq_Run1.fastq.gz
# TFX2_AZD2906_TechRep2_S38_L003_R2_001_NovaSeq_Run1.fastq.gz
# TFX2_AZD2906_TechRep3_S44_L003_R1_001_NovaSeq_Run1.fastq.gz
# TFX2_AZD2906_TechRep3_S44_L003_R2_001_NovaSeq_Run1.fastq.gz
# TFX2_AZD9567_TechRep1_S42_L003_R1_001_NovaSeq_Run1.fastq.gz
# TFX2_AZD9567_TechRep1_S42_L003_R2_001_NovaSeq_Run1.fastq.gz
# TFX2_AZD9567_TechRep2_S92_L004_R1_001_NovaSeq_Run1.fastq.gz
# TFX2_AZD9567_TechRep2_S92_L004_R2_001_NovaSeq_Run1.fastq.gz
# TFX2_AZD9567_TechRep3_S98_L004_R1_001_NovaSeq_Run1.fastq.gz
# TFX2_AZD9567_TechRep3_S98_L004_R2_001_NovaSeq_Run1.fastq.gz
# TFX2_CORT108297_TechRep1_S87_L004_R1_001_NovaSeq_Run1.fastq.gz
# TFX2_CORT108297_TechRep1_S87_L004_R2_001_NovaSeq_Run1.fastq.gz
# TFX2_CORT108297_TechRep2_S93_L004_R1_001_NovaSeq_Run1.fastq.gz
# TFX2_CORT108297_TechRep2_S93_L004_R2_001_NovaSeq_Run1.fastq.gz
# TFX2_CORT108297_TechRep3_S99_L004_R1_001_NovaSeq_Run1.fastq.gz
# ...

# %%
# %%bash
#  less ${file} \
# | awk '{ if(NR%4==2) print $0 }' \
# | awk '{ print  length($0) }' \
# | sort \
# | uniq -c > ${file}_read_length.txt
# Out:
# Process is terminated.

# %%
# %%bash
# mkdir -p /data/reddylab/Revathy/dev/Graham/ENCODE/data/read_length
# cd /data/reddylab/Revathy/dev/Graham/ENCODE/data/Novaseq/
# out_dir=/data/reddylab/Revathy/dev/Graham/ENCODE/data/read_length
# files=$(ls *_R1*.fastq.gz)
# for file in ${files[@]};
# do
#  less ${file} \
# | awk '{ if(NR%4==2) print $0 }' \
# | awk '{ print  length($0) }' \
# | sort \
# | uniq -c > ${out_dir}/${file}_read_length.txt
# done
# Out:
# Process is terminated.

# %%
# %%bash
# cd /data/reddylab/Flowcells/gjohnson/wgss/wgss3/wgss3_output_fastqs/TFX2/NovaSeq_Run2_fastqs
# ls
# Out:
# TFX2_AZD2906_TechRep1_S112_L003_I1_001_NovaSeq_Run2.fastq.gz
# TFX2_AZD2906_TechRep1_S112_L003_R1_001_NovaSeq_Run2.fastq.gz
# TFX2_AZD2906_TechRep1_S112_L003_R2_001_NovaSeq_Run2.fastq.gz
# TFX2_AZD2906_TechRep1_S112_L003_R3_001_NovaSeq_Run2.fastq.gz
# TFX2_AZD2906_TechRep2_S34_L001_I1_001_NovaSeq_Run2.fastq.gz
# TFX2_AZD2906_TechRep2_S34_L001_R1_001_NovaSeq_Run2.fastq.gz
# TFX2_AZD2906_TechRep2_S34_L001_R2_001_NovaSeq_Run2.fastq.gz
# TFX2_AZD2906_TechRep2_S34_L001_R3_001_NovaSeq_Run2.fastq.gz
# TFX2_AZD2906_TechRep3_S130_L004_I1_001_NovaSeq_Run2.fastq.gz
# TFX2_AZD2906_TechRep3_S130_L004_R1_001_NovaSeq_Run2.fastq.gz
# TFX2_AZD2906_TechRep3_S130_L004_R2_001_NovaSeq_Run2.fastq.gz
# TFX2_AZD2906_TechRep3_S130_L004_R3_001_NovaSeq_Run2.fastq.gz
# TFX2_AZD2906_TechRep4_S140_L004_I1_001_NovaSeq_Run2.fastq.gz
# TFX2_AZD2906_TechRep4_S140_L004_R1_001_NovaSeq_Run2.fastq.gz
# TFX2_AZD2906_TechRep4_S140_L004_R2_001_NovaSeq_Run2.fastq.gz
# ...

# %%
# %%bash
# mkdir -p /data/reddylab/Revathy/dev/Graham/ENCODE/data/Novaseq
# cp /data/reddylab/Flowcells/gjohnson/wgss/wgss3/wgss3_output_fastqs/TFX2/NovaSeq_Run1_fastqs/*.fastq.gz /data/reddylab/Revathy/dev/Graham/ENCODE/data/Novaseq
# cp /data/reddylab/Flowcells/gjohnson/wgss/wgss3/wgss3_output_fastqs/TFX2/NovaSeq_Run2_fastqs/*.fastq.gz /data/reddylab/Revathy/dev/Graham/ENCODE/data/Novaseq

# %%
# %%bash
# cd /data/reddylab/Flowcells/gjohnson/wgss/wgss3/wgss3_output_fastqs/TFX2/NovaSeq_Run1_fastqs/
# ls *_Mapracorat_TechRep3_*_R1_*.fastq.gz
# Out:
# ls: cannot access *_Mapracorat_TechRep3_*_R1_*.fastq.gz: No such file or directory

# %%
# %%bash
# mkdir -p /data/reddylab/Revathy/dev/Graham/ENCODE/data/Novaseq/processed
# cd /data/reddylab/Revathy/dev/Graham/ENCODE/data/Novaseq
# NAMES=(AZD2906 AZD9567 CORT108297 CpdA Dex DMSO GW870086 Hydrocortisone Mapracorat RU486 ZK216348)
# for NAME in ${NAMES[@]};
# do
# cat *_${NAME}_TechRep1_*_R3_*.fastq.gz > processed/TFX2_${NAME}_TechRep1_R3_NovaSeq.fastq.gz
# cat *_${NAME}_TechRep2_*_R3_*.fastq.gz > processed/TFX2_${NAME}_TechRep2_R3_NovaSeq.fastq.gz
# cat *_${NAME}_TechRep3_*_R3_*.fastq.gz > processed/TFX2_${NAME}_TechRep3_R3_NovaSeq.fastq.gz
# cat *_${NAME}_TechRep4_*_R3_*.fastq.gz > processed/TFX2_${NAME}_TechRep4_R3_NovaSeq.fastq.gz
# done
# Out:
# cat: *_Mapracorat_TechRep3_*_R3_*.fastq.gz: No such file or directory

# %%
# %%bash
# ls /data/reddylab/Flowcells/gjohnson/wgss/wgss3/wgss3_output_fastqs/TFX2/SPrime_fastqs/*_R3_*.gz
# Out:
# /data/reddylab/Flowcells/gjohnson/wgss/wgss3/wgss3_output_fastqs/TFX2/SPrime_fastqs/Undetermined_S0_L001_R3_001_SPrime.fastq.gz
# /data/reddylab/Flowcells/gjohnson/wgss/wgss3/wgss3_output_fastqs/TFX2/SPrime_fastqs/Undetermined_S0_L002_R3_001_SPrime.fastq.gz
# /data/reddylab/Flowcells/gjohnson/wgss/wgss3/wgss3_output_fastqs/TFX2/SPrime_fastqs/WGSS3_TFX2_AZD2906_TechRep1_S2_L001_R3_001_SPrime.fastq.gz
# /data/reddylab/Flowcells/gjohnson/wgss/wgss3/wgss3_output_fastqs/TFX2/SPrime_fastqs/WGSS3_TFX2_AZD2906_TechRep1_S2_L002_R3_001_SPrime.fastq.gz
# /data/reddylab/Flowcells/gjohnson/wgss/wgss3/wgss3_output_fastqs/TFX2/SPrime_fastqs/WGSS3_TFX2_AZD2906_TechRep2_S13_L001_R3_001_SPrime.fastq.gz
# /data/reddylab/Flowcells/gjohnson/wgss/wgss3/wgss3_output_fastqs/TFX2/SPrime_fastqs/WGSS3_TFX2_AZD2906_TechRep2_S13_L002_R3_001_SPrime.fastq.gz
# /data/reddylab/Flowcells/gjohnson/wgss/wgss3/wgss3_output_fastqs/TFX2/SPrime_fastqs/WGSS3_TFX2_AZD2906_TechRep3_S24_L001_R3_001_SPrime.fastq.gz
# ...

# %%
# %%bash
# cd /data/reddylab/Flowcells/gjohnson/wgss/wgss3/wgss3_output_fastqs/TFX2/SPrime_fastqs
# NAMES=(AZD2906 AZD9567 CORT108297 CpdA Dex DMSO GW870086 Hydrocortisone Mapracorat RU486 ZK216348)
# for NAME in ${NAMES[@]};
# do
# cat WGSS3_TFX2_${NAME}_TechRep1_*_R3_*.gz > /data/reddylab/Revathy/dev/Graham/ENCODE/data/WGSS3_TFX2_${NAME}_TechRep1_R3_SPrime.fastq.gz
# cat WGSS3_TFX2_${NAME}_TechRep2_*_R3_*.gz > /data/reddylab/Revathy/dev/Graham/ENCODE/data/WGSS3_TFX2_${NAME}_TechRep2_R3_SPrime.fastq.gz
# cat WGSS3_TFX2_${NAME}_TechRep3_*_R3_*.gz > /data/reddylab/Revathy/dev/Graham/ENCODE/data/WGSS3_TFX2_${NAME}_TechRep3_R3_SPrime.fastq.gz
# cat WGSS3_TFX2_${NAME}_TechRep4_*_R3_*.gz > /data/reddylab/Revathy/dev/Graham/ENCODE/data/WGSS3_TFX2_${NAME}_TechRep4_R3_SPrime.fastq.gz
# done

# %%
# %%bash
# mkdir -p /data/reddylab/Revathy/dev/Graham/ENCODE/data
# cd /data/reddylab/Flowcells/gjohnson/wgss/wgss3/wgss3_output_fastqs/TFX2/SPrime_fastqs
# cat WGSS3_TFX2_CORT108297_TechRep1_S5_L00{1,2}_R1_001_SPrime.fastq.gz > /data/reddylab/Revathy/dev/Graham/ENCODE/data/WGSS3_TFX2_CORT108297_TechRep1_R1_SPrime.fastq.gz
# cat WGSS3_TFX2_CORT108297_TechRep1_S5_L00{1,2}_R2_001_SPrime.fastq.gz > /data/reddylab/Revathy/dev/Graham/ENCODE/data/WGSS3_TFX2_CORT108297_TechRep1_R2_SPrime.fastq.gz
# cat WGSS3_TFX2_CORT108297_TechRep2_S16_L00{1,2}_R1_001_SPrime.fastq.gz > /data/reddylab/Revathy/dev/Graham/ENCODE/data/WGSS3_TFX2_CORT108297_TechRep2_R1_SPrime.fastq.gz
# cat WGSS3_TFX2_CORT108297_TechRep2_S16_L00{1,2}_R2_001_SPrime.fastq.gz > /data/reddylab/Revathy/dev/Graham/ENCODE/data/WGSS3_TFX2_CORT108297_TechRep2_R2_SPrime.fastq.gz
# cat WGSS3_TFX2_CORT108297_TechRep3_S27_L00{1,2}_R1_001_SPrime.fastq.gz > /data/reddylab/Revathy/dev/Graham/ENCODE/data/WGSS3_TFX2_CORT108297_TechRep3_R1_SPrime.fastq.gz
# cat WGSS3_TFX2_CORT108297_TechRep3_S27_L00{1,2}_R2_001_SPrime.fastq.gz > /data/reddylab/Revathy/dev/Graham/ENCODE/data/WGSS3_TFX2_CORT108297_TechRep3_R2_SPrime.fastq.gz
# cat WGSS3_TFX2_CORT108297_TechRep4_S38_L00{1,2}_R1_001_SPrime.fastq.gz > /data/reddylab/Revathy/dev/Graham/ENCODE/data/WGSS3_TFX2_CORT108297_TechRep4_R1_SPrime.fastq.gz
# cat WGSS3_TFX2_CORT108297_TechRep4_S38_L00{1,2}_R2_001_SPrime.fastq.gz > /data/reddylab/Revathy/dev/Graham/ENCODE/data/WGSS3_TFX2_CORT108297_TechRep4_R2_SPrime.fastq.gz

# %%
# %%bash
# ls /data/reddylab/Revathy/dev/Graham/ENCODE/data/*_R3_*.gz
# Out:
# /data/reddylab/Revathy/dev/Graham/ENCODE/data/WGSS3_TFX2_AZD2906_TechRep1_R3_SPrime.fastq.gz
# /data/reddylab/Revathy/dev/Graham/ENCODE/data/WGSS3_TFX2_AZD2906_TechRep2_R3_SPrime.fastq.gz
# /data/reddylab/Revathy/dev/Graham/ENCODE/data/WGSS3_TFX2_AZD2906_TechRep3_R3_SPrime.fastq.gz
# /data/reddylab/Revathy/dev/Graham/ENCODE/data/WGSS3_TFX2_AZD2906_TechRep4_R3_SPrime.fastq.gz
# /data/reddylab/Revathy/dev/Graham/ENCODE/data/WGSS3_TFX2_AZD9567_TechRep1_R3_SPrime.fastq.gz
# /data/reddylab/Revathy/dev/Graham/ENCODE/data/WGSS3_TFX2_AZD9567_TechRep2_R3_SPrime.fastq.gz
# /data/reddylab/Revathy/dev/Graham/ENCODE/data/WGSS3_TFX2_AZD9567_TechRep3_R3_SPrime.fastq.gz
# /data/reddylab/Revathy/dev/Graham/ENCODE/data/WGSS3_TFX2_AZD9567_TechRep4_R3_SPrime.fastq.gz
# /data/reddylab/Revathy/dev/Graham/ENCODE/data/WGSS3_TFX2_CORT108297_TechRep1_R3_SPrime.fastq.gz
# /data/reddylab/Revathy/dev/Graham/ENCODE/data/WGSS3_TFX2_CORT108297_TechRep2_R3_SPrime.fastq.gz
# ...

# %%
# %%bash
# cd /data/reddylab/Flowcells/gjohnson/wgss/wgss3/wgss3_output_fastqs/TFX2/SPrime_fastqs
# NAMES=(AZD2906 AZD9567 CORT108297 CpdA Dex DMSO GW870086 Hydrocortisone Mapracorat RU486 ZK216348)
#
# for NAME in ${NAMES[@]};
# do
# cat WGSS3_TFX2_${NAME}_TechRep1_S3_L00{1,2}_R1_001_SPrime.fastq.gz > /data/reddylab/Revathy/dev/Graham/ENCODE/data/WGSS3_TFX2_AZD9567_TechRep1_R1_SPrime.fastq.gz
# cat WGSS3_TFX2_${NAME}_TechRep1_S3_L00{1,2}_R2_001_SPrime.fastq.gz > /data/reddylab/Revathy/dev/Graham/ENCODE/data/WGSS3_TFX2_AZD9567_TechRep1_R2_SPrime.fastq.gz
# cat WGSS3_TFX2_${NAME}_TechRep2_S14_L00{1,2}_R1_001_SPrime.fastq.gz > /data/reddylab/Revathy/dev/Graham/ENCODE/data/WGSS3_TFX2_AZD9567_TechRep2_R1_SPrime.fastq.gz
# cat WGSS3_TFX2_${NAME}_TechRep2_S14_L00{1,2}_R2_001_SPrime.fastq.gz > /data/reddylab/Revathy/dev/Graham/ENCODE/data/WGSS3_TFX2_AZD9567_TechRep2_R2_SPrime.fastq.gz
# cat WGSS3_TFX2_${NAME}_TechRep3_S25_L00{1,2}_R1_001_SPrime.fastq.gz > /data/reddylab/Revathy/dev/Graham/ENCODE/data/WGSS3_TFX2_AZD9567_TechRep3_R1_SPrime.fastq.gz
# cat WGSS3_TFX2_${NAME}_TechRep3_S25_L00{1,2}_R2_001_SPrime.fastq.gz > /data/reddylab/Revathy/dev/Graham/ENCODE/data/WGSS3_TFX2_AZD9567_TechRep3_R2_SPrime.fastq.gz
# cat WGSS3_TFX2_${NAME}_TechRep4_S36_L00{1,2}_R1_001_SPrime.fastq.gz > /data/reddylab/Revathy/dev/Graham/ENCODE/data/WGSS3_TFX2_AZD9567_TechRep4_R1_SPrime.fastq.gz
# cat WGSS3_TFX2_${NAME}_TechRep4_S36_L00{1,2}_R2_001_SPrime.fastq.gz > /data/reddylab/Revathy/dev/Graham/ENCODE/data/WGSS3_TFX2_AZD9567_TechRep4_R2_SPrime.fastq.gza/WGSS3_TFX2_${NAME}_TechRep1_R1_SPrime.fastq.gz
# Out:
# Johnson_6506_200909A6.checksum
# README.rtf
# Undetermined_S0_L001_I1_001_SPrime.fastq.gz
# Undetermined_S0_L001_R1_001_SPrime.fastq.gz
# Undetermined_S0_L001_R2_001_SPrime.fastq.gz
# Undetermined_S0_L001_R3_001_SPrime.fastq.gz
# Undetermined_S0_L002_I1_001_SPrime.fastq.gz
# Undetermined_S0_L002_R1_001_SPrime.fastq.gz
# Undetermined_S0_L002_R2_001_SPrime.fastq.gz
# Undetermined_S0_L002_R3_001_SPrime.fastq.gz
# WGSS3_TFX2_AZD2906_TechRep1_S2_L001_I1_001_SPrime.fastq.gz
# WGSS3_TFX2_AZD2906_TechRep1_S2_L001_R1_001_SPrime.fastq.gz
# WGSS3_TFX2_AZD2906_TechRep1_S2_L001_R2_001_SPrime.fastq.gz
# WGSS3_TFX2_AZD2906_TechRep1_S2_L001_R3_001_SPrime.fastq.gz
# WGSS3_TFX2_AZD2906_TechRep1_S2_L002_I1_001_SPrime.fastq.gz
# WGSS3_TFX2_AZD2906_TechRep1_S2_L002_R1_001_SPrime.fastq.gz
# WGSS3_TFX2_AZD2906_TechRep1_S2_L002_R2_001_SPrime.fastq.gz
# WGSS3_TFX2_AZD2906_TechRep1_S2_L002_R3_001_SPrime.fastq.gz
# WGSS3_TFX2_AZD2906_TechRep2_S13_L001_I1_001_SPrime.fastq.gz
# ...

# %%
# %%bash
# ls /data/reddylab/Revathy/dev/Graham/ENCODE/data/Novaseq/processed/*_R2_*
# Out:
# /data/reddylab/Revathy/dev/Graham/ENCODE/data/Novaseq/processed/TFX2_AZD2906_TechRep1_R2_NovaSeq.fastq.gz
# /data/reddylab/Revathy/dev/Graham/ENCODE/data/Novaseq/processed/TFX2_AZD2906_TechRep2_R2_NovaSeq.fastq.gz
# /data/reddylab/Revathy/dev/Graham/ENCODE/data/Novaseq/processed/TFX2_AZD2906_TechRep3_R2_NovaSeq.fastq.gz
# /data/reddylab/Revathy/dev/Graham/ENCODE/data/Novaseq/processed/TFX2_AZD2906_TechRep4_R2_NovaSeq.fastq.gz
# /data/reddylab/Revathy/dev/Graham/ENCODE/data/Novaseq/processed/TFX2_AZD9567_TechRep1_R2_NovaSeq.fastq.gz
# /data/reddylab/Revathy/dev/Graham/ENCODE/data/Novaseq/processed/TFX2_AZD9567_TechRep2_R2_NovaSeq.fastq.gz
# /data/reddylab/Revathy/dev/Graham/ENCODE/data/Novaseq/processed/TFX2_AZD9567_TechRep3_R2_NovaSeq.fastq.gz
# /data/reddylab/Revathy/dev/Graham/ENCODE/data/Novaseq/processed/TFX2_AZD9567_TechRep4_R2_NovaSeq.fastq.gz
# /data/reddylab/Revathy/dev/Graham/ENCODE/data/Novaseq/processed/TFX2_CORT108297_TechRep1_R2_NovaSeq.fastq.gz
# ...

# %%
# %%bash
# mkdir -p /data/reddylab/Revathy/dev/Graham/ENCODE/data/peaks
# cd /data/reddylab/gjohnson/whole_genome_STARRseq/wgss3/peak_calls/macs/bio_rep_peak_sets/
# files=$(ls *.gz)
# for file in ${files[@]};
# do
# zcat ${file} | awk 'BEGIN{OFS=FS}$5>1000{$5=1000}{print}' > /data/reddylab/Revathy/dev/Graham/ENCODE/data/peaks/${file/.gz}
# done

# %%
# %%bash
# cd /data/reddylab/Revathy/dev/Graham/ENCODE/data/peaks
# files=$(ls *.narrowPeak)
# for file in ${files[@]};
# do
# gzip -c ${file} > /data/reddylab/Revathy/dev/Graham/ENCODE/data/peaks/${file}.gz
# done

# %%
# %%bash
# ls /data/reddylab/Revathy/dev/Graham/ENCODE/data/peaks/*.gz
# Out:
# /data/reddylab/Revathy/dev/Graham/ENCODE/data/peaks/TFX2_AZD2906_peaks.narrowPeak.gz
# /data/reddylab/Revathy/dev/Graham/ENCODE/data/peaks/TFX2_AZD9567_peaks.narrowPeak.gz
# /data/reddylab/Revathy/dev/Graham/ENCODE/data/peaks/TFX2_CORT108297_peaks.narrowPeak.gz
# /data/reddylab/Revathy/dev/Graham/ENCODE/data/peaks/TFX2_CpdA_peaks.narrowPeak.gz
# /data/reddylab/Revathy/dev/Graham/ENCODE/data/peaks/TFX2_Dex_peaks.narrowPeak.gz
# /data/reddylab/Revathy/dev/Graham/ENCODE/data/peaks/TFX2_DMSO_peaks.narrowPeak.gz
# /data/reddylab/Revathy/dev/Graham/ENCODE/data/peaks/TFX2_GW870086_peaks.narrowPeak.gz
# /data/reddylab/Revathy/dev/Graham/ENCODE/data/peaks/TFX2_Hydrocortisone_peaks.narrowPeak.gz
# /data/reddylab/Revathy/dev/Graham/ENCODE/data/peaks/TFX2_Mapracorat_peaks.narrowPeak.gz
# /data/reddylab/Revathy/dev/Graham/ENCODE/data/peaks/TFX2_RU486_peaks.narrowPeak.gz
# /data/reddylab/Revathy/dev/Graham/ENCODE/data/peaks/TFX2_ZK216348_peaks.narrowPeak.gz
# ...

# %%
import pandas as pd
patched_bams = pd.read_csv('/data/reddylab/Revathy/dev/Graham/ENCODE/metadata/patched_bams.txt', sep='\t')
patched_bams = patched_bams.dropna(axis=1)
patched_bams.to_csv('/data/reddylab/Revathy/dev/Graham/ENCODE/metadata/patched_bams.txt', sep='\t', index=False)

# %%
patched_bams
# Out:
#       record_id                                       derived_from
# 0   ENCFF703FRQ  tim-reddy:A549-wg-starrseq-AZD2906-brep1-trep1...
# 1   ENCFF366AQO  tim-reddy:A549-wg-starrseq-AZD2906-brep1-trep2...
# 2   ENCFF233VEO  tim-reddy:A549-wg-starrseq-AZD2906-brep1-trep3...
# 3   ENCFF787KFF  tim-reddy:A549-wg-starrseq-AZD2906-brep1-trep4...
# 4   ENCFF643MKA  tim-reddy:A549-wg-starrseq-AZD9567-brep1-trep1...
# 5   ENCFF082MJX  tim-reddy:A549-wg-starrseq-AZD9567-brep1-trep2...
# 6   ENCFF886PZA  tim-reddy:A549-wg-starrseq-AZD9567-brep1-trep3...
# 7   ENCFF072KVA  tim-reddy:A549-wg-starrseq-AZD9567-brep1-trep4...
# 8   ENCFF930POD  tim-reddy:A549-wg-starrseq-CORT108297-brep1-tr...
# 9   ENCFF754KAO  tim-reddy:A549-wg-starrseq-CORT108297-brep1-tr...
# 10  ENCFF890BNS  tim-reddy:A549-wg-starrseq-CORT108297-brep1-tr...
# 11  ENCFF679ILI  tim-reddy:A549-wg-starrseq-CORT108297-brep1-tr...
# 12  ENCFF240JGX  tim-reddy:A549-wg-starrseq-CpdA-brep1-trep1-sh...
# ...

# %%
# !head /data/reddylab/Revathy/dev/Graham/ENCODE/metadata/patched_bams.tsv
# Out:
# record_id	derived_from
# ENCFF703FRQ	tim-reddy:A549-wg-starrseq-AZD2906-brep1-trep1-short-read1, tim-reddy:A549-wg-starrseq-AZD2906-brep1-trep1-short-read2
# ENCFF366AQO	tim-reddy:A549-wg-starrseq-AZD2906-brep1-trep2-short-read1, tim-reddy:A549-wg-starrseq-AZD2906-brep1-trep2-short-read2
# ENCFF233VEO	tim-reddy:A549-wg-starrseq-AZD2906-brep1-trep3-short-read1, tim-reddy:A549-wg-starrseq-AZD2906-brep1-trep3-short-read2
# ENCFF787KFF	tim-reddy:A549-wg-starrseq-AZD2906-brep1-trep4-short-read1, tim-reddy:A549-wg-starrseq-AZD2906-brep1-trep4-short-read2
# ENCFF643MKA	tim-reddy:A549-wg-starrseq-AZD9567-brep1-trep1-short-read1, tim-reddy:A549-wg-starrseq-AZD9567-brep1-trep1-short-read2
# ENCFF082MJX	tim-reddy:A549-wg-starrseq-AZD9567-brep1-trep2-short-read1, tim-reddy:A549-wg-starrseq-AZD9567-brep1-trep2-short-read2
# ENCFF886PZA	tim-reddy:A549-wg-starrseq-AZD9567-brep1-trep3-short-read1, tim-reddy:A549-wg-starrseq-AZD9567-brep1-trep3-short-read2
# ...

# %% [markdown]
# #### Create bigBeds from narrowPeaks

# %%
# %%bash
# cd /data/reddylab/Revathy/collabs/Graham/ENCODE/data/peaks/
# for file in $(/bin/ls *.narrowPeak);
# do
# /data/reddylab/software/bin/bedToBigBed \
# -type=bed6+5 \
# -as=/data/reddylab/software/encValData/as/narrowPeak.as \
# /data/reddylab/Revathy/collabs/Graham/ENCODE/data/peaks/${file} \
# /data/reddylab/Reference_Data/Genomes/hg38/GCA_000001405.15_GRCh38_no_alt_analysis_set.sizes \
# /data/reddylab/Revathy/collabs/Graham/ENCODE/data/bigBeds/${file/.narrowPeak/.bigBed}
# done
# Out:
# pass1 - making usageList (24 chroms): 69 millis
# pass2 - checking and writing primary data (92365 records, 10 fields): 494 millis
# pass1 - making usageList (24 chroms): 56 millis
# pass2 - checking and writing primary data (89251 records, 10 fields): 389 millis
# pass1 - making usageList (24 chroms): 56 millis
# pass2 - checking and writing primary data (90819 records, 10 fields): 406 millis
# pass1 - making usageList (24 chroms): 47 millis
# pass2 - checking and writing primary data (94101 records, 10 fields): 409 millis
# pass1 - making usageList (24 chroms): 67 millis
# pass2 - checking and writing primary data (94433 records, 10 fields): 406 millis
# pass1 - making usageList (24 chroms): 47 millis
# pass2 - checking and writing primary data (87398 records, 10 fields): 377 millis
# pass1 - making usageList (24 chroms): 57 millis
# pass2 - checking and writing primary data (98387 records, 10 fields): 428 millis
# pass1 - making usageList (24 chroms): 68 millis
# ...

# %% [markdown]
# #### Gzip bigBeds

# %%
# %%bash
# cd /data/reddylab/Revathy/collabs/Graham/ENCODE/data/bigBeds
# files=$(ls *.bigBed)
# for file in ${files[@]};
# do
# gzip -c ${file} > /data/reddylab/Revathy/collabs/Graham/ENCODE/data/bigBeds/${file}.gz
# done

# %%
ls /data/reddylab/Revathy/collabs/Graham/ENCODE/data/bigBeds/*.gz
# Out:
# /data/reddylab/Revathy/collabs/Graham/ENCODE/data/bigBeds/TFX2_AZD2906_peaks.bigBed.gz
# /data/reddylab/Revathy/collabs/Graham/ENCODE/data/bigBeds/TFX2_AZD9567_peaks.bigBed.gz
# /data/reddylab/Revathy/collabs/Graham/ENCODE/data/bigBeds/TFX2_CORT108297_peaks.bigBed.gz
# /data/reddylab/Revathy/collabs/Graham/ENCODE/data/bigBeds/TFX2_CpdA_peaks.bigBed.gz
# /data/reddylab/Revathy/collabs/Graham/ENCODE/data/bigBeds/TFX2_Dex_peaks.bigBed.gz
# /data/reddylab/Revathy/collabs/Graham/ENCODE/data/bigBeds/TFX2_DMSO_peaks.bigBed.gz
# /data/reddylab/Revathy/collabs/Graham/ENCODE/data/bigBeds/TFX2_GW870086_peaks.bigBed.gz
# /data/reddylab/Revathy/collabs/Graham/ENCODE/data/bigBeds/TFX2_Hydrocortisone_peaks.bigBed.gz
# /data/reddylab/Revathy/collabs/Graham/ENCODE/data/bigBeds/TFX2_Mapracorat_peaks.bigBed.gz
# /data/reddylab/Revathy/collabs/Graham/ENCODE/data/bigBeds/TFX2_RU486_peaks.bigBed.gz
# /data/reddylab/Revathy/collabs/Graham/ENCODE/data/bigBeds/TFX2_ZK216348_peaks.bigBed.gz
# ...

# %% [markdown]
# ## patching software to data

# %%
import encode_utils as eu
from encode_utils.connection import Connection

conn = Connection("prod")
# Out:
# 2021-06-07 12:03:07,722:eu_debug:	Connecting to www.encodeproject.org
# 2021-06-07 12:03:07,728:eu_debug:	submission=False: In non-submission mode.

# %%
conn.get('ENCFF661ZEU')
# Out:
# 2021-06-02 13:45:16,509:eu_debug:	>>>>>>GET ENCFF661ZEU From DCC with URL https://www.encodeproject.org/ENCFF661ZEU/?format=json
# {'@context': '/terms/',
#  '@id': '/files/ENCFF661ZEU/',
#  '@type': ['File', 'Item'],
#  'accession': 'ENCFF661ZEU',
#  'actions': [{'href': '/files/ENCFF661ZEU/#!edit',
#    'name': 'edit',
#    'profile': '/profiles/File.json',
#    'title': 'Edit'},
#   {'href': '/files/ENCFF661ZEU/#!edit-json',
#    'name': 'edit-json',
#    'profile': '/profiles/File.json',
#    'title': 'Edit JSON'}],
#  'aliases': ['tim-reddy:A549-wg-starrseq-AZD2906-brep2-merged-bam'],
#  'alternate_accessions': [],
#  'analyses': [],
#  'assay_term_name': 'STARR-seq',
#  'assay_title': 'STARR-seq',
#  'assembly': 'GRCh38',
#  'audit': {'WARNING': [{'category': 'missing analysis_step_run',
#     'detail': 'Missing analysis_step_run information in file {ENCFF661ZEU|/files/ENCFF661ZEU/}.',
#     'level': 40,
#     'level_name': 'WARNING',
#     'name': 'audit_file',
# ...

# %%
import pandas as pd
import csv
narrow = pd.read_csv('/data/reddylab/Revathy/collabs/Graham/ENCODE/metadata/patch_narrowPeak.txt', sep='\t')
narrow.to_csv('/data/reddylab/Revathy/collabs/Graham/ENCODE/metadata/patch_narrowPeak_corrected.txt', sep='\t', quoting=csv.QUOTE_NONE, index=None)

# %%
# %%bash
# source /data/reddylab/software/miniconda3/bin/activate revathy_py3
# cd /data/reddylab/Revathy/collabs/Graham/ENCODE/metadata
# eu_register.py -m prod -p file -i patch_narrowPeak_bledit.txt --patch -w
# Out:
# 2021-06-07 15:10:32,108:eu_debug:	Connecting to www.encodeproject.org
# 2021-06-07 15:10:32,108:eu_debug:	submission=False: In non-submission mode.
# 2021-06-07 15:10:32,751:eu_debug:	submission=True: In submission mode.
# 2021-06-07 15:10:32,764:eu_debug:
# IN patch()
# 2021-06-07 15:10:32,765:eu_debug:	>>>>>>GET files/ENCFF002QHW From DCC with URL https://www.encodeproject.org/files/ENCFF002QHW/?format=json&datastore=database&frame=edit
# 2021-06-07 15:10:33,100:eu_debug:	<<<<<< PATCHING /files/ENCFF002QHW/ To DCC with URL https://www.encodeproject.org/files/ENCFF002QHW and this payload:
#
# {
#   "derived_from": [
#     "tim-reddy:wg-starr-a549-exclusion-list",
#     "tim-reddy:A549-wg-starrseq-input-trep2-bam",
#     "tim-reddy:A549-wg-starrseq-AZD2906-brep1-merged-bam"
#   ]
# }
#
#
# 2021-06-07 15:10:33,571:eu_debug:	Success.
# 2021-06-07 15:10:33,572:eu_debug:
# IN patch()
# ...

# %%
# %%bash
# source /data/reddylab/software/miniconda3/bin/activate revathy_py3
# cd /data/reddylab/Revathy/collabs/Graham/ENCODE/metadata

# %%
# %%bash
# eu_register.py --help
# Out:
# usage: eu_register.py [-h] [-m DCC_MODE] [-d] [--no-aliases] -p PROFILE_ID -i
#                       INFILE [--patch] [-w]
#
# Given a tab-delimited or JSON input file containing one or more records belonging to one of the profiles
# listed on the ENCODE Portal (such as https://www.encodeproject.org/profiles/biosample.json),
# either POSTS or PATCHES the records. The default is to POST each record; to PATCH instead, see
# the ``--patch`` option.
#
# When POSTING file records, the md5sum of each file will be calculated for you if you haven't
# already provided the `md5sum` property. Then, after the POST operation completes, the actual file
# will be uploaded to AWS S3. In order for this to work, you must set the `submitted_file_name`
# property to the full, local path to your file to upload. Alternatively, you can set
# `submitted_file_name` to and existing S3 object, i.e. s3://mybucket/reads.fastq.
#
# ...

# %%
import pandas as pd
import csv
bigbed = pd.read_csv('/data/reddylab/Revathy/collabs/Graham/ENCODE/metadata/Reddy-DCC-data-wgSTARRseq-Graham-bigBed.txt', sep='\t')
bigbed.to_csv('/data/reddylab/Revathy/collabs/Graham/ENCODE/metadata/Reddy-DCC-data-wgSTARRseq-Graham-bigBed-corrected.txt', sep='\t', quoting=csv.QUOTE_NONE, index=None)

# %%
# !cat /data/reddylab/Revathy/collabs/Graham/ENCODE/metadata/Reddy-DCC-data-wgSTARRseq-Graham-bigBed-corrected.txt
# Out:
# dataset	file_format	file_format_type	output_type	submitted_file_name	award	lab	aliases	assembly	derived_from
# tim-reddy:A549-wg-starrseq-AZD2906	bigBed	narrowPeak	candidate Cis-Regulatory Elements	/data/reddylab/Revathy/collabs/Graham/ENCODE/data/bigBeds/TFX2_AZD2906_peaks.bigBed	/awards/UM1HG009428/	/labs/tim-reddy/	tim-reddy:A549-wg-starrseq-AZD2906-brep1-bigBed	GRCh38	/files/GRCh38_no_alt_analysis_set_GCA_000001405.15/,tim-reddy:A549-wg-starrseq-AZD2906-brep1-narrowpeak
# tim-reddy:A549-wg-starrseq-AZD9567	bigBed	narrowPeak	candidate Cis-Regulatory Elements	/data/reddylab/Revathy/collabs/Graham/ENCODE/data/bigBeds/TFX2_AZD9567_peaks.bigBed	/awards/UM1HG009428/	/labs/tim-reddy/	tim-reddy:A549-wg-starrseq-AZD9567-brep1-bigBed	GRCh38	/files/GRCh38_no_alt_analysis_set_GCA_000001405.15/,tim-reddy:A549-wg-starrseq-AZD9567-brep1-narrowpeak
# ...

# %%
# !head /data/reddylab/Revathy/collabs/Graham/ENCODE/data/bigBeds/TFX2_DMSO_peaks.bigBed
# Out:
# head: cannot open ‘/data/reddylab/Revathy/collabs/Graham/ENCODE/data/bigBeds/TFX2_DMSO_peaks.bigBed’ for reading: No such file or directory

# %%
# %%bash
# source /data/reddylab/software/miniconda3/bin/activate revathy_py3
# cd /data/reddylab/Revathy/collabs/Graham/ENCODE/metadata
# eu_register.py -m prod -p file -i Reddy-DCC-data-wgSTARRseq-Graham-bigBed-corrected.txt
# Out:
# 2021-06-04 10:57:48,769:eu_debug:	Connecting to www.encodeproject.org
# 2021-06-04 10:57:48,769:eu_debug:	submission=False: In non-submission mode.
# 2021-06-04 10:57:49,500:eu_debug:	submission=True: In submission mode.
# 2021-06-04 10:57:49,506:eu_debug:
# IN post().
# 2021-06-04 10:57:49,524:eu_debug:	<<<<<< POST file record tim-reddy:A549-wg-starrseq-AZD2906-brep1-bigBed To DCC with URL https://www.encodeproject.org/file and this payload:
#
# {
#   "aliases": [
#     "tim-reddy:A549-wg-starrseq-AZD2906-brep1-bigBed"
#   ],
#   "assembly": "GRCh38",
#   "award": "/awards/UM1HG009428/",
#   "dataset": "tim-reddy:A549-wg-starrseq-AZD2906",
#   "derived_from": [
#     "/files/GRCh38_no_alt_analysis_set_GCA_000001405.15/",
#     "tim-reddy:A549-wg-starrseq-AZD2906-brep1-narrowpeak"
#   ],
#   "file_format": "bigBed",
#   "file_format_type": "narrowPeak",
#   "file_size": 5160008,
#   "lab": "/labs/tim-reddy/",
#   "md5sum": "a0cbd3af331d0c50731fcf4b338b482e",
# ...

# %% [markdown]
# ### patch analysis step_run and change output types

# %% [markdown]
# ##### patch the narrowPeaks and bigBeds to the appropriate step runs; correct the output_type to "element quantifications" for both of them

# %%
import pandas as pd

beds = pd.read_excel('/data/reddylab/Revathy/collabs/Graham/ENCODE/metadata/bed_step_run.xlsx')
beds.to_csv('/data/reddylab/Revathy/collabs/Graham/ENCODE/metadata/bed_step_run.txt', sep='\t', index=False)

# %%
# %%bash
# source /data/reddylab/software/miniconda3/bin/activate revathy_py3
# cd /data/reddylab/Revathy/collabs/Graham/ENCODE/metadata
# eu_register.py -m prod -p file -i bed_step_run.txt --patch -w
# Out:
# 2021-06-07 17:38:05,905:eu_debug:	Connecting to www.encodeproject.org
# 2021-06-07 17:38:05,906:eu_debug:	submission=False: In non-submission mode.
# 2021-06-07 17:38:07,050:eu_debug:	submission=True: In submission mode.
# 2021-06-07 17:38:07,057:eu_debug:
# IN patch()
# 2021-06-07 17:38:07,057:eu_debug:	>>>>>>GET files/ENCFF532WMK From DCC with URL https://www.encodeproject.org/files/ENCFF532WMK/?format=json&datastore=database&frame=edit
# 2021-06-07 17:38:07,421:eu_debug:	<<<<<< PATCHING /files/ENCFF532WMK/ To DCC with URL https://www.encodeproject.org/files/ENCFF532WMK and this payload:
#
# {
#   "output_type": "element quantifications",
#   "step_run": "tim-reddy:starrseq_bam_to_bed_macs_v2.1.0.20151222_step_run"
# }
#
#
# 2021-06-07 17:38:07,896:eu_debug:	Success.
# 2021-06-07 17:38:07,896:eu_debug:
# IN patch()
# ...

# %% [markdown]
# ##### patch the bams for the individual technical replicates to the associated step_run
# For the merged bam file, still waiting on confirmation as to how to go about with that in including them in the schema

# %%
import pandas as pd

bam = pd.read_excel('/data/reddylab/Revathy/collabs/Graham/ENCODE/metadata/bam_step_run.xlsx')
bam.to_csv('/data/reddylab/Revathy/collabs/Graham/ENCODE/metadata/bam_step_run.txt', sep='\t', index=False)

# %%
# %%bash
# source /data/reddylab/software/miniconda3/bin/activate revathy_py3
# cd /data/reddylab/Revathy/collabs/Graham/ENCODE/metadata
# eu_register.py -m prod -p file -i bam_step_run.txt --patch
# Out:
# 2021-06-07 18:02:45,110:eu_debug:	Connecting to www.encodeproject.org
# 2021-06-07 18:02:45,111:eu_debug:	submission=False: In non-submission mode.
# 2021-06-07 18:02:46,478:eu_debug:	submission=True: In submission mode.
# 2021-06-07 18:02:46,484:eu_debug:
# IN patch()
# 2021-06-07 18:02:46,484:eu_debug:	>>>>>>GET files/ENCFF703FRQ From DCC with URL https://www.encodeproject.org/files/ENCFF703FRQ/?format=json&datastore=database&frame=edit
# 2021-06-07 18:02:46,818:eu_debug:	<<<<<< PATCHING /files/ENCFF703FRQ/ To DCC with URL https://www.encodeproject.org/files/ENCFF703FRQ and this payload:
#
# {
#   "step_run": "tim-reddy:starrseq_fastq_to_bam_no_umi_step_run"
# }
#
#
# 2021-06-07 18:02:47,275:eu_debug:	Success.
# 2021-06-07 18:02:47,276:eu_debug:
# IN patch()
# 2021-06-07 18:02:47,276:eu_debug:	>>>>>>GET files/ENCFF366AQO From DCC with URL https://www.encodeproject.org/files/ENCFF366AQO/?format=json&datastore=database&frame=edit
# ...

# %% [markdown]
# #### patch the corrected derived_from to the narrowpeaks

# %%
# %%bash
# source /data/reddylab/software/miniconda3/bin/activate revathy_py3
# cd /data/reddylab/Revathy/collabs/Graham/ENCODE/metadata
# eu_register.py -m prod -p file -i patch_narrowPeak_corrected.txt --patch -w
# Out:
# 2021-06-09 15:52:10,813:eu_debug:	Connecting to www.encodeproject.org
# 2021-06-09 15:52:10,876:eu_debug:	submission=False: In non-submission mode.
# 2021-06-09 15:52:11,515:eu_debug:	submission=True: In submission mode.
# 2021-06-09 15:52:11,536:eu_debug:
# IN patch()
# 2021-06-09 15:52:11,536:eu_debug:	>>>>>>GET files/ENCFF215TWQ From DCC with URL https://www.encodeproject.org/files/ENCFF215TWQ/?format=json&datastore=database&frame=edit
# 2021-06-09 15:52:11,894:eu_debug:	<<<<<< PATCHING /files/ENCFF215TWQ/ To DCC with URL https://www.encodeproject.org/files/ENCFF215TWQ and this payload:
#
# {
#   "derived_from": [
#     "tim-reddy:A549-wg-starrseq-input-trep2-bam",
#     "tim-reddy:wg-starr-a549-exclusion-list",
#     "tim-reddy:A549-wg-starrseq-AZD2906-brep1-merged-bam"
#   ]
# }
#
#
# 2021-06-09 15:52:12,413:eu_debug:	Success.
# 2021-06-09 15:52:12,414:eu_debug:
# IN patch()
# ...

# %% [markdown]
# #### upload the bigWigs to the data

# %%
# %%bash
# source /data/reddylab/software/miniconda3/bin/activate revathy_py3
# cd /data/reddylab/Revathy/collabs/Graham/ENCODE/metadata
# eu_register.py -m prod -p file -i bigWigs.txt
# Out:
# 2021-09-22 12:16:36,420:eu_debug:	Connecting to www.encodeproject.org
# 2021-09-22 12:16:36,449:eu_debug:	submission=False: In non-submission mode.
# 2021-09-22 12:16:37,106:eu_debug:	submission=True: In submission mode.
# 2021-09-22 12:16:37,130:eu_debug:
# IN post().
# 2021-09-22 12:16:43,789:eu_debug:	<<<<<< POST file record tim-reddy:A549-wg-starrseq-input-trep1-bw To DCC with URL https://www.encodeproject.org/file and this payload:
#
# {
#   "aliases": [
#     "tim-reddy:A549-wg-starrseq-input-trep1-bw"
#   ],
#   "assembly": "GRCh38",
#   "award": "/awards/UM1HG009428/",
#   "dataset": "tim-reddy:A549-wg-starrseq-input",
#   "derived_from": [
#     "tim-reddy:A549-wg-starrseq-input-trep1-bam"
#   ],
#   "file_format": "bigWig",
#   "file_size": 2431360226,
#   "lab": "/labs/tim-reddy/",
#   "md5sum": "db5c39c342c73b980bbc69eb990422f0",
#   "output_type": "signal of unique reads",
# ...

# %%
# %%bash
# source /data/reddylab/software/miniconda3/bin/activate revathy_py3
# cd /data/reddylab/Revathy/collabs/Graham/ENCODE/metadata
# eu_register.py -m prod -p file -i bigWigs_v1.txt
# Out:
# 2021-09-22 13:16:54,317:eu_debug:	Connecting to www.encodeproject.org
# 2021-09-22 13:16:54,359:eu_debug:	submission=False: In non-submission mode.
# 2021-09-22 13:16:54,964:eu_debug:	submission=True: In submission mode.
# 2021-09-22 13:16:54,971:eu_debug:
# IN post().
# 2021-09-22 13:16:55,816:eu_debug:	<<<<<< POST file record tim-reddy:A549-wg-starrseq-ZK216348-brep1-bw To DCC with URL https://www.encodeproject.org/file and this payload:
#
# {
#   "aliases": [
#     "tim-reddy:A549-wg-starrseq-ZK216348-brep1-bw"
#   ],
#   "assembly": "GRCh38",
#   "award": "/awards/UM1HG009428/",
#   "dataset": "tim-reddy:A549-wg-starrseq-ZK216348",
#   "derived_from": [
#     "tim-reddy:A549-wg-starrseq-ZK216348-brep1-bam"
#   ],
#   "file_format": "bigWig",
#   "file_size": 280378452,
#   "lab": "/labs/tim-reddy/",
#   "md5sum": "b355dc21cb6a89d44f386026d551babd",
#   "output_type": "signal of unique reads",
# ...

# %% [markdown]
# ### patch analysis_step_run to bigWig

# %%
# %%bash
# source /data/reddylab/software/miniconda3/bin/activate revathy_py3
# cd /data/reddylab/Revathy/collabs/Graham/ENCODE/metadata
# eu_register.py -m prod -p file -i bigWig_step_run.txt --patch
# Out:
# 2021-09-22 19:00:06,266:eu_debug:	Connecting to www.encodeproject.org
# 2021-09-22 19:00:06,289:eu_debug:	submission=False: In non-submission mode.
# 2021-09-22 19:00:06,969:eu_debug:	submission=True: In submission mode.
# 2021-09-22 19:00:06,975:eu_debug:
# IN patch()
# 2021-09-22 19:00:06,975:eu_debug:	>>>>>>GET files/ENCFF425CZV From DCC with URL https://www.encodeproject.org/files/ENCFF425CZV/?format=json&datastore=database&frame=edit
# 2021-09-22 19:00:07,306:eu_debug:	<<<<<< PATCHING /files/ENCFF425CZV/ To DCC with URL https://www.encodeproject.org/files/ENCFF425CZV and this payload:
#
# {
#   "step_run": "tim-reddy:starrseq_bam_to_bigwig_deeptools_step_run"
# }
#
#
# 2021-09-22 19:00:08,004:eu_debug:	Success.
# 2021-09-22 19:00:08,005:eu_debug:
# IN patch()
# 2021-09-22 19:00:08,005:eu_debug:	>>>>>>GET files/ENCFF477HYY From DCC with URL https://www.encodeproject.org/files/ENCFF477HYY/?format=json&datastore=database&frame=edit
# ...

# %% [markdown]
# ### submit CRADLE peaks

# %%
# %%bash
# source /data/reddylab/software/miniconda3/bin/activate revathy_py3
# cd /data/reddylab/Revathy/collabs/Graham/ENCODE/metadata
# eu_register.py -m prod -p file -i Reddy-DCC-data-wgSTARRseq-Graham-files-CRADLE-bed-v1.txt
# Out:
# 2023-04-21 18:44:31,294:eu_debug:	Connecting to www.encodeproject.org
# 2023-04-21 18:44:31,338:eu_debug:	submission=False: In non-submission mode.
# 2023-04-21 18:44:31,983:eu_debug:	submission=True: In submission mode.
# 2023-04-21 18:44:31,988:eu_debug:
# IN post().
# 2023-04-21 18:44:32,030:eu_debug:	<<<<<< POST file record tim-reddy:A549-wg-starrseq-AZD2906-cradlePeak-bed To DCC with URL https://www.encodeproject.org/file and this payload:
#
# {
#   "aliases": [
#     "tim-reddy:A549-wg-starrseq-AZD2906-cradlePeak-bed"
#   ],
#   "assembly": "GRCh38",
#   "award": "/awards/UM1HG009428/",
#   "dataset": "tim-reddy:A549-wg-starrseq-AZD2906",
#   "derived_from": [
#     "tim-reddy:A549-wg-starrseq-AZD2906-brep1-bw",
#     "tim-reddy:A549-wg-starrseq-AZD2906-brep2-bw",
#     "tim-reddy:A549-wg-starrseq-AZD2906-brep3-bw",
#     "tim-reddy:A549-wg-starrseq-AZD2906-brep4-bw",
#     "tim-reddy:A549-wg-starrseq-input-trep1-bw",
#     "tim-reddy:A549-wg-starrseq-input-trep2-bw",
# ...

# %%
# %%bash
# mkdir -p /data/reddylab/Revathy/collabs/Graham/ENCODE/data/CRADLE_peaks
# treatments=(\ AZD2906 \
#               AZD9567 \
#               CORT108297 \
#               CpdA \
#               Dex \
#               DMSO \
#               GW870086 \
#               Hydrocortisone \
#               Mapracorat \
#               RU486 \
#               ZK216348)
#
# for treatment in ${treatments[@]};
# do
# cat /data/reddylab/gjohnson/STARRseq_projects/GR_agonists_study/peak_calls/cradle/callPeak/${treatment}_vs_input/CRADLE_peaks \
# | tail -n+2 \
# | awk -vOFS="\t" '{print $1, $2, $3, $4, '100',$6, $7, $8, $9, $10, $11}' \
# > /data/reddylab/Revathy/collabs/Graham/ENCODE/data/CRADLE_peaks/${treatment}_vs_input.CRADLE_peaks.bed
# done

# %%
# !ls /data/reddylab/gjohnson/STARRseq_projects/GR_agonists_study/peak_calls/cradle/callPeak/AZD2906_vs_input
# Out:
# AZD2906_active_peaks.bed
# AZD2906_active_peaks_fc2_annotation.pdf
# AZD2906_active_peaks_fc2_annotation.txt?FALSE
# AZD2906_active_peaks_fc2.bed
# AZD2906_active_peaks_fc2.fa
# AZD2906_peak_characterization.pdf
# AZD2906_peak_cohenD_by_type.csv
# AZD2906_peak_cohenD_summary.txt
# AZD2906_peak_FCs_by_type.csv
# AZD2906_peak_FCs_summary.txt
# AZD2906_peak_lengths_by_type.csv
# AZD2906_peak_lengths_summary.txt
# AZD2906_peak_negLog10FDR_by_type.csv
# AZD2906_peak_negLog10FDR_summary.txt
# AZD2906_repressed_peaks.bed
# AZD2906_repressed_peaks_fc2.bed
# CRADLE_peaks

# %%
# %%bash
# cat /data/reddylab/gjohnson/STARRseq_projects/GR_agonists_study/peak_calls/cradle/callPeak/AZD2906_vs_input/CRADLE_peaks \
# | tail -n+2 | awk '{print $1, $2, $3, $4, '100'}' | head
# Out:
# chr1 854737 855629 chr1:854737-855629 100
# chr1 877407 878170 chr1:877407-878170 100
# chr1 902162 902488 chr1:902162-902488 100
# chr1 905388 905788 chr1:905388-905788 100
# chr1 915574 916224 chr1:915574-916224 100
# chr1 919398 919698 chr1:919398-919698 100
# chr1 921160 922622 chr1:921160-922622 100
# chr1 926315 927062 chr1:926315-927062 100
# chr1 927374 928136 chr1:927374-928136 100
# chr1 929910 930722 chr1:929910-930722 100

# %%
# %%bash
# treatments=(\ AZD2906 \
#               AZD9567 \
#               CORT108297 \
#               CpdA \
#               Dex \
#               DMSO \
#               GW870086 \
#               Hydrocortisone \
#               Mapracorat \
#               RU486 \
#               ZK216348)
#
# for treatment in ${treatments[@]};
# do
# gzip -c /data/reddylab/Revathy/collabs/Graham/ENCODE/data/CRADLE_peaks/${treatment}_vs_input.CRADLE_peaks.bed \
# > /data/reddylab/Revathy/collabs/Graham/ENCODE/data/CRADLE_peaks/${treatment}_vs_input.CRADLE_peaks.bed.gz
# done

# %%
# !ls /data/reddylab/Revathy/collabs/Graham/ENCODE/data/CRADLE_peaks/*.bed.gz
# Out:
# /data/reddylab/Revathy/collabs/Graham/ENCODE/data/CRADLE_peaks/AZD2906_vs_input.CRADLE_peaks.bed.gz
# /data/reddylab/Revathy/collabs/Graham/ENCODE/data/CRADLE_peaks/AZD9567_vs_input.CRADLE_peaks.bed.gz
# /data/reddylab/Revathy/collabs/Graham/ENCODE/data/CRADLE_peaks/CORT108297_vs_input.CRADLE_peaks.bed.gz
# /data/reddylab/Revathy/collabs/Graham/ENCODE/data/CRADLE_peaks/CpdA_vs_input.CRADLE_peaks.bed.gz
# /data/reddylab/Revathy/collabs/Graham/ENCODE/data/CRADLE_peaks/Dex_vs_input.CRADLE_peaks.bed.gz
# /data/reddylab/Revathy/collabs/Graham/ENCODE/data/CRADLE_peaks/DMSO_vs_input.CRADLE_peaks.bed.gz
# /data/reddylab/Revathy/collabs/Graham/ENCODE/data/CRADLE_peaks/GW870086_vs_input.CRADLE_peaks.bed.gz
# /data/reddylab/Revathy/collabs/Graham/ENCODE/data/CRADLE_peaks/Hydrocortisone_vs_input.CRADLE_peaks.bed.gz
# /data/reddylab/Revathy/collabs/Graham/ENCODE/data/CRADLE_peaks/Mapracorat_vs_input.CRADLE_peaks.bed.gz
# ...

# %%
# !ls -la /data/reddylab/Revathy/collabs/Graham/ENCODE/data/CRADLE_peaks/*_vs_input.CRADLE_peaks.bigBed
# Out:
# -rw-rw-r-- 1 rv103 reddylab 4761472 Apr 21 13:43 /data/reddylab/Revathy/collabs/Graham/ENCODE/data/CRADLE_peaks/AZD2906_vs_input.CRADLE_peaks.bigBed
# -rw-rw-r-- 1 rv103 reddylab 4656862 Apr 21 13:43 /data/reddylab/Revathy/collabs/Graham/ENCODE/data/CRADLE_peaks/AZD9567_vs_input.CRADLE_peaks.bigBed
# -rw-rw-r-- 1 rv103 reddylab 4363325 Apr 21 13:43 /data/reddylab/Revathy/collabs/Graham/ENCODE/data/CRADLE_peaks/CORT108297_vs_input.CRADLE_peaks.bigBed
# -rw-rw-r-- 1 rv103 reddylab 3755796 Apr 21 13:43 /data/reddylab/Revathy/collabs/Graham/ENCODE/data/CRADLE_peaks/CpdA_vs_input.CRADLE_peaks.bigBed
# -rw-rw-r-- 1 rv103 reddylab 4894046 Apr 21 13:43 /data/reddylab/Revathy/collabs/Graham/ENCODE/data/CRADLE_peaks/Dex_vs_input.CRADLE_peaks.bigBed
# -rw-rw-r-- 1 rv103 reddylab 3497532 Apr 21 13:43 /data/reddylab/Revathy/collabs/Graham/ENCODE/data/CRADLE_peaks/DMSO_vs_input.CRADLE_peaks.bigBed
# ...

# %%
# !cat /data/reddylab/Revathy/collabs/Graham/ENCODE/metadata/wgSTARRseq_CRADLE_peaks.txt
# Out:
# file_id	file_path
# ENCFF672VAQ	/data/reddylab/Revathy/collabs/Graham/ENCODE/data/CRADLE_peaks/AZD2906_vs_input.CRADLE_peaks.bigBed
# ENCFF094APD	/data/reddylab/Revathy/collabs/Graham/ENCODE/data/CRADLE_peaks/AZD9567_vs_input.CRADLE_peaks.bigBed
# ENCFF876OBH	/data/reddylab/Revathy/collabs/Graham/ENCODE/data/CRADLE_peaks/CORT108297_vs_input.CRADLE_peaks.bigBed
# ENCFF806QQY	/data/reddylab/Revathy/collabs/Graham/ENCODE/data/CRADLE_peaks/CpdA_vs_input.CRADLE_peaks.bigBed
# ENCFF945PVU	/data/reddylab/Revathy/collabs/Graham/ENCODE/data/CRADLE_peaks/Dex_vs_input.CRADLE_peaks.bigBed
# ENCFF503GUN	/data/reddylab/Revathy/collabs/Graham/ENCODE/data/CRADLE_peaks/DMSO_vs_input.CRADLE_peaks.bigBed
# ENCFF714OMR	/data/reddylab/Revathy/collabs/Graham/ENCODE/data/CRADLE_peaks/GW870086_vs_input.CRADLE_peaks.bigBed
# ENCFF435NEX	/data/reddylab/Revathy/collabs/Graham/ENCODE/data/CRADLE_peaks/Hydrocortisone_vs_input.CRADLE_peaks.bigBed
# ...

# %%
import pandas as pd
import encode_utils as eu
from encode_utils.connection import Connection

conn = Connection("prod")

cradle_peaks = pd.read_csv('/data/reddylab/Revathy/collabs/Graham/ENCODE/metadata/wgSTARRseq_CRADLE_peaks.txt', sep='\t')

for peak in range(len(cradle_peaks)):
    conn.upload_file(file_id=cradle_peaks['file_id'][peak], file_path=cradle_peaks['file_path'][peak])
# Out:
# 2023-04-21 14:54:39,828:eu_debug:	Connecting to www.encodeproject.org
# 2023-04-21 14:54:39,870:eu_debug:	submission=False: In non-submission mode.
# 2023-04-21 14:54:40,610:eu_debug:
# IN upload_file()
#
# 2023-04-21 14:54:40,613:eu_debug:	Attempting to generate new file upload credentials
# 2023-04-21 14:54:41,953:eu_debug:	Success: upload credentials for 'ENCFF672VAQ' regenerated.
# 2023-04-21 14:54:41,954:eu_debug:	>>>>>>GET ENCFF672VAQ From DCC with URL https://www.encodeproject.org/ENCFF672VAQ/?format=json
# 2023-04-21 14:54:42,609:eu_debug:	Running command 'aws s3 cp /data/reddylab/Revathy/collabs/Graham/ENCODE/data/CRADLE_peaks/AZD2906_vs_input.CRADLE_peaks.bigBed s3://encode-files/2022/10/17/4926b2d3-6169-41e3-834d-3cad18e55fc8/ENCFF672VAQ.bed.gz'.
# 2023-04-21 14:54:45,201:eu_debug:	AWS upload successful.
# 2023-04-21 14:54:45,204:eu_debug:
# IN upload_file()
#
# 2023-04-21 14:54:45,205:eu_debug:	Attempting to generate new file upload credentials
# ...

# %%
# !ls /data/reddylab/Revathy/collabs/Graham/ENCODE/data/CRADLE_peaks/*.bigBed
# Out:
# /data/reddylab/Revathy/collabs/Graham/ENCODE/data/CRADLE_peaks/AZD2906_vs_input.CRADLE_peaks.bigBed
# /data/reddylab/Revathy/collabs/Graham/ENCODE/data/CRADLE_peaks/AZD9567_vs_input.CRADLE_peaks.bigBed
# /data/reddylab/Revathy/collabs/Graham/ENCODE/data/CRADLE_peaks/CORT108297_vs_input.CRADLE_peaks.bigBed
# /data/reddylab/Revathy/collabs/Graham/ENCODE/data/CRADLE_peaks/CpdA_vs_input.CRADLE_peaks.bigBed
# /data/reddylab/Revathy/collabs/Graham/ENCODE/data/CRADLE_peaks/Dex_vs_input.CRADLE_peaks.bigBed
# /data/reddylab/Revathy/collabs/Graham/ENCODE/data/CRADLE_peaks/DMSO_vs_input.CRADLE_peaks.bigBed
# /data/reddylab/Revathy/collabs/Graham/ENCODE/data/CRADLE_peaks/GW870086_vs_input.CRADLE_peaks.bigBed
# /data/reddylab/Revathy/collabs/Graham/ENCODE/data/CRADLE_peaks/Hydrocortisone_vs_input.CRADLE_peaks.bigBed
# /data/reddylab/Revathy/collabs/Graham/ENCODE/data/CRADLE_peaks/Mapracorat_vs_input.CRADLE_peaks.bigBed
# ...

# %% [markdown]
# ### Correcting the CRADLE peak calls to the bigBed format

# %%
# %%bash
# cd /data/reddylab/Revathy/collabs/Graham/ENCODE/data/CRADLE_peaks
# treatments=(\ AZD2906 \
#               AZD9567 \
#               CORT108297 \
#               CpdA \
#               Dex \
#               DMSO \
#               GW870086 \
#               Hydrocortisone \
#               Mapracorat \
#               RU486 \
#               ZK216348)
#
# for treatment in ${treatments[@]};
# do
#    /data/common/shared_conda_envs/ucsc/bin/bedToBigBed \
#           /data/reddylab/Revathy/collabs/Graham/ENCODE/data/CRADLE_peaks/${treatment}_vs_input.CRADLE_peaks.bed \
#           /data/reddylab/Reference_Data/Genomes/hg38/hg38.fa.chrom.sizes \
#           -as=/home/rv103/reddylab_data/Revathy/software/mpra_starr.as \
#           -type=bed6+5 \
#           /data/reddylab/Revathy/collabs/Graham/ENCODE/data/CRADLE_peaks/${treatment}_vs_input.CRADLE_peaks.bigBed
# done
# Out:
# pass1 - making usageList (23 chroms): 40 millis
# pass2 - checking and writing primary data (82095 records, 11 fields): 377 millis
# pass1 - making usageList (23 chroms): 38 millis
# pass2 - checking and writing primary data (79269 records, 11 fields): 359 millis
# pass1 - making usageList (23 chroms): 38 millis
# pass2 - checking and writing primary data (73299 records, 11 fields): 333 millis
# pass1 - making usageList (23 chroms): 11 millis
# pass2 - checking and writing primary data (61550 records, 11 fields): 283 millis
# pass1 - making usageList (23 chroms): 39 millis
# pass2 - checking and writing primary data (85117 records, 11 fields): 388 millis
# pass1 - making usageList (23 chroms): 11 millis
# pass2 - checking and writing primary data (56448 records, 11 fields): 254 millis
# pass1 - making usageList (23 chroms): 65 millis
# pass2 - checking and writing primary data (96089 records, 11 fields): 434 millis
# pass1 - making usageList (23 chroms): 40 millis
# ...

# %%
# %%bash
# treatments=(\ AZD2906 \
#               AZD9567 \
#               CORT108297 \
#               CpdA \
#               Dex \
#               DMSO \
#               GW870086 \
#               Hydrocortisone \
#               Mapracorat \
#               RU486 \
#               ZK216348)
#
# for treatment in ${treatments[@]};
# do
# /data/common/shared_conda_envs/ucsc/bin/validateFiles \
# -type=bed6+5 \
# -chromInfo=/data/reddylab/software/encValData/hg38/chrom.sizes \
# -as=/data/reddylab/Alex/software/encValData/as/mpra_starr.as \
# /data/reddylab/Revathy/collabs/Graham/ENCODE/data/CRADLE_peaks/${treatment}_vs_input.CRADLE_peaks.bed
# done
# Out:
# Error count 0
# Error count 0
# Error count 0
# Error count 0
# Error count 0
# Error count 0
# Error count 0
# Error count 0
# Error count 0
# Error count 0
# Error count 0

# %%
# %%bash
# treatments=(\ AZD2906 \
#               AZD9567 \
#               CORT108297 \
#               CpdA \
#               Dex \
#               DMSO \
#               GW870086 \
#               Hydrocortisone \
#               Mapracorat \
#               RU486 \
#               ZK216348)
#
# for treatment in ${treatments[@]};
# do
# md5sum /data/reddylab/Revathy/collabs/Graham/ENCODE/data/CRADLE_peaks/${treatment}_vs_input.CRADLE_peaks.bigBed
# done
# Out:
# 062199fdbeebce90feb578a7be42a2f3  /data/reddylab/Revathy/collabs/Graham/ENCODE/data/CRADLE_peaks/AZD2906_vs_input.CRADLE_peaks.bigBed
# 590e5daca26a989caa8987e1ab227a26  /data/reddylab/Revathy/collabs/Graham/ENCODE/data/CRADLE_peaks/AZD9567_vs_input.CRADLE_peaks.bigBed
# ba59deb6066d71b07df46f0c5e95706f  /data/reddylab/Revathy/collabs/Graham/ENCODE/data/CRADLE_peaks/CORT108297_vs_input.CRADLE_peaks.bigBed
# c7bbd10ad6e6a1ca75a41fed120aac43  /data/reddylab/Revathy/collabs/Graham/ENCODE/data/CRADLE_peaks/CpdA_vs_input.CRADLE_peaks.bigBed
# 12fd366b35f1c8f17dbbf306c62aab50  /data/reddylab/Revathy/collabs/Graham/ENCODE/data/CRADLE_peaks/Dex_vs_input.CRADLE_peaks.bigBed
# 2b4608429a292c012da3e0dc243ffb29  /data/reddylab/Revathy/collabs/Graham/ENCODE/data/CRADLE_peaks/DMSO_vs_input.CRADLE_peaks.bigBed
# 78c9ab32e56e2b7264506fc5e96b95c1  /data/reddylab/Revathy/collabs/Graham/ENCODE/data/CRADLE_peaks/GW870086_vs_input.CRADLE_peaks.bigBed
# ...
