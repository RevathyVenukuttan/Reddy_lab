# %%
# %%bash
# eu_register.py --help
# Out:
# usage: eu_register.py [-h] [-m DCC_MODE] [-d] [--no-aliases] -p PROFILE_ID -i
#                       INFILE [--patch] [-w]
#
# Given a tab-delimited or JSON input file containing one or more records belonging to one of the profiles
# listed on the ENCODE Portal (such as https://www.encodeproject.org/profiles/biosample.json),
# either POSTS or PATCHES the records. The default is to POST each record; to PATCH instead, see
# the ``--patch`` option.
#
# When POSTING file records, the md5sum of each file will be calculated for you if you haven't
# already provided the `md5sum` property. Then, after the POST operation completes, the actual file
# will be uploaded to AWS S3. In order for this to work, you must set the `submitted_file_name`
# property to the full, local path to your file to upload. Alternatively, you can set
# `submitted_file_name` to and existing S3 object, i.e. s3://mybucket/reads.fastq.
#
# ...

# %%
# %%bash
# source /data/reddylab/software/miniconda3/bin/activate revathy_py3
# python /data/reddylab/Revathy/scripts/excel_to_text_for_ENCODE.py \
# -i /data/reddylab/Revathy/collabs/Graham/ENCODE/Reddy-DCC-data-RNAseq-Graham_v2.xlsx \
# -o /data/reddylab/Revathy/collabs/Graham/ENCODE/metadata \
# --sheet-names biosample library experiment replicate

# %%
# %%bash
# source /data/reddylab/software/miniconda3/bin/activate revathy_py3
# python /data/reddylab/Revathy/scripts/excel_to_text_for_ENCODE.py \
# -i /data/reddylab/Revathy/collabs/Graham/ENCODE/wg-RNAseq-files.xlsx \
# -o /data/reddylab/Revathy/collabs/Graham/ENCODE/metadata \
# --sheet-names file

# %% [markdown]
# ## submission into the production server

# %%
# %%bash
# cd /data/reddylab/Revathy/collabs/Graham/ENCODE/metadata
# eu_register.py -m prod -p replicate -i replicate.txt
# Out:
# 2022-02-28 00:05:11,850:eu_debug:	Connecting to www.encodeproject.org
# 2022-02-28 00:05:11,851:eu_debug:	submission=False: In non-submission mode.
# 2022-02-28 00:05:12,503:eu_debug:	submission=True: In submission mode.
# 2022-02-28 00:05:12,510:eu_debug:
# IN post().
# 2022-02-28 00:05:12,510:eu_debug:	<<<<<< POST replicate record tim-reddy:A549-wg-rnaseq-AZD2906-brep5-trep1 To DCC with URL https://www.encodeproject.org/replicate and this payload:
#
# {
#   "aliases": [
#     "tim-reddy:A549-wg-rnaseq-AZD2906-brep5-trep1"
#   ],
#   "biological_replicate_number": 5,
#   "experiment": "tim-reddy:A549-wg-rnaseq-AZD2906",
#   "library": "tim-reddy:A549-wg-rnaseq-AZD2906-brep5-trep1-lib",
#   "technical_replicate_number": 1
# }
#
#
# 2022-02-28 00:05:12,860:eu_debug:	Success.
# 2022-02-28 00:05:12,861:eu_debug:
# IN post().
# ...

# %% [markdown]
# #### post data into the production server

# %%
# %%bash
# cd /data/reddylab/Revathy/collabs/Graham/ENCODE/metadata
# eu_register.py -m prod -p file -i file.txt

# %%
# %%bash
# cd /data/reddylab/Revathy/collabs/Graham/ENCODE/metadata
# eu_register.py -m prod -p document -i document.txt
# Out:
# 2022-07-11 13:40:35,616:eu_debug:	Connecting to www.encodeproject.org
# 2022-07-11 13:40:35,617:eu_debug:	submission=False: In non-submission mode.
# 2022-07-11 13:40:36,350:eu_debug:	submission=True: In submission mode.
# Error: Invalid JSON in field 'attachment', row '2'
# Traceback (most recent call last):
#   File "/data/reddylab/software/miniconda3/envs/revathy_py3/bin/eu_register.py", line 345, in <module>
#     main()
#   File "/data/reddylab/software/miniconda3/envs/revathy_py3/bin/eu_register.py", line 154, in main
#     for payload in gen:
#   File "/data/reddylab/software/miniconda3/envs/revathy_py3/bin/eu_register.py", line 314, in create_payloads_from_tsv
#     val = check_valid_json(field, val, line_count)
#   File "/data/reddylab/software/miniconda3/envs/revathy_py3/bin/eu_register.py", line 185, in check_valid_json
#     json_val = json.loads(val)
#   File "/data/reddylab/software/miniconda3/envs/revathy_py3/lib/python3.5/json/__init__.py", line 319, in loads
# ...

# %% [markdown]
# ### Get accesions of library and replicate objects

# %%
# %%writefile /data/reddylab/Revathy/collabs/Graham/ENCODE/metadata/library_object_to_archive_aliases.txt
# tim-reddy:A549-wg-rnaseq-AZD2906-brep1-trep2-lib
# tim-reddy:A549-wg-rnaseq-AZD2906-brep1-trep3-lib
# tim-reddy:A549-wg-rnaseq-AZD2906-brep1-trep4-lib
# tim-reddy:A549-wg-rnaseq-AZD2906-brep2-trep2-lib
# tim-reddy:A549-wg-rnaseq-AZD2906-brep2-trep3-lib
# tim-reddy:A549-wg-rnaseq-AZD2906-brep2-trep4-lib
# tim-reddy:A549-wg-rnaseq-AZD2906-brep3-trep2-lib
# tim-reddy:A549-wg-rnaseq-AZD2906-brep3-trep3-lib
# tim-reddy:A549-wg-rnaseq-AZD2906-brep3-trep4-lib
# tim-reddy:A549-wg-rnaseq-AZD2906-brep4-trep2-lib
# tim-reddy:A549-wg-rnaseq-AZD2906-brep4-trep3-lib
# tim-reddy:A549-wg-rnaseq-AZD2906-brep4-trep4-lib
# tim-reddy:A549-wg-rnaseq-AZD9567-brep1-trep2-lib
# tim-reddy:A549-wg-rnaseq-AZD9567-brep1-trep3-lib
# tim-reddy:A549-wg-rnaseq-AZD9567-brep1-trep4-lib
# tim-reddy:A549-wg-rnaseq-AZD9567-brep2-trep2-lib
# tim-reddy:A549-wg-rnaseq-AZD9567-brep2-trep3-lib
# tim-reddy:A549-wg-rnaseq-AZD9567-brep2-trep4-lib
# tim-reddy:A549-wg-rnaseq-AZD9567-brep3-trep2-lib
# tim-reddy:A549-wg-rnaseq-AZD9567-brep3-trep3-lib
# tim-reddy:A549-wg-rnaseq-AZD9567-brep3-trep4-lib
# tim-reddy:A549-wg-rnaseq-AZD9567-brep4-trep2-lib
# tim-reddy:A549-wg-rnaseq-AZD9567-brep4-trep3-lib
# tim-reddy:A549-wg-rnaseq-AZD9567-brep4-trep4-lib
# tim-reddy:A549-wg-rnaseq-CORT108297-brep1-trep2-lib
# tim-reddy:A549-wg-rnaseq-CORT108297-brep1-trep3-lib
# tim-reddy:A549-wg-rnaseq-CORT108297-brep1-trep4-lib
# tim-reddy:A549-wg-rnaseq-CORT108297-brep2-trep2-lib
# tim-reddy:A549-wg-rnaseq-CORT108297-brep2-trep3-lib
# tim-reddy:A549-wg-rnaseq-CORT108297-brep2-trep4-lib
# tim-reddy:A549-wg-rnaseq-CORT108297-brep3-trep2-lib
# tim-reddy:A549-wg-rnaseq-CORT108297-brep3-trep3-lib
# tim-reddy:A549-wg-rnaseq-CORT108297-brep3-trep4-lib
# tim-reddy:A549-wg-rnaseq-CORT108297-brep4-trep2-lib
# tim-reddy:A549-wg-rnaseq-CORT108297-brep4-trep3-lib
# tim-reddy:A549-wg-rnaseq-CORT108297-brep4-trep4-lib
# tim-reddy:A549-wg-rnaseq-CpdA-brep1-trep2-lib
# tim-reddy:A549-wg-rnaseq-CpdA-brep1-trep3-lib
# tim-reddy:A549-wg-rnaseq-CpdA-brep1-trep4-lib
# tim-reddy:A549-wg-rnaseq-CpdA-brep2-trep2-lib
# tim-reddy:A549-wg-rnaseq-CpdA-brep2-trep3-lib
# tim-reddy:A549-wg-rnaseq-CpdA-brep2-trep4-lib
# tim-reddy:A549-wg-rnaseq-CpdA-brep3-trep2-lib
# tim-reddy:A549-wg-rnaseq-CpdA-brep3-trep3-lib
# tim-reddy:A549-wg-rnaseq-CpdA-brep3-trep4-lib
# tim-reddy:A549-wg-rnaseq-CpdA-brep4-trep2-lib
# tim-reddy:A549-wg-rnaseq-CpdA-brep4-trep3-lib
# tim-reddy:A549-wg-rnaseq-CpdA-brep4-trep4-lib
# tim-reddy:A549-wg-rnaseq-Dex-brep1-trep2-lib
# tim-reddy:A549-wg-rnaseq-Dex-brep1-trep3-lib
# tim-reddy:A549-wg-rnaseq-Dex-brep1-trep4-lib
# tim-reddy:A549-wg-rnaseq-Dex-brep2-trep2-lib
# tim-reddy:A549-wg-rnaseq-Dex-brep2-trep3-lib
# tim-reddy:A549-wg-rnaseq-Dex-brep2-trep4-lib
# tim-reddy:A549-wg-rnaseq-Dex-brep3-trep2-lib
# tim-reddy:A549-wg-rnaseq-Dex-brep3-trep3-lib
# tim-reddy:A549-wg-rnaseq-Dex-brep3-trep4-lib
# tim-reddy:A549-wg-rnaseq-Dex-brep4-trep2-lib
# tim-reddy:A549-wg-rnaseq-Dex-brep4-trep3-lib
# tim-reddy:A549-wg-rnaseq-Dex-brep4-trep4-lib
# tim-reddy:A549-wg-rnaseq-DMSO-brep1-trep2-lib
# tim-reddy:A549-wg-rnaseq-DMSO-brep1-trep3-lib
# tim-reddy:A549-wg-rnaseq-DMSO-brep1-trep4-lib
# tim-reddy:A549-wg-rnaseq-DMSO-brep2-trep2-lib
# tim-reddy:A549-wg-rnaseq-DMSO-brep2-trep3-lib
# tim-reddy:A549-wg-rnaseq-DMSO-brep2-trep4-lib
# tim-reddy:A549-wg-rnaseq-DMSO-brep3-trep2-lib
# tim-reddy:A549-wg-rnaseq-DMSO-brep3-trep3-lib
# tim-reddy:A549-wg-rnaseq-DMSO-brep3-trep4-lib
# tim-reddy:A549-wg-rnaseq-DMSO-brep4-trep2-lib
# tim-reddy:A549-wg-rnaseq-DMSO-brep4-trep3-lib
# tim-reddy:A549-wg-rnaseq-DMSO-brep4-trep4-lib
# tim-reddy:A549-wg-rnaseq-GW870086-brep1-trep2-lib
# tim-reddy:A549-wg-rnaseq-GW870086-brep1-trep3-lib
# tim-reddy:A549-wg-rnaseq-GW870086-brep1-trep4-lib
# tim-reddy:A549-wg-rnaseq-GW870086-brep2-trep2-lib
# tim-reddy:A549-wg-rnaseq-GW870086-brep2-trep3-lib
# tim-reddy:A549-wg-rnaseq-GW870086-brep2-trep4-lib
# tim-reddy:A549-wg-rnaseq-GW870086-brep3-trep2-lib
# tim-reddy:A549-wg-rnaseq-GW870086-brep3-trep3-lib
# tim-reddy:A549-wg-rnaseq-GW870086-brep3-trep4-lib
# tim-reddy:A549-wg-rnaseq-GW870086-brep4-trep2-lib
# tim-reddy:A549-wg-rnaseq-GW870086-brep4-trep3-lib
# tim-reddy:A549-wg-rnaseq-GW870086-brep4-trep4-lib
# tim-reddy:A549-wg-rnaseq-Hydrocortisone-brep1-trep2-lib
# tim-reddy:A549-wg-rnaseq-Hydrocortisone-brep1-trep3-lib
# tim-reddy:A549-wg-rnaseq-Hydrocortisone-brep1-trep4-lib
# tim-reddy:A549-wg-rnaseq-Hydrocortisone-brep2-trep2-lib
# tim-reddy:A549-wg-rnaseq-Hydrocortisone-brep2-trep3-lib
# tim-reddy:A549-wg-rnaseq-Hydrocortisone-brep2-trep4-lib
# tim-reddy:A549-wg-rnaseq-Hydrocortisone-brep3-trep2-lib
# tim-reddy:A549-wg-rnaseq-Hydrocortisone-brep3-trep3-lib
# tim-reddy:A549-wg-rnaseq-Hydrocortisone-brep3-trep4-lib
# tim-reddy:A549-wg-rnaseq-Hydrocortisone-brep4-trep2-lib
# tim-reddy:A549-wg-rnaseq-Hydrocortisone-brep4-trep3-lib
# tim-reddy:A549-wg-rnaseq-Hydrocortisone-brep4-trep4-lib
# tim-reddy:A549-wg-rnaseq-Mapracorat-brep1-trep2-lib
# tim-reddy:A549-wg-rnaseq-Mapracorat-brep1-trep3-lib
# tim-reddy:A549-wg-rnaseq-Mapracorat-brep1-trep4-lib
# tim-reddy:A549-wg-rnaseq-Mapracorat-brep2-trep2-lib
# tim-reddy:A549-wg-rnaseq-Mapracorat-brep2-trep3-lib
# tim-reddy:A549-wg-rnaseq-Mapracorat-brep2-trep4-lib
# tim-reddy:A549-wg-rnaseq-Mapracorat-brep3-trep2-lib
# tim-reddy:A549-wg-rnaseq-Mapracorat-brep3-trep3-lib
# tim-reddy:A549-wg-rnaseq-Mapracorat-brep3-trep4-lib
# tim-reddy:A549-wg-rnaseq-Mapracorat-brep4-trep2-lib
# tim-reddy:A549-wg-rnaseq-Mapracorat-brep4-trep3-lib
# tim-reddy:A549-wg-rnaseq-Mapracorat-brep4-trep4-lib
# tim-reddy:A549-wg-rnaseq-RU486-brep1-trep2-lib
# tim-reddy:A549-wg-rnaseq-RU486-brep1-trep3-lib
# tim-reddy:A549-wg-rnaseq-RU486-brep1-trep4-lib
# tim-reddy:A549-wg-rnaseq-RU486-brep2-trep2-lib
# tim-reddy:A549-wg-rnaseq-RU486-brep2-trep3-lib
# tim-reddy:A549-wg-rnaseq-RU486-brep2-trep4-lib
# tim-reddy:A549-wg-rnaseq-RU486-brep3-trep2-lib
# tim-reddy:A549-wg-rnaseq-RU486-brep3-trep3-lib
# tim-reddy:A549-wg-rnaseq-RU486-brep3-trep4-lib
# tim-reddy:A549-wg-rnaseq-RU486-brep4-trep2-lib
# tim-reddy:A549-wg-rnaseq-RU486-brep4-trep3-lib
# tim-reddy:A549-wg-rnaseq-RU486-brep4-trep4-lib
# tim-reddy:A549-wg-rnaseq-ZK216348-brep1-trep2-lib
# tim-reddy:A549-wg-rnaseq-ZK216348-brep1-trep3-lib
# tim-reddy:A549-wg-rnaseq-ZK216348-brep1-trep4-lib
# tim-reddy:A549-wg-rnaseq-ZK216348-brep2-trep2-lib
# tim-reddy:A549-wg-rnaseq-ZK216348-brep2-trep3-lib
# tim-reddy:A549-wg-rnaseq-ZK216348-brep2-trep4-lib
# tim-reddy:A549-wg-rnaseq-ZK216348-brep3-trep2-lib
# tim-reddy:A549-wg-rnaseq-ZK216348-brep3-trep3-lib
# tim-reddy:A549-wg-rnaseq-ZK216348-brep3-trep4-lib
# tim-reddy:A549-wg-rnaseq-ZK216348-brep4-trep2-lib
# tim-reddy:A549-wg-rnaseq-ZK216348-brep4-trep3-lib
# tim-reddy:A549-wg-rnaseq-ZK216348-brep4-trep4-lib
# Out:
# Writing /data/reddylab/Revathy/collabs/Graham/ENCODE/metadata/library_object_to_archive_aliases.txt

# %%
# %%bash
# cd /data/reddylab/Revathy/collabs/Graham/ENCODE/metadata
# eu_get_accessions.py -m prod -i library_object_to_archive_aliases.txt -o library_object_to_archive_accesions.txt -l tim-reddy
# Out:
# 2022-04-18 12:17:35,600:eu_debug:	Connecting to www.encodeproject.org
# 2022-04-18 12:17:35,643:eu_debug:	submission=False: In non-submission mode.
# 2022-04-18 12:17:36,364:eu_debug:	>>>>>>GET tim-reddy:A549-wg-rnaseq-AZD2906-brep1-trep2-lib From DCC with URL https://www.encodeproject.org/tim-reddy:A549-wg-rnaseq-AZD2906-brep1-trep2-lib/?format=json
# 2022-04-18 12:17:37,000:eu_debug:	>>>>>>GET tim-reddy:A549-wg-rnaseq-AZD2906-brep1-trep3-lib From DCC with URL https://www.encodeproject.org/tim-reddy:A549-wg-rnaseq-AZD2906-brep1-trep3-lib/?format=json
# 2022-04-18 12:17:37,595:eu_debug:	>>>>>>GET tim-reddy:A549-wg-rnaseq-AZD2906-brep1-trep4-lib From DCC with URL https://www.encodeproject.org/tim-reddy:A549-wg-rnaseq-AZD2906-brep1-trep4-lib/?format=json
# 2022-04-18 12:17:38,229:eu_debug:	>>>>>>GET tim-reddy:A549-wg-rnaseq-AZD2906-brep2-trep2-lib From DCC with URL https://www.encodeproject.org/tim-reddy:A549-wg-rnaseq-AZD2906-brep2-trep2-lib/?format=json
# ...

# %%
# %%writefile /data/reddylab/Revathy/collabs/Graham/ENCODE/metadata/replicate_object_to_archive_aliases.txt
# tim-reddy:A549-wg-rnaseq-AZD2906-brep1-trep2
# tim-reddy:A549-wg-rnaseq-AZD2906-brep1-trep3
# tim-reddy:A549-wg-rnaseq-AZD2906-brep1-trep4
# tim-reddy:A549-wg-rnaseq-AZD2906-brep2-trep2
# tim-reddy:A549-wg-rnaseq-AZD2906-brep2-trep3
# tim-reddy:A549-wg-rnaseq-AZD2906-brep2-trep4
# tim-reddy:A549-wg-rnaseq-AZD2906-brep3-trep2
# tim-reddy:A549-wg-rnaseq-AZD2906-brep3-trep3
# tim-reddy:A549-wg-rnaseq-AZD2906-brep3-trep4
# tim-reddy:A549-wg-rnaseq-AZD2906-brep4-trep2
# tim-reddy:A549-wg-rnaseq-AZD2906-brep4-trep3
# tim-reddy:A549-wg-rnaseq-AZD2906-brep4-trep4
# tim-reddy:A549-wg-rnaseq-AZD9567-brep1-trep2
# tim-reddy:A549-wg-rnaseq-AZD9567-brep1-trep3
# tim-reddy:A549-wg-rnaseq-AZD9567-brep1-trep4
# tim-reddy:A549-wg-rnaseq-AZD9567-brep2-trep2
# tim-reddy:A549-wg-rnaseq-AZD9567-brep2-trep3
# tim-reddy:A549-wg-rnaseq-AZD9567-brep2-trep4
# tim-reddy:A549-wg-rnaseq-AZD9567-brep3-trep2
# tim-reddy:A549-wg-rnaseq-AZD9567-brep3-trep3
# tim-reddy:A549-wg-rnaseq-AZD9567-brep3-trep4
# tim-reddy:A549-wg-rnaseq-AZD9567-brep4-trep2
# tim-reddy:A549-wg-rnaseq-AZD9567-brep4-trep3
# tim-reddy:A549-wg-rnaseq-AZD9567-brep4-trep4
# tim-reddy:A549-wg-rnaseq-CORT108297-brep1-trep2
# tim-reddy:A549-wg-rnaseq-CORT108297-brep1-trep3
# tim-reddy:A549-wg-rnaseq-CORT108297-brep1-trep4
# tim-reddy:A549-wg-rnaseq-CORT108297-brep2-trep2
# tim-reddy:A549-wg-rnaseq-CORT108297-brep2-trep3
# tim-reddy:A549-wg-rnaseq-CORT108297-brep2-trep4
# tim-reddy:A549-wg-rnaseq-CORT108297-brep3-trep2
# tim-reddy:A549-wg-rnaseq-CORT108297-brep3-trep3
# tim-reddy:A549-wg-rnaseq-CORT108297-brep3-trep4
# tim-reddy:A549-wg-rnaseq-CORT108297-brep4-trep2
# tim-reddy:A549-wg-rnaseq-CORT108297-brep4-trep3
# tim-reddy:A549-wg-rnaseq-CORT108297-brep4-trep4
# tim-reddy:A549-wg-rnaseq-CpdA-brep1-trep2
# tim-reddy:A549-wg-rnaseq-CpdA-brep1-trep3
# tim-reddy:A549-wg-rnaseq-CpdA-brep1-trep4
# tim-reddy:A549-wg-rnaseq-CpdA-brep2-trep2
# tim-reddy:A549-wg-rnaseq-CpdA-brep2-trep3
# tim-reddy:A549-wg-rnaseq-CpdA-brep2-trep4
# tim-reddy:A549-wg-rnaseq-CpdA-brep3-trep2
# tim-reddy:A549-wg-rnaseq-CpdA-brep3-trep3
# tim-reddy:A549-wg-rnaseq-CpdA-brep3-trep4
# tim-reddy:A549-wg-rnaseq-CpdA-brep4-trep2
# tim-reddy:A549-wg-rnaseq-CpdA-brep4-trep3
# tim-reddy:A549-wg-rnaseq-CpdA-brep4-trep4
# tim-reddy:A549-wg-rnaseq-Dex-brep1-trep2
# tim-reddy:A549-wg-rnaseq-Dex-brep1-trep3
# tim-reddy:A549-wg-rnaseq-Dex-brep1-trep4
# tim-reddy:A549-wg-rnaseq-Dex-brep2-trep2
# tim-reddy:A549-wg-rnaseq-Dex-brep2-trep3
# tim-reddy:A549-wg-rnaseq-Dex-brep2-trep4
# tim-reddy:A549-wg-rnaseq-Dex-brep3-trep2
# tim-reddy:A549-wg-rnaseq-Dex-brep3-trep3
# tim-reddy:A549-wg-rnaseq-Dex-brep3-trep4
# tim-reddy:A549-wg-rnaseq-Dex-brep4-trep2
# tim-reddy:A549-wg-rnaseq-Dex-brep4-trep3
# tim-reddy:A549-wg-rnaseq-Dex-brep4-trep4
# tim-reddy:A549-wg-rnaseq-DMSO-brep1-trep2
# tim-reddy:A549-wg-rnaseq-DMSO-brep1-trep3
# tim-reddy:A549-wg-rnaseq-DMSO-brep1-trep4
# tim-reddy:A549-wg-rnaseq-DMSO-brep2-trep2
# tim-reddy:A549-wg-rnaseq-DMSO-brep2-trep3
# tim-reddy:A549-wg-rnaseq-DMSO-brep2-trep4
# tim-reddy:A549-wg-rnaseq-DMSO-brep3-trep2
# tim-reddy:A549-wg-rnaseq-DMSO-brep3-trep3
# tim-reddy:A549-wg-rnaseq-DMSO-brep3-trep4
# tim-reddy:A549-wg-rnaseq-DMSO-brep4-trep2
# tim-reddy:A549-wg-rnaseq-DMSO-brep4-trep3
# tim-reddy:A549-wg-rnaseq-DMSO-brep4-trep4
# tim-reddy:A549-wg-rnaseq-GW870086-brep1-trep2
# tim-reddy:A549-wg-rnaseq-GW870086-brep1-trep3
# tim-reddy:A549-wg-rnaseq-GW870086-brep1-trep4
# tim-reddy:A549-wg-rnaseq-GW870086-brep2-trep2
# tim-reddy:A549-wg-rnaseq-GW870086-brep2-trep3
# tim-reddy:A549-wg-rnaseq-GW870086-brep2-trep4
# tim-reddy:A549-wg-rnaseq-GW870086-brep3-trep2
# tim-reddy:A549-wg-rnaseq-GW870086-brep3-trep3
# tim-reddy:A549-wg-rnaseq-GW870086-brep3-trep4
# tim-reddy:A549-wg-rnaseq-GW870086-brep4-trep2
# tim-reddy:A549-wg-rnaseq-GW870086-brep4-trep3
# tim-reddy:A549-wg-rnaseq-GW870086-brep4-trep4
# tim-reddy:A549-wg-rnaseq-Hydrocortisone-brep1-trep2
# tim-reddy:A549-wg-rnaseq-Hydrocortisone-brep1-trep3
# tim-reddy:A549-wg-rnaseq-Hydrocortisone-brep1-trep4
# tim-reddy:A549-wg-rnaseq-Hydrocortisone-brep2-trep2
# tim-reddy:A549-wg-rnaseq-Hydrocortisone-brep2-trep3
# tim-reddy:A549-wg-rnaseq-Hydrocortisone-brep2-trep4
# tim-reddy:A549-wg-rnaseq-Hydrocortisone-brep3-trep2
# tim-reddy:A549-wg-rnaseq-Hydrocortisone-brep3-trep3
# tim-reddy:A549-wg-rnaseq-Hydrocortisone-brep3-trep4
# tim-reddy:A549-wg-rnaseq-Hydrocortisone-brep4-trep2
# tim-reddy:A549-wg-rnaseq-Hydrocortisone-brep4-trep3
# tim-reddy:A549-wg-rnaseq-Hydrocortisone-brep4-trep4
# tim-reddy:A549-wg-rnaseq-Mapracorat-brep1-trep2
# tim-reddy:A549-wg-rnaseq-Mapracorat-brep1-trep3
# tim-reddy:A549-wg-rnaseq-Mapracorat-brep1-trep4
# tim-reddy:A549-wg-rnaseq-Mapracorat-brep2-trep2
# tim-reddy:A549-wg-rnaseq-Mapracorat-brep2-trep3
# tim-reddy:A549-wg-rnaseq-Mapracorat-brep2-trep4
# tim-reddy:A549-wg-rnaseq-Mapracorat-brep3-trep2
# tim-reddy:A549-wg-rnaseq-Mapracorat-brep3-trep3
# tim-reddy:A549-wg-rnaseq-Mapracorat-brep3-trep4
# tim-reddy:A549-wg-rnaseq-Mapracorat-brep4-trep2
# tim-reddy:A549-wg-rnaseq-Mapracorat-brep4-trep3
# tim-reddy:A549-wg-rnaseq-Mapracorat-brep4-trep4
# tim-reddy:A549-wg-rnaseq-RU486-brep1-trep2
# tim-reddy:A549-wg-rnaseq-RU486-brep1-trep3
# tim-reddy:A549-wg-rnaseq-RU486-brep1-trep4
# tim-reddy:A549-wg-rnaseq-RU486-brep2-trep2
# tim-reddy:A549-wg-rnaseq-RU486-brep2-trep3
# tim-reddy:A549-wg-rnaseq-RU486-brep2-trep4
# tim-reddy:A549-wg-rnaseq-RU486-brep3-trep2
# tim-reddy:A549-wg-rnaseq-RU486-brep3-trep3
# tim-reddy:A549-wg-rnaseq-RU486-brep3-trep4
# tim-reddy:A549-wg-rnaseq-RU486-brep4-trep2
# tim-reddy:A549-wg-rnaseq-RU486-brep4-trep3
# tim-reddy:A549-wg-rnaseq-RU486-brep4-trep4
# tim-reddy:A549-wg-rnaseq-ZK216348-brep1-trep2
# tim-reddy:A549-wg-rnaseq-ZK216348-brep1-trep3
# tim-reddy:A549-wg-rnaseq-ZK216348-brep1-trep4
# tim-reddy:A549-wg-rnaseq-ZK216348-brep2-trep2
# tim-reddy:A549-wg-rnaseq-ZK216348-brep2-trep3
# tim-reddy:A549-wg-rnaseq-ZK216348-brep2-trep4
# tim-reddy:A549-wg-rnaseq-ZK216348-brep3-trep2
# tim-reddy:A549-wg-rnaseq-ZK216348-brep3-trep3
# tim-reddy:A549-wg-rnaseq-ZK216348-brep3-trep4
# tim-reddy:A549-wg-rnaseq-ZK216348-brep4-trep2
# tim-reddy:A549-wg-rnaseq-ZK216348-brep4-trep3
# tim-reddy:A549-wg-rnaseq-ZK216348-brep4-trep4
# Out:
# Writing /data/reddylab/Revathy/collabs/Graham/ENCODE/metadata/replicate_object_to_archive_aliases.txt

# %%
# %%bash
# cd /data/reddylab/Revathy/collabs/Graham/ENCODE/metadata
# eu_get_accessions.py -m prod -i libray_object_aliases.txt -o libray_object_aliases_accesions.txt -l tim-reddy
# Out:
# 2022-07-19 09:32:51,925:eu_debug:	Connecting to www.encodeproject.org
# 2022-07-19 09:32:51,969:eu_debug:	submission=False: In non-submission mode.
# 2022-07-19 09:32:52,653:eu_debug:	>>>>>>GET tim-reddy:A549-wg-rnaseq-AZD2906-brep1-trep1-lib From DCC with URL https://www.encodeproject.org/tim-reddy:A549-wg-rnaseq-AZD2906-brep1-trep1-lib/?format=json
# 2022-07-19 09:32:53,467:eu_debug:	>>>>>>GET tim-reddy:A549-wg-rnaseq-AZD9567-brep1-trep1-lib From DCC with URL https://www.encodeproject.org/tim-reddy:A549-wg-rnaseq-AZD9567-brep1-trep1-lib/?format=json
# 2022-07-19 09:32:54,064:eu_debug:	>>>>>>GET tim-reddy:A549-wg-rnaseq-CORT108297-brep1-trep1-lib From DCC with URL https://www.encodeproject.org/tim-reddy:A549-wg-rnaseq-CORT108297-brep1-trep1-lib/?format=json
# 2022-07-19 09:32:54,714:eu_debug:	>>>>>>GET tim-reddy:A549-wg-rnaseq-CpdA-brep1-trep1-lib From DCC with URL https://www.encodeproject.org/tim-reddy:A549-wg-rnaseq-CpdA-brep1-trep1-lib/?format=json
# ...

# %%
# %%bash
# cd /data/reddylab/Revathy/collabs/Graham/ENCODE/metadata
# eu_get_accessions.py -m prod -i replicate_object_to_archive_aliases.txt -o replicate_object_to_archive_accesions.txt -l tim-reddy
