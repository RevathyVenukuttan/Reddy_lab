# %%
# %%bash
# mkdir -p /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/metadata_Th17

# %%
# %%bash
# mkdir -p /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/metadata
# source /data/reddylab/software/miniconda3/bin/activate revathy_py3
# python /data/reddylab/Revathy/scripts/excel_to_text_for_ENCODE.py \
# -i /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/Reddy-DCC-Siklenka-Th17-ASTARRData.xlsx \
# -o /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/metadata_Th17 \
# --sheet-names genetic_modification biosample functional_characterization_exp library replicate

# %%
# %%bash
# source /data/reddylab/software/miniconda3/bin/activate revathy_py3
# cd /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/metadata_Th17
# sbatch -p all \
#     -o /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/logs/file.out \
#     --mem 16G \
#     <<'EOF'
# #!/bin/bash
# NAMES=( \
#     replicate \
# )
# NAME=${NAMES[${SLURM_ARRAY_TASK_ID}]}
# eu_register.py -m prod -p ${NAME} -i ${NAME}.txt \
# EOF
# Out:
# Submitted batch job 25942494

# %%
# %%bash
# source /data/reddylab/software/miniconda3/bin/activate revathy_py3
# cd /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/metadata_Th17
# sbatch -p all \
#     -o /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/logs/file.out \
#     --mem 16G \
#     <<'EOF'
# #!/bin/bash
# NAMES=( \
#     fastq \
# )
# NAME=${NAMES[${SLURM_ARRAY_TASK_ID}]}
# eu_register.py -m prod -p file -i ${NAME}.txt \
# EOF
# Out:
# Submitted batch job 26066903

# %% [markdown]
# ENCFF040GNB : /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/data/KS163_Th17_pooledASTARR_output_rep4.f3q10.sorted.with_umis.dups_marked.encode.bam <br>
#
# ENCFF764ERT: /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/data/KS151_Th17_ASTARR_pool_rep3.f3q10.sorted.with_umis.dups_marked.encode.bam<br>
#
# ENCFF464BLK: /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/data/KS180_Th2_pooledASTARR_output_rep1.f3q10.sorted.with_umis.dups_marked.encode.bam<br>
#
# ENCFF538JII: /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/data/KS151_AllCD4Pooled_ASTARR_retransformed_input_rep4.masked.dups_marked.encode.bam

# %%
import encode_utils as eu
from encode_utils.connection import Connection

conn = Connection("prod")
# Out:
# 2022-04-18 14:35:53,495:eu_debug:	Connecting to www.encodeproject.org
# 2022-04-18 14:35:53,541:eu_debug:	submission=False: In non-submission mode.

# %%
conn.upload_file(file_id='ENCFF764ERT', file_path='/data/reddylab/Revathy/collabs/Keith/ENCODE_submission/data/KS151_Th17_ASTARR_pool_rep3.f3q10.sorted.with_umis.dups_marked.encode.bam')
conn.upload_file(file_id='ENCFF040GNB', file_path='/data/reddylab/Revathy/collabs/Keith/ENCODE_submission/data/KS163_Th17_pooledASTARR_output_rep4.f3q10.sorted.with_umis.dups_marked.encode.bam')
conn.upload_file(file_id='ENCFF464BLK', file_path='/data/reddylab/Revathy/collabs/Keith/ENCODE_submission/data/KS180_Th2_pooledASTARR_output_rep1.f3q10.sorted.with_umis.dups_marked.encode.bam')
conn.upload_file(file_id='ENCFF538JII', file_path='/data/reddylab/Revathy/collabs/Keith/ENCODE_submission/data/KS151_AllCD4Pooled_ASTARR_retransformed_input_rep4.masked.dups_marked.encode.bam')
# Out:
# 2022-04-18 14:36:06,366:eu_debug:
# IN upload_file()
#
# 2022-04-18 14:36:06,368:eu_debug:	Attempting to generate new file upload credentials
# 2022-04-18 14:36:07,132:eu_debug:	Success: upload credentials for 'ENCFF764ERT' regenerated.
# 2022-04-18 14:36:07,135:eu_debug:	>>>>>>GET ENCFF764ERT From DCC with URL https://www.encodeproject.org/ENCFF764ERT/?format=json
# 2022-04-18 14:36:07,686:eu_debug:	Running command 'aws s3 cp /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/data/KS151_Th17_ASTARR_pool_rep3.f3q10.sorted.with_umis.dups_marked.encode.bam s3://encode-files/2021/08/31/c732d1b8-05fd-478f-a4b2-c87b40521c0a/ENCFF764ERT.bam'.
# 2022-04-18 14:36:47,671:eu_debug:	AWS upload successful.
# 2022-04-18 14:36:47,674:eu_debug:
# IN upload_file()
#
# 2022-04-18 14:36:47,675:eu_debug:	Attempting to generate new file upload credentials
# 2022-04-18 14:36:48,442:eu_debug:	Success: upload credentials for 'ENCFF040GNB' regenerated.
# ...

# %%
# %%bash
# md5sum /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/data/KS163_Th17_pooledASTARR_output_rep4.f3q10.sorted.with_umis.dups_marked.encode.bam
# md5sum /data/reddylab/Keith/encode4_duke/processing/starr_seq/210731_KS183_Th1_PooledASTARR_Output_NextSeq-pe-umis/KS187_Th2_ASTARR_allPool_output_Rep2.f3q10.sorted.with_umis.dups_marked.bam
# Out:
# 67958a0f7c5ea855f756d36f53ae7f89  /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/data/KS163_Th17_pooledASTARR_output_rep4.f3q10.sorted.with_umis.dups_marked.encode.bam
# 240b26b0cdeef2b5ec65b2f6256c7205  /data/reddylab/Keith/encode4_duke/processing/starr_seq/210731_KS183_Th1_PooledASTARR_Output_NextSeq-pe-umis/KS187_Th2_ASTARR_allPool_output_Rep2.f3q10.sorted.with_umis.dups_marked.bam

# %% [markdown]
# ### Register biosamples for rep2 and rep3 of Th17 ATACseq

# %%
# %%bash
# source /data/reddylab/software/miniconda3/bin/activate revathy_py3
# cd /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/metadata_Th17
# eu_register.py -m prod -p biosample -i biosample_v1.txt
# Out:
# 2022-06-06 14:30:36,905:eu_debug:	Connecting to www.encodeproject.org
# 2022-06-06 14:30:36,928:eu_debug:	submission=False: In non-submission mode.
# 2022-06-06 14:30:37,640:eu_debug:	submission=True: In submission mode.
# 2022-06-06 14:30:37,667:eu_debug:
# IN post().
# 2022-06-06 14:30:37,667:eu_debug:	<<<<<< POST biosample record tim-reddy:Th17-atac-starrseq-biosample-rep2 To DCC with URL https://www.encodeproject.org/biosample and this payload:
#
# {
#   "aliases": [
#     "tim-reddy:Th17-atac-starrseq-biosample-rep2"
#   ],
#   "award": "/awards/UM1HG009428/",
#   "biosample_ontology": "/biosample-types/primary_cell_CL_0000899/",
#   "donor": "encode:C57BL_6NJ",
#   "genetic_modifications": [
#     "tim-reddy:Th17-atac-starrseq-genetic-modification"
#   ],
#   "lab": "/labs/tim-reddy/",
#   "organism": "mouse",
#   "source": "/sources/maria-ciofani/",
#   "treatments": [
#     "tim-reddy:anti-CD3e",
#     "tim-reddy:anti-CD28",
#     "tim-reddy:3d-anti-IL-4",
# ...

# %%
# %%bash
# source /data/reddylab/software/miniconda3/bin/activate revathy_py3
# cd /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/metadata_Th17
# eu_register.py -m prod -p file -i Th17_ASTARR_processed_data.txt
# Out:
# 2022-09-26 13:23:22,476:eu_debug:	Connecting to www.encodeproject.org
# 2022-09-26 13:23:22,511:eu_debug:	submission=False: In non-submission mode.
# 2022-09-26 13:23:23,262:eu_debug:	submission=True: In submission mode.
# 2022-09-26 13:23:23,283:eu_debug:
# IN post().
# 2022-09-26 13:23:31,636:eu_debug:	<<<<<< POST file record tim-reddy:Th17-atac-starrseq-rep1-bam To DCC with URL https://www.encodeproject.org/file and this payload:
#
# {
#   "aliases": [
#     "tim-reddy:Th17-atac-starrseq-rep1-bam"
#   ],
#   "assembly": "mm10",
#   "award": "/awards/UM1HG009428/",
#   "dataset": "tim-reddy:Th17-atac-starrseq",
#   "derived_from": [
#     "/files/mm10_no_alt_analysis_set_ENCODE/",
#     "tim-reddy:Th17-atac-starrseq-rep1-read1",
#     "tim-reddy:Th17-atac-starrseq-rep1-read2"
#   ],
#   "file_format": "bam",
#   "file_size": 3049944209,
#   "lab": "/labs/tim-reddy/",
#   "md5sum": "29c325a777e2c7dfd11bb7c002a3263c",
#   "output_type": "alignments",
# ...

# %%
# %%bash
# source /data/reddylab/software/miniconda3/bin/activate revathy_py3
# cd /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/metadata_Th17
# eu_register.py -m prod -p file -i Th17_ASTARR_input_processed_data.txt
# Out:
# 2022-09-26 14:02:22,112:eu_debug:	Connecting to www.encodeproject.org
# 2022-09-26 14:02:22,143:eu_debug:	submission=False: In non-submission mode.
# 2022-09-26 14:02:22,835:eu_debug:	submission=True: In submission mode.
# 2022-09-26 14:02:22,841:eu_debug:
# IN post().
# 2022-09-26 14:02:25,981:eu_debug:	<<<<<< POST file record tim-reddy:mmTh17-atac-starrseq-input-rep1-bam To DCC with URL https://www.encodeproject.org/file and this payload:
#
# {
#   "aliases": [
#     "tim-reddy:mmTh17-atac-starrseq-input-rep1-bam"
#   ],
#   "assembly": "mm10",
#   "award": "/awards/UM1HG009428/",
#   "dataset": "tim-reddy:mmTh17-atac-starrseq-input",
#   "derived_from": [
#     "/files/mm10_no_alt_analysis_set_ENCODE/",
#     "tim-reddy:mmTh17-atac-starrseq-input-rep1-read1",
#     "tim-reddy:mmTh17-atac-starrseq-input-rep1-read2"
#   ],
#   "file_format": "bam",
#   "file_size": 1136917023,
#   "lab": "/labs/tim-reddy/",
#   "md5sum": "4abc946d93c3ac25908ceb4ad648563d",
# ...

# %%
# %%bash
# source /data/reddylab/software/miniconda3/bin/activate revathy_py3
# cd /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/metadata_Th17
# eu_register.py -m prod -p file -i Th17_processed_data_step_run.txt --patch -w
# Out:
# 2022-09-26 14:20:11,890:eu_debug:	Connecting to www.encodeproject.org
# 2022-09-26 14:20:11,923:eu_debug:	submission=False: In non-submission mode.
# 2022-09-26 14:20:14,453:eu_debug:	submission=True: In submission mode.
# 2022-09-26 14:20:14,459:eu_debug:
# IN patch()
# 2022-09-26 14:20:14,460:eu_debug:	>>>>>>GET files/ENCFF401RFS From DCC with URL https://www.encodeproject.org/files/ENCFF401RFS/?format=json&datastore=database&frame=edit
# 2022-09-26 14:20:14,837:eu_debug:	<<<<<< PATCHING /files/ENCFF401RFS/ To DCC with URL https://www.encodeproject.org/files/ENCFF401RFS and this payload:
#
# {
#   "step_run": "tim-reddy:starrseq_fastq_to_bam_no_umi_step_run"
# }
#
#
# 2022-09-26 14:20:15,365:eu_debug:	Success.
# 2022-09-26 14:20:15,366:eu_debug:
# IN patch()
# 2022-09-26 14:20:15,366:eu_debug:	>>>>>>GET files/ENCFF316HRY From DCC with URL https://www.encodeproject.org/files/ENCFF316HRY/?format=json&datastore=database&frame=edit
# ...

# %%
# %%bash
# source /data/reddylab/software/miniconda3/bin/activate revathy_py3
# cd /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/metadata_Th17
# eu_register.py -m prod -p file -i Th17_input_processed_data_step_run.txt --patch -w
# Out:
# 2022-09-26 14:38:31,081:eu_debug:	Connecting to www.encodeproject.org
# 2022-09-26 14:38:31,082:eu_debug:	submission=False: In non-submission mode.
# 2022-09-26 14:38:31,848:eu_debug:	submission=True: In submission mode.
# 2022-09-26 14:38:31,854:eu_debug:
# IN patch()
# 2022-09-26 14:38:31,854:eu_debug:	>>>>>>GET files/ENCFF140RFT From DCC with URL https://www.encodeproject.org/files/ENCFF140RFT/?format=json&datastore=database&frame=edit
# 2022-09-26 14:38:32,232:eu_debug:	<<<<<< PATCHING /files/ENCFF140RFT/ To DCC with URL https://www.encodeproject.org/files/ENCFF140RFT and this payload:
#
# {
#   "step_run": "tim-reddy:starrseq_fastq_to_bam_no_umi_step_run"
# }
#
#
# 2022-09-26 14:38:32,660:eu_debug:	Success.
# 2022-09-26 14:38:32,661:eu_debug:
# IN patch()
# 2022-09-26 14:38:32,661:eu_debug:	>>>>>>GET files/ENCFF291HHN From DCC with URL https://www.encodeproject.org/files/ENCFF291HHN/?format=json&datastore=database&frame=edit
# ...

# %%
import encode_utils as eu
from encode_utils.connection import Connection

conn = Connection("prod")

conn.upload_file(file_id='ENCFF140RFT', file_path='/data/reddylab/Revathy/collabs/Keith/ENCODE_submission/data/Th17/KS136_Th17ASTARRInput_rep1.masked.dups_marked.encode.bam')
conn.upload_file(file_id='ENCFF291HHN', file_path='/data/reddylab/Revathy/collabs/Keith/ENCODE_submission/data/Th17/KS136_Th17ASTARRInput_rep2.masked.dups_marked.encode.bam')
conn.upload_file(file_id='ENCFF411EXB', file_path='/data/reddylab/Revathy/collabs/Keith/ENCODE_submission/data/Th17/KS136_Th17ASTARRInput_rep3.masked.dups_marked.encode.bam')
conn.upload_file(file_id='ENCFF403MLB', file_path='/data/reddylab/Revathy/collabs/Keith/ENCODE_submission/data/Th17/KS136_Th17ASTARRInput_rep1.masked.dedup.sorted.rpkm.encode.bw')
conn.upload_file(file_id='ENCFF826LCY', file_path='/data/reddylab/Revathy/collabs/Keith/ENCODE_submission/data/Th17/KS136_Th17ASTARRInput_rep2.masked.dedup.sorted.rpkm.encode.bw')
conn.upload_file(file_id='ENCFF553SBS', file_path='/data/reddylab/Revathy/collabs/Keith/ENCODE_submission/data/Th17/KS136_Th17ASTARRInput_rep3.masked.dedup.sorted.rpkm.encode.bw')
# Out:
# 2022-09-26 14:13:27,585:eu_debug:	Connecting to www.encodeproject.org
# 2022-09-26 14:13:27,617:eu_debug:	submission=False: In non-submission mode.
# 2022-09-26 14:13:28,343:eu_debug:
# IN upload_file()
#
# 2022-09-26 14:13:28,347:eu_debug:	Attempting to generate new file upload credentials
# 2022-09-26 14:13:29,086:eu_debug:	Success: upload credentials for 'ENCFF140RFT' regenerated.
# 2022-09-26 14:13:29,090:eu_debug:	>>>>>>GET ENCFF140RFT From DCC with URL https://www.encodeproject.org/ENCFF140RFT/?format=json
# 2022-09-26 14:13:29,736:eu_debug:	Running command 'aws s3 cp /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/data/Th17/KS136_Th17ASTARRInput_rep1.masked.dups_marked.encode.bam s3://encode-files/2022/09/26/53f8429b-649d-4e5e-a661-70aed24df52c/ENCFF140RFT.bam'.
# 2022-09-26 14:13:46,331:eu_debug:	AWS upload successful.
# 2022-09-26 14:13:46,333:eu_debug:
# IN upload_file()
#
# 2022-09-26 14:13:46,335:eu_debug:	Attempting to generate new file upload credentials
# ...

# %%
conn.upload_file(file_id='ENCFF401RFS', file_path='/data/reddylab/Revathy/collabs/Keith/ENCODE_submission/data/Th17/KS148_Th17_ASTARR_Th17Inp_rep1.f3q10.sorted.with_umis.dups_marked.encode.bam')
conn.upload_file(file_id='ENCFF316HRY', file_path='/data/reddylab/Revathy/collabs/Keith/ENCODE_submission/data/Th17/KS149_Th17_ASTARR_Th17Inp_rep2.f3q10.sorted.with_umis.dups_marked.encode.bam')
conn.upload_file(file_id='ENCFF973LWN', file_path='/data/reddylab/Revathy/collabs/Keith/ENCODE_submission/data/Th17/KS163_Th17_Th17ASTARR_output_rep4.f3q10.sorted.with_umis.dups_marked.encode.bam')
conn.upload_file(file_id='ENCFF241EYI', file_path='/data/reddylab/Revathy/collabs/Keith/ENCODE_submission/data/Th17/KS148_Th17_ASTARR_Th17Inp_rep1.f3q10.sorted.with_umis.dedup.rpkm.encode.bw')
conn.upload_file(file_id='ENCFF780SFM', file_path='/data/reddylab/Revathy/collabs/Keith/ENCODE_submission/data/Th17/KS149_Th17_ASTARR_Th17Inp_rep2.f3q10.sorted.with_umis.dedup.rpkm.encode.bw')
conn.upload_file(file_id='ENCFF121LMY', file_path='/data/reddylab/Revathy/collabs/Keith/ENCODE_submission/data/Th17/KS163_Th17_Th17ASTARR_output_rep4.f3q10.sorted.with_umis.dedup.rpkm.encode.bw')
# Out:
# 2022-09-26 16:46:51,952:eu_debug:
# IN upload_file()
#
# 2022-09-26 16:46:51,954:eu_debug:	Attempting to generate new file upload credentials
# 2022-09-26 16:46:52,791:eu_debug:	Success: upload credentials for 'ENCFF401RFS' regenerated.
# 2022-09-26 16:46:52,792:eu_debug:	>>>>>>GET ENCFF401RFS From DCC with URL https://www.encodeproject.org/ENCFF401RFS/?format=json
# 2022-09-26 16:46:53,428:eu_debug:	Running command 'aws s3 cp /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/data/Th17/KS148_Th17_ASTARR_Th17Inp_rep1.f3q10.sorted.with_umis.dups_marked.encode.bam s3://encode-files/2022/09/26/5a757aa9-6d33-4e6b-8a42-755590a248b7/ENCFF401RFS.bam'.
# 2022-09-26 16:47:30,398:eu_debug:	AWS upload successful.
# 2022-09-26 16:47:30,401:eu_debug:
# IN upload_file()
#
# 2022-09-26 16:47:30,404:eu_debug:	Attempting to generate new file upload credentials
# 2022-09-26 16:47:31,161:eu_debug:	Success: upload credentials for 'ENCFF316HRY' regenerated.
# ...

# %%
import encode_utils as eu
from encode_utils.connection import Connection

conn = Connection("prod")
conn.upload_file(file_id='ENCFF316HRY', file_path='/data/reddylab/Revathy/collabs/Keith/ENCODE_submission/data/Th17/KS149_Th17_ASTARR_Th17Inp_rep2.f3q10.sorted.with_umis.dups_marked.encode.bam')
# Out:
# 2022-10-04 12:02:28,045:eu_debug:	Connecting to www.encodeproject.org
# 2022-10-04 12:02:28,093:eu_debug:	submission=False: In non-submission mode.
# 2022-10-04 12:02:28,824:eu_debug:
# IN upload_file()
#
# 2022-10-04 12:02:28,825:eu_debug:	Attempting to generate new file upload credentials
# 2022-10-04 12:02:29,644:eu_debug:	Success: upload credentials for 'ENCFF316HRY' regenerated.
# 2022-10-04 12:02:29,647:eu_debug:	>>>>>>GET ENCFF316HRY From DCC with URL https://www.encodeproject.org/ENCFF316HRY/?format=json
# 2022-10-04 12:02:30,292:eu_debug:	Running command 'aws s3 cp /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/data/Th17/KS149_Th17_ASTARR_Th17Inp_rep2.f3q10.sorted.with_umis.dups_marked.encode.bam s3://encode-files/2022/09/26/8cfd37f5-6362-4b21-978e-68b9de30d7ef/ENCFF316HRY.bam'.
# 2022-10-04 12:02:58,958:eu_debug:	AWS upload successful.

# %%
# %%bash
# source /data/reddylab/software/miniconda3/bin/activate revathy_py3
# cd /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/metadata_Th17
# eu_register.py -m prod -p reference -i reference_object.txt
# Out:
# 2023-05-08 17:33:39,459:eu_debug:	Connecting to www.encodeproject.org
# 2023-05-08 17:33:39,460:eu_debug:	submission=False: In non-submission mode.
# 2023-05-08 17:33:40,117:eu_debug:	submission=True: In submission mode.
# 2023-05-08 17:33:40,122:eu_debug:
# IN post().
# 2023-05-08 17:33:40,123:eu_debug:	<<<<<< POST reference record tim-reddy:Th17-atac-starrseq-input-reference To DCC with URL https://www.encodeproject.org/reference and this payload:
#
# {
#   "aliases": [
#     "tim-reddy:Th17-atac-starrseq-input-reference"
#   ],
#   "award": "/awards/UM1HG009428/",
#   "elements_selection_method": [
#     "accessible genome regions"
#   ],
#   "lab": "/labs/tim-reddy/",
#   "reference_type": "functional elements"
# }
#
#
# 2023-05-08 17:33:40,522:eu_debug:	Success.
