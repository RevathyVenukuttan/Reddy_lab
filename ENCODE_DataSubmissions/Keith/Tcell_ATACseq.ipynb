# %%
# !ls /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/metadata_Tcell_ATACseq
# Out:
# biosample.txt  experiment.txt  files-fastq.txt	library.txt  replicate.txt

# %%
# %%bash
# source /data/reddylab/software/miniconda3/bin/activate revathy_py3
# cd /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/metadata_Tcell_ATACseq
# sbatch -p all \
#     -o /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/logs/Tcell_ATAC_seq.out \
#     --mem 16G \
#     <<'EOF'
# #!/bin/bash
# NAMES=(biosample experiment library replicate)
# for NAME in ${NAMES[@]};
# do
# eu_register.py -m prod -p ${NAME} -i ${NAME}.txt
# done
# EOF
# Out:
# Submitted batch job 30374416

# %%
# %%bash
# source /data/reddylab/software/miniconda3/bin/activate revathy_py3
# cd /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/metadata_Tcell_ATACseq
# eu_register.py -m prod -p file -i files-fastq.txt
# tim-reddy:mmCD4-Th1-rnaseq-00hr-rep1-read1
# Out:
# 2023-11-13 13:41:31,597:eu_debug:	Connecting to www.encodeproject.org
# 2023-11-13 13:41:31,598:eu_debug:	submission=False: In non-submission mode.
# 2023-11-13 13:41:32,263:eu_debug:	submission=True: In submission mode.
# 2023-11-13 13:41:32,269:eu_debug:
# IN post().
# 2023-11-13 13:41:35,954:eu_debug:	<<<<<< POST file record tim-reddy:mmCD4-Th0-atacseq-rep1-read1 To DCC with URL https://www.encodeproject.org/file and this payload:
#
# {
#   "aliases": [
#     "tim-reddy:mmCD4-Th0-atacseq-rep1-read1"
#   ],
#   "award": "/awards/UM1HG009428/",
#   "dataset": "tim-reddy:mmCD4-Th0-atacseq",
#   "file_format": "fastq",
#   "file_size": 1238135419,
#   "lab": "/labs/tim-reddy/",
#   "md5sum": "6e65d636de1c5a818a28ccaeafc1f710",
#   "output_type": "reads",
#   "paired_end": "1",
#   "platform": "encode:NextSeq500",
#   "read_length": 26,
#   "replicate": "tim-reddy:mmCD4-Th0-atacseq-rep1",
#   "run_type": "paired-ended",
# ...

# %% [markdown]
# ### Submit processed data

# %%
# %%bash
# source /data/reddylab/software/miniconda3/bin/activate revathy_py3
# cd /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/metadata_Tcell_ATACseq
# eu_register.py -m prod -p file -i files_processed_data.txt
# Out:
# 2024-01-29 01:20:32,210:eu_debug:	Connecting to www.encodeproject.org
# 2024-01-29 01:20:32,211:eu_debug:	submission=False: In non-submission mode.
# 2024-01-29 01:20:32,906:eu_debug:	submission=True: In submission mode.
# 2024-01-29 01:20:32,911:eu_debug:
# IN post().
# 2024-01-29 01:20:38,597:eu_debug:	<<<<<< POST file record tim-reddy:mmCD4-Th0-atacseq-rep1-bam To DCC with URL https://www.encodeproject.org/file and this payload:
#
# {
#   "aliases": [
#     "tim-reddy:mmCD4-Th0-atacseq-rep1-bam"
#   ],
#   "assembly": "mm10",
#   "award": "/awards/UM1HG009428/",
#   "dataset": "tim-reddy:mmCD4-Th0-atacseq",
#   "derived_from": [
#     "tim-reddy:mmCD4-Th0-atacseq-rep1-read1",
#     "tim-reddy:mmCD4-Th0-atacseq-rep1-read2"
#   ],
#   "file_format": "bam",
#   "file_size": 2580534791,
#   "lab": "/labs/tim-reddy/",
#   "md5sum": "3ff4d8be7611d39343f878062c982b15",
#   "output_type": "alignments",
# ...

# %% [markdown]
# #### Submit biosamples for other replicates

# %%
# %%bash
# source /data/reddylab/software/miniconda3/bin/activate revathy_py3
# cd /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/metadata_Tcell_ATACseq
# eu_register.py -m prod -p biosample -i biosample_v1.txt
# Out:
# 2024-01-28 23:08:50,438:eu_debug:	Connecting to www.encodeproject.org
# 2024-01-28 23:08:50,460:eu_debug:	submission=False: In non-submission mode.
# 2024-01-28 23:08:51,181:eu_debug:	submission=True: In submission mode.
# 2024-01-28 23:08:51,188:eu_debug:
# IN post().
# 2024-01-28 23:08:51,188:eu_debug:	<<<<<< POST biosample record tim-reddy:mmCD4-Th0-atacseq-rep2-biosample To DCC with URL https://www.encodeproject.org/biosample and this payload:
#
# {
#   "aliases": [
#     "tim-reddy:mmCD4-Th0-atacseq-rep2-biosample"
#   ],
#   "award": "/awards/UM1HG009428/",
#   "biosample_ontology": "/biosample-types/primary_cell_CL_0000084/",
#   "donor": "encode:C57BL_6NJ",
#   "lab": "/labs/tim-reddy/",
#   "organism": "mouse",
#   "source": "/sources/maria-ciofani/"
# }
#
#
# 2024-01-28 23:08:51,614:eu_debug:	Success.
# 2024-01-28 23:08:51,626:eu_debug:
# IN post().
# ...

# %% [markdown]
# ### Correct the bams and bigWigs

# %%
# %%bash
# mkdir -p /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/data/ATAC_seq/bam
# source /data/reddylab/software/miniconda3/bin/activate alex_py3
# sbatch -p all \
#     --array=0-11 \
#     --mem 16G \
#     -o /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/logs/recreate_bams_ATAC.%a.out \
#     <<'EOF'
# #!/bin/bash
# BAMS=(\
# /data/reddylab/Revathy/collabs/atac-seq_Siklenka/processing/atac_seq/Siklenka_6420_200805A5-pe-blacklist-removal/KS133.Treg.72hrs.ASTARR.insert.rep1.masked.dups_marked.bam \
# /data/reddylab/Revathy/collabs/atac-seq_Siklenka/processing/atac_seq/Siklenka_6420_200804A5-pe-blacklist-removal/KS136.Th17.72hrs.ASTARR.insert.rep3.masked.dups_marked.bam \
# /data/reddylab/Revathy/collabs/atac-seq_Siklenka/processing/atac_seq/Siklenka_6420_200805A5-pe-blacklist-removal/KS131.Th2.96hrs.ASTARR.insert.rep2.masked.dups_marked.bam \
# /data/reddylab/Revathy/collabs/atac-seq_Siklenka/processing/atac_seq/Siklenka_6420_200804A5-pe-blacklist-removal/KS134.Th17.72hrs.ASTARR.insert.rep1.masked.dups_marked.bam \
# /data/reddylab/Revathy/collabs/atac-seq_Siklenka/processing/atac_seq/Siklenka_6420_200805A5-pe-blacklist-removal/KS133.Th0.72hrs.ASTARR.insert.rep1.masked.dups_marked.bam \
# /data/reddylab/Revathy/collabs/atac-seq_Siklenka/processing/atac_seq/Siklenka_6420_200805A5-pe-blacklist-removal/KS130.Th1.96hrs.ASTARR.insert.rep2.masked.dups_marked.bam \
# /data/reddylab/Revathy/collabs/atac-seq_Siklenka/processing/atac_seq/Siklenka_6420_200804A5-pe-blacklist-removal/KS136.Th17.72hrs.ASTARR.insert.rep4.masked.dups_marked.bam \
# /data/reddylab/Revathy/collabs/atac-seq_Siklenka/processing/atac_seq/Siklenka_6420_200805A5-pe-blacklist-removal/KS133.Th0.72hrs.ASTARR.insert.rep2.masked.dups_marked.bam \
# /data/reddylab/Revathy/collabs/atac-seq_Siklenka/processing/atac_seq/Siklenka_6420_200804A5-pe-blacklist-removal/KS134.Th17.72hrs.ASTARR.insert.rep2.masked.dups_marked.bam \
# /data/reddylab/Revathy/collabs/atac-seq_Siklenka/processing/atac_seq/Siklenka_6420_200805A5-pe-blacklist-removal/KS130.Th1.96hrs.ASTARR.insert.rep1.masked.dups_marked.bam \
# /data/reddylab/Revathy/collabs/atac-seq_Siklenka/processing/atac_seq/Siklenka_6420_200805A5-pe-blacklist-removal/KS131.Th2.96hrs.ASTARR.insert.rep1.masked.dups_marked.bam \
# /data/reddylab/Revathy/collabs/atac-seq_Siklenka/processing/atac_seq/Siklenka_6420_200805A5-pe-blacklist-removal/KS133.Treg.72hrs.ASTARR.insert.rep2.masked.dups_marked.bam \
# )
# BAM=${BAMS[${SLURM_ARRAY_TASK_ID}]}
# BAM_NAME=$(echo $BAM | cut -d"/" -f10)
# module load samtools
# samtools view -h ${BAM} \
# | sed 's@JH584295.1@chr4_JH584295_random@;s@JH584292.1@chr4_JH584292_random@;s@GL456368.1@chrUn_GL456368@;s@GL456396.1@chrUn_GL456396@;s@GL456359.1@chrUn_GL456359@;s@GL456382.1@chrUn_GL456382@;s@GL456392.1@chrUn_GL456392@;s@GL456394.1@chrUn_GL456394@;s@GL456390.1@chrUn_GL456390@;s@GL456387.1@chrUn_GL456387@;s@GL456381.1@chrUn_GL456381@;s@GL456370.1@chrUn_GL456370@;s@GL456372.1@chrUn_GL456372@;s@GL456389.1@chrUn_GL456389@;s@GL456378.1@chrUn_GL456378@;s@GL456360.1@chrUn_GL456360@;s@GL456385.1@chrUn_GL456385@;s@GL456383.1@chrUn_GL456383@;s@GL456213.1@chr1_GL456213_random@;s@GL456239.1@chrUn_GL456239@;s@GL456367.1@chrUn_GL456367@;s@GL456366.1@chrUn_GL456366@;s@GL456393.1@chrUn_GL456393@;s@GL456216.1@chr4_GL456216_random@;s@GL456379.1@chrUn_GL456379@;s@JH584304.1@chrUn_JH584304@;s@GL456212.1@chr1_GL456212_random@;s@JH584302.1@chrY_JH584302_random@;s@JH584303.1@chrY_JH584303_random@;s@GL456210.1@chr1_GL456210_random@;s@GL456219.1@chr7_GL456219_random@;s@JH584300.1@chrY_JH584300_random@;s@JH584298.1@chr5_JH584298_random@;s@JH584294.1@chr4_JH584294_random@;s@GL456354.1@chr5_GL456354_random@;s@JH584296.1@chr5_JH584296_random@;s@JH584297.1@chr5_JH584297_random@;s@GL456221.1@chr1_GL456221_random@;s@JH584293.1@chr4_JH584293_random@;s@GL456350.1@chr4_GL456350_random@;s@GL456211.1@chr1_GL456211_random@;s@JH584301.1@chrY_JH584301_random@;s@GL456233.1@chrX_GL456233_random@;s@JH584299.1@chr5_JH584299_random@;' \
# | samtools view -b \
# > /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/data/ATAC_seq/bam/${BAM_NAME/.bam/.encode.bam}
# EOF
# Out:
# Submitted batch job 30653120

# %%
# !ls /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/data/ATAC_seq/bam
# Out:
# KS130.Th1.96hrs.ASTARR.insert.rep1.masked.dups_marked.encode.bam
# KS130.Th1.96hrs.ASTARR.insert.rep2.masked.dups_marked.encode.bam
# KS131.Th2.96hrs.ASTARR.insert.rep1.masked.dups_marked.encode.bam
# KS131.Th2.96hrs.ASTARR.insert.rep2.masked.dups_marked.encode.bam
# KS133.Th0.72hrs.ASTARR.insert.rep1.masked.dups_marked.encode.bam
# KS133.Th0.72hrs.ASTARR.insert.rep2.masked.dups_marked.encode.bam
# KS133.Treg.72hrs.ASTARR.insert.rep1.masked.dups_marked.encode.bam
# KS133.Treg.72hrs.ASTARR.insert.rep2.masked.dups_marked.encode.bam
# KS134.Th17.72hrs.ASTARR.insert.rep1.masked.dups_marked.encode.bam
# KS134.Th17.72hrs.ASTARR.insert.rep2.masked.dups_marked.encode.bam
# KS136.Th17.72hrs.ASTARR.insert.rep3.masked.dups_marked.encode.bam
# KS136.Th17.72hrs.ASTARR.insert.rep4.masked.dups_marked.encode.bam

# %%
# %%bash
# mkdir -p /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/data/ATAC_seq/bigWig/
# source /data/reddylab/software/miniconda3/bin/activate alex_py3
# sbatch -p all \
#     --array=0-11 \
#     --mem 16G \
#     -o /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/logs/recreate_bigWigs_ATAC.%a.out \
#     <<'EOF'
# #!/bin/bash
# BIGWIGS=(\
# /data/reddylab/Revathy/collabs/atac-seq_Siklenka/processing/atac_seq/Siklenka_6420_200804A5-pe-blacklist-removal/KS134.Th17.72hrs.ASTARR.insert.rep1.masked.dedup.sorted.rpkm.bw \
# /data/reddylab/Revathy/collabs/atac-seq_Siklenka/processing/atac_seq/Siklenka_6420_200804A5-pe-blacklist-removal/KS134.Th17.72hrs.ASTARR.insert.rep2.masked.dedup.sorted.rpkm.bw \
# /data/reddylab/Revathy/collabs/atac-seq_Siklenka/processing/atac_seq/Siklenka_6420_200805A5-pe-blacklist-removal/KS130.Th1.96hrs.ASTARR.insert.rep1.masked.dedup.sorted.rpkm.bw \
# /data/reddylab/Revathy/collabs/atac-seq_Siklenka/processing/atac_seq/Siklenka_6420_200805A5-pe-blacklist-removal/KS133.Treg.72hrs.ASTARR.insert.rep2.masked.dedup.sorted.rpkm.bw \
# /data/reddylab/Revathy/collabs/atac-seq_Siklenka/processing/atac_seq/Siklenka_6420_200804A5-pe-blacklist-removal/KS136.Th17.72hrs.ASTARR.insert.rep3.masked.dedup.sorted.rpkm.bw \
# /data/reddylab/Revathy/collabs/atac-seq_Siklenka/processing/atac_seq/Siklenka_6420_200805A5-pe-blacklist-removal/KS133.Th0.72hrs.ASTARR.insert.rep1.masked.dedup.sorted.rpkm.bw \
# /data/reddylab/Revathy/collabs/atac-seq_Siklenka/processing/atac_seq/Siklenka_6420_200805A5-pe-blacklist-removal/KS130.Th1.96hrs.ASTARR.insert.rep2.masked.dedup.sorted.rpkm.bw \
# /data/reddylab/Revathy/collabs/atac-seq_Siklenka/processing/atac_seq/Siklenka_6420_200805A5-pe-blacklist-removal/KS131.Th2.96hrs.ASTARR.insert.rep1.masked.dedup.sorted.rpkm.bw \
# /data/reddylab/Revathy/collabs/atac-seq_Siklenka/processing/atac_seq/Siklenka_6420_200805A5-pe-blacklist-removal/KS133.Treg.72hrs.ASTARR.insert.rep1.masked.dedup.sorted.rpkm.bw \
# /data/reddylab/Revathy/collabs/atac-seq_Siklenka/processing/atac_seq/Siklenka_6420_200804A5-pe-blacklist-removal/KS136.Th17.72hrs.ASTARR.insert.rep4.masked.dedup.sorted.rpkm.bw \
# /data/reddylab/Revathy/collabs/atac-seq_Siklenka/processing/atac_seq/Siklenka_6420_200805A5-pe-blacklist-removal/KS131.Th2.96hrs.ASTARR.insert.rep2.masked.dedup.sorted.rpkm.bw \
# /data/reddylab/Revathy/collabs/atac-seq_Siklenka/processing/atac_seq/Siklenka_6420_200805A5-pe-blacklist-removal/KS133.Th0.72hrs.ASTARR.insert.rep2.masked.dedup.sorted.rpkm.bw \
# )
# BIGWIG=${BIGWIGS[${SLURM_ARRAY_TASK_ID}]}
# BIGWIG_NAME=$(echo $BIGWIG | cut -d"/" -f10)
# TMPBDG=/data/reddylab/Revathy/collabs/Keith/ENCODE_submission/data/ATAC_seq/bigWig/${BIGWIG_NAME/.bw/.bdg}
#
# # bigWigToBedGraph
# /data/common/shared_conda_envs/ucsc/bin/bigWigToBedGraph \
#     ${BIGWIG} \
#     ${TMPBDG}
# # Rename chromosomes as needed, and sort again by chromosome and start coordinate
# cat ${TMPBDG} \
# | sed 's@JH584295.1@chr4_JH584295_random@;s@JH584292.1@chr4_JH584292_random@;s@GL456368.1@chrUn_GL456368@;s@GL456396.1@chrUn_GL456396@;s@GL456359.1@chrUn_GL456359@;s@GL456382.1@chrUn_GL456382@;s@GL456392.1@chrUn_GL456392@;s@GL456394.1@chrUn_GL456394@;s@GL456390.1@chrUn_GL456390@;s@GL456387.1@chrUn_GL456387@;s@GL456381.1@chrUn_GL456381@;s@GL456370.1@chrUn_GL456370@;s@GL456372.1@chrUn_GL456372@;s@GL456389.1@chrUn_GL456389@;s@GL456378.1@chrUn_GL456378@;s@GL456360.1@chrUn_GL456360@;s@GL456385.1@chrUn_GL456385@;s@GL456383.1@chrUn_GL456383@;s@GL456213.1@chr1_GL456213_random@;s@GL456239.1@chrUn_GL456239@;s@GL456367.1@chrUn_GL456367@;s@GL456366.1@chrUn_GL456366@;s@GL456393.1@chrUn_GL456393@;s@GL456216.1@chr4_GL456216_random@;s@GL456379.1@chrUn_GL456379@;s@JH584304.1@chrUn_JH584304@;s@GL456212.1@chr1_GL456212_random@;s@JH584302.1@chrY_JH584302_random@;s@JH584303.1@chrY_JH584303_random@;s@GL456210.1@chr1_GL456210_random@;s@GL456219.1@chr7_GL456219_random@;s@JH584300.1@chrY_JH584300_random@;s@JH584298.1@chr5_JH584298_random@;s@JH584294.1@chr4_JH584294_random@;s@GL456354.1@chr5_GL456354_random@;s@JH584296.1@chr5_JH584296_random@;s@JH584297.1@chr5_JH584297_random@;s@GL456221.1@chr1_GL456221_random@;s@JH584293.1@chr4_JH584293_random@;s@GL456350.1@chr4_GL456350_random@;s@GL456211.1@chr1_GL456211_random@;s@JH584301.1@chrY_JH584301_random@;s@GL456233.1@chrX_GL456233_random@;s@JH584299.1@chr5_JH584299_random@;' \
# | sort -k1,1 -k2,2n \
# > ${TMPBDG/.bdg/.1.bdg}
# rm -f ${TMPBDG}
# # bedGraphToBigWig
# /data/common/shared_conda_envs/ucsc/bin/bedGraphToBigWig \
#     ${TMPBDG/.bdg/.1.bdg} \
#     /data/reddylab/Reference_Data/Genomes/GRCm38.p6/mm10_no_alt_analysis_set_ENCODE.chrom_sizes.txt \
#     ${TMPBDG/.bdg/.encode.bw}
# rm -f ${TMPBDG/.bdg/.1.bdg}
# EOF
# Out:
# Submitted batch job 30653132

# %%
import encode_utils as eu
from encode_utils.connection import Connection
import pandas as pd

conn = Connection("prod")
corrected_bam = pd.read_csv('/data/reddylab/Revathy/collabs/Keith/ENCODE_submission/metadata_Tcell_ATACseq/corrected_bam.txt', sep='\t')

for n in range(0,len(corrected_bam)):
    conn.upload_file(file_id=corrected_bam.file_id[n], file_path=corrected_bam.file_path[n])
# Out:
# 2024-02-05 15:14:18,018:eu_debug:	Connecting to www.encodeproject.org
# 2024-02-05 15:14:18,067:eu_debug:	submission=False: In non-submission mode.
# 2024-02-05 15:14:18,758:eu_debug:
# IN upload_file()
#
# 2024-02-05 15:14:18,759:eu_debug:	Attempting to generate new file upload credentials
# 2024-02-05 15:14:19,536:eu_debug:	Success: upload credentials for 'ENCFF705NGT' regenerated.
# 2024-02-05 15:14:19,538:eu_debug:	>>>>>>GET ENCFF705NGT From DCC with URL https://www.encodeproject.org/ENCFF705NGT/?format=json
# 2024-02-05 15:14:20,145:eu_debug:	Running command 'aws s3 cp /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/data/ATAC_seq/bam/KS133.Treg.72hrs.ASTARR.insert.rep1.masked.dups_marked.encode.bam s3://encode-files/2024/01/29/e8452eec-c259-4e38-bddd-8a603c1a9bdd/ENCFF705NGT.bam'.
# 2024-02-05 15:14:47,682:eu_debug:	AWS upload successful.
# 2024-02-05 15:14:47,684:eu_debug:
# IN upload_file()
#
# ...

# %%
import encode_utils as eu
from encode_utils.connection import Connection
import pandas as pd

conn = Connection("prod")
corrected_bw = pd.read_csv('/data/reddylab/Revathy/collabs/Keith/ENCODE_submission/metadata_Tcell_ATACseq/corrected_bw.txt', sep='\t')

for n in range(0,len(corrected_bw)):
    conn.upload_file(file_id=corrected_bw.file_id[n], file_path=corrected_bw.file_path[n])
# Out:
# 2024-02-05 15:19:54,889:eu_debug:	Connecting to www.encodeproject.org
# 2024-02-05 15:19:54,892:eu_debug:	submission=False: In non-submission mode.
# 2024-02-05 15:19:55,660:eu_debug:
# IN upload_file()
#
# 2024-02-05 15:19:55,661:eu_debug:	Attempting to generate new file upload credentials
# 2024-02-05 15:19:56,520:eu_debug:	Success: upload credentials for 'ENCFF227SLV' regenerated.
# 2024-02-05 15:19:56,522:eu_debug:	>>>>>>GET ENCFF227SLV From DCC with URL https://www.encodeproject.org/ENCFF227SLV/?format=json
# 2024-02-05 15:19:57,229:eu_debug:	Running command 'aws s3 cp /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/data/ATAC_seq/bigWig/KS134.Th17.72hrs.ASTARR.insert.rep1.masked.dedup.sorted.rpkm.encode.bw s3://encode-files/2024/01/29/cb323f7d-fb4f-40c6-9a8d-97c1b5395e12/ENCFF227SLV.bigWig'.
# 2024-02-05 15:20:02,852:eu_debug:	AWS upload successful.
# 2024-02-05 15:20:02,855:eu_debug:
# IN upload_file()
#
# ...

# %%
# !ls /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/metadata_Tcell_ATACseq/*.txt
# Out:
# /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/metadata_Tcell_ATACseq/biosample.txt
# /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/metadata_Tcell_ATACseq/biosample_v1.txt
# /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/metadata_Tcell_ATACseq/corrected_bam.txt
# /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/metadata_Tcell_ATACseq/corrected_bw.txt
# /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/metadata_Tcell_ATACseq/experiment.txt
# /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/metadata_Tcell_ATACseq/file_ids.txt
# /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/metadata_Tcell_ATACseq/file_md5sum.txt
# /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/metadata_Tcell_ATACseq/files-fastq.txt
# /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/metadata_Tcell_ATACseq/files_processed_data.txt
# /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/metadata_Tcell_ATACseq/library.txt
# ...

# %%
import pandas as pd

file_id = pd.read_csv('/data/reddylab/Revathy/collabs/Keith/ENCODE_submission/metadata_Tcell_ATACseq/file_ids.txt', sep='\t')
file_md5sum = pd.read_csv('/data/reddylab/Revathy/collabs/Keith/ENCODE_submission/metadata_Tcell_ATACseq/file_md5sum.txt', sep='\t')

md5sum = file_id.merge(file_md5sum, on='original_file_name', how='inner')
md5sum[['ID','md5sum']].to_csv('/data/reddylab/Revathy/collabs/Keith/ENCODE_submission/metadata_Tcell_ATACseq/patch_md5sum.txt', sep='\t', index=None)

# %%
# !cat /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/metadata_Tcell_ATACseq/file_md5sum.txt
# Out:
# md5sum	original_file_name
# 39db15a7005aa0f367a79d7a126ab51a	/data/reddylab/Revathy/collabs/Keith/ENCODE_submission/data/ATAC_seq/bam/KS130.Th1.96hrs.ASTARR.insert.rep1.masked.dups_marked.encode.bam
# 1f7c13c8cddadee22403cb12e8f850d2	/data/reddylab/Revathy/collabs/Keith/ENCODE_submission/data/ATAC_seq/bam/KS130.Th1.96hrs.ASTARR.insert.rep2.masked.dups_marked.encode.bam
# 6b59331b99e32200f39968c4adae661e	/data/reddylab/Revathy/collabs/Keith/ENCODE_submission/data/ATAC_seq/bam/KS131.Th2.96hrs.ASTARR.insert.rep1.masked.dups_marked.encode.bam
# fe66d5475c4b2eefba9142f4af3a4c83	/data/reddylab/Revathy/collabs/Keith/ENCODE_submission/data/ATAC_seq/bam/KS131.Th2.96hrs.ASTARR.insert.rep2.masked.dups_marked.encode.bam
# a0c3709f710aeb5c0ee836484bcbbd68	/data/reddylab/Revathy/collabs/Keith/ENCODE_submission/data/ATAC_seq/bam/KS133.Th0.72hrs.ASTARR.insert.rep1.masked.dups_marked.encode.bam
# ...

# %%
# %%bash
# source /data/reddylab/software/miniconda3/bin/activate revathy_py3
# cd /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/metadata_Tcell_ATACseq/
# eu_register.py -m prod -p file -i patch_md5sum.txt --patch -w
# Out:
# 2024-02-13 14:55:45,350:eu_debug:	Connecting to www.encodeproject.org
# 2024-02-13 14:55:45,397:eu_debug:	submission=False: In non-submission mode.
# 2024-02-13 14:55:46,080:eu_debug:	submission=True: In submission mode.
# 2024-02-13 14:55:46,086:eu_debug:
# IN patch()
# 2024-02-13 14:55:46,086:eu_debug:	>>>>>>GET ENCFF125ODP From DCC with URL https://www.encodeproject.org/ENCFF125ODP/?format=json&datastore=database&frame=edit
# 2024-02-13 14:55:46,464:eu_debug:	<<<<<< PATCHING ENCFF125ODP To DCC with URL https://www.encodeproject.org/ENCFF125ODP and this payload:
#
# {
#   "md5sum": "ba41584b3145ad1c1157211e9119e93f"
# }
#
#
# 2024-02-13 14:55:46,939:eu_debug:	Success.
# 2024-02-13 14:55:46,939:eu_debug:
# IN patch()
# 2024-02-13 14:55:46,939:eu_debug:	>>>>>>GET ENCFF652FOA From DCC with URL https://www.encodeproject.org/ENCFF652FOA/?format=json&datastore=database&frame=edit
# ...

# %%
# !md5sum /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/data/ATAC_seq/bigWig/*Th2*.bw
# Out:
# 37e8aa69373076b96ebb352fa5ae3a6a  /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/data/ATAC_seq/bigWig/KS131.Th2.96hrs.ASTARR.insert.rep1.masked.dedup.sorted.rpkm.encode.bw
# 3ba78d4d24bf6488f2f711041188c7b6  /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/data/ATAC_seq/bigWig/KS131.Th2.96hrs.ASTARR.insert.rep2.masked.dedup.sorted.rpkm.encode.bw
