# %%
# %%bash
# source /data/reddylab/software/miniconda3/bin/activate revathy_py3
# cd /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/metadata_Tcell_RNAseq
# sbatch -p all \
#     -o /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/logs/Tcell_RNAseq.out \
#     --mem 16G \
#     <<'EOF'
# #!/bin/bash
# NAMES=(biosample experiment library replicate)
# for NAME in ${NAMES[@]};
# do
# eu_register.py -m prod -p ${NAME} -i ${NAME}.txt
# done
# EOF
# Out:
# Submitted batch job 30654879

# %%
# !ls /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/metadata_Tcell_RNAseq
# Out:
# biosample.txt  experiment-series.txt  files-fastq.txt  replicate.txt
# EU_Logs        experiment.txt	      library.txt

# %%
# %%bash
# source /data/reddylab/software/miniconda3/bin/activate revathy_py3
# cd /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/metadata_Tcell_RNAseq
# eu_register.py -m prod -p file -i files-fastq.txt
# Out:
# 2024-03-04 15:07:56,157:eu_debug:	Connecting to www.encodeproject.org
# 2024-03-04 15:07:56,158:eu_debug:	submission=False: In non-submission mode.
# 2024-03-04 15:07:56,876:eu_debug:	submission=True: In submission mode.
# 2024-03-04 15:07:56,882:eu_debug:
# IN post().
# 2024-03-04 15:08:02,550:eu_debug:	<<<<<< POST file record tim-reddy:mmCD4-Th1-rnaseq-00hr-rep1-read1 To DCC with URL https://www.encodeproject.org/file and this payload:
#
# {
#   "aliases": [
#     "tim-reddy:mmCD4-Th1-rnaseq-00hr-rep1-read1"
#   ],
#   "award": "/awards/UM1HG009428/",
#   "dataset": "tim-reddy:mmCD4-Th1-rnaseq-00hr",
#   "file_format": "fastq",
#   "file_size": 2212515165,
#   "lab": "/labs/tim-reddy/",
#   "md5sum": "669cb47748b38f9886f5801ed9524a9d",
#   "output_type": "reads",
#   "paired_end": "1",
#   "platform": "encode:NextSeq500",
#   "read_length": 26,
#   "replicate": "tim-reddy:mmCD4-Th1-rnaseq-00hr-rep1",
#   "run_type": "paired-ended",
# ...

# %%
# %%bash
# source /data/reddylab/software/miniconda3/bin/activate revathy_py3
# cd /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/metadata_Tcell_RNAseq
# eu_register.py -m prod -p experiment_series -i experiment-series.txt
# Out:
# 2024-02-05 13:55:18,126:eu_debug:	Connecting to www.encodeproject.org
# 2024-02-05 13:55:18,127:eu_debug:	submission=False: In non-submission mode.
# 2024-02-05 13:55:18,791:eu_debug:	submission=True: In submission mode.
# 2024-02-05 13:55:18,795:eu_debug:
# IN post().
# 2024-02-05 13:55:18,796:eu_debug:	<<<<<< POST experiment_series record tim-reddy:mmCD4-Th1-rnaseq-series To DCC with URL https://www.encodeproject.org/experiment_series and this payload:
#
# {
#   "aliases": [
#     "tim-reddy:mmCD4-Th1-rnaseq-series"
#   ],
#   "award": "/awards/UM1HG009428/",
#   "lab": "/labs/tim-reddy/",
#   "related_datasets": [
#     "tim-reddy:mmCD4-Th1-rnaseq-00hr",
#     "tim-reddy:mmCD4-Th1-rnaseq-02hr",
#     "tim-reddy:mmCD4-Th1-rnaseq-16hr",
#     "tim-reddy:mmCD4-Th1-rnaseq-24hr",
#     "tim-reddy:mmCD4-Th1-rnaseq-48hr",
#     "tim-reddy:mmCD4-Th1-rnaseq-sorted72hr"
#   ]
# }
#
#
# 2024-02-05 13:55:19,513:eu_debug:	Success.

# %% [markdown]
# ### patch the correct read length for the fastq files

# %%
# %%bash
# source /data/reddylab/software/miniconda3/bin/activate revathy_py3
# cd /data/reddylab/Revathy/collabs/Keith/ENCODE_submission/metadata_Tcell_RNAseq
# eu_register.py -m prod -p file -i corrected_read_len_Tcell_RNA.txt --patch -w
# Out:
# 2024-04-15 12:42:32,652:eu_debug:	Connecting to www.encodeproject.org
# 2024-04-15 12:42:32,688:eu_debug:	submission=False: In non-submission mode.
# 2024-04-15 12:42:33,299:eu_debug:	submission=True: In submission mode.
# 2024-04-15 12:42:33,306:eu_debug:
# IN patch()
# 2024-04-15 12:42:33,306:eu_debug:	>>>>>>GET ENCFF296ZHT From DCC with URL https://www.encodeproject.org/ENCFF296ZHT/?format=json&datastore=database&frame=edit
# 2024-04-15 12:42:33,685:eu_debug:	<<<<<< PATCHING ENCFF296ZHT To DCC with URL https://www.encodeproject.org/ENCFF296ZHT and this payload:
#
# {
#   "read_length": 51
# }
#
#
# 2024-04-15 12:42:34,226:eu_debug:	Success.
# 2024-04-15 12:42:34,226:eu_debug:
# IN patch()
# 2024-04-15 12:42:34,227:eu_debug:	>>>>>>GET ENCFF132YTK From DCC with URL https://www.encodeproject.org/ENCFF132YTK/?format=json&datastore=database&frame=edit
# ...
