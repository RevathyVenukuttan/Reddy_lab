# %%
# !pwd
# Out:
# /gpfs/fs1/data/reddylab/Revathy/collabs/Kari/ENCODE/wgSTARR_5person

# %%
# %%bash
# cd /data/reddylab/Revathy/collabs/Kari/ENCODE/wgSTARR_5person/metadata
# eu_register.py -m prod -p biosample -i biosample.txt
# Out:
# 2023-05-01 09:58:10,836:eu_debug:	Connecting to www.encodeproject.org
# 2023-05-01 09:58:10,837:eu_debug:	submission=False: In non-submission mode.
# 2023-05-01 09:58:11,520:eu_debug:	submission=True: In submission mode.
# 2023-05-01 09:58:11,526:eu_debug:
# IN post().
# 2023-05-01 09:58:11,526:eu_debug:	<<<<<< POST biosample record tim-reddy:wg-starrseq-k562-5person-rep1-biosample To DCC with URL https://www.encodeproject.org/biosample and this payload:
#
# {
#   "aliases": [
#     "tim-reddy:wg-starrseq-k562-5person-rep1-biosample"
#   ],
#   "award": "/awards/UM1HG009428/",
#   "biosample_ontology": "encode:K562",
#   "donor": "encode:donor of K562",
#   "genetic_modifications": [
#     "tim-reddy:wg-starrseq-NA18517-genetic-modification"
#   ],
#   "lab": "/labs/tim-reddy/",
#   "organism": "human",
#   "source": "/sources/atcc/"
# }
#
#
# 2023-05-01 09:58:12,437:eu_debug:	Success.
# 2023-05-01 09:58:12,437:eu_debug:
# IN post().
# ...

# %%
# %%bash
# cd /data/reddylab/Revathy/collabs/Kari/ENCODE/wgSTARR_5person/metadata
# eu_register.py -m prod -p library -i library.txt
# Out:
# 2023-05-01 12:40:27,722:eu_debug:	Connecting to www.encodeproject.org
# 2023-05-01 12:40:27,723:eu_debug:	submission=False: In non-submission mode.
# 2023-05-01 12:40:28,383:eu_debug:	submission=True: In submission mode.
# 2023-05-01 12:40:28,388:eu_debug:
# IN post().
# 2023-05-01 12:40:28,388:eu_debug:	<<<<<< POST library record tim-reddy:wg-starrseq-5person-input-rep1-lib To DCC with URL https://www.encodeproject.org/library and this payload:
#
# {
#   "aliases": [
#     "tim-reddy:wg-starrseq-5person-input-rep1-lib"
#   ],
#   "award": "/awards/UM1HG009428/",
#   "lab": "/labs/tim-reddy/",
#   "nucleic_acid_term_name": "DNA",
#   "size_range": "300-800"
# }
#
#
# 2023-05-01 12:40:28,779:eu_debug:	{'code': 409, 'title': 'Conflict', '@type': ['HTTPConflict', 'Error'], 'description': 'There was a conflict when trying to complete your request.', 'detail': "Keys conflict: [('alias', 'tim-reddy:wg-starrseq-5person-input-rep1-lib')]", 'status': 'error'}
# ...

# %%
# %%bash
# cd /data/reddylab/Revathy/collabs/Kari/ENCODE/wgSTARR_5person/metadata
# eu_register.py -m prod -p functional_characterization_experiment -i FunctionalCharacterizationExperiment.txt
# Out:
# 2023-05-01 13:12:14,798:eu_debug:	Connecting to www.encodeproject.org
# 2023-05-01 13:12:14,801:eu_debug:	submission=False: In non-submission mode.
# 2023-05-01 13:12:15,461:eu_debug:	submission=True: In submission mode.
# 2023-05-01 13:12:15,472:eu_debug:
# IN post().
# 2023-05-01 13:12:15,473:eu_debug:	<<<<<< POST functional_characterization_experiment record tim-reddy:wg-starrseq-5person-input To DCC with URL https://www.encodeproject.org/functional_characterization_experiment and this payload:
#
# {
#   "aliases": [
#     "tim-reddy:wg-starrseq-5person-input"
#   ],
#   "assay_term_name": "pooled clone sequencing",
#   "award": "/awards/UM1HG009428/",
#   "biosample_ontology": "/biosample-types/cloning_host_NTR_0000545/",
#   "control_type": "control",
#   "lab": "/labs/tim-reddy/",
#   "plasmids_library_type": "elements mapping"
# }
#
#
# 2023-05-01 13:12:15,913:eu_debug:	Success.
# 2023-05-01 13:12:15,936:eu_debug:
# IN post().
# ...

# %%
# %%bash
# cd /data/reddylab/Revathy/collabs/Kari/ENCODE/wgSTARR_5person/metadata
# eu_register.py -m prod -p replicate -i Replicate.txt
# Out:
# 2023-08-07 08:50:26,009:eu_debug:	Connecting to www.encodeproject.org
# 2023-08-07 08:50:26,010:eu_debug:	submission=False: In non-submission mode.
# 2023-08-07 08:50:26,686:eu_debug:	submission=True: In submission mode.
# 2023-08-07 08:50:26,692:eu_debug:
# IN post().
# 2023-08-07 08:50:26,692:eu_debug:	<<<<<< POST replicate record tim-reddy:wg-starrseq-5person-input-rep2 To DCC with URL https://www.encodeproject.org/replicate and this payload:
#
# {
#   "aliases": [
#     "tim-reddy:wg-starrseq-5person-input-rep2"
#   ],
#   "biological_replicate_number": 1,
#   "experiment": "tim-reddy:wg-starrseq-k562-5person-input",
#   "library": "tim-reddy:wg-starrseq-5person-input-rep2-lib",
#   "technical_replicate_number": 2
# }
#
#
# 2023-08-07 08:50:27,136:eu_debug:	Success.
# 2023-08-07 08:50:27,137:eu_debug:
# IN post().
# ...

# %%
# %%bash
# cd /data/reddylab/Revathy/collabs/Kari/ENCODE/wgSTARR_5person/metadata
# eu_register.py -m prod -p file -i files.txt
# Out:
# Process is terminated.

# %%
# !ls /data/reddylab/kstrouse/superstarr/output_libs/POOL1_K562/data/starr_seq/processed_raw_reads/Strouse_7124_210718A6/POOL1_K562_rep1.1.R1.fastq.gz
# Out:
# /data/reddylab/kstrouse/superstarr/output_libs/POOL1_K562/data/starr_seq/processed_raw_reads/Strouse_7124_210718A6/POOL1_K562_rep1.1.R1.fastq.gz

# %%
import encode_utils as eu
from encode_utils.connection import Connection

conn = Connection("prod")
conn.upload_file(file_id='ENCFF511FSD', file_path='/data/reddylab/kstrouse/superstarr/output_libs/POOL1_K562/data/starr_seq/processed_raw_reads/Strouse_7124_210718A6/POOL1_K562_rep1.1.R1.fastq.gz')
# Out:
# 2023-06-05 12:37:58,584:eu_debug:	Connecting to www.encodeproject.org
# 2023-06-05 12:37:58,587:eu_debug:	submission=False: In non-submission mode.
# 2023-06-05 12:37:59,311:eu_debug:
# IN upload_file()
#
# 2023-06-05 12:37:59,313:eu_debug:	Attempting to generate new file upload credentials
# 2023-06-05 12:38:00,270:eu_debug:	Success: upload credentials for 'ENCFF511FSD' regenerated.
# 2023-06-05 12:38:00,272:eu_debug:	>>>>>>GET ENCFF511FSD From DCC with URL https://www.encodeproject.org/ENCFF511FSD/?format=json
# 2023-06-05 12:38:00,983:eu_debug:	Running command 'aws s3 cp /data/reddylab/kstrouse/superstarr/output_libs/POOL1_K562/data/starr_seq/processed_raw_reads/Strouse_7124_210718A6/POOL1_K562_rep1.1.R1.fastq.gz s3://encode-files/2023/05/22/757bfc06-d592-48b1-99af-89451e356e0c/ENCFF511FSD.fastq.gz'.
# 2023-06-05 12:38:48,312:eu_debug:	AWS upload successful.

# %% [markdown]
# ### CRADLE peak file

# %%
# %%bash
# mkdir -p /data/reddylab/Revathy/collabs/Kari/ENCODE/wgSTARR_5person/data/
# cat /data/reddylab/kstrouse/superstarr/output_libs/POOL1_K562/processing/starr_seq/POOL1_K562_reps123/CRADLEcorr_kmer100/peaks/fdr0.05/CRADLE_peaks \
# | tail -n+2 \
# | awk -vOFS="\t" '{print $1, $2, $3, $4, '100',$6, $7, $8, $9, $10, $11}' \
# > /data/reddylab/Revathy/collabs/Kari/ENCODE/wgSTARR_5person/data/wgSTARRseq_k562_5person_fdr0.05.CRADLE_peaks

# %%
# %%bash
# gzip -c /data/reddylab/Revathy/collabs/Kari/ENCODE/wgSTARR_5person/data/wgSTARRseq_k562_5person_fdr0.05.CRADLE_peaks \
# > /data/reddylab/Revathy/collabs/Kari/ENCODE/wgSTARR_5person/data/wgSTARRseq_k562_5person_fdr0.05.CRADLE_peaks.bed.gz

# %%
# %%bash
# /data/common/shared_conda_envs/ucsc/bin/bedToBigBed \
# /data/reddylab/Revathy/collabs/Kari/ENCODE/wgSTARR_5person/data/wgSTARRseq_k562_5person_fdr0.05.CRADLE_peaks \
# /data/reddylab/Reference_Data/Genomes/hg38/hg38.fa.chrom.sizes \
# -as=/home/rv103/reddylab_data/Revathy/software/mpra_starr.as \
# -type=bed6+5 \
# /data/reddylab/Revathy/collabs/Kari/ENCODE/wgSTARR_5person/data/wgSTARRseq_k562_5person_fdr0.05.CRADLE_peaks.bigBed
# Out:
# pass1 - making usageList (23 chroms): 16 millis
# pass2 - checking and writing primary data (60732 records, 11 fields): 377 millis

# %%
# %%bash
# cd /data/reddylab/Revathy/collabs/Kari/ENCODE/wgSTARR_5person/metadata
# eu_register.py -m prod -p file -i file-CRADLE_peaks.txt
# Out:
# 2023-06-05 13:21:32,634:eu_debug:	Connecting to www.encodeproject.org
# 2023-06-05 13:21:32,665:eu_debug:	submission=False: In non-submission mode.
# 2023-06-05 13:21:33,340:eu_debug:	submission=True: In submission mode.
# 2023-06-05 13:21:33,346:eu_debug:
# IN post().
# 2023-06-05 13:21:33,352:eu_debug:	<<<<<< POST file record tim-reddy:wg-starrseq-k562-5person_CRADLE_peak-bed To DCC with URL https://www.encodeproject.org/file and this payload:
#
# {
#   "aliases": [
#     "tim-reddy:wg-starrseq-k562-5person_CRADLE_peak-bed"
#   ],
#   "assembly": "GRCh38",
#   "award": "/awards/UM1HG009428/",
#   "dataset": "tim-reddy:wg-starrseq-k562-NA18517_NA18519_NA18858_NA18868_NA18873",
#   "derived_from": [
#     "tim-reddy:wg-starrseq-k562-5person_rep1_bw",
#     "tim-reddy:wg-starrseq-k562-5person_rep2_bw",
#     "tim-reddy:wg-starrseq-k562-5person_rep3_bw"
#   ],
#   "file_format": "bed",
#   "file_format_type": "element enrichments",
#   "file_size": 1338262,
# ...

# %% [markdown]
# ### Patch Analysis Step run

# %%
# %%bash
# source /data/reddylab/software/miniconda3/bin/activate revathy_py3
# cd /data/reddylab/Revathy/collabs/Kari/ENCODE/wgSTARR_5person/metadata
# eu_register.py -m prod -p file -i patch_step_run.txt --patch
# Out:
# 2023-06-05 13:54:15,050:eu_debug:	Connecting to www.encodeproject.org
# 2023-06-05 13:54:15,083:eu_debug:	submission=False: In non-submission mode.
# 2023-06-05 13:54:15,740:eu_debug:	submission=True: In submission mode.
# 2023-06-05 13:54:15,747:eu_debug:
# IN patch()
# 2023-06-05 13:54:15,747:eu_debug:	>>>>>>GET files/ENCFF678CBN From DCC with URL https://www.encodeproject.org/files/ENCFF678CBN/?format=json&datastore=database&frame=edit
# 2023-06-05 13:54:16,105:eu_debug:	<<<<<< PATCHING /files/ENCFF678CBN/ To DCC with URL https://www.encodeproject.org/files/ENCFF678CBN and this payload:
#
# {
#   "step_run": "tim-reddy:starrseq_fastq_to_bam_with_umi_step_run"
# }
#
#
# 2023-06-05 13:54:16,762:eu_debug:	Success.
# 2023-06-05 13:54:16,762:eu_debug:
# IN patch()
# 2023-06-05 13:54:16,763:eu_debug:	>>>>>>GET files/ENCFF405KDE From DCC with URL https://www.encodeproject.org/files/ENCFF405KDE/?format=json&datastore=database&frame=edit
# ...

# %% [markdown]
# ## Input samples

# %%
# %%bash
# cd /data/reddylab/Revathy/collabs/Kari/ENCODE/wgSTARR_5person/metadata
# eu_register.py -m prod -p file -i files_input.txt
# Out:
# 2023-08-07 08:50:34,532:eu_debug:	Connecting to www.encodeproject.org
# 2023-08-07 08:50:34,533:eu_debug:	submission=False: In non-submission mode.
# 2023-08-07 08:50:35,200:eu_debug:	submission=True: In submission mode.
# 2023-08-07 08:50:35,206:eu_debug:
# IN post().
# 2023-08-07 08:51:18,066:eu_debug:	<<<<<< POST file record tim-reddy:wg-starrseq-k562-5person-input_rep1_read1 To DCC with URL https://www.encodeproject.org/file and this payload:
#
# {
#   "aliases": [
#     "tim-reddy:wg-starrseq-k562-5person-input_rep1_read1"
#   ],
#   "award": "/awards/UM1HG009428/",
#   "dataset": "tim-reddy:wg-starrseq-k562-5person-input",
#   "file_format": "fastq",
#   "file_size": 16982732336,
#   "lab": "/labs/tim-reddy/",
#   "md5sum": "59368e9f4525939500aed589d34d850b",
#   "output_type": "reads",
#   "paired_end": "1",
#   "platform": "encode:NextSeq500",
#   "read_length": 25,
#   "replicate": "tim-reddy:wg-starrseq-5person-input-rep1",
#   "run_type": "paired-ended",
# ...

# %% [markdown]
# ### Submit elements reference

# %%
# %%bash
# source /data/reddylab/software/miniconda3/bin/activate revathy_py3
# cd /data/reddylab/Revathy/collabs/Kari/ENCODE/wgSTARR_5person/metadata
# eu_register.py -m prod -p reference -i reference_object.txt
# Out:
# 2023-08-21 09:41:33,791:eu_debug:	Connecting to www.encodeproject.org
# 2023-08-21 09:41:33,822:eu_debug:	submission=False: In non-submission mode.
# 2023-08-21 09:41:34,534:eu_debug:	submission=True: In submission mode.
# 2023-08-21 09:41:34,540:eu_debug:
# IN post().
# 2023-08-21 09:41:34,541:eu_debug:	<<<<<< POST reference record tim-reddy:wg-starrseq-k562-NA18517_NA18519_NA18858_NA18868_NA18873-input-reference To DCC with URL https://www.encodeproject.org/reference and this payload:
#
# {
#   "aliases": [
#     "tim-reddy:wg-starrseq-k562-NA18517_NA18519_NA18858_NA18868_NA18873-input-reference"
#   ],
#   "award": "/awards/UM1HG009428/",
#   "elements_selection_method": [
#     "accessible genome regions"
#   ],
#   "lab": "/labs/tim-reddy/",
#   "reference_type": "functional elements"
# }
#
#
# 2023-08-21 09:41:34,943:eu_debug:	Success.
