# %%
import pandas as pd

de_tables = pd.read_csv('/data/reddylab/Revathy/dev/Maria/human-th-ms/results/rna-seq/de_tables/MSvControl.tab', sep='\t')
ABC_scores = pd.read_csv('/data/reddylab/Revathy/dev/Maria/ABC/ABC_score/Th17_hic.threshold0.02/EnhancerPredictions.txt', sep='\t')
ABC_scores.sort_values('ABC.Score', ascending=False).head(10)
# Out:
#           chr     start       end                                name  \
# 19327   chr15  22838394  22838894       genic|chr15:22838394-22838894
# 92510    chr3  81761395  81761895        genic|chr3:81761395-81761895
# 524      chr9  71910943  71911760        genic|chr9:71910943-71911760
# 19389   chr15  23039322  23039822  intergenic|chr15:23039322-23039822
# 92566    chr3  88059005  88059505   intergenic|chr3:88059005-88059505
# 89052    chr3  36992881  36993600   intergenic|chr3:36992881-36993600
# 154872  chr18  70205476  70205976       genic|chr18:70205476-70205976
# 600      chr9  72364985  72365485        genic|chr9:72364985-72365485
# 136988   chrX  84502229  84502729        genic|chrX:84502229-84502729
# 61377    chr7  87345278  87345914        genic|chr7:87345278-87345914
#
#        TargetGene  TargetGeneTSS CellType  ABC.Score
# 19327     TUBGCP5       22833394     Th17   0.859508
# 92510        GBE1       81810950     Th17   0.817031
# ...

# %%
de_tables.sort_values('FDR').head(10)
# Out:
#         ENSEMBL_ID     Symbol  \
# 0  ENSG00000103811       CTSH
# 1  ENSG00000253522  MIR3142HG
# 2  ENSG00000186654       PRR5
# 3  ENSG00000012779      ALOX5
# 4  ENSG00000180549       FUT7
# 5  ENSG00000135631  RAB11FIP5
# 6  ENSG00000099985        OSM
# 7  ENSG00000134107    BHLHE40
# 8  ENSG00000080573     COL5A3
# 9  ENSG00000099282    TSPAN15
#
#                                          Description     logFC    logCPM  \
# 0     cathepsin H [Source:HGNC Symbol;Acc:HGNC:2535] -1.328381  5.678615
# 1  MIR3142 host gene [Source:HGNC Symbol;Acc:HGNC...  1.380565  2.565995
# 2  proline rich 5 [Source:HGNC Symbol;Acc:HGNC:31... -1.101990  4.491412
# 3  arachidonate 5-lipoxygenase [Source:HGNC Symbo... -1.499499  4.491759
# 4  fucosyltransferase 7 [Source:HGNC Symbol;Acc:H... -1.230372  4.536089
# 5  RAB11 family interacting protein 5 [Source:HGN... -0.788384  4.601653
# 6    oncostatin M [Source:HGNC Symbol;Acc:HGNC:8506] -1.234146  3.506080
# ...
