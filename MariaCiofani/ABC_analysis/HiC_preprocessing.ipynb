# %%
# %%bash
# source /data/reddylab/software/miniconda3/bin/activate jung_py3
# ABC=/data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction
# for sample in $(echo Th1 Th17);
# do
# python ${ABC}/src/juicebox_dump.py \
# --hic_file /data/reddylab/Jungkyun/MS_maria/transfer/hic/hic_files/${sample}.hic \
# --juicebox "java -jar /gpfs/fs1/data/reddylab/Revathy/software/juicebox/v1.10/juicer_tools_1.10.09_jcuda.0.8.jar" \
# --outdir /data/reddylab/Revathy/dev/Maria/hic/${sample}
# done
# Out:
# Starting chr1 ...
# java -jar /gpfs/fs1/data/reddylab/Revathy/software/juicebox/v1.10/juicer_tools_1.10.09_jcuda.0.8.jar dump observed KR /data/reddylab/Jungkyun/MS_maria/transfer/hic/hic_files/Th1.hic 1 1 BP 5000 /data/reddylab/Revathy/dev/Maria/hic/Th1/chr1//chr1.KRobserved
# Running command: gzip /data/reddylab/Revathy/dev/Maria/hic/Th1/chr1//chr1.KRobserved
# java -jar /gpfs/fs1/data/reddylab/Revathy/software/juicebox/v1.10/juicer_tools_1.10.09_jcuda.0.8.jar dump norm KR /data/reddylab/Jungkyun/MS_maria/transfer/hic/hic_files/Th1.hic 1 BP 5000 /data/reddylab/Revathy/dev/Maria/hic/Th1/chr1//chr1.KRnorm
# Running command: gzip /data/reddylab/Revathy/dev/Maria/hic/Th1/chr1//chr1.KRnorm
# Starting chr2 ...
# java -jar /gpfs/fs1/data/reddylab/Revathy/software/juicebox/v1.10/juicer_tools_1.10.09_jcuda.0.8.jar dump observed KR /data/reddylab/Jungkyun/MS_maria/transfer/hic/hic_files/Th1.hic 2 2 BP 5000 /data/reddylab/Revathy/dev/Maria/hic/Th1/chr2//chr2.KRobserved
# ...

# %%
# %%bash
# source /data/reddylab/software/miniconda3/bin/activate jung_py3
# for sample in $(echo Th1 Th17);
# do
# mkdir -p /data/reddylab/Revathy/dev/Maria/hic/${sample}/powerlaw
# python /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/src/compute_powerlaw_fit_from_hic.py \
# --hicDir /data/reddylab/Revathy/dev/Maria/hic/${sample} \
# --outDir /data/reddylab/Revathy/dev/Maria/hic/${sample}/powerlaw \
# --maxWindow 1000000 \
# --minWindow 5000 \
# --resolution 5000
# done
# Out:
# Using: /data/reddylab/Revathy/dev/Maria/hic/Th1/chr1/chr1.KRobserved.gz
# Working on /data/reddylab/Revathy/dev/Maria/hic/Th1/chr1/chr1.KRobserved.gz
# Loading HiC
# hic.to.sparse: Elapsed time: 9.023836135864258
# HiC Matrix has row sums of 1821.457072176637, making doubly stochastic...
# HiC has 5528363 rows after windowing between 5000 and 1000000
# process.hic: Elapsed time: 17.49988031387329
# Using: /data/reddylab/Revathy/dev/Maria/hic/Th1/chr2/chr2.KRobserved.gz
# Working on /data/reddylab/Revathy/dev/Maria/hic/Th1/chr2/chr2.KRobserved.gz
# Loading HiC
# hic.to.sparse: Elapsed time: 9.857124328613281
# HiC Matrix has row sums of 1784.1953619122014, making doubly stochastic...
# HiC has 5794300 rows after windowing between 5000 and 1000000
# process.hic: Elapsed time: 18.831227779388428
# Using: /data/reddylab/Revathy/dev/Maria/hic/Th1/chr3/chr3.KRobserved.gz
# Working on /data/reddylab/Revathy/dev/Maria/hic/Th1/chr3/chr3.KRobserved.gz
# Loading HiC
# ...
