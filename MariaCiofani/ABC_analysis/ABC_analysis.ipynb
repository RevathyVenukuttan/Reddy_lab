# %% [markdown]
# #### Define candidate enhancer regions

# %%
# %%bash
# mkdir -p /data/reddylab/Revathy/dev/Maria/ABC
# source /data/reddylab/software/miniconda3/bin/activate jung_py3
# module load bedtools2
# abc=/data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction
# abc_dir=/data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction
# in_dir=/data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal
# out_dir=/data/reddylab/Revathy/dev/Maria/ABC
# list=list_of_samples.txt
# samples=$(cat /data/reddylab/Revathy/dev/Maria/ABC/$list|tr '\n' ' ')
# # Need hg38 version of whitelist and gene list in bed format
#
# #hg38_RefSeqCurated.170308.bed.CollapsedGeneBounds.bed
# #hg38_wgEncodeHg19ConsensusSignalArtifactRegions.bed
# #hg38_RefSeqCurated.170308.bed.CollapsedGeneBounds.TSS500bp.bed
# ################################################################################################################
# # 1. Count DNase-seq reads in each peak and retain the top N peaks with the most read counts
# ################################################################################################################
#
# task=candidate_region_by_dnase
# mkdir -p /data/reddylab/Revathy/dev/Maria/ABC/${task}
# mkdir -p /data/reddylab/Revathy/dev/Maria/ABC/logs
# for dnase in ${samples} ;
# do
# python ${abc}/src/makeCandidateRegions.py \
# --narrowPeak ${in_dir}/${dnase}.masked.dedup.sorted_peaks.narrowPeak \
# --bam ${in_dir}/${dnase}.masked.dups_marked.bam \
# --outDir /data/reddylab/Revathy/dev/Maria/ABC/${task}/ \
# --chrom_sizes ${abc_dir}/reference/chr_sizes \
# --regions_blacklist /data/reddylab/Revathy/dev/Maria/hg38_wgEncodeHg19ConsensusSignalArtifactRegions.bed \
# --regions_whitelist /data/reddylab/Revathy/dev/Maria/hg38_RefSeqCurated.170308.bed.CollapsedGeneBounds.TSS500bp.bed \
# --peakExtendFromSummit 250 \
# --nStrongestPeaks 150000
# done
# Out:
# Running: awk 'FNR==NR {x2[$1] = $0; next} $1 in x2 {print x2[$1]}' /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes <(samtools view -H /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th01_1.masked.dups_marked.bam | grep SQ | cut -f 2 | cut -c 4- )  > /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th01_1.masked.dedup.sorted_peaks.narrowPeak.Th01_1.masked.dups_marked.bam.Counts.bed.temp_sort_order
# Running: bedtools sort -faidx /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th01_1.masked.dedup.sorted_peaks.narrowPeak.Th01_1.masked.dups_marked.bam.Counts.bed.temp_sort_order -i /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th01_1.masked.dedup.sorted_peaks.narrowPeak | bedtools coverage -g /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th01_1.masked.dedup.sorted_peaks.narrowPeak.Th01_1.masked.dups_marked.bam.Counts.bed.temp_sort_order -counts -sorted -a stdin -b /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th01_1.masked.dups_marked.bam | awk '{print $1 "\t" $2 "\t" $3 "\t" $NF}'  | bedtools sort -faidx /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes -i stdin > /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th01_1.masked.dedup.sorted_peaks.narrowPeak.Th01_1.masked.dups_marked.bam.Counts.bed; rm /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th01_1.masked.dedup.sorted_peaks.narrowPeak.Th01_1.masked.dups_marked.bam.Counts.bed.temp_sort_order
# Fast count method failed to count: /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th01_1.masked.dups_marked.bam
#
# Error: The genome file /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th01_1.masked.dedup.sorted_peaks.narrowPeak.Th01_1.masked.dups_marked.bam.Counts.bed.temp_sort_order has no valid entries. Exiting.
# Chromosome "chr1" undefined in /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th01_1.masked.dedup.sorted_peaks.narrowPeak.Th01_1.masked.dups_marked.bam.Counts.bed.temp_sort_order
#
# Trying bamtobed method ...
#
# Running: bedtools bamtobed -i /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th01_1.masked.dups_marked.bam | cut -f 1-3 | bedtools intersect -wa -a stdin -b /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes.bed | bedtools sort -i stdin -faidx /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes | bedtools coverage -g /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes -counts -sorted -a /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th01_1.masked.dedup.sorted_peaks.narrowPeak -b stdin | awk '{print $1 "\t" $2 "\t" $3 "\t" $NF}' > /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th01_1.masked.dedup.sorted_peaks.narrowPeak.Th01_1.masked.dups_marked.bam.Counts.bed
# BEDTools failed to count file: /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th01_1.masked.dups_marked.bam
#
# Error: requested chromosome chr14_GL000225v1_random does not exist in the genome file /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes. Exiting.
#
# Running: bedtools sort -i /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th01_1.masked.dedup.sorted_peaks.narrowPeak.Th01_1.masked.dups_marked.bam.Counts.bed -faidx /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes | bedtools merge -i stdin -c 4 -o max | sort -nr -k 4 | head -n 150000 |bedtools intersect -b stdin -a /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th01_1.masked.dedup.sorted_peaks.narrowPeak -wa |awk '{print $1 "\t" $2 + $10 "\t" $2 + $10}' |bedtools slop -i stdin -b 250 -g /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes |bedtools sort -i stdin -faidx /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes |bedtools merge -i stdin | bedtools intersect -v -wa -a stdin -b /data/reddylab/Revathy/dev/Maria/hg38_wgEncodeHg19ConsensusSignalArtifactRegions.bed | cut -f 1-3 | (bedtools intersect -a /data/reddylab/Revathy/dev/Maria/hg38_RefSeqCurated.170308.bed.CollapsedGeneBounds.TSS500bp.bed -b /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes.bed -wa | cut -f 1-3 && cat) |bedtools sort -i stdin -faidx /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes | bedtools merge -i stdin > /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th01_1.masked.dedup.sorted_peaks.narrowPeak.candidateRegions.bed
# Running: awk 'FNR==NR {x2[$1] = $0; next} $1 in x2 {print x2[$1]}' /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes <(samtools view -H /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th01_2.masked.dups_marked.bam | grep SQ | cut -f 2 | cut -c 4- )  > /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th01_2.masked.dedup.sorted_peaks.narrowPeak.Th01_2.masked.dups_marked.bam.Counts.bed.temp_sort_order
# Running: bedtools sort -faidx /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th01_2.masked.dedup.sorted_peaks.narrowPeak.Th01_2.masked.dups_marked.bam.Counts.bed.temp_sort_order -i /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th01_2.masked.dedup.sorted_peaks.narrowPeak | bedtools coverage -g /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th01_2.masked.dedup.sorted_peaks.narrowPeak.Th01_2.masked.dups_marked.bam.Counts.bed.temp_sort_order -counts -sorted -a stdin -b /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th01_2.masked.dups_marked.bam | awk '{print $1 "\t" $2 "\t" $3 "\t" $NF}'  | bedtools sort -faidx /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes -i stdin > /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th01_2.masked.dedup.sorted_peaks.narrowPeak.Th01_2.masked.dups_marked.bam.Counts.bed; rm /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th01_2.masked.dedup.sorted_peaks.narrowPeak.Th01_2.masked.dups_marked.bam.Counts.bed.temp_sort_order
# Fast count method failed to count: /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th01_2.masked.dups_marked.bam
#
# Error: The genome file /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th01_2.masked.dedup.sorted_peaks.narrowPeak.Th01_2.masked.dups_marked.bam.Counts.bed.temp_sort_order has no valid entries. Exiting.
# Chromosome "chr1" undefined in /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th01_2.masked.dedup.sorted_peaks.narrowPeak.Th01_2.masked.dups_marked.bam.Counts.bed.temp_sort_order
#
# Trying bamtobed method ...
#
# Running: bedtools bamtobed -i /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th01_2.masked.dups_marked.bam | cut -f 1-3 | bedtools intersect -wa -a stdin -b /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes.bed | bedtools sort -i stdin -faidx /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes | bedtools coverage -g /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes -counts -sorted -a /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th01_2.masked.dedup.sorted_peaks.narrowPeak -b stdin | awk '{print $1 "\t" $2 "\t" $3 "\t" $NF}' > /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th01_2.masked.dedup.sorted_peaks.narrowPeak.Th01_2.masked.dups_marked.bam.Counts.bed
# BEDTools failed to count file: /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th01_2.masked.dups_marked.bam
#
# Error: requested chromosome chr14_GL000225v1_random does not exist in the genome file /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes. Exiting.
#
# Running: bedtools sort -i /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th01_2.masked.dedup.sorted_peaks.narrowPeak.Th01_2.masked.dups_marked.bam.Counts.bed -faidx /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes | bedtools merge -i stdin -c 4 -o max | sort -nr -k 4 | head -n 150000 |bedtools intersect -b stdin -a /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th01_2.masked.dedup.sorted_peaks.narrowPeak -wa |awk '{print $1 "\t" $2 + $10 "\t" $2 + $10}' |bedtools slop -i stdin -b 250 -g /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes |bedtools sort -i stdin -faidx /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes |bedtools merge -i stdin | bedtools intersect -v -wa -a stdin -b /data/reddylab/Revathy/dev/Maria/hg38_wgEncodeHg19ConsensusSignalArtifactRegions.bed | cut -f 1-3 | (bedtools intersect -a /data/reddylab/Revathy/dev/Maria/hg38_RefSeqCurated.170308.bed.CollapsedGeneBounds.TSS500bp.bed -b /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes.bed -wa | cut -f 1-3 && cat) |bedtools sort -i stdin -faidx /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes | bedtools merge -i stdin > /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th01_2.masked.dedup.sorted_peaks.narrowPeak.candidateRegions.bed
# Running: awk 'FNR==NR {x2[$1] = $0; next} $1 in x2 {print x2[$1]}' /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes <(samtools view -H /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th01_cc_1.masked.dups_marked.bam | grep SQ | cut -f 2 | cut -c 4- )  > /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th01_cc_1.masked.dedup.sorted_peaks.narrowPeak.Th01_cc_1.masked.dups_marked.bam.Counts.bed.temp_sort_order
# Running: bedtools sort -faidx /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th01_cc_1.masked.dedup.sorted_peaks.narrowPeak.Th01_cc_1.masked.dups_marked.bam.Counts.bed.temp_sort_order -i /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th01_cc_1.masked.dedup.sorted_peaks.narrowPeak | bedtools coverage -g /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th01_cc_1.masked.dedup.sorted_peaks.narrowPeak.Th01_cc_1.masked.dups_marked.bam.Counts.bed.temp_sort_order -counts -sorted -a stdin -b /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th01_cc_1.masked.dups_marked.bam | awk '{print $1 "\t" $2 "\t" $3 "\t" $NF}'  | bedtools sort -faidx /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes -i stdin > /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th01_cc_1.masked.dedup.sorted_peaks.narrowPeak.Th01_cc_1.masked.dups_marked.bam.Counts.bed; rm /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th01_cc_1.masked.dedup.sorted_peaks.narrowPeak.Th01_cc_1.masked.dups_marked.bam.Counts.bed.temp_sort_order
# Fast count method failed to count: /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th01_cc_1.masked.dups_marked.bam
#
# Error: The genome file /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th01_cc_1.masked.dedup.sorted_peaks.narrowPeak.Th01_cc_1.masked.dups_marked.bam.Counts.bed.temp_sort_order has no valid entries. Exiting.
# Chromosome "chr1" undefined in /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th01_cc_1.masked.dedup.sorted_peaks.narrowPeak.Th01_cc_1.masked.dups_marked.bam.Counts.bed.temp_sort_order
#
# Trying bamtobed method ...
#
# Running: bedtools bamtobed -i /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th01_cc_1.masked.dups_marked.bam | cut -f 1-3 | bedtools intersect -wa -a stdin -b /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes.bed | bedtools sort -i stdin -faidx /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes | bedtools coverage -g /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes -counts -sorted -a /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th01_cc_1.masked.dedup.sorted_peaks.narrowPeak -b stdin | awk '{print $1 "\t" $2 "\t" $3 "\t" $NF}' > /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th01_cc_1.masked.dedup.sorted_peaks.narrowPeak.Th01_cc_1.masked.dups_marked.bam.Counts.bed
# BEDTools failed to count file: /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th01_cc_1.masked.dups_marked.bam
#
# Error: requested chromosome chr14_GL000194v1_random does not exist in the genome file /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes. Exiting.
#
# Running: bedtools sort -i /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th01_cc_1.masked.dedup.sorted_peaks.narrowPeak.Th01_cc_1.masked.dups_marked.bam.Counts.bed -faidx /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes | bedtools merge -i stdin -c 4 -o max | sort -nr -k 4 | head -n 150000 |bedtools intersect -b stdin -a /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th01_cc_1.masked.dedup.sorted_peaks.narrowPeak -wa |awk '{print $1 "\t" $2 + $10 "\t" $2 + $10}' |bedtools slop -i stdin -b 250 -g /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes |bedtools sort -i stdin -faidx /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes |bedtools merge -i stdin | bedtools intersect -v -wa -a stdin -b /data/reddylab/Revathy/dev/Maria/hg38_wgEncodeHg19ConsensusSignalArtifactRegions.bed | cut -f 1-3 | (bedtools intersect -a /data/reddylab/Revathy/dev/Maria/hg38_RefSeqCurated.170308.bed.CollapsedGeneBounds.TSS500bp.bed -b /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes.bed -wa | cut -f 1-3 && cat) |bedtools sort -i stdin -faidx /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes | bedtools merge -i stdin > /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th01_cc_1.masked.dedup.sorted_peaks.narrowPeak.candidateRegions.bed
# Running: awk 'FNR==NR {x2[$1] = $0; next} $1 in x2 {print x2[$1]}' /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes <(samtools view -H /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th01_cc_2.masked.dups_marked.bam | grep SQ | cut -f 2 | cut -c 4- )  > /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th01_cc_2.masked.dedup.sorted_peaks.narrowPeak.Th01_cc_2.masked.dups_marked.bam.Counts.bed.temp_sort_order
# Running: bedtools sort -faidx /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th01_cc_2.masked.dedup.sorted_peaks.narrowPeak.Th01_cc_2.masked.dups_marked.bam.Counts.bed.temp_sort_order -i /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th01_cc_2.masked.dedup.sorted_peaks.narrowPeak | bedtools coverage -g /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th01_cc_2.masked.dedup.sorted_peaks.narrowPeak.Th01_cc_2.masked.dups_marked.bam.Counts.bed.temp_sort_order -counts -sorted -a stdin -b /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th01_cc_2.masked.dups_marked.bam | awk '{print $1 "\t" $2 "\t" $3 "\t" $NF}'  | bedtools sort -faidx /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes -i stdin > /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th01_cc_2.masked.dedup.sorted_peaks.narrowPeak.Th01_cc_2.masked.dups_marked.bam.Counts.bed; rm /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th01_cc_2.masked.dedup.sorted_peaks.narrowPeak.Th01_cc_2.masked.dups_marked.bam.Counts.bed.temp_sort_order
# Fast count method failed to count: /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th01_cc_2.masked.dups_marked.bam
#
# Error: The genome file /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th01_cc_2.masked.dedup.sorted_peaks.narrowPeak.Th01_cc_2.masked.dups_marked.bam.Counts.bed.temp_sort_order has no valid entries. Exiting.
# Chromosome "chr1" undefined in /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th01_cc_2.masked.dedup.sorted_peaks.narrowPeak.Th01_cc_2.masked.dups_marked.bam.Counts.bed.temp_sort_order
#
# Trying bamtobed method ...
#
# Running: bedtools bamtobed -i /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th01_cc_2.masked.dups_marked.bam | cut -f 1-3 | bedtools intersect -wa -a stdin -b /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes.bed | bedtools sort -i stdin -faidx /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes | bedtools coverage -g /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes -counts -sorted -a /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th01_cc_2.masked.dedup.sorted_peaks.narrowPeak -b stdin | awk '{print $1 "\t" $2 "\t" $3 "\t" $NF}' > /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th01_cc_2.masked.dedup.sorted_peaks.narrowPeak.Th01_cc_2.masked.dups_marked.bam.Counts.bed
# BEDTools failed to count file: /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th01_cc_2.masked.dups_marked.bam
#
# Error: requested chromosome chr14_GL000194v1_random does not exist in the genome file /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes. Exiting.
#
# Running: bedtools sort -i /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th01_cc_2.masked.dedup.sorted_peaks.narrowPeak.Th01_cc_2.masked.dups_marked.bam.Counts.bed -faidx /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes | bedtools merge -i stdin -c 4 -o max | sort -nr -k 4 | head -n 150000 |bedtools intersect -b stdin -a /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th01_cc_2.masked.dedup.sorted_peaks.narrowPeak -wa |awk '{print $1 "\t" $2 + $10 "\t" $2 + $10}' |bedtools slop -i stdin -b 250 -g /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes |bedtools sort -i stdin -faidx /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes |bedtools merge -i stdin | bedtools intersect -v -wa -a stdin -b /data/reddylab/Revathy/dev/Maria/hg38_wgEncodeHg19ConsensusSignalArtifactRegions.bed | cut -f 1-3 | (bedtools intersect -a /data/reddylab/Revathy/dev/Maria/hg38_RefSeqCurated.170308.bed.CollapsedGeneBounds.TSS500bp.bed -b /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes.bed -wa | cut -f 1-3 && cat) |bedtools sort -i stdin -faidx /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes | bedtools merge -i stdin > /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th01_cc_2.masked.dedup.sorted_peaks.narrowPeak.candidateRegions.bed
# Running: awk 'FNR==NR {x2[$1] = $0; next} $1 in x2 {print x2[$1]}' /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes <(samtools view -H /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th17_1.masked.dups_marked.bam | grep SQ | cut -f 2 | cut -c 4- )  > /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th17_1.masked.dedup.sorted_peaks.narrowPeak.Th17_1.masked.dups_marked.bam.Counts.bed.temp_sort_order
# Running: bedtools sort -faidx /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th17_1.masked.dedup.sorted_peaks.narrowPeak.Th17_1.masked.dups_marked.bam.Counts.bed.temp_sort_order -i /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th17_1.masked.dedup.sorted_peaks.narrowPeak | bedtools coverage -g /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th17_1.masked.dedup.sorted_peaks.narrowPeak.Th17_1.masked.dups_marked.bam.Counts.bed.temp_sort_order -counts -sorted -a stdin -b /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th17_1.masked.dups_marked.bam | awk '{print $1 "\t" $2 "\t" $3 "\t" $NF}'  | bedtools sort -faidx /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes -i stdin > /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th17_1.masked.dedup.sorted_peaks.narrowPeak.Th17_1.masked.dups_marked.bam.Counts.bed; rm /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th17_1.masked.dedup.sorted_peaks.narrowPeak.Th17_1.masked.dups_marked.bam.Counts.bed.temp_sort_order
# Fast count method failed to count: /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th17_1.masked.dups_marked.bam
#
# Error: The genome file /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th17_1.masked.dedup.sorted_peaks.narrowPeak.Th17_1.masked.dups_marked.bam.Counts.bed.temp_sort_order has no valid entries. Exiting.
# Chromosome "chr1" undefined in /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th17_1.masked.dedup.sorted_peaks.narrowPeak.Th17_1.masked.dups_marked.bam.Counts.bed.temp_sort_order
#
# Trying bamtobed method ...
#
# Running: bedtools bamtobed -i /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th17_1.masked.dups_marked.bam | cut -f 1-3 | bedtools intersect -wa -a stdin -b /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes.bed | bedtools sort -i stdin -faidx /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes | bedtools coverage -g /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes -counts -sorted -a /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th17_1.masked.dedup.sorted_peaks.narrowPeak -b stdin | awk '{print $1 "\t" $2 "\t" $3 "\t" $NF}' > /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th17_1.masked.dedup.sorted_peaks.narrowPeak.Th17_1.masked.dups_marked.bam.Counts.bed
# BEDTools failed to count file: /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th17_1.masked.dups_marked.bam
#
# Error: requested chromosome chr14_GL000194v1_random does not exist in the genome file /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes. Exiting.
#
# Running: bedtools sort -i /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th17_1.masked.dedup.sorted_peaks.narrowPeak.Th17_1.masked.dups_marked.bam.Counts.bed -faidx /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes | bedtools merge -i stdin -c 4 -o max | sort -nr -k 4 | head -n 150000 |bedtools intersect -b stdin -a /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th17_1.masked.dedup.sorted_peaks.narrowPeak -wa |awk '{print $1 "\t" $2 + $10 "\t" $2 + $10}' |bedtools slop -i stdin -b 250 -g /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes |bedtools sort -i stdin -faidx /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes |bedtools merge -i stdin | bedtools intersect -v -wa -a stdin -b /data/reddylab/Revathy/dev/Maria/hg38_wgEncodeHg19ConsensusSignalArtifactRegions.bed | cut -f 1-3 | (bedtools intersect -a /data/reddylab/Revathy/dev/Maria/hg38_RefSeqCurated.170308.bed.CollapsedGeneBounds.TSS500bp.bed -b /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes.bed -wa | cut -f 1-3 && cat) |bedtools sort -i stdin -faidx /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes | bedtools merge -i stdin > /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th17_1.masked.dedup.sorted_peaks.narrowPeak.candidateRegions.bed
# Running: awk 'FNR==NR {x2[$1] = $0; next} $1 in x2 {print x2[$1]}' /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes <(samtools view -H /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th17_2.masked.dups_marked.bam | grep SQ | cut -f 2 | cut -c 4- )  > /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th17_2.masked.dedup.sorted_peaks.narrowPeak.Th17_2.masked.dups_marked.bam.Counts.bed.temp_sort_order
# Running: bedtools sort -faidx /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th17_2.masked.dedup.sorted_peaks.narrowPeak.Th17_2.masked.dups_marked.bam.Counts.bed.temp_sort_order -i /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th17_2.masked.dedup.sorted_peaks.narrowPeak | bedtools coverage -g /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th17_2.masked.dedup.sorted_peaks.narrowPeak.Th17_2.masked.dups_marked.bam.Counts.bed.temp_sort_order -counts -sorted -a stdin -b /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th17_2.masked.dups_marked.bam | awk '{print $1 "\t" $2 "\t" $3 "\t" $NF}'  | bedtools sort -faidx /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes -i stdin > /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th17_2.masked.dedup.sorted_peaks.narrowPeak.Th17_2.masked.dups_marked.bam.Counts.bed; rm /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th17_2.masked.dedup.sorted_peaks.narrowPeak.Th17_2.masked.dups_marked.bam.Counts.bed.temp_sort_order
# Fast count method failed to count: /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th17_2.masked.dups_marked.bam
#
# Error: The genome file /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th17_2.masked.dedup.sorted_peaks.narrowPeak.Th17_2.masked.dups_marked.bam.Counts.bed.temp_sort_order has no valid entries. Exiting.
# Chromosome "chr1" undefined in /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th17_2.masked.dedup.sorted_peaks.narrowPeak.Th17_2.masked.dups_marked.bam.Counts.bed.temp_sort_order
#
# Trying bamtobed method ...
#
# Running: bedtools bamtobed -i /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th17_2.masked.dups_marked.bam | cut -f 1-3 | bedtools intersect -wa -a stdin -b /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes.bed | bedtools sort -i stdin -faidx /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes | bedtools coverage -g /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes -counts -sorted -a /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th17_2.masked.dedup.sorted_peaks.narrowPeak -b stdin | awk '{print $1 "\t" $2 "\t" $3 "\t" $NF}' > /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th17_2.masked.dedup.sorted_peaks.narrowPeak.Th17_2.masked.dups_marked.bam.Counts.bed
# BEDTools failed to count file: /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th17_2.masked.dups_marked.bam
#
# Error: requested chromosome chr14_GL000225v1_random does not exist in the genome file /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes. Exiting.
#
# Running: bedtools sort -i /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th17_2.masked.dedup.sorted_peaks.narrowPeak.Th17_2.masked.dups_marked.bam.Counts.bed -faidx /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes | bedtools merge -i stdin -c 4 -o max | sort -nr -k 4 | head -n 150000 |bedtools intersect -b stdin -a /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th17_2.masked.dedup.sorted_peaks.narrowPeak -wa |awk '{print $1 "\t" $2 + $10 "\t" $2 + $10}' |bedtools slop -i stdin -b 250 -g /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes |bedtools sort -i stdin -faidx /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes |bedtools merge -i stdin | bedtools intersect -v -wa -a stdin -b /data/reddylab/Revathy/dev/Maria/hg38_wgEncodeHg19ConsensusSignalArtifactRegions.bed | cut -f 1-3 | (bedtools intersect -a /data/reddylab/Revathy/dev/Maria/hg38_RefSeqCurated.170308.bed.CollapsedGeneBounds.TSS500bp.bed -b /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes.bed -wa | cut -f 1-3 && cat) |bedtools sort -i stdin -faidx /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes | bedtools merge -i stdin > /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th17_2.masked.dedup.sorted_peaks.narrowPeak.candidateRegions.bed
# Running: awk 'FNR==NR {x2[$1] = $0; next} $1 in x2 {print x2[$1]}' /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes <(samtools view -H /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th17_cc_1.masked.dups_marked.bam | grep SQ | cut -f 2 | cut -c 4- )  > /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th17_cc_1.masked.dedup.sorted_peaks.narrowPeak.Th17_cc_1.masked.dups_marked.bam.Counts.bed.temp_sort_order
# Running: bedtools sort -faidx /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th17_cc_1.masked.dedup.sorted_peaks.narrowPeak.Th17_cc_1.masked.dups_marked.bam.Counts.bed.temp_sort_order -i /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th17_cc_1.masked.dedup.sorted_peaks.narrowPeak | bedtools coverage -g /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th17_cc_1.masked.dedup.sorted_peaks.narrowPeak.Th17_cc_1.masked.dups_marked.bam.Counts.bed.temp_sort_order -counts -sorted -a stdin -b /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th17_cc_1.masked.dups_marked.bam | awk '{print $1 "\t" $2 "\t" $3 "\t" $NF}'  | bedtools sort -faidx /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes -i stdin > /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th17_cc_1.masked.dedup.sorted_peaks.narrowPeak.Th17_cc_1.masked.dups_marked.bam.Counts.bed; rm /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th17_cc_1.masked.dedup.sorted_peaks.narrowPeak.Th17_cc_1.masked.dups_marked.bam.Counts.bed.temp_sort_order
# Fast count method failed to count: /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th17_cc_1.masked.dups_marked.bam
#
# Error: The genome file /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th17_cc_1.masked.dedup.sorted_peaks.narrowPeak.Th17_cc_1.masked.dups_marked.bam.Counts.bed.temp_sort_order has no valid entries. Exiting.
# Chromosome "chr1" undefined in /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th17_cc_1.masked.dedup.sorted_peaks.narrowPeak.Th17_cc_1.masked.dups_marked.bam.Counts.bed.temp_sort_order
#
# Trying bamtobed method ...
#
# Running: bedtools bamtobed -i /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th17_cc_1.masked.dups_marked.bam | cut -f 1-3 | bedtools intersect -wa -a stdin -b /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes.bed | bedtools sort -i stdin -faidx /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes | bedtools coverage -g /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes -counts -sorted -a /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th17_cc_1.masked.dedup.sorted_peaks.narrowPeak -b stdin | awk '{print $1 "\t" $2 "\t" $3 "\t" $NF}' > /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th17_cc_1.masked.dedup.sorted_peaks.narrowPeak.Th17_cc_1.masked.dups_marked.bam.Counts.bed
# BEDTools failed to count file: /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th17_cc_1.masked.dups_marked.bam
#
# Error: requested chromosome chr14_GL000194v1_random does not exist in the genome file /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes. Exiting.
#
# Running: bedtools sort -i /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th17_cc_1.masked.dedup.sorted_peaks.narrowPeak.Th17_cc_1.masked.dups_marked.bam.Counts.bed -faidx /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes | bedtools merge -i stdin -c 4 -o max | sort -nr -k 4 | head -n 150000 |bedtools intersect -b stdin -a /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th17_cc_1.masked.dedup.sorted_peaks.narrowPeak -wa |awk '{print $1 "\t" $2 + $10 "\t" $2 + $10}' |bedtools slop -i stdin -b 250 -g /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes |bedtools sort -i stdin -faidx /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes |bedtools merge -i stdin | bedtools intersect -v -wa -a stdin -b /data/reddylab/Revathy/dev/Maria/hg38_wgEncodeHg19ConsensusSignalArtifactRegions.bed | cut -f 1-3 | (bedtools intersect -a /data/reddylab/Revathy/dev/Maria/hg38_RefSeqCurated.170308.bed.CollapsedGeneBounds.TSS500bp.bed -b /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes.bed -wa | cut -f 1-3 && cat) |bedtools sort -i stdin -faidx /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes | bedtools merge -i stdin > /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th17_cc_1.masked.dedup.sorted_peaks.narrowPeak.candidateRegions.bed

# %%
# %%bash
# cd /data/reddylab/Revathy/dev/Maria/ABC/data
# cp *.bam *.bam.bai /data/reddylab/Jungkyun/MS_maria/results/processing/chip_seq/CIOFANI_5481_190305B1_MCS234-249-se

# %%
# %%bash
# cd /data/reddylab/Revathy/dev/Maria/ABC/data
# for file in *.bam ;
# do
# mv "$file" "${file//_input_1/_1}"
# mv "$file" "${file//_input_2/_2}"
# done

# %% [markdown]
# #### Quantify enhancer activity

# %%
# %%bash
# task=enhancer_acitivity
# mkdir -p /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/${task}
# source /data/reddylab/software/miniconda3/bin/activate jung_py3
# module load bedtools2
# module load samtools
# H3K27ac_dir=/data/reddylab/Revathy/dev/Maria/ABC/data
# dnase_dir=/data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal
# abc=/data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction
# abc_dir=/data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction
# gene_ex_dir=/data/reddylab/Revathy/dev/Maria/ABC/data/rna_seq
# LIST=sample_names.txt
# SAMPLES=$(cat /data/reddylab/Revathy/dev/Maria/ABC/$LIST|tr '\n' ' ')
#
# for sample in ${SAMPLES};
# do
#
# idx=$(echo ${sample}|cut -d "_" -f1)
# echo ${idx}
# mkdir -p /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/${task}/${idx}_abc
#
# python ${abc}/src/run.neighborhoods.py \
# --candidate_enhancer_regions /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/${sample}.masked.dedup.sorted_peaks.narrowPeak.candidateRegions.bed \
# --genes ${abc_dir}/reference/RefSeqCurated.170308.bed.CollapsedGeneBounds.bed \
# --H3K27ac ${H3K27ac_dir}/${sample}.masked.dedup.sorted.bam \
# --DHS ${dnase_dir}/${sample}.masked.dups_marked.bam \
# --expression_table /data/reddylab/Revathy/dev/Maria/ABC/data/rna_seq/${idx}.TPM_Expr.txt \
# --chrom_sizes ${abc_dir}/reference/chr_sizes \
# --ubiquitously_expressed_genes ${abc_dir}/reference/UbiquitouslyExpressedGenesHG19.txt \
# --cellType ${idx}_abc \
# --outdir /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/${task}/${idx}_abc
#
# done
# Out:
# Th01
# Namespace(ATAC='', DHS='/data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th01_1.masked.dups_marked.bam', H3K27ac='/data/reddylab/Revathy/dev/Maria/ABC/data/Th01_1.masked.dedup.sorted.bam', candidate_enhancer_regions='/data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th01_1.masked.dedup.sorted_peaks.narrowPeak.candidateRegions.bed', cellType='Th01_abc', chrom_sizes='/data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes', default_accessibility_feature=None, enhancer_class_override=None, expression_table='/data/reddylab/Revathy/dev/Maria/ABC/data/rna_seq/Th01.TPM_Expr.txt', gene_name_annotations='symbol', genes='/data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/RefSeqCurated.170308.bed.CollapsedGeneBounds.bed', genes_for_class_assignment=None, outdir='/gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th01_abc', primary_gene_identifier='symbol', qnorm=None, skip_gene_counts=False, skip_rpkm_quantile=False, supplementary_features=None, tss_slop_for_class_assignment=500, ubiquitously_expressed_genes='/data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/UbiquitouslyExpressedGenesHG19.txt', use_secondary_counting_method=False)
# Using gene expression from files: ['/data/reddylab/Revathy/dev/Maria/ABC/data/rna_seq/Th01.TPM_Expr.txt']
#
# Running command: bedtools sort -faidx /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes -i /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th01_abc/GeneList.TSS1kb.bed > /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th01_abc/GeneList.TSS1kb.bed.sorted; mv /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th01_abc/GeneList.TSS1kb.bed.sorted /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th01_abc/GeneList.TSS1kb.bed
# Loading coverage from pre-calculated file for Genes.H3K27ac.Th01_1.masked.dedup.sorted.bam
# Feature H3K27ac completed in 19.764678716659546
# Loading coverage from pre-calculated file for Genes.DHS.Th01_1.masked.dups_marked.bam
# Feature DHS completed in 0.3242614269256592
# Loading coverage from pre-calculated file for Genes.TSS1kb.H3K27ac.Th01_1.masked.dedup.sorted.bam
# Feature H3K27ac completed in 19.56548047065735
# Loading coverage from pre-calculated file for Genes.TSS1kb.DHS.Th01_1.masked.dups_marked.bam
# Feature DHS completed in 0.21199703216552734
# Regenerating /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th01_abc/Enhancers.H3K27ac.Th01_1.masked.dedup.sorted.bam.CountReads.bedgraph
# Counting coverage for Enhancers.H3K27ac.Th01_1.masked.dedup.sorted.bam
# Running: awk 'FNR==NR {x2[$1] = $0; next} $1 in x2 {print x2[$1]}' /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes <(samtools view -H /data/reddylab/Revathy/dev/Maria/ABC/data/Th01_1.masked.dedup.sorted.bam | grep SQ | cut -f 2 | cut -c 4- )  > /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th01_abc/Enhancers.H3K27ac.Th01_1.masked.dedup.sorted.bam.CountReads.bedgraph.temp_sort_order
# Running: bedtools sort -faidx /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th01_abc/Enhancers.H3K27ac.Th01_1.masked.dedup.sorted.bam.CountReads.bedgraph.temp_sort_order -i /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th01_1.masked.dedup.sorted_peaks.narrowPeak.candidateRegions.bed | bedtools coverage -g /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th01_abc/Enhancers.H3K27ac.Th01_1.masked.dedup.sorted.bam.CountReads.bedgraph.temp_sort_order -counts -sorted -a stdin -b /data/reddylab/Revathy/dev/Maria/ABC/data/Th01_1.masked.dedup.sorted.bam | awk '{print $1 "\t" $2 "\t" $3 "\t" $NF}'  | bedtools sort -faidx /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes -i stdin > /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th01_abc/Enhancers.H3K27ac.Th01_1.masked.dedup.sorted.bam.CountReads.bedgraph; rm /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th01_abc/Enhancers.H3K27ac.Th01_1.masked.dedup.sorted.bam.CountReads.bedgraph.temp_sort_order
# BEDTools completed successfully.
#
# Feature H3K27ac completed in 58.66090679168701
# Regenerating /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th01_abc/Enhancers.DHS.Th01_1.masked.dups_marked.bam.CountReads.bedgraph
# Counting coverage for Enhancers.DHS.Th01_1.masked.dups_marked.bam
# Running: awk 'FNR==NR {x2[$1] = $0; next} $1 in x2 {print x2[$1]}' /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes <(samtools view -H /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th01_1.masked.dups_marked.bam | grep SQ | cut -f 2 | cut -c 4- )  > /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th01_abc/Enhancers.DHS.Th01_1.masked.dups_marked.bam.CountReads.bedgraph.temp_sort_order
# Running: bedtools sort -faidx /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th01_abc/Enhancers.DHS.Th01_1.masked.dups_marked.bam.CountReads.bedgraph.temp_sort_order -i /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th01_1.masked.dedup.sorted_peaks.narrowPeak.candidateRegions.bed | bedtools coverage -g /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th01_abc/Enhancers.DHS.Th01_1.masked.dups_marked.bam.CountReads.bedgraph.temp_sort_order -counts -sorted -a stdin -b /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th01_1.masked.dups_marked.bam | awk '{print $1 "\t" $2 "\t" $3 "\t" $NF}'  | bedtools sort -faidx /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes -i stdin > /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th01_abc/Enhancers.DHS.Th01_1.masked.dups_marked.bam.CountReads.bedgraph; rm /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th01_abc/Enhancers.DHS.Th01_1.masked.dups_marked.bam.CountReads.bedgraph.temp_sort_order
# BEDTools completed successfully.
#
# Feature DHS completed in 95.8973798751831
# Assigning classes to enhancers
# Total enhancers: 50650
#          Promoters: 1678
#          Genic: 23498
#          Intergenic: 25474
# Neighborhoods Complete!
#
# Th01
# Namespace(ATAC='', DHS='/data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th01_2.masked.dups_marked.bam', H3K27ac='/data/reddylab/Revathy/dev/Maria/ABC/data/Th01_2.masked.dedup.sorted.bam', candidate_enhancer_regions='/data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th01_2.masked.dedup.sorted_peaks.narrowPeak.candidateRegions.bed', cellType='Th01_abc', chrom_sizes='/data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes', default_accessibility_feature=None, enhancer_class_override=None, expression_table='/data/reddylab/Revathy/dev/Maria/ABC/data/rna_seq/Th01.TPM_Expr.txt', gene_name_annotations='symbol', genes='/data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/RefSeqCurated.170308.bed.CollapsedGeneBounds.bed', genes_for_class_assignment=None, outdir='/gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th01_abc', primary_gene_identifier='symbol', qnorm=None, skip_gene_counts=False, skip_rpkm_quantile=False, supplementary_features=None, tss_slop_for_class_assignment=500, ubiquitously_expressed_genes='/data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/UbiquitouslyExpressedGenesHG19.txt', use_secondary_counting_method=False)
# Using gene expression from files: ['/data/reddylab/Revathy/dev/Maria/ABC/data/rna_seq/Th01.TPM_Expr.txt']
#
# Running command: bedtools sort -faidx /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes -i /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th01_abc/GeneList.TSS1kb.bed > /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th01_abc/GeneList.TSS1kb.bed.sorted; mv /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th01_abc/GeneList.TSS1kb.bed.sorted /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th01_abc/GeneList.TSS1kb.bed
# Loading coverage from pre-calculated file for Genes.H3K27ac.Th01_2.masked.dedup.sorted.bam
# Feature H3K27ac completed in 23.909016847610474
# Loading coverage from pre-calculated file for Genes.DHS.Th01_2.masked.dups_marked.bam
# Feature DHS completed in 0.3666038513183594
# Loading coverage from pre-calculated file for Genes.TSS1kb.H3K27ac.Th01_2.masked.dedup.sorted.bam
# Feature H3K27ac completed in 23.755717277526855
# Loading coverage from pre-calculated file for Genes.TSS1kb.DHS.Th01_2.masked.dups_marked.bam
# Feature DHS completed in 0.2169022560119629
# Regenerating /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th01_abc/Enhancers.H3K27ac.Th01_2.masked.dedup.sorted.bam.CountReads.bedgraph
# Counting coverage for Enhancers.H3K27ac.Th01_2.masked.dedup.sorted.bam
# Running: awk 'FNR==NR {x2[$1] = $0; next} $1 in x2 {print x2[$1]}' /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes <(samtools view -H /data/reddylab/Revathy/dev/Maria/ABC/data/Th01_2.masked.dedup.sorted.bam | grep SQ | cut -f 2 | cut -c 4- )  > /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th01_abc/Enhancers.H3K27ac.Th01_2.masked.dedup.sorted.bam.CountReads.bedgraph.temp_sort_order
# Running: bedtools sort -faidx /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th01_abc/Enhancers.H3K27ac.Th01_2.masked.dedup.sorted.bam.CountReads.bedgraph.temp_sort_order -i /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th01_2.masked.dedup.sorted_peaks.narrowPeak.candidateRegions.bed | bedtools coverage -g /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th01_abc/Enhancers.H3K27ac.Th01_2.masked.dedup.sorted.bam.CountReads.bedgraph.temp_sort_order -counts -sorted -a stdin -b /data/reddylab/Revathy/dev/Maria/ABC/data/Th01_2.masked.dedup.sorted.bam | awk '{print $1 "\t" $2 "\t" $3 "\t" $NF}'  | bedtools sort -faidx /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes -i stdin > /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th01_abc/Enhancers.H3K27ac.Th01_2.masked.dedup.sorted.bam.CountReads.bedgraph; rm /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th01_abc/Enhancers.H3K27ac.Th01_2.masked.dedup.sorted.bam.CountReads.bedgraph.temp_sort_order
# BEDTools completed successfully.
#
# Feature H3K27ac completed in 70.87147355079651
# Regenerating /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th01_abc/Enhancers.DHS.Th01_2.masked.dups_marked.bam.CountReads.bedgraph
# Counting coverage for Enhancers.DHS.Th01_2.masked.dups_marked.bam
# Running: awk 'FNR==NR {x2[$1] = $0; next} $1 in x2 {print x2[$1]}' /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes <(samtools view -H /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th01_2.masked.dups_marked.bam | grep SQ | cut -f 2 | cut -c 4- )  > /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th01_abc/Enhancers.DHS.Th01_2.masked.dups_marked.bam.CountReads.bedgraph.temp_sort_order
# Running: bedtools sort -faidx /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th01_abc/Enhancers.DHS.Th01_2.masked.dups_marked.bam.CountReads.bedgraph.temp_sort_order -i /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th01_2.masked.dedup.sorted_peaks.narrowPeak.candidateRegions.bed | bedtools coverage -g /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th01_abc/Enhancers.DHS.Th01_2.masked.dups_marked.bam.CountReads.bedgraph.temp_sort_order -counts -sorted -a stdin -b /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th01_2.masked.dups_marked.bam | awk '{print $1 "\t" $2 "\t" $3 "\t" $NF}'  | bedtools sort -faidx /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes -i stdin > /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th01_abc/Enhancers.DHS.Th01_2.masked.dups_marked.bam.CountReads.bedgraph; rm /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th01_abc/Enhancers.DHS.Th01_2.masked.dups_marked.bam.CountReads.bedgraph.temp_sort_order
# BEDTools completed successfully.
#
# Feature DHS completed in 93.64930939674377
# Assigning classes to enhancers
# Total enhancers: 48454
#          Promoters: 1647
#          Genic: 22387
#          Intergenic: 24420
# Neighborhoods Complete!
#
# Th17
# Namespace(ATAC='', DHS='/data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th17_1.masked.dups_marked.bam', H3K27ac='/data/reddylab/Revathy/dev/Maria/ABC/data/Th17_1.masked.dedup.sorted.bam', candidate_enhancer_regions='/data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th17_1.masked.dedup.sorted_peaks.narrowPeak.candidateRegions.bed', cellType='Th17_abc', chrom_sizes='/data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes', default_accessibility_feature=None, enhancer_class_override=None, expression_table='/data/reddylab/Revathy/dev/Maria/ABC/data/rna_seq/Th17.TPM_Expr.txt', gene_name_annotations='symbol', genes='/data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/RefSeqCurated.170308.bed.CollapsedGeneBounds.bed', genes_for_class_assignment=None, outdir='/gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th17_abc', primary_gene_identifier='symbol', qnorm=None, skip_gene_counts=False, skip_rpkm_quantile=False, supplementary_features=None, tss_slop_for_class_assignment=500, ubiquitously_expressed_genes='/data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/UbiquitouslyExpressedGenesHG19.txt', use_secondary_counting_method=False)
# Using gene expression from files: ['/data/reddylab/Revathy/dev/Maria/ABC/data/rna_seq/Th17.TPM_Expr.txt']
#
# Running command: bedtools sort -faidx /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes -i /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th17_abc/GeneList.TSS1kb.bed > /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th17_abc/GeneList.TSS1kb.bed.sorted; mv /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th17_abc/GeneList.TSS1kb.bed.sorted /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th17_abc/GeneList.TSS1kb.bed
# Loading coverage from pre-calculated file for Genes.H3K27ac.Th17_1.masked.dedup.sorted.bam
# Feature H3K27ac completed in 25.734113931655884
# Loading coverage from pre-calculated file for Genes.DHS.Th17_1.masked.dups_marked.bam
# Feature DHS completed in 0.33610057830810547
# Loading coverage from pre-calculated file for Genes.TSS1kb.H3K27ac.Th17_1.masked.dedup.sorted.bam
# Feature H3K27ac completed in 24.974273443222046
# Loading coverage from pre-calculated file for Genes.TSS1kb.DHS.Th17_1.masked.dups_marked.bam
# Feature DHS completed in 0.20738577842712402
# Regenerating /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th17_abc/Enhancers.H3K27ac.Th17_1.masked.dedup.sorted.bam.CountReads.bedgraph
# Counting coverage for Enhancers.H3K27ac.Th17_1.masked.dedup.sorted.bam
# Running: awk 'FNR==NR {x2[$1] = $0; next} $1 in x2 {print x2[$1]}' /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes <(samtools view -H /data/reddylab/Revathy/dev/Maria/ABC/data/Th17_1.masked.dedup.sorted.bam | grep SQ | cut -f 2 | cut -c 4- )  > /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th17_abc/Enhancers.H3K27ac.Th17_1.masked.dedup.sorted.bam.CountReads.bedgraph.temp_sort_order
# Running: bedtools sort -faidx /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th17_abc/Enhancers.H3K27ac.Th17_1.masked.dedup.sorted.bam.CountReads.bedgraph.temp_sort_order -i /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th17_1.masked.dedup.sorted_peaks.narrowPeak.candidateRegions.bed | bedtools coverage -g /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th17_abc/Enhancers.H3K27ac.Th17_1.masked.dedup.sorted.bam.CountReads.bedgraph.temp_sort_order -counts -sorted -a stdin -b /data/reddylab/Revathy/dev/Maria/ABC/data/Th17_1.masked.dedup.sorted.bam | awk '{print $1 "\t" $2 "\t" $3 "\t" $NF}'  | bedtools sort -faidx /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes -i stdin > /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th17_abc/Enhancers.H3K27ac.Th17_1.masked.dedup.sorted.bam.CountReads.bedgraph; rm /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th17_abc/Enhancers.H3K27ac.Th17_1.masked.dedup.sorted.bam.CountReads.bedgraph.temp_sort_order
# BEDTools completed successfully.
#
# Feature H3K27ac completed in 73.95325016975403
# Regenerating /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th17_abc/Enhancers.DHS.Th17_1.masked.dups_marked.bam.CountReads.bedgraph
# Counting coverage for Enhancers.DHS.Th17_1.masked.dups_marked.bam
# Running: awk 'FNR==NR {x2[$1] = $0; next} $1 in x2 {print x2[$1]}' /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes <(samtools view -H /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th17_1.masked.dups_marked.bam | grep SQ | cut -f 2 | cut -c 4- )  > /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th17_abc/Enhancers.DHS.Th17_1.masked.dups_marked.bam.CountReads.bedgraph.temp_sort_order
# Running: bedtools sort -faidx /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th17_abc/Enhancers.DHS.Th17_1.masked.dups_marked.bam.CountReads.bedgraph.temp_sort_order -i /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th17_1.masked.dedup.sorted_peaks.narrowPeak.candidateRegions.bed | bedtools coverage -g /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th17_abc/Enhancers.DHS.Th17_1.masked.dups_marked.bam.CountReads.bedgraph.temp_sort_order -counts -sorted -a stdin -b /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th17_1.masked.dups_marked.bam | awk '{print $1 "\t" $2 "\t" $3 "\t" $NF}'  | bedtools sort -faidx /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes -i stdin > /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th17_abc/Enhancers.DHS.Th17_1.masked.dups_marked.bam.CountReads.bedgraph; rm /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th17_abc/Enhancers.DHS.Th17_1.masked.dups_marked.bam.CountReads.bedgraph.temp_sort_order
# BEDTools completed successfully.
#
# Feature DHS completed in 83.54709267616272
# Assigning classes to enhancers
# Total enhancers: 36043
#          Promoters: 1383
#          Genic: 16087
#          Intergenic: 18573
# Neighborhoods Complete!
#
# Th17
# Namespace(ATAC='', DHS='/data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th17_2.masked.dups_marked.bam', H3K27ac='/data/reddylab/Revathy/dev/Maria/ABC/data/Th17_2.masked.dedup.sorted.bam', candidate_enhancer_regions='/data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th17_2.masked.dedup.sorted_peaks.narrowPeak.candidateRegions.bed', cellType='Th17_abc', chrom_sizes='/data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes', default_accessibility_feature=None, enhancer_class_override=None, expression_table='/data/reddylab/Revathy/dev/Maria/ABC/data/rna_seq/Th17.TPM_Expr.txt', gene_name_annotations='symbol', genes='/data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/RefSeqCurated.170308.bed.CollapsedGeneBounds.bed', genes_for_class_assignment=None, outdir='/gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th17_abc', primary_gene_identifier='symbol', qnorm=None, skip_gene_counts=False, skip_rpkm_quantile=False, supplementary_features=None, tss_slop_for_class_assignment=500, ubiquitously_expressed_genes='/data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/UbiquitouslyExpressedGenesHG19.txt', use_secondary_counting_method=False)
# Using gene expression from files: ['/data/reddylab/Revathy/dev/Maria/ABC/data/rna_seq/Th17.TPM_Expr.txt']
#
# Running command: bedtools sort -faidx /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes -i /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th17_abc/GeneList.TSS1kb.bed > /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th17_abc/GeneList.TSS1kb.bed.sorted; mv /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th17_abc/GeneList.TSS1kb.bed.sorted /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th17_abc/GeneList.TSS1kb.bed
# Loading coverage from pre-calculated file for Genes.H3K27ac.Th17_2.masked.dedup.sorted.bam
# Feature H3K27ac completed in 26.15342402458191
# Loading coverage from pre-calculated file for Genes.DHS.Th17_2.masked.dups_marked.bam
# Feature DHS completed in 0.32222795486450195
# Loading coverage from pre-calculated file for Genes.TSS1kb.H3K27ac.Th17_2.masked.dedup.sorted.bam
# Feature H3K27ac completed in 25.869748830795288
# Loading coverage from pre-calculated file for Genes.TSS1kb.DHS.Th17_2.masked.dups_marked.bam
# Feature DHS completed in 0.20093822479248047
# Regenerating /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th17_abc/Enhancers.H3K27ac.Th17_2.masked.dedup.sorted.bam.CountReads.bedgraph
# Counting coverage for Enhancers.H3K27ac.Th17_2.masked.dedup.sorted.bam
# Running: awk 'FNR==NR {x2[$1] = $0; next} $1 in x2 {print x2[$1]}' /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes <(samtools view -H /data/reddylab/Revathy/dev/Maria/ABC/data/Th17_2.masked.dedup.sorted.bam | grep SQ | cut -f 2 | cut -c 4- )  > /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th17_abc/Enhancers.H3K27ac.Th17_2.masked.dedup.sorted.bam.CountReads.bedgraph.temp_sort_order
# Running: bedtools sort -faidx /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th17_abc/Enhancers.H3K27ac.Th17_2.masked.dedup.sorted.bam.CountReads.bedgraph.temp_sort_order -i /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th17_2.masked.dedup.sorted_peaks.narrowPeak.candidateRegions.bed | bedtools coverage -g /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th17_abc/Enhancers.H3K27ac.Th17_2.masked.dedup.sorted.bam.CountReads.bedgraph.temp_sort_order -counts -sorted -a stdin -b /data/reddylab/Revathy/dev/Maria/ABC/data/Th17_2.masked.dedup.sorted.bam | awk '{print $1 "\t" $2 "\t" $3 "\t" $NF}'  | bedtools sort -faidx /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes -i stdin > /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th17_abc/Enhancers.H3K27ac.Th17_2.masked.dedup.sorted.bam.CountReads.bedgraph; rm /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th17_abc/Enhancers.H3K27ac.Th17_2.masked.dedup.sorted.bam.CountReads.bedgraph.temp_sort_order
# BEDTools completed successfully.
#
# Feature H3K27ac completed in 76.94649028778076
# Regenerating /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th17_abc/Enhancers.DHS.Th17_2.masked.dups_marked.bam.CountReads.bedgraph
# Counting coverage for Enhancers.DHS.Th17_2.masked.dups_marked.bam
# Running: awk 'FNR==NR {x2[$1] = $0; next} $1 in x2 {print x2[$1]}' /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes <(samtools view -H /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th17_2.masked.dups_marked.bam | grep SQ | cut -f 2 | cut -c 4- )  > /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th17_abc/Enhancers.DHS.Th17_2.masked.dups_marked.bam.CountReads.bedgraph.temp_sort_order
# Running: bedtools sort -faidx /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th17_abc/Enhancers.DHS.Th17_2.masked.dups_marked.bam.CountReads.bedgraph.temp_sort_order -i /data/reddylab/Revathy/dev/Maria/ABC/candidate_region_by_dnase/Th17_2.masked.dedup.sorted_peaks.narrowPeak.candidateRegions.bed | bedtools coverage -g /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th17_abc/Enhancers.DHS.Th17_2.masked.dups_marked.bam.CountReads.bedgraph.temp_sort_order -counts -sorted -a stdin -b /data/reddylab/Jungkyun/MS_maria/results/processing/atac_seq/Ciofani_5484_190307A5_MCS226-233_258_259-pe-blacklist-removal/Th17_2.masked.dups_marked.bam | awk '{print $1 "\t" $2 "\t" $3 "\t" $NF}'  | bedtools sort -faidx /data/reddylab/Revathy/dev/Maria/ABC/ABC-Enhancer-Gene-Prediction/reference/chr_sizes -i stdin > /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th17_abc/Enhancers.DHS.Th17_2.masked.dups_marked.bam.CountReads.bedgraph; rm /gpfs/fs1/data/reddylab/Revathy/dev/Maria/ABC/enhancer_acitivity/Th17_abc/Enhancers.DHS.Th17_2.masked.dups_marked.bam.CountReads.bedgraph.temp_sort_order
# BEDTools completed successfully.
#
# Feature DHS completed in 98.4563398361206
# Assigning classes to enhancers
# Total enhancers: 48972
#          Promoters: 1653
#          Genic: 22662
#          Intergenic: 24657
# Neighborhoods Complete!
# [E::idx_find_and_load] Could not retrieve index file for '/data/reddylab/Revathy/dev/Maria/ABC/data/Th01_1.masked.dedup.sorted.bam'
# samtools idxstats: fail to load index for "/data/reddylab/Revathy/dev/Maria/ABC/data/Th01_1.masked.dedup.sorted.bam", reverting to slow method
# [E::idx_find_and_load] Could not retrieve index file for '/data/reddylab/Revathy/dev/Maria/ABC/data/Th01_1.masked.dedup.sorted.bam'
# samtools idxstats: fail to load index for "/data/reddylab/Revathy/dev/Maria/ABC/data/Th01_1.masked.dedup.sorted.bam", reverting to slow method
# [E::idx_find_and_load] Could not retrieve index file for '/data/reddylab/Revathy/dev/Maria/ABC/data/Th01_1.masked.dedup.sorted.bam'
# samtools idxstats: fail to load index for "/data/reddylab/Revathy/dev/Maria/ABC/data/Th01_1.masked.dedup.sorted.bam", reverting to slow method
# [E::idx_find_and_load] Could not retrieve index file for '/data/reddylab/Revathy/dev/Maria/ABC/data/Th01_2.masked.dedup.sorted.bam'
# samtools idxstats: fail to load index for "/data/reddylab/Revathy/dev/Maria/ABC/data/Th01_2.masked.dedup.sorted.bam", reverting to slow method
# [E::idx_find_and_load] Could not retrieve index file for '/data/reddylab/Revathy/dev/Maria/ABC/data/Th01_2.masked.dedup.sorted.bam'
# samtools idxstats: fail to load index for "/data/reddylab/Revathy/dev/Maria/ABC/data/Th01_2.masked.dedup.sorted.bam", reverting to slow method
# [E::idx_find_and_load] Could not retrieve index file for '/data/reddylab/Revathy/dev/Maria/ABC/data/Th01_2.masked.dedup.sorted.bam'
# samtools idxstats: fail to load index for "/data/reddylab/Revathy/dev/Maria/ABC/data/Th01_2.masked.dedup.sorted.bam", reverting to slow method
# [E::idx_find_and_load] Could not retrieve index file for '/data/reddylab/Revathy/dev/Maria/ABC/data/Th17_1.masked.dedup.sorted.bam'
# samtools idxstats: fail to load index for "/data/reddylab/Revathy/dev/Maria/ABC/data/Th17_1.masked.dedup.sorted.bam", reverting to slow method
# [E::idx_find_and_load] Could not retrieve index file for '/data/reddylab/Revathy/dev/Maria/ABC/data/Th17_1.masked.dedup.sorted.bam'
# samtools idxstats: fail to load index for "/data/reddylab/Revathy/dev/Maria/ABC/data/Th17_1.masked.dedup.sorted.bam", reverting to slow method
# [E::idx_find_and_load] Could not retrieve index file for '/data/reddylab/Revathy/dev/Maria/ABC/data/Th17_1.masked.dedup.sorted.bam'
# samtools idxstats: fail to load index for "/data/reddylab/Revathy/dev/Maria/ABC/data/Th17_1.masked.dedup.sorted.bam", reverting to slow method
# [E::idx_find_and_load] Could not retrieve index file for '/data/reddylab/Revathy/dev/Maria/ABC/data/Th17_2.masked.dedup.sorted.bam'
# samtools idxstats: fail to load index for "/data/reddylab/Revathy/dev/Maria/ABC/data/Th17_2.masked.dedup.sorted.bam", reverting to slow method
# [E::idx_find_and_load] Could not retrieve index file for '/data/reddylab/Revathy/dev/Maria/ABC/data/Th17_2.masked.dedup.sorted.bam'
# samtools idxstats: fail to load index for "/data/reddylab/Revathy/dev/Maria/ABC/data/Th17_2.masked.dedup.sorted.bam", reverting to slow method
# [E::idx_find_and_load] Could not retrieve index file for '/data/reddylab/Revathy/dev/Maria/ABC/data/Th17_2.masked.dedup.sorted.bam'
# samtools idxstats: fail to load index for "/data/reddylab/Revathy/dev/Maria/ABC/data/Th17_2.masked.dedup.sorted.bam", reverting to slow method

# %% [markdown]
# HiC files are pre-processed using Juicer, can be found in /data/reddylab/Revathy/dev/Maria/HiC_preprocessing.ipynb

# %% [markdown]
# #### Compute ABC scores

# %%
# %%bash
# source /data/reddylab/software/miniconda3/bin/activate jung_py3
# ABC=/gpfs/fs1/data/reddylab/Revathy/collabs/Maria/ABC/ABC-Enhancer-Gene-Prediction
# task=ABC_score
# mkdir -p /gpfs/fs1/data/reddylab/Revathy/collabs/Maria/ABC/${task}
# Enhancer_activity=/gpfs/fs1/data/reddylab/Revathy/collabs/Maria/ABC/enhancer_acitivity
# hic=/gpfs/fs1/data/reddylab/Revathy/collabs/Maria/hic
#
# cd ${Enhancer_activity}
#
# threshold=02
# LIST=sample_names.txt
# SAMPLES=$(cat /data/reddylab/Revathy/dev/Maria/ABC/$LIST|tr '\n' ' ')
#
# for sample in $(echo Th01 Th17);
# do
# python ${ABC}/src/predict.py \
# --enhancers ${Enhancer_activity}/${sample}_abc/EnhancerList.txt \
# --genes ${Enhancer_activity}/${sample}_abc/GeneList.txt \
# --HiCdir ${hic}/${sample} \
# --hic_resolution 5000 \
# --scale_hic_using_powerlaw \
# --threshold .${threshold} \
# --cellType ${sample} \
# --outdir /gpfs/fs1/data/reddylab/Revathy/collabs/Maria/ABC/${task}/${sample}_hic.threshold0.${threshold} \
# --make_all_putative
#
# done
# Out:
# reading genes
# reading enhancers
# Making predictions for chromosome: chr22
# Making putative predictions table...
# Using: /gpfs/fs1/data/reddylab/Revathy/dev/Maria/hic/Th01/chr22/chr22.KRobserved.gz
# Begin HiC
# Loading HiC
# hic.to.sparse: Elapsed time: 0.9547169208526611
# HiC Matrix has row sums of 1669.5396348412314, making doubly stochastic...
# HiC has 1399603 rows after windowing between 0 and 5000000
# process.hic: Elapsed time: 2.2869439125061035
# HiC added to predictions table. Elapsed time: 0.37697601318359375
# HiC Complete
# Completed chromosome: chr22. Elapsed time: 4.167795658111572
#
# Making predictions for chromosome: chr1
# Making putative predictions table...
# Using: /gpfs/fs1/data/reddylab/Revathy/dev/Maria/hic/Th01/chr1/chr1.KRobserved.gz
# Begin HiC
# Loading HiC
# hic.to.sparse: Elapsed time: 8.680987119674683
# HiC Matrix has row sums of 1821.457072176637, making doubly stochastic...
# HiC has 9718374 rows after windowing between 0 and 5000000
# process.hic: Elapsed time: 18.089518070220947
# HiC added to predictions table. Elapsed time: 4.740597248077393
# HiC Complete
# Completed chromosome: chr1. Elapsed time: 34.64890098571777
#
# Making predictions for chromosome: chr15
# Making putative predictions table...
# Using: /gpfs/fs1/data/reddylab/Revathy/dev/Maria/hic/Th01/chr15/chr15.KRobserved.gz
# Begin HiC
# Loading HiC
# hic.to.sparse: Elapsed time: 2.550659656524658
# HiC Matrix has row sums of 1700.5841866727549, making doubly stochastic...
# HiC has 3350294 rows after windowing between 0 and 5000000
# process.hic: Elapsed time: 5.8311076164245605
# HiC added to predictions table. Elapsed time: 1.1859140396118164
# HiC Complete
# Completed chromosome: chr15. Elapsed time: 10.259731531143188
#
# Making predictions for chromosome: chr20
# Making putative predictions table...
# Using: /gpfs/fs1/data/reddylab/Revathy/dev/Maria/hic/Th01/chr20/chr20.KRobserved.gz
# Begin HiC
# Loading HiC
# hic.to.sparse: Elapsed time: 1.994340181350708
# HiC Matrix has row sums of 1711.636629811376, making doubly stochastic...
# HiC has 2710341 rows after windowing between 0 and 5000000
# process.hic: Elapsed time: 4.477664470672607
# HiC added to predictions table. Elapsed time: 0.7996923923492432
# HiC Complete
# Completed chromosome: chr20. Elapsed time: 7.840063571929932
#
# Making predictions for chromosome: chr11
# Making putative predictions table...
# Using: /gpfs/fs1/data/reddylab/Revathy/dev/Maria/hic/Th01/chr11/chr11.KRobserved.gz
# Begin HiC
# Loading HiC
# hic.to.sparse: Elapsed time: 5.616123199462891
# HiC Matrix has row sums of 1718.4666921751407, making doubly stochastic...
# HiC has 5644661 rows after windowing between 0 and 5000000
# process.hic: Elapsed time: 10.28699016571045
# HiC added to predictions table. Elapsed time: 2.402630567550659
# HiC Complete
# Completed chromosome: chr11. Elapsed time: 20.185552835464478
#
# Making predictions for chromosome: chr3
# Making putative predictions table...
# Using: /gpfs/fs1/data/reddylab/Revathy/dev/Maria/hic/Th01/chr3/chr3.KRobserved.gz
# Begin HiC
# Loading HiC
# hic.to.sparse: Elapsed time: 8.328439235687256
# HiC Matrix has row sums of 1777.7829211558487, making doubly stochastic...
# HiC has 8765088 rows after windowing between 0 and 5000000
# process.hic: Elapsed time: 16.04148006439209
# HiC added to predictions table. Elapsed time: 3.574261426925659
# HiC Complete
# Completed chromosome: chr3. Elapsed time: 30.013935804367065
#
# Making predictions for chromosome: chr18
# Making putative predictions table...
# Using: /gpfs/fs1/data/reddylab/Revathy/dev/Maria/hic/Th01/chr18/chr18.KRobserved.gz
# Begin HiC
# Loading HiC
# hic.to.sparse: Elapsed time: 2.6987690925598145
# HiC Matrix has row sums of 1586.2914158939402, making doubly stochastic...
# HiC has 3201448 rows after windowing between 0 and 5000000
# process.hic: Elapsed time: 5.680152654647827
# HiC added to predictions table. Elapsed time: 0.8589756488800049
# HiC Complete
# Completed chromosome: chr18. Elapsed time: 9.909788608551025
#
# Making predictions for chromosome: chr6
# Making putative predictions table...
# Using: /gpfs/fs1/data/reddylab/Revathy/dev/Maria/hic/Th01/chr6/chr6.KRobserved.gz
# Begin HiC
# Loading HiC
# hic.to.sparse: Elapsed time: 6.887752532958984
# HiC Matrix has row sums of 1756.3692637008692, making doubly stochastic...
# HiC has 7461927 rows after windowing between 0 and 5000000
# process.hic: Elapsed time: 13.63762378692627
# HiC added to predictions table. Elapsed time: 3.2331974506378174
# HiC Complete
# Completed chromosome: chr6. Elapsed time: 25.591208934783936
#
# Making predictions for chromosome: chr2
# Making putative predictions table...
# Using: /gpfs/fs1/data/reddylab/Revathy/dev/Maria/hic/Th01/chr2/chr2.KRobserved.gz
# Begin HiC
# Loading HiC
# hic.to.sparse: Elapsed time: 9.966347455978394
# HiC Matrix has row sums of 1784.1953619122014, making doubly stochastic...
# HiC has 10239912 rows after windowing between 0 and 5000000
# process.hic: Elapsed time: 19.78471612930298
# HiC added to predictions table. Elapsed time: 4.043871641159058
# HiC Complete
# Completed chromosome: chr2. Elapsed time: 36.24546480178833
#
# Making predictions for chromosome: chr17
# Making putative predictions table...
# Using: /gpfs/fs1/data/reddylab/Revathy/dev/Maria/hic/Th01/chr17/chr17.KRobserved.gz
# Begin HiC
# Loading HiC
# hic.to.sparse: Elapsed time: 2.51920747756958
# HiC Matrix has row sums of 1742.3018261408577, making doubly stochastic...
# HiC has 3166013 rows after windowing between 0 and 5000000
# process.hic: Elapsed time: 5.63075590133667
# HiC added to predictions table. Elapsed time: 1.332564353942871
# HiC Complete
# Completed chromosome: chr17. Elapsed time: 10.34425139427185
#
# Making predictions for chromosome: chr14
# Making putative predictions table...
# Using: /gpfs/fs1/data/reddylab/Revathy/dev/Maria/hic/Th01/chr14/chr14.KRobserved.gz
# Begin HiC
# Loading HiC
# hic.to.sparse: Elapsed time: 3.2229676246643066
# HiC Matrix has row sums of 1707.215499012547, making doubly stochastic...
# HiC has 3911041 rows after windowing between 0 and 5000000
# process.hic: Elapsed time: 6.3689539432525635
# HiC added to predictions table. Elapsed time: 1.5917332172393799
# HiC Complete
# Completed chromosome: chr14. Elapsed time: 12.225194692611694
#
# Making predictions for chromosome: chr12
# Making putative predictions table...
# Using: /gpfs/fs1/data/reddylab/Revathy/dev/Maria/hic/Th01/chr12/chr12.KRobserved.gz
# Begin HiC
# Loading HiC
# hic.to.sparse: Elapsed time: 5.179730176925659
# HiC Matrix has row sums of 1760.9094632563801, making doubly stochastic...
# HiC has 5851233 rows after windowing between 0 and 5000000
# process.hic: Elapsed time: 10.293895483016968
# HiC added to predictions table. Elapsed time: 2.3303587436676025
# HiC Complete
# Completed chromosome: chr12. Elapsed time: 19.486316204071045
#
# Making predictions for chromosome: chr19
# Making putative predictions table...
# Using: /gpfs/fs1/data/reddylab/Revathy/dev/Maria/hic/Th01/chr19/chr19.KRobserved.gz
# Begin HiC
# Loading HiC
# hic.to.sparse: Elapsed time: 1.696004867553711
# HiC Matrix has row sums of 1771.123374264509, making doubly stochastic...
# HiC has 2413972 rows after windowing between 0 and 5000000
# process.hic: Elapsed time: 3.8413403034210205
# HiC added to predictions table. Elapsed time: 1.1094412803649902
# HiC Complete
# Completed chromosome: chr19. Elapsed time: 7.663561582565308
#
# Making predictions for chromosome: chr13
# Making putative predictions table...
# Using: /gpfs/fs1/data/reddylab/Revathy/dev/Maria/hic/Th01/chr13/chr13.KRobserved.gz
# Begin HiC
# Loading HiC
# hic.to.sparse: Elapsed time: 3.7369606494903564
# HiC Matrix has row sums of 1587.994570594416, making doubly stochastic...
# HiC has 4202560 rows after windowing between 0 and 5000000
# process.hic: Elapsed time: 7.4319727420806885
# HiC added to predictions table. Elapsed time: 1.5038387775421143
# HiC Complete
# Completed chromosome: chr13. Elapsed time: 13.65760087966919
#
# Making predictions for chromosome: chr9
# Making putative predictions table...
# Using: /gpfs/fs1/data/reddylab/Revathy/dev/Maria/hic/Th01/chr9/chr9.KRobserved.gz
# Begin HiC
# Loading HiC
# hic.to.sparse: Elapsed time: 3.830440044403076
# HiC Matrix has row sums of 1626.9624805381495, making doubly stochastic...
# HiC has 4888634 rows after windowing between 0 and 5000000
# process.hic: Elapsed time: 8.45158863067627
# HiC added to predictions table. Elapsed time: 1.710240364074707
# HiC Complete
# Completed chromosome: chr9. Elapsed time: 15.02242374420166
#
# Making predictions for chromosome: chr4
# Making putative predictions table...
# Using: /gpfs/fs1/data/reddylab/Revathy/dev/Maria/hic/Th01/chr4/chr4.KRobserved.gz
# Begin HiC
# Loading HiC
# hic.to.sparse: Elapsed time: 7.617102384567261
# HiC Matrix has row sums of 1623.1186781733436, making doubly stochastic...
# HiC has 7967834 rows after windowing between 0 and 5000000
# process.hic: Elapsed time: 15.215095281600952
# HiC added to predictions table. Elapsed time: 3.018317461013794
# HiC Complete
# Completed chromosome: chr4. Elapsed time: 27.680612087249756
#
# Making predictions for chromosome: chr8
# Making putative predictions table...
# Using: /gpfs/fs1/data/reddylab/Revathy/dev/Maria/hic/Th01/chr8/chr8.KRobserved.gz
# Begin HiC
# Loading HiC
# hic.to.sparse: Elapsed time: 5.96468710899353
# HiC Matrix has row sums of 1697.2077205693502, making doubly stochastic...
# HiC has 6101265 rows after windowing between 0 and 5000000
# process.hic: Elapsed time: 11.39745831489563
# HiC added to predictions table. Elapsed time: 2.009514093399048
# HiC Complete
# Completed chromosome: chr8. Elapsed time: 20.76465082168579
#
# Making predictions for chromosome: chrX
# Making putative predictions table...
# Using: /gpfs/fs1/data/reddylab/Revathy/dev/Maria/hic/Th01/chrX/chrX.KRobserved.gz
# Begin HiC
# Loading HiC
# hic.to.sparse: Elapsed time: 4.378861904144287
# HiC Matrix has row sums of 1107.965440437105, making doubly stochastic...
# HiC has 5000671 rows after windowing between 0 and 5000000
# process.hic: Elapsed time: 10.595508337020874
# HiC added to predictions table. Elapsed time: 1.7283008098602295
# HiC Complete
# Completed chromosome: chrX. Elapsed time: 17.810474634170532
#
# Making predictions for chromosome: chr21
# Making putative predictions table...
# Using: /gpfs/fs1/data/reddylab/Revathy/dev/Maria/hic/Th01/chr21/chr21.KRobserved.gz
# Begin HiC
# Loading HiC
# hic.to.sparse: Elapsed time: 0.904597282409668
# HiC Matrix has row sums of 1434.0243901188376, making doubly stochastic...
# HiC has 1445668 rows after windowing between 0 and 5000000
# process.hic: Elapsed time: 2.2500083446502686
# HiC added to predictions table. Elapsed time: 0.32821083068847656
# HiC Complete
# Completed chromosome: chr21. Elapsed time: 3.7603182792663574
#
# Making predictions for chromosome: chr5
# Making putative predictions table...
# Using: /gpfs/fs1/data/reddylab/Revathy/dev/Maria/hic/Th01/chr5/chr5.KRobserved.gz
# Begin HiC
# Loading HiC
# hic.to.sparse: Elapsed time: 7.169315338134766
# HiC Matrix has row sums of 1697.4367414618423, making doubly stochastic...
# HiC has 7761556 rows after windowing between 0 and 5000000
# process.hic: Elapsed time: 14.18867039680481
# HiC added to predictions table. Elapsed time: 3.1603620052337646
# HiC Complete
# Completed chromosome: chr5. Elapsed time: 26.266308784484863
#
# Making predictions for chromosome: chr7
# Making putative predictions table...
# Using: /gpfs/fs1/data/reddylab/Revathy/dev/Maria/hic/Th01/chr7/chr7.KRobserved.gz
# Begin HiC
# Loading HiC
# hic.to.sparse: Elapsed time: 6.10869836807251
# HiC Matrix has row sums of 1626.1438683648717, making doubly stochastic...
# HiC has 6382703 rows after windowing between 0 and 5000000
# process.hic: Elapsed time: 12.184859037399292
# HiC added to predictions table. Elapsed time: 2.730220079421997
# HiC Complete
# Completed chromosome: chr7. Elapsed time: 22.52267575263977
#
# Making predictions for chromosome: chr10
# Making putative predictions table...
# Using: /gpfs/fs1/data/reddylab/Revathy/dev/Maria/hic/Th01/chr10/chr10.KRobserved.gz
# Begin HiC
# Loading HiC
# hic.to.sparse: Elapsed time: 5.264261245727539
# HiC Matrix has row sums of 1728.315837839723, making doubly stochastic...
# HiC has 5664741 rows after windowing between 0 and 5000000
# process.hic: Elapsed time: 10.327777624130249
# HiC added to predictions table. Elapsed time: 2.078084707260132
# HiC Complete
# Completed chromosome: chr10. Elapsed time: 19.13106060028076
#
# Making predictions for chromosome: chr16
# Making putative predictions table...
# Using: /gpfs/fs1/data/reddylab/Revathy/dev/Maria/hic/Th01/chr16/chr16.KRobserved.gz
# Begin HiC
# Loading HiC
# hic.to.sparse: Elapsed time: 2.4166016578674316
# HiC Matrix has row sums of 1633.3944067329098, making doubly stochastic...
# HiC has 3090105 rows after windowing between 0 and 5000000
# process.hic: Elapsed time: 5.612248182296753
# HiC added to predictions table. Elapsed time: 0.9386165142059326
# HiC Complete
# Completed chromosome: chr16. Elapsed time: 9.718830347061157
#
# Writing output files...
# Done.
# reading genes
# reading enhancers
# Making predictions for chromosome: chr9
# Making putative predictions table...
# Using: /gpfs/fs1/data/reddylab/Revathy/dev/Maria/hic/Th17/chr9/chr9.KRobserved.gz
# Begin HiC
# Loading HiC
# hic.to.sparse: Elapsed time: 3.723721504211426
# HiC Matrix has row sums of 1390.3454375769775, making doubly stochastic...
# HiC has 4438665 rows after windowing between 0 and 5000000
# process.hic: Elapsed time: 7.8922741413116455
# HiC added to predictions table. Elapsed time: 1.5816800594329834
# HiC Complete
# Completed chromosome: chr9. Elapsed time: 14.349733114242554
#
# Making predictions for chromosome: chr17
# Making putative predictions table...
# Using: /gpfs/fs1/data/reddylab/Revathy/dev/Maria/hic/Th17/chr17/chr17.KRobserved.gz
# Begin HiC
# Loading HiC
# hic.to.sparse: Elapsed time: 2.1438519954681396
# HiC Matrix has row sums of 1483.2684323072097, making doubly stochastic...
# HiC has 2897231 rows after windowing between 0 and 5000000
# process.hic: Elapsed time: 5.178173303604126
# HiC added to predictions table. Elapsed time: 1.0116078853607178
# HiC Complete
# Completed chromosome: chr17. Elapsed time: 9.157618284225464
#
# Making predictions for chromosome: chr15
# Making putative predictions table...
# Using: /gpfs/fs1/data/reddylab/Revathy/dev/Maria/hic/Th17/chr15/chr15.KRobserved.gz
# Begin HiC
# Loading HiC
# hic.to.sparse: Elapsed time: 2.286987543106079
# HiC Matrix has row sums of 1445.3765565881868, making doubly stochastic...
# HiC has 3091119 rows after windowing between 0 and 5000000
# process.hic: Elapsed time: 5.376974821090698
# HiC added to predictions table. Elapsed time: 0.868840217590332
# HiC Complete
# Completed chromosome: chr15. Elapsed time: 9.159915208816528
#
# Making predictions for chromosome: chr19
# Making putative predictions table...
# Using: /gpfs/fs1/data/reddylab/Revathy/dev/Maria/hic/Th17/chr19/chr19.KRobserved.gz
# Begin HiC
# Loading HiC
# hic.to.sparse: Elapsed time: 1.6013741493225098
# HiC Matrix has row sums of 1526.2347998480657, making doubly stochastic...
# HiC has 2234044 rows after windowing between 0 and 5000000
# process.hic: Elapsed time: 3.5399997234344482
# HiC added to predictions table. Elapsed time: 1.072981357574463
# HiC Complete
# Completed chromosome: chr19. Elapsed time: 7.235585689544678
#
# Making predictions for chromosome: chr5
# Making putative predictions table...
# Using: /gpfs/fs1/data/reddylab/Revathy/dev/Maria/hic/Th17/chr5/chr5.KRobserved.gz
# Begin HiC
# Loading HiC
# hic.to.sparse: Elapsed time: 6.460506439208984
# HiC Matrix has row sums of 1455.796622666746, making doubly stochastic...
# HiC has 7067083 rows after windowing between 0 and 5000000
# process.hic: Elapsed time: 13.079856395721436
# HiC added to predictions table. Elapsed time: 2.872908353805542
# HiC Complete
# Completed chromosome: chr5. Elapsed time: 23.974833726882935
#
# Making predictions for chromosome: chr22
# Making putative predictions table...
# Using: /gpfs/fs1/data/reddylab/Revathy/dev/Maria/hic/Th17/chr22/chr22.KRobserved.gz
# Begin HiC
# Loading HiC
# hic.to.sparse: Elapsed time: 0.8730366230010986
# HiC Matrix has row sums of 1417.4417063775095, making doubly stochastic...
# HiC has 1277651 rows after windowing between 0 and 5000000
# process.hic: Elapsed time: 2.0893394947052
# HiC added to predictions table. Elapsed time: 0.3574495315551758
# HiC Complete
# Completed chromosome: chr22. Elapsed time: 3.6595773696899414
#
# Making predictions for chromosome: chr21
# Making putative predictions table...
# Using: /gpfs/fs1/data/reddylab/Revathy/dev/Maria/hic/Th17/chr21/chr21.KRobserved.gz
# Begin HiC
# Loading HiC
# hic.to.sparse: Elapsed time: 0.8842592239379883
# HiC Matrix has row sums of 1223.7193572134345, making doubly stochastic...
# HiC has 1313543 rows after windowing between 0 and 5000000
# process.hic: Elapsed time: 2.059053897857666
# HiC added to predictions table. Elapsed time: 0.3217923641204834
# HiC Complete
# Completed chromosome: chr21. Elapsed time: 3.5147948265075684
#
# Making predictions for chromosome: chr7
# Making putative predictions table...
# Using: /gpfs/fs1/data/reddylab/Revathy/dev/Maria/hic/Th17/chr7/chr7.KRobserved.gz
# Begin HiC
# Loading HiC
# hic.to.sparse: Elapsed time: 5.276389122009277
# HiC Matrix has row sums of 1397.4282790987377, making doubly stochastic...
# HiC has 5791417 rows after windowing between 0 and 5000000
# process.hic: Elapsed time: 11.15759801864624
# HiC added to predictions table. Elapsed time: 2.0024564266204834
# HiC Complete
# Completed chromosome: chr7. Elapsed time: 19.787452459335327
#
# Making predictions for chromosome: chr2
# Making putative predictions table...
# Using: /gpfs/fs1/data/reddylab/Revathy/dev/Maria/hic/Th17/chr2/chr2.KRobserved.gz
# Begin HiC
# Loading HiC
# hic.to.sparse: Elapsed time: 8.960262060165405
# HiC Matrix has row sums of 1536.974560245516, making doubly stochastic...
# HiC has 9317321 rows after windowing between 0 and 5000000
# process.hic: Elapsed time: 18.221892595291138
# HiC added to predictions table. Elapsed time: 3.8291003704071045
# HiC Complete
# Completed chromosome: chr2. Elapsed time: 33.20798301696777
#
# Making predictions for chromosome: chr3
# Making putative predictions table...
# Using: /gpfs/fs1/data/reddylab/Revathy/dev/Maria/hic/Th17/chr3/chr3.KRobserved.gz
# Begin HiC
# Loading HiC
# hic.to.sparse: Elapsed time: 7.322037696838379
# HiC Matrix has row sums of 1518.217219048322, making doubly stochastic...
# HiC has 7955184 rows after windowing between 0 and 5000000
# process.hic: Elapsed time: 14.695894241333008
# HiC added to predictions table. Elapsed time: 3.2464966773986816
# HiC Complete
# Completed chromosome: chr3. Elapsed time: 27.103429079055786
#
# Making predictions for chromosome: chr13
# Making putative predictions table...
# Using: /gpfs/fs1/data/reddylab/Revathy/dev/Maria/hic/Th17/chr13/chr13.KRobserved.gz
# Begin HiC
# Loading HiC
# hic.to.sparse: Elapsed time: 3.454299211502075
# HiC Matrix has row sums of 1371.9076569656688, making doubly stochastic...
# HiC has 3850169 rows after windowing between 0 and 5000000
# process.hic: Elapsed time: 6.852335453033447
# HiC added to predictions table. Elapsed time: 1.3212146759033203
# HiC Complete
# Completed chromosome: chr13. Elapsed time: 12.513129472732544
#
# Making predictions for chromosome: chr1
# Making putative predictions table...
# Using: /gpfs/fs1/data/reddylab/Revathy/dev/Maria/hic/Th17/chr1/chr1.KRobserved.gz
# Begin HiC
# Loading HiC
# hic.to.sparse: Elapsed time: 7.8138086795806885
# HiC Matrix has row sums of 1549.9904993515233, making doubly stochastic...
# HiC has 8850041 rows after windowing between 0 and 5000000
# process.hic: Elapsed time: 16.91107439994812
# HiC added to predictions table. Elapsed time: 4.495526552200317
# HiC Complete
# Completed chromosome: chr1. Elapsed time: 32.233598947525024
#
# Making predictions for chromosome: chr11
# Making putative predictions table...
# Using: /gpfs/fs1/data/reddylab/Revathy/dev/Maria/hic/Th17/chr11/chr11.KRobserved.gz
# Begin HiC
# Loading HiC
# hic.to.sparse: Elapsed time: 4.538697004318237
# HiC Matrix has row sums of 1470.015573589537, making doubly stochastic...
# HiC has 5110354 rows after windowing between 0 and 5000000
# process.hic: Elapsed time: 9.516477346420288
# HiC added to predictions table. Elapsed time: 2.1928622722625732
# HiC Complete
# Completed chromosome: chr11. Elapsed time: 18.012093544006348
#
# Making predictions for chromosome: chr12
# Making putative predictions table...
# Using: /gpfs/fs1/data/reddylab/Revathy/dev/Maria/hic/Th17/chr12/chr12.KRobserved.gz
# Begin HiC
# Loading HiC
# hic.to.sparse: Elapsed time: 4.783036947250366
# HiC Matrix has row sums of 1502.404267592939, making doubly stochastic...
# HiC has 5306512 rows after windowing between 0 and 5000000
# process.hic: Elapsed time: 9.582131624221802
# HiC added to predictions table. Elapsed time: 2.1730899810791016
# HiC Complete
# Completed chromosome: chr12. Elapsed time: 18.06832528114319
#
# Making predictions for chromosome: chrX
# Making putative predictions table...
# Using: /gpfs/fs1/data/reddylab/Revathy/dev/Maria/hic/Th17/chrX/chrX.KRobserved.gz
# Begin HiC
# Loading HiC
# hic.to.sparse: Elapsed time: 4.124722719192505
# HiC Matrix has row sums of 961.0704462520184, making doubly stochastic...
# HiC has 4539179 rows after windowing between 0 and 5000000
# process.hic: Elapsed time: 9.932192325592041
# HiC added to predictions table. Elapsed time: 1.5994281768798828
# HiC Complete
# Completed chromosome: chrX. Elapsed time: 16.682201147079468
#
# Making predictions for chromosome: chr8
# Making putative predictions table...
# Using: /gpfs/fs1/data/reddylab/Revathy/dev/Maria/hic/Th17/chr8/chr8.KRobserved.gz
# Begin HiC
# Loading HiC
# hic.to.sparse: Elapsed time: 5.17205810546875
# HiC Matrix has row sums of 1467.1368826893463, making doubly stochastic...
# HiC has 5555717 rows after windowing between 0 and 5000000
# process.hic: Elapsed time: 10.603359460830688
# HiC added to predictions table. Elapsed time: 1.8901891708374023
# HiC Complete
# Completed chromosome: chr8. Elapsed time: 18.92940092086792
#
# Making predictions for chromosome: chr18
# Making putative predictions table...
# Using: /gpfs/fs1/data/reddylab/Revathy/dev/Maria/hic/Th17/chr18/chr18.KRobserved.gz
# Begin HiC
# Loading HiC
# hic.to.sparse: Elapsed time: 2.443580389022827
# HiC Matrix has row sums of 1368.3268768812343, making doubly stochastic...
# HiC has 2903944 rows after windowing between 0 and 5000000
# process.hic: Elapsed time: 5.274777412414551
# HiC added to predictions table. Elapsed time: 0.7645535469055176
# HiC Complete
# Completed chromosome: chr18. Elapsed time: 9.101156949996948
#
# Making predictions for chromosome: chr16
# Making putative predictions table...
# Using: /gpfs/fs1/data/reddylab/Revathy/dev/Maria/hic/Th17/chr16/chr16.KRobserved.gz
# Begin HiC
# Loading HiC
# hic.to.sparse: Elapsed time: 2.1839239597320557
# HiC Matrix has row sums of 1398.0825106876464, making doubly stochastic...
# HiC has 2821468 rows after windowing between 0 and 5000000
# process.hic: Elapsed time: 5.14653468132019
# HiC added to predictions table. Elapsed time: 0.859835147857666
# HiC Complete
# Completed chromosome: chr16. Elapsed time: 8.895794868469238
#
# Making predictions for chromosome: chr4
# Making putative predictions table...
# Using: /gpfs/fs1/data/reddylab/Revathy/dev/Maria/hic/Th17/chr4/chr4.KRobserved.gz
# Begin HiC
# Loading HiC
# hic.to.sparse: Elapsed time: 7.19158148765564
# HiC Matrix has row sums of 1400.7624801900968, making doubly stochastic...
# HiC has 7248464 rows after windowing between 0 and 5000000
# process.hic: Elapsed time: 14.07811450958252
# HiC added to predictions table. Elapsed time: 2.9371042251586914
# HiC Complete
# Completed chromosome: chr4. Elapsed time: 25.865135192871094
#
# Making predictions for chromosome: chr20
# Making putative predictions table...
# Using: /gpfs/fs1/data/reddylab/Revathy/dev/Maria/hic/Th17/chr20/chr20.KRobserved.gz
# Begin HiC
# Loading HiC
# hic.to.sparse: Elapsed time: 1.941455602645874
# HiC Matrix has row sums of 1457.633436399556, making doubly stochastic...
# HiC has 2456417 rows after windowing between 0 and 5000000
# process.hic: Elapsed time: 4.015393018722534
# HiC added to predictions table. Elapsed time: 0.7260286808013916
# HiC Complete
# Completed chromosome: chr20. Elapsed time: 7.220844984054565
#
# Making predictions for chromosome: chr10
# Making putative predictions table...
# Using: /gpfs/fs1/data/reddylab/Revathy/dev/Maria/hic/Th17/chr10/chr10.KRobserved.gz
# Begin HiC
# Loading HiC
# hic.to.sparse: Elapsed time: 4.562747478485107
# HiC Matrix has row sums of 1473.9607341365308, making doubly stochastic...
# HiC has 5164413 rows after windowing between 0 and 5000000
# process.hic: Elapsed time: 9.478096961975098
# HiC added to predictions table. Elapsed time: 1.961728811264038
# HiC Complete
# Completed chromosome: chr10. Elapsed time: 17.343820810317993
#
# Making predictions for chromosome: chr6
# Making putative predictions table...
# Using: /gpfs/fs1/data/reddylab/Revathy/dev/Maria/hic/Th17/chr6/chr6.KRobserved.gz
# Begin HiC
# Loading HiC
# hic.to.sparse: Elapsed time: 6.026068449020386
# HiC Matrix has row sums of 1509.6881820120548, making doubly stochastic...
# HiC has 6780726 rows after windowing between 0 and 5000000
# process.hic: Elapsed time: 12.499083280563354
# HiC added to predictions table. Elapsed time: 2.832386016845703
# HiC Complete
# Completed chromosome: chr6. Elapsed time: 22.995885133743286
#
# Making predictions for chromosome: chr14
# Making putative predictions table...
# Using: /gpfs/fs1/data/reddylab/Revathy/dev/Maria/hic/Th17/chr14/chr14.KRobserved.gz
# Begin HiC
# Loading HiC
# hic.to.sparse: Elapsed time: 2.95397686958313
# HiC Matrix has row sums of 1464.4410384660755, making doubly stochastic...
# HiC has 3596196 rows after windowing between 0 and 5000000
# process.hic: Elapsed time: 6.226326942443848
# HiC added to predictions table. Elapsed time: 1.4025909900665283
# HiC Complete
# Completed chromosome: chr14. Elapsed time: 11.543150186538696
#
# Writing output files...
# Done.

# %% [markdown]
# #### Create ABC enhancer beds

# %%
# %%bash
# module load bedtools2
# task=enhancers_by_ABC_bed
# mkdir -p /data/reddylab/Revathy/dev/Maria/ABC/${task}
# in_dir=/data/reddylab/Revathy/dev/Maria/ABC/ABC_score
#
# cd ${in_dir}
#
# for i in `ls -d *`;
# do
# cat ${in_dir}/${i}/EnhancerPredictions.txt | \
# cut -f 1-3,5,7|grep -v end > \
# /data/reddylab/Revathy/dev/Maria/ABC/${task}/${i}.bed
# done

# %%
# %%bash
#
# wc -l /data/reddylab/Revathy/dev/Maria/ABC/ABC_score/Th01_hic.threshold0.008/EnhancerPredictions.txt
# wc -l /data/reddylab/Revathy/dev/Maria/ABC/ABC_score/Th17_hic.threshold0.008/EnhancerPredictions.txt
# Out:
# 598211 /data/reddylab/Revathy/dev/Maria/ABC/ABC_score/Th01_hic.threshold0.008/EnhancerPredictions.txt
# 589871 /data/reddylab/Revathy/dev/Maria/ABC/ABC_score/Th17_hic.threshold0.008/EnhancerPredictions.txt

# %%
# %%bash
#
# wc -l /data/reddylab/Revathy/dev/Maria/ABC/ABC_score/Th01_hic.threshold0.02/EnhancerPredictions.txt
# wc -l /data/reddylab/Revathy/dev/Maria/ABC/ABC_score/Th17_hic.threshold0.02/EnhancerPredictions.txt
# Out:
# 195312 /data/reddylab/Revathy/dev/Maria/ABC/ABC_score/Th01_hic.threshold0.02/EnhancerPredictions.txt
# 203522 /data/reddylab/Revathy/dev/Maria/ABC/ABC_score/Th17_hic.threshold0.02/EnhancerPredictions.txt
