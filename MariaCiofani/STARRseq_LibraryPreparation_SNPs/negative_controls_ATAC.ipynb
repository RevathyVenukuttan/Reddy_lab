# %%
# !pwd
# Out:
# /gpfs/fs1/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/notebooks

# %%
# !ls /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/*hESC*
# Out:
# /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/GSM4130883_H1-hESC-1_final_ATAC.bw
# /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/GSM4130884_H1-hESC-2_final_ATAC.bw
# /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/GSM4130885_H9-hESC-1_final_ATAC.bw
# /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/GSM4130886_H9-hESC-2_final_ATAC.bw

# %%
# %%bash
# /data/common/shared_conda_envs/ucsc/bin/bigWigToBedGraph /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/GSM4130884_H1-hESC-2_final_ATAC.bw \
# /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/GSM4130884_H1-hESC-2_final_ATAC.bdg

# %%
# !head /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/GSM4130884_H1-hESC-2_final_ATAC.bdg
# Out:
# chr1	9909	9918	0
# chr1	9918	9920	0.1
# chr1	9920	9921	0.2
# chr1	9921	9923	0.3
# chr1	9923	9925	0.4
# chr1	9925	9926	0.6
# chr1	9926	9927	0.7
# chr1	9927	9928	0.8
# chr1	9928	9929	0.9
# chr1	9929	9930	1.2

# %%
# %%bash
# source /data/reddylab/software/miniconda2/bin/activate alex_dev
# cd /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq
# macs2 bdgpeakcall -i GSM4130884_H1-hESC-2_final_ATAC.bdg -o GSM4130883_H1-hESC-2_final_ATAC.narrowPeak
# Out:
# INFO  @ Thu, 18 Aug 2022 02:07:29: Read and build bedGraph...
# INFO  @ Thu, 18 Aug 2022 02:11:26: Call peaks from bedGraph...
# INFO  @ Thu, 18 Aug 2022 02:11:43: Write peaks...
# INFO  @ Thu, 18 Aug 2022 02:11:44: Done

# %%
# %%bash
# /data/common/shared_conda_envs/ucsc/bin/bigWigToBedGraph /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/GSM4130885_H9-hESC-1_final_ATAC.bw \
# /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/GSM4130885_H9-hESC-1_final_ATAC.bdg

# %%
# %%bash
# source /data/reddylab/software/miniconda2/bin/activate alex_dev
# cd /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq
# macs2 bdgpeakcall -i GSM4130885_H9-hESC-1_final_ATAC.bdg -o GSM4130885_H9-hESC-1_final_ATAC.narrowPeak
# Out:
# INFO  @ Thu, 18 Aug 2022 09:10:53: Read and build bedGraph...
# INFO  @ Thu, 18 Aug 2022 09:14:50: Call peaks from bedGraph...
# INFO  @ Thu, 18 Aug 2022 09:15:06: Write peaks...
# INFO  @ Thu, 18 Aug 2022 09:15:06: Done

# %%
# %%bash
# /data/common/shared_conda_envs/ucsc/bin/bigWigToBedGraph /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/GSM4130886_H9-hESC-2_final_ATAC.bw \
# /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/GSM4130886_H9-hESC-2_final_ATAC.bdg

# %%
# %%bash
# source /data/reddylab/software/miniconda2/bin/activate alex_dev
# cd /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq
# macs2 bdgpeakcall -i GSM4130886_H9-hESC-2_final_ATAC.bdg -o GSM4130886_H9-hESC-2_final_ATAC.narrowPeak
# Out:
# INFO  @ Thu, 18 Aug 2022 09:17:34: Read and build bedGraph...
# INFO  @ Thu, 18 Aug 2022 09:22:00: Call peaks from bedGraph...
# INFO  @ Thu, 18 Aug 2022 09:22:20: Write peaks...
# INFO  @ Thu, 18 Aug 2022 09:22:20: Done

# %%
# %%bash
# module load bedtools2
# cd /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq
# cat GSM4130883_H1-hESC-1_final_ATAC.narrowPeak \
#     GSM4130884_H1-hESC-2_final_ATAC.narrowPeak \
#     GSM4130885_H9-hESC-1_final_ATAC.narrowPeak \
#     GSM4130886_H9-hESC-2_final_ATAC.narrowPeak \
# | sort -k1,1 -k2,2n | bedtools merge -i - > H1_H9-hESC_final.ATACseq.UnionPeakSet.narrowPeak

# %%
# %%bash
# module load bedtools2
# cd /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq
# cat GSM4130883_H1-hESC-1_final_ATAC.narrowPeak \
#     GSM4130884_H1-hESC-2_final_ATAC.narrowPeak \
# | sort -k1,1 -k2,2n | bedtools merge -i - > H1_hESC_final.ATACseq.UnionPeakSet.narrowPeak

# %%
# %%bash
# cd /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq
# wc -l *.narrowPeak
# Out:
#   105106 GSM4130883_H1-hESC-1_final_ATAC.narrowPeak
#   107728 GSM4130884_H1-hESC-2_final_ATAC.narrowPeak
#    92690 GSM4130885_H9-hESC-1_final_ATAC.narrowPeak
#   123319 GSM4130886_H9-hESC-2_final_ATAC.narrowPeak
#   178686 H1_H9-hESC_final.ATACseq.UnionPeakSet.narrowPeak
#   607529 total

# %%
# %%bash
# cd /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq
# head -n 20 H1_H9-hESC_final.ATACseq.UnionPeakSet.narrowPeak
# Out:
# chr1	9927	10151
# chr1	564501	564792
# chr1	564836	565056
# chr1	565538	565893
# chr1	566254	568372
# chr1	568697	570253
# chr1	713513	714721
# chr1	756949	757199
# chr1	762602	763040
# chr1	779922	780176
# chr1	780582	781312
# chr1	791954	792160
# chr1	794044	794299
# chr1	804952	805454
# chr1	808009	808264
# chr1	808415	808619
# chr1	812227	813029
# chr1	839049	839463
# chr1	839605	840346
# chr1	840463	840855

# %% [markdown]
# * There are 12216 peaks that intersect in the hESC ATACseq and Th1/Th17 combined ATAC_peaks set
# * To create the library of negative_control set subtract the Th1/Th17 ATACseq from the hESC ATAC peakset - use bedtools subtract

# %%
# %%bash
# module load bedtools2
# bedtools subtract -a /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/H1_H9-hESC_final.ATACseq.UnionPeakSet.bed \
# -b /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/snp_data/atac_snp_loop/combined_ATAC_peaks.bed \
# > /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/H1_H9-hESC_peaks_not_in_Th1_Th17.ATACseq.UnionPeakSet.bed
# Out:
# ***** WARNING: File /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/snp_data/atac_snp_loop/combined_ATAC_peaks.bed has inconsistent naming convention for record:
# GL000008.2	73	4042	GL000008.2.74.4042	.
#
# ***** WARNING: File /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/snp_data/atac_snp_loop/combined_ATAC_peaks.bed has inconsistent naming convention for record:
# GL000008.2	73	4042	GL000008.2.74.4042	.

# %%
# !wc -l /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/H1_H9-hESC_peaks_not_in_Th1_Th17.ATACseq.UnionPeakSet.bed
# !wc -l /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/H1_H9-hESC_final.ATACseq.UnionPeakSet.bed
# Out:
# 175738 /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/H1_H9-hESC_peaks_not_in_Th1_Th17.ATACseq.UnionPeakSet.bed
# 178686 /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/H1_H9-hESC_final.ATACseq.UnionPeakSet.bed

# %% [markdown]
# #### Calculate GC content for both target and negative control library set - bedtools nuc

# %%
# %%bash
# module load bedtools2
# bedtools nuc -fi /data/reddylab/Reference_Data/Genomes/hg19/hg19.fa \
# -bed /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/H1_H9-hESC_peaks_not_in_Th1_Th17.ATACseq.UnionPeakSet.bed \
# > /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/H1_H9-hESC_peaks_not_in_Th1_Th17.ATACseq.GC_content.txt

# %%
# %%bash
# module load bedtools2
# bedtools nuc -fi /data/reddylab/Reference_Data/Genomes/hg38/hg38.fa \
# -bed /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/snp_data/atac_snp_loop/combined_ATAC_peaks.bed \
# > /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/combined_ATAC_peaks.GC_content.txt
# Out:
# Feature (GL000008.2:73-4042) beyond the length of GL000008.2 size (0 bp).  Skipping.
# Feature (GL000008.2:83315-83749) beyond the length of GL000008.2 size (0 bp).  Skipping.
# Feature (GL000008.2:98872-99878) beyond the length of GL000008.2 size (0 bp).  Skipping.
# Feature (GL000008.2:117923-119471) beyond the length of GL000008.2 size (0 bp).  Skipping.
# Feature (GL000008.2:126634-127962) beyond the length of GL000008.2 size (0 bp).  Skipping.
# Feature (GL000008.2:136158-136795) beyond the length of GL000008.2 size (0 bp).  Skipping.
# Feature (GL000008.2:154528-156110) beyond the length of GL000008.2 size (0 bp).  Skipping.
# Feature (GL000008.2:173635-174095) beyond the length of GL000008.2 size (0 bp).  Skipping.
# Feature (GL000009.2:2312-4162) beyond the length of GL000009.2 size (0 bp).  Skipping.
# Feature (GL000009.2:39660-40395) beyond the length of GL000009.2 size (0 bp).  Skipping.
# ...

# %% [markdown]
# #### GC content for the hESC peaks that intersect with the variant library

# %%
import pandas as pd

variant = pd.read_csv('/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/snp_data/library/variant_library_with_all_info.txt', sep='\t')
variant[['chr','position']] = variant['coordinates'].str.split(':', expand=True)
variant[['start','end_1']] = variant['position'].str.split('-', expand=True)
variant = variant.astype({"start": int, "end_1": int})
variant['end'] = variant['end_1']+1
variant_subset = variant[['chr','start','end','snp_id']].drop_duplicates()
variant_subset.to_csv('/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/snp_data/library/variant_library_coordinates.bed', sep='\t', index=False, header=None)
variant_subset.dtypes
# Out:
# chr       object
# start      int64
# end        int64
# snp_id    object
# dtype: object

# %%
# %%bash
# module load bedtools2
# bedtools intersect \
# -a /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/snp_data/library/variant_library_coordinates.bed \
# -b /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/H1_H9-hESC_peaks_not_in_Th1_Th17.ATACseq.UnionPeakSet.bed \
# > /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/H1_H9-hESC_peaks_in_variant_library.ATACseq.bed

# %%
# !wc -l /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/H1_H9-hESC_peaks_in_variant_library.ATACseq.bed
# Out:
# 0 /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/H1_H9-hESC_peaks_in_variant_library.ATACseq.bed

# %%
# !head /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/H1_H9-hESC_peaks_not_in_Th1_Th17.ATACseq.GC_content.txt
# Out:
# #1_usercol	2_usercol	3_usercol	4_pct_at	5_pct_gc	6_num_A	7_num_C	8_num_G	9_num_T	10_num_N	11_num_oth	12_seq_len
# chr1	9927	9939	0.000000	0.000000	0	0	0	0	12	0	12
# chr1	564501	564792	0.563574	0.436426	88	102	25	76	0	0	291
# chr1	564836	565056	0.568182	0.431818	67	64	31	58	0	0	220
# chr1	565538	565893	0.569014	0.430986	113	123	30	89	0	0	355
# chr1	566254	568372	0.548159	0.451841	594	623	334	567	0	0	2118
# chr1	568697	570253	0.553342	0.446658	486	510	185	375	0	0	1556
# chr1	713513	714721	0.399834	0.600166	233	378	347	250	0	0	1208
# chr1	756949	757199	0.456000	0.544000	52	98	38	62	0	0	250
# chr1	762602	763040	0.301370	0.698630	84	122	184	48	0	0	438

# %%
# !head /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/combined_ATAC_peaks.GC_content.txt
# Out:
# #1_usercol	2_usercol	3_usercol	4_usercol	5_usercol	6_pct_at	7_pct_gc	8_num_A	9_num_C	10_num_G	11_num_T	12_num_N	13_num_oth	14_seq_len
# chr1	9939	11526	chr1.9940.11526	.	0.339635	0.621928	331	579	408	208	61	0	1587
# chr1	28527	30143	chr1.28528.30143	.	0.369431	0.630569	282	567	452	315	0	0	1616
# chr1	38551	38855	chr1.38552.38855	.	0.565789	0.434211	93	52	80	79	0	0	304
# chr1	91075	91593	chr1.91076.91593	.	0.500000	0.500000	122	109	150	137	0	0	518
# chr1	127420	127976	chr1.127421.127976	.	0.584532	0.415468	161	121	110	164	0	0	556
# chr1	136176	137561	chr1.136177.137561	.	0.306859	0.693141	206	360	600	219	0	0	1385
# chr1	180665	182081	chr1.180666.182081	.	0.353107	0.646893	302	498	418	198	0	0	1416
# chr1	191235	191987	chr1.191236.191987	.	0.420213	0.579787	155	256	180	161	0	0	752
# chr1	199113	200559	chr1.199114.200559	.	0.341632	0.658368	238	538	414	256	0	0	1446

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

hESC_GC = pd.read_csv('/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/H1_H9-hESC_peaks_not_in_Th1_Th17.ATACseq.GC_content.txt', sep='\t')
Th_GC = pd.read_csv('/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/combined_ATAC_peaks.GC_content.txt', sep='\t')

hESC_GC['peak'] = hESC_GC['#1_usercol']+'_'+hESC_GC['2_usercol'].astype('str')+'_'+hESC_GC['3_usercol'].astype('str')
hESC_GC.rename(columns={'5_pct_gc':'GC_content'}, inplace=True)
hESC_GC['GC_content'] = hESC_GC['GC_content']*100
hESC_GC['type']='negative_control'
hESC_GC_subset = hESC_GC[['peak','GC_content','type']]

Th_GC['peak'] = Th_GC['#1_usercol']+'_'+Th_GC['2_usercol'].astype('str')+'_'+Th_GC['3_usercol'].astype('str')
Th_GC.rename(columns={'7_pct_gc':'GC_content'}, inplace=True)
Th_GC['GC_content'] = Th_GC['GC_content']*100
Th_GC['type']='target_library'
Th_GC_subset = Th_GC[['peak','GC_content','type']]

GC_content = pd.concat([hESC_GC_subset,Th_GC_subset])

plt.figure(figsize=(10,8))
plt.hist(hESC_GC_subset['GC_content'], bins=100, alpha=0.5, label="negative_control")
count_Th, bins_Th, patches_Th = plt.hist(Th_GC_subset['GC_content'], bins=100, alpha=0.5, label="target_library")
plt.xlabel("Data", size=14)
plt.ylabel("Count", size=14)
plt.legend(loc='upper right')
sns.despine()
plt.show()

# %%
import random 
import numpy as np
import pandas as pd

random.seed(42)

count_hESC, bin_edge = np.histogram(hESC_GC_subset['GC_content'], bins = bins_Th)

df=None
for i in range(100):
    if ((count_hESC[i]>int(count_Th[i])) and (count_hESC[i]!=0)):
        bin_start = bins_Th[i]
        bin_stop = bins_Th[i+1]
        k = random.sample(range(0, count_hESC[i]), int(count_Th[i]))
        hESC_GC_subset_v1 = hESC_GC_subset[(hESC_GC_subset['GC_content']>=bin_start)&(hESC_GC_subset['GC_content']<bin_stop)].reset_index()
        hESC_GC_random = hESC_GC_subset_v1.iloc[k]
        if df is None:
            df = hESC_GC_random
        else:
            df = pd.concat([df,hESC_GC_random])
            
    elif ((count_hESC[i]<int(count_Th[i])) and (count_hESC[i]!=0)):
        bin_start = bins_Th[i]
        bin_stop = bins_Th[i+1]
        k = list(range(0,count_hESC[i]))
        hESC_GC_subset_v1 = hESC_GC_subset[(hESC_GC_subset['GC_content']>=bin_start)&(hESC_GC_subset['GC_content']<bin_stop)].reset_index()
        hESC_GC_random = hESC_GC_subset_v1.iloc[k]
        if df is None:
            df = hESC_GC_random
        else:
            df = pd.concat([df,hESC_GC_random])
    
plt.figure(figsize=(10,8))
plt.hist(df['GC_content'], bins=100, alpha=0.5, label="negative_control")
plt.hist(Th_GC_subset['GC_content'], bins=100, alpha=0.5, label="target_library")
plt.xlabel("Data", size=14)
plt.ylabel("Count", size=14)
plt.legend(loc='upper right')
sns.despine()
plt.show()

# %%
df_sample = df.sample(frac=0.1, random_state=1)
plt.figure(figsize=(8,6))
plt.hist(df_sample['GC_content'], bins=100, alpha=0.5, label="negative_control")
plt.hist(Th_GC_subset['GC_content'], bins=100, alpha=0.5, label="target_library")
plt.xlabel("Data", size=14)
plt.ylabel("Count", size=14)
plt.legend(loc='upper right')
plt.show()

# %%
df_sample
# Out:
#        index                       peak  GC_content              type
# 74      6986     chr1_66820224_66820510     42.3077  negative_control
# 2280   94364   chr2_228245047_228245273     44.6903  negative_control
# 3328  113317   chr3_136016706_136016966     53.8462  negative_control
# 1541   60565    chr16_26610592_26611273     43.9060  negative_control
# 97     12434   chr1_186449404_186449695     39.1753  negative_control
# 890    78280    chr19_18546967_18550583     66.0951  negative_control
# 1671  110972     chr3_89233823_89234029     40.7767  negative_control
# 3446  125090   chr4_174147644_174147854     46.1905  negative_control
# 541    29374    chr11_65626497_65628937     62.7459  negative_control
# 614    44963    chr13_65332314_65333124     40.1235  negative_control
# 685   142780   chr6_125752954_125753542     36.2245  negative_control
# 308   147241     chr7_19753355_19753706     34.1880  negative_control
# ...

# %%
plt.figure(figsize=(10,8))
plt.hist(hESC_GC_subset['GC_content'], density=True, bins=100, alpha=0.5, label="negative_control")
plt.hist(Th_GC_subset['GC_content'], density=True, bins=100, alpha=0.5, label="target_library")
plt.xlabel("Data", size=12)
plt.ylabel("Density", size=12)
plt.legend(loc='upper right')
sns.despine()
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.hist(df['GC_content'], density=True, bins=100, alpha=0.5, label="negative_control")
plt.hist(Th_GC_subset['GC_content'], density=True, bins=100, alpha=0.5, label="target_library")
plt.xlabel("Data", size=12)
plt.ylabel("Density", size=12)
plt.legend(loc='upper right')
sns.despine()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.hist(df_sample['GC_content'], density=True, bins=100, alpha=0.5, label="negative_control")
plt.hist(Th_GC_subset['GC_content'], density=True, bins=100, alpha=0.5, label="target_library")
plt.xlabel("Data", size=12)
plt.ylabel("Density", size=12)
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# ## Download raw reads for the hESC files

# %%
module load sratoolkit/2.8.1-gcb01
fastq-dump SRR10311789 --gzip

# %%
# %%bash
# cd /data/reddylab/Revathy/software
# wget https://ftp-trace.ncbi.nlm.nih.gov/sra/sdk/3.0.0/sratoolkit.3.0.0-centos_linux64.tar.gz
# Out:
# --2022-09-07 15:03:08--  https://ftp-trace.ncbi.nlm.nih.gov/sra/sdk/3.0.0/sratoolkit.3.0.0-centos_linux64.tar.gz
# Resolving ftp-trace.ncbi.nlm.nih.gov (ftp-trace.ncbi.nlm.nih.gov)... 130.14.250.12, 130.14.250.10, 2607:f220:41f:250::230, ...
# Connecting to ftp-trace.ncbi.nlm.nih.gov (ftp-trace.ncbi.nlm.nih.gov)|130.14.250.12|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85777281 (82M) [application/x-gzip]
# Saving to: ‘sratoolkit.3.0.0-centos_linux64.tar.gz’
#
#      0K .......... .......... .......... .......... ..........  0% 1.56M 52s
#     50K .......... .......... .......... .......... ..........  0% 3.07M 40s
#    100K .......... .......... .......... .......... ..........  0%  117M 27s
#    150K .......... .......... .......... .......... ..........  0% 3.17M 26s
#    200K .......... .......... .......... .......... ..........  0% 91.8M 21s
#    250K .......... .......... .......... .......... ..........  0%  104M 18s
# ...

# %%
# %%bash
# cd /data/reddylab/Revathy/software
# tar -vxzf sratoolkit.3.0.0-centos_linux64.tar.gz
# Out:
# sratoolkit.3.0.0-centos_linux64/
# sratoolkit.3.0.0-centos_linux64/bin/
# sratoolkit.3.0.0-centos_linux64/bin/abi-dump
# sratoolkit.3.0.0-centos_linux64/bin/abi-dump.3
# sratoolkit.3.0.0-centos_linux64/bin/abi-load
# sratoolkit.3.0.0-centos_linux64/bin/abi-load.3
# sratoolkit.3.0.0-centos_linux64/bin/align-info
# sratoolkit.3.0.0-centos_linux64/bin/align-info.3
# sratoolkit.3.0.0-centos_linux64/bin/bam-load
# sratoolkit.3.0.0-centos_linux64/bin/bam-load.3
# sratoolkit.3.0.0-centos_linux64/bin/cache-mgr
# sratoolkit.3.0.0-centos_linux64/bin/cache-mgr.3
# sratoolkit.3.0.0-centos_linux64/bin/cg-load
# sratoolkit.3.0.0-centos_linux64/bin/cg-load.3
# sratoolkit.3.0.0-centos_linux64/bin/dump-ref-fasta
# sratoolkit.3.0.0-centos_linux64/bin/dump-ref-fasta.3
# sratoolkit.3.0.0-centos_linux64/bin/fasterq-dump
# sratoolkit.3.0.0-centos_linux64/bin/fasterq-dump.3
# sratoolkit.3.0.0-centos_linux64/bin/fasterq-dump.3.0.0
# sratoolkit.3.0.0-centos_linux64/bin/fastq-dump
# ...

# %%
# %%bash
# mkdir -p /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/logs
# cd /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/fastq
# export PATH=$PATH:/data/reddylab/Revathy/software/sratoolkit.3.0.0-centos_linux64/bin
# sbatch -p all \
#     --array=0-3 \
#     --mem 16G \
#     -o /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/logs/download_sra.%a.out \
#     <<'EOF'
# #!/bin/bash
# sra_ids=(SRR10311789 SRR10311790 SRR10311791 SRR10311792)
# sra_id=${sra_ids[${SLURM_ARRAY_TASK_ID}]}
# fastq-dump --gzip --split-files --origfmt ${sra_id}
# EOF

# %% [markdown]
# 1. Downloaded fastqs were ran through the ATACseq processing pipelines.
# 2. Next Step: Callpeaks using MACS2 on the bams

# %% [markdown]
# #### MACS2 Peak Calling

# %%
# %%bash
# source /data/reddylab/software/miniconda2/bin/activate alex_dev
# mkdir -p /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling
# cd /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/processing/atac_seq/ATAC-Seq_H1_H9-hESC-pe-blacklist-removal
# sbatch -p all \
#     --mem 16G \
#     --array=0-1 \
#     -o /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/logs/macs2_SRR_ATACseq.%a.out \
#     <<'EOF'
# #!/bin/bash
# files=(SRR10311790.masked.dups_marked.bam SRR10311792.masked.dups_marked.bam)
# file=${files[${SLURM_ARRAY_TASK_ID}]}
# file_name=$(echo $file | cut -d"." -f1)
# macs2 callpeak \
# -t /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/processing/atac_seq/ATAC-Seq_H1_H9-hESC-pe-blacklist-removal/${file} \
# -g hs \
# -q 0.01 \
# --keep-dup all \
# -n ${file_name} \
# --outdir /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling \
# EOF
# Out:
# Submitted batch job 29008025

# %% [markdown]
# #### Create UnionPeakSet file for the h1 peaks

# %%
# !wc -l /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling/*.narrowPeak
# Out:
#    84738 /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling/H1_hESC_final.ATACseq.UnionPeakSet.narrowPeak
#    84485 /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling/SRR10311789_peaks.narrowPeak
#    34574 /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling/SRR10311790_peaks.narrowPeak
#    45840 /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling/SRR10311792_peaks.narrowPeak
#   249637 total

# %%
# %%bash
# module load bedtools2
# cd /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling
# cat SRR10311789_peaks.narrowPeak \
#     SRR10311790_peaks.narrowPeak \
# | sort -k1,1 -k2,2n | bedtools merge -i - > H1_hESC_final.ATACseq.UnionPeakSet.narrowPeak

# %%
# !wc -l /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling/H1_hESC_final.ATACseq.UnionPeakSet.narrowPeak
# !wc -l /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/snp_data/atac_snp_loop/combined_ATAC_peaks.bed
# Out:
# 84738 /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling/H1_hESC_final.ATACseq.UnionPeakSet.narrowPeak
# 88138 /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/snp_data/atac_snp_loop/combined_ATAC_peaks.bed

# %% [markdown]
# Subtract the target_library ATAC peaks from the UnionPeakSet

# %%
# %%bash
# module load bedtools2
# bedtools subtract -a /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling/H1_hESC_final.ATACseq.UnionPeakSet.narrowPeak \
# -b /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/snp_data/atac_snp_loop/combined_ATAC_peaks.bed \
# > /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling/H1_hESC_peaks_not_in_Th1_Th17.ATACseq.UnionPeakSet.bed
# Out:
# ***** WARNING: File /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/snp_data/atac_snp_loop/combined_ATAC_peaks.bed has inconsistent naming convention for record:
# GL000008.2	73	4042	GL000008.2.74.4042	.
#
# ***** WARNING: File /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/snp_data/atac_snp_loop/combined_ATAC_peaks.bed has inconsistent naming convention for record:
# GL000008.2	73	4042	GL000008.2.74.4042	.

# %%
# !wc -l /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling/H1_hESC_peaks_not_in_Th1_Th17.ATACseq.UnionPeakSet.bed
# Out:
# 82102 /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling/H1_hESC_peaks_not_in_Th1_Th17.ATACseq.UnionPeakSet.bed

# %% [markdown]
# #### Calculate GC content of the UnionPeakSet file (target_library_peaks subtracted)

# %%
# %%bash
# module load bedtools2
# bedtools nuc -fi /data/reddylab/Reference_Data/Genomes/hg19/hg19.fa \
# -bed /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling/H1_hESC_peaks_not_in_Th1_Th17.ATACseq.UnionPeakSet.bed \
# > /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling/H1_hESC_peaks_not_in_Th1_Th17.ATACseq.UnionPeakSet.GC_content.txt

# %%
# !head /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling/H1_hESC_peaks_not_in_Th1_Th17.ATACseq.UnionPeakSet.GC_content.txt
# Out:
# #1_usercol	2_usercol	3_usercol	4_pct_at	5_pct_gc	6_num_A	7_num_C	8_num_G	9_num_T	10_num_N	11_num_oth	12_seq_len
# chr1	713789	714524	0.356463	0.643537	134	259	214	128	0	0	735
# chr1	762666	763113	0.306488	0.693512	73	130	180	64	0	0	447
# chr1	780955	781368	0.564165	0.435835	118	108	72	115	0	0	413
# chr1	794097	794343	0.382114	0.617886	53	67	85	41	0	0	246
# chr1	805066	805528	0.261905	0.738095	63	189	152	58	0	0	462
# chr1	839783	840220	0.233410	0.766590	49	221	114	53	0	0	437
# chr1	848203	848454	0.430279	0.569721	62	59	84	46	0	0	251
# chr1	856368	856709	0.313783	0.686217	60	98	136	47	0	0	341
# chr1	860377	860548	0.222222	0.777778	21	74	59	17	0	0	171

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

H1_hESC_GC = pd.read_csv('/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling/H1_hESC_peaks_not_in_Th1_Th17.ATACseq.UnionPeakSet.GC_content.txt', sep='\t')
Th_GC = pd.read_csv('/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/combined_ATAC_peaks.GC_content.txt', sep='\t')

H1_hESC_GC['peak'] = H1_hESC_GC['#1_usercol']+'_'+H1_hESC_GC['2_usercol'].astype('str')+'_'+H1_hESC_GC['3_usercol'].astype('str')
H1_hESC_GC.rename(columns={'5_pct_gc':'GC_content'}, inplace=True)
H1_hESC_GC['GC_content'] = H1_hESC_GC['GC_content']*100
H1_hESC_GC['type']='negative_control'
H1_hESC_GC_subset = H1_hESC_GC[['peak','GC_content','type']]

Th_GC['peak'] = Th_GC['#1_usercol']+'_'+Th_GC['2_usercol'].astype('str')+'_'+Th_GC['3_usercol'].astype('str')
Th_GC.rename(columns={'7_pct_gc':'GC_content'}, inplace=True)
Th_GC['GC_content'] = Th_GC['GC_content']*100
Th_GC['type']='target_library'
Th_GC_subset = Th_GC[['peak','GC_content','type']]

plt.figure(figsize=(10,8))
plt.hist(H1_hESC_GC_subset['GC_content'], bins=100, alpha=0.5, label="negative_control")
count_Th, bins_Th, patches_Th = plt.hist(Th_GC_subset['GC_content'], bins=100, alpha=0.5, label="target_library")
plt.xlabel("Data", size=14)
plt.ylabel("Count", size=14)
plt.legend(loc='upper right')
sns.despine()
plt.show()

# %%
H1_hESC_GC_subset.shape
# Out:
# (82102, 3)

# %%
import random 
import numpy as np
import pandas as pd

random.seed(42)

count_hESC, bin_edge = np.histogram(H1_hESC_GC_subset['GC_content'], bins = bins_Th)

def random_sample(count_df1, count_df2, bin_size):
    m = [0]
    if (count_df1[bin_size]>=int(count_df2[bin_size]) and (count_df2[bin_size]!=0)):
        m = list(random.sample(range(0, count_df1[bin_size]), int(count_df2[bin_size])))
        
    elif (count_df1[bin_size]<int(count_df2[bin_size]) and (count_df1[bin_size]!=0)):
        range_list = list(range(0, count_df1[bin_size]))
        m = list(np.random.choice(range_list, size=int(count_df2[bin_size])))
        
    elif (count_df1[bin_size]==int(count_df2[bin_size]) and (count_df1[bin_size]!=0)):
        m = list(range(0, count_df1[bin_size]))
    
    return m 


df=None
for i in range(0,100):
    bin_start = bins_Th[i]
    bin_stop = bins_Th[i+1]
    H1_hESC_GC_subset_v1 = H1_hESC_GC_subset[(H1_hESC_GC_subset['GC_content']>=bin_start)&(H1_hESC_GC_subset['GC_content']<bin_stop)].reset_index()
    H1_hESC_GC_subset_v1.drop(columns='index', inplace=True)

    if not H1_hESC_GC_subset_v1.empty:
        sample_size = random_sample(count_hESC, count_Th, i)
        H1_hESC_GC_random = H1_hESC_GC_subset_v1.loc[sample_size]
        if df is None:
            df = H1_hESC_GC_random
        else:
            df = pd.concat([df,H1_hESC_GC_random])  




    
plt.figure(figsize=(10,8))
plt.hist(df['GC_content'], bins=100, alpha=0.5, label="negative_control")
plt.hist(Th_GC_subset['GC_content'], bins=100, alpha=0.5, label="target_library")
plt.xlabel("Data", size=14)
plt.ylabel("Count", size=14)
plt.legend(loc='upper right')
sns.despine()
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.hist(df['GC_content'], density=True, bins=100, alpha=0.5, label="negative_control")
plt.hist(Th_GC_subset['GC_content'], density=True, bins=100, alpha=0.5, label="target_library")
plt.xlabel("Data", size=12)
plt.ylabel("Density", size=12)
plt.legend(loc='upper right')
sns.despine()
plt.show()

# %%
df_1 = df.drop_duplicates()
plt.figure(figsize=(10,8))
plt.hist(df_1['GC_content'], density=True, bins=100, alpha=0.5, label="negative_control")
plt.hist(Th_GC_subset['GC_content'], density=True, bins=100, alpha=0.5, label="target_library")
plt.xlabel("Data", size=12)
plt.ylabel("Density", size=12)
plt.legend(loc='upper right')
sns.despine()
plt.show()

# %%
df_sample = df.sample(frac=2.7/100, random_state=1)

plt.figure(figsize=(10,8))
plt.hist(df_sample['GC_content'], bins=100, alpha=0.5, label="negative_control")
plt.hist(Th_GC_subset['GC_content'], bins=100, alpha=0.5, label="target_library")
plt.xlabel("Data", size=14)
plt.ylabel("Count", size=14)
plt.legend(loc='upper right')
sns.despine()
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.hist(df_sample['GC_content'], density=True, bins=100, alpha=0.5, label="negative_control")
plt.hist(Th_GC_subset['GC_content'], density=True, bins=100, alpha=0.5, label="target_library")
plt.xlabel("Data", size=14)
plt.ylabel("Density", size=14)
plt.legend(loc='upper right')
sns.despine()
plt.show()

# %%
# %%bash
# source /data/reddylab/software/miniconda2/bin/activate alex_dev
# mkdir -p /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling
# cd /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/processing/atac_seq/ATAC-Seq_H1_H9-hESC-pe-blacklist-removal
# sbatch -p all \
#     --mem 16G \
#     --array=0-1 \
#     -o /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/logs/macs2_SRR_ATACseq.%a.out \
#     <<'EOF'
# #!/bin/bash
# macs2 callpeak \
# -t SRR10311789.masked.dups_marked.bam SRR10311790.masked.dups_marked.bam  \
# -g hs \
# -q 0.01 \
# --keep-dup all \
# -n h1_hESC_rep1_rep2_UnionPeakSet \
# --outdir /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling \
# EOF
# Out:
# Submitted batch job 29126421

# %%
# %%bash
# module load bedtools2
# bedtools subtract -a /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling/h1_hESC_rep1_rep2_UnionPeakSet_peaks.narrowPeak \
# -b /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/snp_data/atac_snp_loop/combined_ATAC_peaks.bed \
# > /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling/h1_hESC_rep1_rep2_UnionPeakSet_peaks_not_in_Th1_Th17.ATACseq.bed
# Out:
# ***** WARNING: File /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/snp_data/atac_snp_loop/combined_ATAC_peaks.bed has inconsistent naming convention for record:
# GL000008.2	73	4042	GL000008.2.74.4042	.
#
# ***** WARNING: File /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/snp_data/atac_snp_loop/combined_ATAC_peaks.bed has inconsistent naming convention for record:
# GL000008.2	73	4042	GL000008.2.74.4042	.

# %%
# %%bash
# wc -l /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling/h1_hESC_rep1_rep2_UnionPeakSet_peaks_not_in_Th1_Th17.ATACseq.bed
# wc -l /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling/h1_hESC_rep1_rep2_UnionPeakSet_peaks.narrowPeak
# Out:
# 66677 /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling/h1_hESC_rep1_rep2_UnionPeakSet_peaks_not_in_Th1_Th17.ATACseq.bed
# 69128 /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling/h1_hESC_rep1_rep2_UnionPeakSet_peaks.narrowPeak

# %%
# %%bash
# module load bedtools2
# bedtools nuc -fi /data/reddylab/Reference_Data/Genomes/hg19/hg19.fa \
# -bed /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling/h1_hESC_rep1_rep2_UnionPeakSet_peaks_not_in_Th1_Th17.ATACseq.bed \
# > /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling/h1_hESC_rep1_rep2_UnionPeakSet_peaks_not_in_Th1_Th17.ATACseq.GC_content.txt

# %%
# !head /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling/h1_hESC_rep1_rep2_UnionPeakSet_peaks_not_in_Th1_Th17.ATACseq.GC_content.txt
# Out:
# #1_usercol	2_usercol	3_usercol	4_usercol	5_usercol	6_usercol	7_usercol	8_usercol	9_usercol	10_usercol	11_pct_at	12_pct_gc	13_num_A	14_num_C	15_num_G	16_num_T	17_num_N	18_num_oth	19_seq_len
# chr1	713787	714490	h1_hESC_rep1_rep2_UnionPeakSet_peak_2	766	.	17.81448	81.06552	76.60837	398	0.365576	0.634424	130	244	202	127	0	0	703
# chr1	762669	763095	h1_hESC_rep1_rep2_UnionPeakSet_peak_3	167	.	9.57815	19.62479	16.75562	155	0.302817	0.697183	71	125	172	58	0	0	426
# chr1	781011	781348	h1_hESC_rep1_rep2_UnionPeakSet_peak_4	253	.	11.36755	28.51870	25.34404	204	0.540059	0.459941	90	91	64	92	0	0	337
# chr1	794128	794327	h1_hESC_rep1_rep2_UnionPeakSet_peak_5	128	.	7.74136	15.50979	12.80630	105	0.391960	0.608040	44	57	64	34	0	0	199
# chr1	805074	805438	h1_hESC_rep1_rep2_UnionPeakSet_peak_6	164	.	9.07887	19.29854	16.44239	135	0.260989	0.739011	50	149	120	45	0	0	364
# chr1	839783	840156	h1_hESC_rep1_rep2_UnionPeakSet_peak_7	170	.	7.78311	19.95564	17.07441	171	0.233244	0.766756	37	192	94	50	0	0	373
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

H1_hESC_GC = pd.read_csv('/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling/h1_hESC_rep1_rep2_UnionPeakSet_peaks_not_in_Th1_Th17.ATACseq.GC_content.txt', sep='\t')
Th_GC = pd.read_csv('/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/combined_ATAC_peaks.GC_content.txt', sep='\t')

H1_hESC_GC['peak'] = H1_hESC_GC['#1_usercol']+'_'+H1_hESC_GC['2_usercol'].astype('str')+'_'+H1_hESC_GC['3_usercol'].astype('str')
H1_hESC_GC.rename(columns={'12_pct_gc':'GC_content'}, inplace=True)
H1_hESC_GC['GC_content'] = H1_hESC_GC['GC_content']*100
H1_hESC_GC['type']='negative_control'
H1_hESC_GC_subset = H1_hESC_GC[['peak','GC_content','type']]

Th_GC['peak'] = Th_GC['#1_usercol']+'_'+Th_GC['2_usercol'].astype('str')+'_'+Th_GC['3_usercol'].astype('str')
Th_GC.rename(columns={'7_pct_gc':'GC_content'}, inplace=True)
Th_GC['GC_content'] = Th_GC['GC_content']*100
Th_GC['type']='target_library'
Th_GC_subset = Th_GC[['peak','GC_content','type']]



plt.figure(figsize=(10,8))
plt.hist(H1_hESC_GC_subset['GC_content'], bins=100, alpha=0.5, label="negative_control")
count_Th, bins_Th, patches_Th = plt.hist(Th_GC_subset['GC_content'], bins=100, alpha=0.5, label="target_library")
plt.xlabel("Data", size=14)
plt.ylabel("Count", size=14)
plt.legend(loc='upper right')
sns.despine()

count_hESC, bin_edge = np.histogram(H1_hESC_GC_subset['GC_content'], bins = bins_Th)

plt.figure(figsize=(10,8))
plt.hist(H1_hESC_GC_subset['GC_content'],density=True, bins=100, alpha=0.5, label="negative_control")
plt.hist(Th_GC_subset['GC_content'],density=True, bins=100, alpha=0.5, label="target_library")
plt.xlabel("Data", size=14)
plt.ylabel("density", size=14)
plt.legend(loc='upper right')
sns.despine()

plt.show()

# %%
import random 
import numpy as np
import pandas as pd

random.seed(42)

df=None
sample_size = ((count_Th.astype(int)/sum(count_Th))*1700).astype(int)
for i in range(0,100):
    bin_start = bins_Th[i]
    bin_stop = bins_Th[i+1]
    H1_hESC_GC_subset_v1 = H1_hESC_GC_subset[(H1_hESC_GC_subset['GC_content']>=bin_start)&(H1_hESC_GC_subset['GC_content']<bin_stop)].reset_index()
    H1_hESC_GC_subset_v1.drop(columns='index', inplace=True)
    
    count_Th = count_Th.astype(int)
    m = list(range(0, sample_size[i]))
    
    if not H1_hESC_GC_subset_v1.empty:
        H1_hESC_GC_random = H1_hESC_GC_subset_v1.loc[m]
        
        if df is None:
            df = H1_hESC_GC_random
        else:
            df = pd.concat([df,H1_hESC_GC_random])  

df[['chr','start','end']] = df['peak'].str.split('_', expand=True)
df[['chr','start','end']].to_csv('/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling/h1_hESC_rep1_rep2_random_subsample_on_Th_distribution_coordinates.hg19.bed', sep='\t', index=False, header=None)
df.to_csv('/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling/h1_hESC_rep1_rep2_random_subsample_on_Th_distribution.ATAC_peaks.txt', sep='\t', index=False)

plt.figure(figsize=(10,8))
plt.hist(df['GC_content'], bins=100, alpha=0.5, label="negative_control")
plt.hist(Th_GC_subset['GC_content'], bins=100, alpha=0.5, label="target_library")
plt.xlabel("Data", size=14)
plt.ylabel("Count", size=14)
plt.legend(loc='upper right')
sns.despine()

plt.figure(figsize=(10,8))
plt.hist(df['GC_content'], density=True, bins=100, alpha=0.5, label="negative_control")
plt.hist(Th_GC_subset['GC_content'], density=True, bins=100, alpha=0.5, label="target_library")
plt.xlabel("Data", size=14)
plt.ylabel("Density", size=14)
plt.legend(loc='upper right')
sns.despine()

plt.show()

# %%
# %%bash
# /data/reddylab/Revathy/software/liftOver/liftOver \
# /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling/h1_hESC_rep1_rep2_random_subsample_on_Th_distribution_coordinates.hg19.bed \
# /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/snp_data/source_snps/hg19ToHg38.over.chain \
# /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling/h1_hESC_rep1_rep2_random_subsample_on_Th_distribution_coordinates.hg38.bed \
# lift_unmapped.bed
# Out:
# Reading liftover chains
# Mapping coordinates

# %%
# %%bash
# /data/reddylab/Revathy/software/liftOver/liftOver \
# /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling/h1_hESC_rep1_rep2_UnionPeakSet_summits.bed \
# /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/snp_data/source_snps/hg19ToHg38.over.chain \
# /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling/h1_hESC_rep1_rep2_UnionPeakSet_summits.hg38.bed \
# lift_unmapped.bed
# Out:
# Reading liftover chains
# Mapping coordinates

# %%
# %%bash
# cat /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling/h1_hESC_rep1_rep2_UnionPeakSet_peaks_not_in_Th1_Th17.ATACseq.bed \
# | cut -f1,2,3,4 \
# > /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling/h1_hESC_rep1_rep2_UnionPeakSet_peaks_not_in_Th1_Th17_coordinates.ATACseq.bed
#
# /data/reddylab/Revathy/software/liftOver/liftOver \
# /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling/h1_hESC_rep1_rep2_UnionPeakSet_peaks_not_in_Th1_Th17_coordinates.ATACseq.bed \
# /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/snp_data/source_snps/hg19ToHg38.over.chain \
# /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling/h1_hESC_rep1_rep2_UnionPeakSet_peaks_not_in_Th1_Th17_coordinates.ATACseq.hg38.bed \
# lift_unmapped.bed
# Out:
# Reading liftover chains
# Mapping coordinates

# %%
import pandas as pd

hESC_peak_calls = pd.read_csv('/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling/h1_hESC_rep1_rep2_UnionPeakSet_peaks_not_in_Th1_Th17_coordinates.ATACseq.hg38.bed', sep='\t',
                              names=['chr','start','end','name'])

hESC_summits = pd.read_csv('/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling/h1_hESC_rep1_rep2_UnionPeakSet_summits.hg38.bed', sep='\t', 
                           names=['chr_S','start_S','end_S','name','qValue'])
hESC_random_samples = pd.read_csv('/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling/h1_hESC_rep1_rep2_random_subsample_on_Th_distribution_coordinates.hg38.bed', sep='\t',
                                  names=['chr','start','end'])


hESC_peak_calls['chr_start_end'] = hESC_peak_calls['chr']+'_'+hESC_peak_calls['start'].astype(str)+'_'+hESC_peak_calls['end'].astype(str)
hESC_random_samples['chr_start_end']=hESC_random_samples['chr']+'_'+hESC_random_samples['start'].astype(str)+'_'+hESC_random_samples['end'].astype(str)


hESC_peak_call_with_summit = hESC_peak_calls.merge(hESC_summits, on='name', how='left')
hESC_peak_call_with_summit = hESC_peak_call_with_summit[['chr_S','start_S','end_S','chr_start_end']]
hESC_subsample_with_summit = hESC_peak_call_with_summit.merge(hESC_random_samples, on='chr_start_end', how='inner')
hESC_subsample_with_summit[['chr_S','start_S','end_S','chr_start_end']].to_csv('/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling/h1_hESC_rep1_rep2_random_subsample_on_Th_distribution_summit_coordinates.hg38.bed', sep='\t', header=None, index=False)

# %%
# %%bash
# module load bedtools2
# bedtools slop \
# -i /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling/h1_hESC_rep1_rep2_random_subsample_on_Th_distribution_summit_coordinates.hg38.bed \
# -g /data/reddylab/Reference_Data/Genomes/hg38/hg38.fa.chrom.sizes \
# -l 122 \
# -r 123 \
# > /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling/h1_hESC_rep1_rep2_random_subsample_on_Th_distribution.summit_coordinates.sloped.hg38.bed

# %%
# %%bash
# module load bedtools2
# bedtools getfasta -fi /data/reddylab/Reference_Data/Genomes/hg38/hg38.fa \
# -bed /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling/h1_hESC_rep1_rep2_random_subsample_on_Th_distribution.summit_coordinates.sloped.hg38.bed \
# -fo /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling/h1_hESC_rep1_rep2_random_subsample_on_Th_distribution.summit_coordinates.sequences.hg38.bed.fa

# %%
### read fasta files to dataframe

import pandas as pd
import glob
import re


tmp_df = pd.read_csv('/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling/h1_hESC_rep1_rep2_random_subsample_on_Th_distribution.summit_coordinates.sequences.hg38.bed.fa', sep='\t', header=None)
tmp_df = pd.DataFrame(tmp_df.values.reshape(-1, 2), columns = ['position', 'sequence'])
tmp_df['position'] = tmp_df['position'].str.replace('>','')
tmp_df['position'] = tmp_df['position'].str.replace(r':|-','_')
tmp_df.to_csv('/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling/h1_hESC_rep1_rep2_random_subsample_on_Th_distribution.summit_coordinates.sequences.hg38.txt',sep='\t',index=False)

# %%
# !head /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling/h1_hESC_rep1_rep2_random_subsample_on_Th_distribution.summit_coordinates.sloped.hg38.bed
# Out:
# chr1	778683	778929	chr1_778407_779110
# chr1	827322	827568	chr1_827289_827715
# chr1	845713	845959	chr1_845631_845968
# chr1	858731	858977	chr1_858748_858947
# chr1	869707	869953	chr1_869694_870058
# chr1	921035	921281	chr1_921123_921296
# chr1	951467	951713	chr1_951503_951676
# chr1	959226	959472	chr1_959202_959449
# chr1	966728	966974	chr1_966381_967194
# chr1	970473	970719	chr1_970461_970768

# %%
import pandas as pd

ATAC_peak_sequences = pd.read_csv('/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling/h1_hESC_rep1_rep2_random_subsample_on_Th_distribution.summit_coordinates.sequences.hg38.txt', sep='\t')
sloped_coordinates = pd.read_csv('/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling/h1_hESC_rep1_rep2_random_subsample_on_Th_distribution.summit_coordinates.sloped.hg38.bed', sep='\t',
                                 names=['chr','start','end','chr_start_end'])
sloped_coordinates['position'] = sloped_coordinates['chr']+'_'+sloped_coordinates['start'].astype(str)+'_'+sloped_coordinates['end'].astype(str)
sloped_coordinates = sloped_coordinates[['position','chr_start_end']]

hESC_peaks_with_sequences = sloped_coordinates.merge(ATAC_peak_sequences, on='position', how='inner')
hESC_peaks_with_sequences['final_sequence'] = 'TTTCCCTACACGACGCTCTTCCGATCT'+hESC_peaks_with_sequences['sequence']+'AGATCGGAAGAGCACACGTCTGAACTC'
hESC_peaks_with_sequences['Identifier'] = hESC_peaks_with_sequences['chr_start_end']+':phase2:neg_control'
hESC_peaks_with_sequences[['Identifier','final_sequence']].to_csv('/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/ATACseq/raw_data/peak_calling/H1_hESC_random_subsample_on_Th_distribution.ATAC_peaks.negative_controls.v1.txt', sep='\t', index=False)

# %%
# import random 
# import numpy as np
# import pandas as pd

# random.seed(42)

# count_hESC, bin_edge = np.histogram(H1_hESC_GC_subset['GC_content'], bins = bins_Th)

# def random_sample(count_df1, count_df2, bin_size):
#     m = [0]
#     if (count_df1[bin_size]>=int(count_df2[bin_size]) and (count_df2[bin_size]!=0)):
#         m = list(random.sample(range(0, count_df1[bin_size]), int(count_df2[bin_size])))
        
#     elif (count_df1[bin_size]<int(count_df2[bin_size]) and (count_df1[bin_size]!=0)):
#         range_list = list(range(0, count_df1[bin_size]))
#         m = list(np.random.choice(range_list, size=int(count_df2[bin_size])))
        
#     elif (count_df1[bin_size]==int(count_df2[bin_size]) and (count_df1[bin_size]!=0)):
#         m = list(range(0, count_df1[bin_size]))
    
#     return m 


# df=None
# for i in range(0,100):
#     bin_start = bins_Th[i]
#     bin_stop = bins_Th[i+1]
#     H1_hESC_GC_subset_v1 = H1_hESC_GC_subset[(H1_hESC_GC_subset['GC_content']>=bin_start)&(H1_hESC_GC_subset['GC_content']<bin_stop)].reset_index()
#     H1_hESC_GC_subset_v1.drop(columns='index', inplace=True)

#     if not H1_hESC_GC_subset_v1.empty:
#         sample_size = random_sample(count_hESC, count_Th, i)
#         H1_hESC_GC_random = H1_hESC_GC_subset_v1.loc[sample_size]
#         if df is None:
#             df = H1_hESC_GC_random
#         else:
#             df = pd.concat([df,H1_hESC_GC_random])  




    
# plt.figure(figsize=(10,8))
# plt.hist(df['GC_content'], bins=100, alpha=0.5, label="negative_control")
# plt.hist(Th_GC_subset['GC_content'], bins=100, alpha=0.5, label="target_library")
# plt.xlabel("Data", size=14)
# plt.ylabel("Count", size=14)
# plt.legend(loc='upper right')
# sns.despine()
# plt.show()

# %%
# import random 
# import numpy as np
# import pandas as pd

# random.seed(42)



# ### function to match distribution of df2 to that of df1 
# # def random_sample(count_df1, count_df2, n_bin):
# #     for i in range(0, n_bin):
# # #         bin_start = count_df1[i]
# # #         bin_stop = count_df1[i+1]
# #         m = [0]
# #         if (count_df1[i]>count_df2[i] and count_df2[i]!=0):
# #             m = list(range(0, count_df2[i]))
        
# #         elif (count_df1[i]<count_df2[i] and count_df1[i]!=0):
# #             m = list(random.sample(range(0, count_df2[i]), count_df1[i]))

# #         elif (count_df1[i]>count_df2[i] and count_df2[i]==0):
# #             count_df2[bin_size+1] = count_df2[bin_size+1]+count_df1
# #             continue
        
# #         elif (count_df1[i]<count_df2[i] and count_df1[i]==0):
# #             m = [0]
        
# #         elif (count_df1[i]==count_df2[i] and count_df2[i]!=0):
# #             m = list(range(0, count_df2[i]))
    
# #     return m 

# df=None
# m = 0
# for i in range(0,100):
#     bin_start = bins_Th[i]
#     bin_stop = bins_Th[i+1]
#     H1_hESC_GC_subset_v1 = H1_hESC_GC_subset[(H1_hESC_GC_subset['GC_content']>=bin_start)&(H1_hESC_GC_subset['GC_content']<bin_stop)].reset_index()
#     H1_hESC_GC_subset_v1.drop(columns='index', inplace=True)
#     count_Th = count_Th.astype(int)

#     if (count_Th[i]>count_hESC[i] and count_hESC[i]!=0 and i!=99):
#         count_hESC[i+1] = count_hESC[i+1]+(count_Th[i]-count_hESC[i])
#         m = list(range(0, count_hESC[i]))
        
#     elif (count_Th[i]<count_hESC[i] and count_Th[i]!=0 and i!=99):
#         count_hESC[i+1] = count_hESC[i+1]-(count_hESC[i]-count_Th[i])
#         m = random.sample(range(0, count_hESC[i]), count_Th[i])

#     elif (count_Th[i]>count_hESC[i] and count_hESC[i]==0 and i!=99):
#         count_hESC[i+1] = count_hESC[i+1]+count_Th[i]
#         continue
        
#     elif (count_Th[i]<count_hESC[i] and count_Th[i]==0):
#         continue
        
#     elif (count_Th[i]==count_hESC[i] and count_hESC[i]!=0):
#         m = list(range(0, count_hESC[i]))

#     if not H1_hESC_GC_subset_v1.empty:
#         H1_hESC_GC_random = H1_hESC_GC_subset_v1.loc[m]
#         if df is None:
#             df = H1_hESC_GC_random
#         else:
#             df = pd.concat([df,H1_hESC_GC_random])  




    
# plt.figure(figsize=(10,8))
# plt.hist(df['GC_content'], bins=100, alpha=0.5, label="negative_control")
# plt.hist(Th_GC_subset['GC_content'], bins=100, alpha=0.5, label="target_library")
# plt.xlabel("Data", size=14)
# plt.ylabel("Count", size=14)
# plt.legend(loc='upper right')
# sns.despine()

# plt.figure(figsize=(10,8))
# plt.hist(df['GC_content'], density=True, bins=100, alpha=0.5, label="negative_control")
# plt.hist(Th_GC_subset['GC_content'], density=True, bins=100, alpha=0.5, label="target_library")
# plt.xlabel("Data", size=14)
# plt.ylabel("Density", size=14)
# plt.legend(loc='upper right')
# sns.despine()

# plt.show()
