# %%
import pandas as pd

josh_ensembl_ldlink_snp = pd.read_csv('/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/snp_data_josh/MS/ensembl_ldlink_snps_r2_0.8.deduplicated.bed', sep='\t',
                                       names=['chr','start','end','snp_id'])
josh_new_ensembl_ldlink_snp = pd.read_csv('/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/josh_ensembl_ldlink_snps_r2_0.8.deduplicated.bed', sep='\t',
                                          names=['chr','start','end','snp_id'])
revathy_ensembl_ldlink_snp = pd.read_csv('/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/snp_data/ld_expansion/ensembl_ldlink_snps_r2_0.8.deduplicated.bed', sep='\t', names=['chr','start','end','snp_id'])
print(josh_new_ensembl_ldlink_snp.shape)
print(josh_ensembl_ldlink_snp.shape)
print(revathy_ensembl_ldlink_snp.shape)
# Out:
# (8958, 4)
# (10327, 4)
# (10916, 4)

# %%
revathy_ensembl_ldlink_snp
# Out:
#          chr      start        end       snp_id
# 0       chr7  106119130  106119136  rs200647091
# 1       chr7  106120707  106120708   rs75667371
# 2       chr7  106098106  106098107   rs17152585
# 3       chr7  106070290  106070291   rs16872046
# 4       chr7  106075141  106075142  rs144484416
# 5       chr7  106116187  106116188   rs73416225
# 6       chr7  106113295  106113296    rs3757490
# 7       chr7  106114626  106114627    rs4140808
# 8       chr7  106091982  106091983     rs176485
# 9       chr7  106092647  106092648  rs112469266
# 10      chr7  106117785  106117786   rs73416232
# 11      chr7  106112635  106112636   rs17426359
# 12      chr7  106111325  106111326    rs3801275
# 13      chr7  106120463  106120464   rs73416237
# 14      chr2    7904384    7904385   rs57369408
# 15      chr2    7905392    7905393    rs7597738
# 16      chr2    7910706    7910707     rs888131
# 17      chr2    7911685    7911686  rs112100235
# 18      chr2    7911696    7911697   rs72777216
# ...

# %%
josh_ensembl_ldlink_snp_list = set(josh_ensembl_ldlink_snp.snp_id.unique().tolist())
josh_new_ensembl_ldlink_snp_list = set(josh_new_ensembl_ldlink_snp.snp_id.unique().tolist())
revathy_ensembl_ldlink_snp_list = set(revathy_ensembl_ldlink_snp.snp_id.unique().tolist())

# %%
len(josh_new_ensembl_ldlink_snp.snp_id.unique())
# Out:
# 8958

# %%
ld_snp_josh_not_in_revathy = list(josh_ensembl_ldlink_snp_list - revathy_ensembl_ldlink_snp_list)
ld_snp_josh_not_in_revathy_set = set(ld_snp_josh_not_in_revathy)
with open("/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/snp_data/snp_data_MS_ldlink_snp_josh_not_in_revathy.txt", "w") as f:
    for s in ld_snp_josh_not_in_revathy:
        f.write(str(s) +"\n")

# %%
ld_snp_josh_not_in_revathy
# Out:
# ['rs79081977',
#  'rs9270967',
#  'rs4337943',
#  'rs7253363',
#  'rs9270579',
#  'rs12047533',
#  'rs9271234',
#  'rs942637',
#  'rs9270749',
#  'rs71159489',
#  'rs34102351',
#  'rs407835',
#  'rs113116589',
#  'rs71044569',
#  'rs9270695',
#  'rs7747995',
#  'rs2874494',
#  'rs9268405',
#  'rs9273442',
#  'rs1257200',
#  'rs17157903',
#  'rs6798842',
#  'rs9271172',
#  'rs1981373',
#  'rs35817932',
#  'rs9271129',
#  'rs144908432',
#  'rs9271029',
#  'rs74999184',
#  'rs9876010',
#  'rs60988936',
#  'rs141128294',
#  'rs8179924',
#  'rs7017789',
#  'rs1398608',
#  'rs77995509',
#  'rs73813229',
#  'rs9270622',
#  'rs180356',
#  'rs9271645',
#  'rs2421481',
#  'rs9270615',
#  'rs180368',
#  'rs9271686',
#  'rs8180659',
#  'rs12492968',
#  'rs9271227',
#  'rs7105269',
#  'rs198376',
#  'rs9275563',
#  'rs72492305',
#  'rs978697',
#  'rs73813228',
#  'rs4680312',
#  'rs3130032',
#  'rs9271007',
#  'rs7450950',
#  'rs338610',
#  'rs9268421',
#  'rs9271766',
#  'rs35028058',
# ...

# %%
ld_snp_josh_not_in_new = list(josh_ensembl_ldlink_snp_list - josh_new_ensembl_ldlink_snp_list)
ld_snp_josh_not_in_new_set = set(ld_snp_josh_not_in_new)

ld_snp_josh_new_not_in_revathy = list(josh_new_ensembl_ldlink_snp_list - revathy_ensembl_ldlink_snp_list)
len(ld_snp_josh_new_not_in_revathy)
# Out:
# 168

# %%
bed_file_ld_snp_josh_not_in_revathy = josh_ensembl_ldlink_snp[josh_ensembl_ldlink_snp.snp_id.isin(ld_snp_josh_not_in_revathy)]
bed_file_ld_snp_josh_not_in_revathy.to_csv('/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/snp_data/snp_data_MS_ldlink_snp_josh_not_in_revathy.txt', sep='\t', header=None,index=False)

# %%
import matplotlib_venn
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib_venn import venn2

sns.set_style("ticks", {"xtick.major.size": 8, "ytick.major.size": 8})
sns.set_context("talk", font_scale=0.8)
fig = plt.gcf()
fig.set_size_inches(10,7)
venn2([josh_ensembl_ldlink_snp_list, revathy_ensembl_ldlink_snp_list], ('Josh', 'Revathy'))
plt.suptitle('Comparison between Josh and Revathy LD SNP list for MS')
plt.show()

# %%
import matplotlib_venn
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib_venn import venn2

sns.set_style("ticks", {"xtick.major.size": 8, "ytick.major.size": 8})
sns.set_context("talk", font_scale=0.8)
fig = plt.gcf()
fig.set_size_inches(10,7)
venn2([josh_ensembl_ldlink_snp_list, josh_new_ensembl_ldlink_snp_list], ('Josh', 'Josh_new'))
plt.suptitle('Comparison between Josh old and new LD SNP list for MS')
plt.show()

# %%
import matplotlib_venn
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib_venn import venn2

sns.set_style("ticks", {"xtick.major.size": 8, "ytick.major.size": 8})
sns.set_context("talk", font_scale=0.8)
fig = plt.gcf()
fig.set_size_inches(10,7)
venn2([revathy_ensembl_ldlink_snp_list, josh_new_ensembl_ldlink_snp_list], ('Revathy', 'Josh_new'))
plt.suptitle('Comparison between Revathy and Josh_new LD SNP list for MS')
plt.show()

# %%
import matplotlib_venn
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib_venn import venn2

sns.set_style("ticks", {"xtick.major.size": 8, "ytick.major.size": 8})
sns.set_context("talk", font_scale=0.8)
fig = plt.gcf()
fig.set_size_inches(10,7)
venn2([ld_snp_josh_not_in_revathy_set, ld_snp_josh_not_in_new_set], ('Revathy', 'Josh_new'))
plt.suptitle('Comparison between SNPs not in Revathy and Josh_new list')
plt.show()

# %% [markdown]
# #### Compare the gwas list of SNPs for both Josh and Revathy

# %%
import pandas as pd

gwas_snp_list_josh = pd.read_csv('/Users/rv103/Revathy/Duke/Collab/20210113_Maria/human-th-ms/data/snp_data_josh/MS/all_unique_ms_snp_cleaned.txt', sep='\t', names=['SNP_id'])
gwas_snp_list_revathy = pd.read_csv('/Users/rv103/Revathy/Duke/Collab/20210113_Maria/human-th-ms/data/snp_data/source_snps/all_unique_ms_snp_cleaned_new.txt', sep='\t', names=['SNP_id'])

# %%
len(gwas_snp_list_revathy.SNP_id.unique())
# Out:
# 650

# %%
josh_gwas_snp_list = set(gwas_snp_list_josh.SNP_id.unique().tolist())
revathy_gwas_snp_list = set(gwas_snp_list_revathy.SNP_id.unique().tolist())

# %%
import matplotlib_venn
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib_venn import venn2

sns.set_style("ticks", {"xtick.major.size": 8, "ytick.major.size": 8})
sns.set_context("talk", font_scale=0.8)
fig = plt.gcf()
fig.set_size_inches(10,7)
venn2([josh_gwas_snp_list, revathy_gwas_snp_list], ('Josh', 'Revathy'))
plt.suptitle('Comparison between Josh and Revathy GWAS SNP list for MS')
plt.show()

# %%
ensembl_ldlink_snp_info = pd.read_csv('/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/josh_ensembl_ldlink_final_snp_info.tab', sep='\t')
ensembl_ldlink_snp_info[ensembl_ldlink_snp_info.result.isin(ld_snp_josh_new_not_in_revathy)]
# Out:
#         d_prime       query        r2       result      MAF  \
# 513    0.972902  rs34286592  0.898283   rs34127220  0.12740
# 516    0.963831  rs34286592  0.881609   rs34222852  0.09804
# 1166   1.000000  rs10466829  0.953403   rs71045296  0.47300
# 1167   0.972831   rs7977720  0.803882   rs71045296  0.47300
# 1196   0.986672    rs531612  0.856252    rs7105628  0.37780
# 1324   0.994012  rs11719975  0.833547   rs71055031  0.29050
# 1325   0.994012   rs9863496  0.833547   rs71055031  0.29050
# 1566   0.990030  rs13192841  0.961111   rs34324947  0.20330
# 1639   1.000000  rs11231749  1.000000    rs7122759  0.17390
# 1844   0.991184  rs12148050  0.982446   rs34411291      NaN
# 1845   0.991184  rs12147246  0.982446   rs34411291      NaN
# 1855   0.995733  rs10271373  0.904816   rs34416654  0.40500
# 2038   0.983761   rs7120737  0.967786    rs7124949  0.21830
# 2063   0.991821   rs7120737  0.952680    rs7116299  0.22560
# 2076   0.991888   rs7120737  0.983842    rs7115371  0.22560
# ...

# %%
josh_ldlink_ibd = pd.read_csv('/Users/rv103/Revathy/Duke/Collab/20210113_Maria/human-th-ms/data/snp_data_josh/IBD/ibd_ld_snps_r2_0.8.bed', sep='\t',
                              names=['chr','start','end','snp_id'])
revathy_ldlink_ibd = pd.read_csv('/Users/rv103/Revathy/Duke/Collab/20210113_Maria/human-th-ms/data/snp_data/ld_expansion_ibd/ibd_ld_snps_r2_0.8_new.bed', sep='\t',
                                 names=['chr','start','end','snp_id'])

revathy_ldlink_ibd
# Out:
#          chr      start        end      snp_id
# 0       chr2   65427229   65427230    rs268124
# 1      chr17   42378876   42378877   rs8071537
# 2      chr17   42351305   42351306   rs8073517
# 3      chr17   42369185   42369186  rs35840966
# 4      chr17   42374254   42374255  rs12949918
# ...      ...        ...        ...         ...
# 15481  chr17   59886175   59886176   rs1292053
# 15482   chr4    3442775    3442776   rs2073505
# 15483   chr5  159387524  159387525  rs10045431
# 15484   chr7   82228576   82228577    rs929351
# 15485  chr11   64329760   64329761    rs694739
#
# [15486 rows x 4 columns]

# %%
len(revathy_ldlink_ibd.snp_id.unique())
# Out:
# 15486

# %%
josh_ldlink_ibd_snp_list = set(josh_ldlink_ibd.snp_id.unique().tolist())
revathy_ldlink_ibd_snp_list = set(revathy_ldlink_ibd.snp_id.unique().tolist())

# %%
import matplotlib_venn
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib_venn import venn2

sns.set_style("ticks", {"xtick.major.size": 8, "ytick.major.size": 8})
sns.set_context("talk", font_scale=0.8)
fig = plt.gcf()
fig.set_size_inches(10,7)
venn2([josh_ldlink_ibd_snp_list, revathy_ldlink_ibd_snp_list], ('Josh', 'Revathy'))
plt.suptitle('Comparison between Josh and Revathy LD SNP list for IBD')
plt.show()
