# %%
# !wc -l /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/snp_data/atac_snp_loop_ra/all_interactions_with_snp.tab
# Out:
# 1345 /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/snp_data/atac_snp_loop_ra/all_interactions_with_snp.tab

# %%
# !wc -l /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/snp_data/atac_snp_loop_ibd/all_interactions_with_snp.tab
# Out:
# 3766 /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/snp_data/atac_snp_loop_ibd/all_interactions_with_snp.tab

# %%
# !wc -l /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/snp_data/atac_snp_loop_ps/all_interactions_with_snp.tab
# Out:
# 811 /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/snp_data/atac_snp_loop_ps/all_interactions_with_snp.tab

# %%
# !wc -l /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/snp_data/all_interactions_with_snp.tab
# Out:
# 2893 /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/snp_data/all_interactions_with_snp.tab

# %%
# !head /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/snp_data/atac_snp_loop_ibd/all_interactions_with_snp.tab
# Out:
# chrom_anc_at	start_anc_at	end_anc_at	chrom_atac	start_atac	end_atac	name_atac	name_anc	anc_pos_at	chrom_anc_ge	start_anc_ge	end_anc_ge	chrom_gene	start_gene	end_gene	name_gene	strand_gene	anc_pos_ge	score	chr_snp	start_snp	end_snp	name_snp	score_gene	gene_symbol	gene_type	atac_promoter	is_lead_snp	is_looped	description	Th1_cytokine_capture	Th1_standard	Th17_cytokine_capture	Th17_standard
# chr1	2525000.0	2550000.0	chr1	2545951.0	2549272.0	chr1.2545952.2549272	loop.13	right	chr1	1900000.0	1925000.0	chr1	1917588.0	1920279.0	ENSG00000178821.13	-	left		chr1	2547071.0	2547072.0	rs2477678		TMEM52	protein_coding	False	False	True
# chr1	2525000.0	2550000.0	chr1	2545951.0	2549272.0	chr1.2545952.2549272	loop.13	right	chr1	1900000.0	1925000.0	chr1	1917588.0	1920279.0	ENSG00000178821.13	-	left		chr1	2548543.0	2548544.0	rs1974044		TMEM52	protein_coding	False	False	True
# ...

# %%
import pandas as pd

snp_atac_ms = pd.read_csv('/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/snp_data/all_interactions_with_snp.tab', sep='\t')
snp_atac_ibd = pd.read_csv('/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/snp_data/atac_snp_loop_ibd/all_interactions_with_snp.tab', sep='\t')
snp_atac_ra = pd.read_csv('/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/snp_data/atac_snp_loop_ra/all_interactions_with_snp.tab', sep='\t')
snp_atac_ps = pd.read_csv('/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/snp_data/atac_snp_loop_ps/all_interactions_with_snp.tab', sep='\t')


## manipulation of the data

snp_atac_ms['chr_start_end_gene'] = snp_atac_ms['chrom_gene'] + '_' + snp_atac_ms['start_gene'].astype(str) + '_' + snp_atac_ms['end_gene'].astype(str)
snp_atac_ibd['chr_start_end_gene'] = snp_atac_ibd['chrom_gene'] + '_' + snp_atac_ibd['start_gene'].astype(str) + '_' + snp_atac_ibd['end_gene'].astype(str)
snp_atac_ra['chr_start_end_gene'] = snp_atac_ra['chrom_gene'] + '_' + snp_atac_ra['start_gene'].astype(str) + '_' + snp_atac_ra['end_gene'].astype(str)
snp_atac_ps['chr_start_end_gene'] = snp_atac_ps['chrom_gene'] + '_' + snp_atac_ps['start_gene'].astype(str) + '_' + snp_atac_ps['end_gene'].astype(str)

snp_atac_ms['chr_start_end_snp'] = snp_atac_ms['chr_snp'] + '_' + snp_atac_ms['start_snp'].astype(int).astype(str) + '_' + snp_atac_ms['end_snp'].astype(int).astype(str)
snp_atac_ibd['chr_start_end_snp'] = snp_atac_ibd['chr_snp'] + '_' + snp_atac_ibd['start_snp'].astype(int).astype(str) + '_' + snp_atac_ibd['end_snp'].astype(int).astype(str)
snp_atac_ra['chr_start_end_snp'] = snp_atac_ra['chr_snp'] + '_' + snp_atac_ra['start_snp'].astype(int).astype(str) + '_' + snp_atac_ra['end_snp'].astype(int).astype(str)
snp_atac_ps['chr_start_end_snp'] = snp_atac_ps['chr_snp'] + '_' + snp_atac_ps['start_snp'].astype(int).astype(str) + '_' + snp_atac_ps['end_snp'].astype(int).astype(str)

snp_atac_ms['chr_start_end_atac'] = snp_atac_ms['chrom_atac'] + '_' + snp_atac_ms['start_atac'].astype(int).astype(str) + '_' + snp_atac_ms['end_atac'].astype(int).astype(str)
snp_atac_ibd['chr_start_end_atac'] = snp_atac_ibd['chrom_atac'] + '_' + snp_atac_ibd['start_atac'].astype(int).astype(str) + '_' + snp_atac_ibd['end_atac'].astype(int).astype(str)
snp_atac_ra['chr_start_end_atac'] = snp_atac_ra['chrom_atac'] + '_' + snp_atac_ra['start_atac'].astype(int).astype(str) + '_' + snp_atac_ra['end_atac'].astype(int).astype(str)
snp_atac_ps['chr_start_end_atac'] = snp_atac_ps['chrom_atac'] + '_' + snp_atac_ps['start_atac'].astype(int).astype(str) + '_' + snp_atac_ps['end_atac'].astype(int).astype(str)

snp_atac_ms['disorder'] = 'MS'
snp_atac_ibd['disorder'] = 'IBD'
snp_atac_ra['disorder'] = 'RA'
snp_atac_ps['disorder'] = 'PS'

snp_atac_ms = snp_atac_ms[['chr_start_end_atac','chr_start_end_gene','chr_start_end_snp','gene_symbol','name_snp','is_lead_snp','atac_promoter','disorder']]
snp_atac_ibd = snp_atac_ibd[['chr_start_end_atac','chr_start_end_gene','chr_start_end_snp','gene_symbol','name_snp','is_lead_snp','atac_promoter','disorder']]
snp_atac_ra = snp_atac_ra[['chr_start_end_atac','chr_start_end_gene','chr_start_end_snp','gene_symbol','name_snp','is_lead_snp','atac_promoter','disorder']]
snp_atac_ps = snp_atac_ps[['chr_start_end_atac','chr_start_end_gene','chr_start_end_snp','gene_symbol','name_snp','is_lead_snp','atac_promoter','disorder']]

## create unique list of snps in each category

unique_snp_ms_list = set(snp_atac_ms.name_snp.unique().tolist())
unique_snp_ibd_list = set(snp_atac_ibd.name_snp.unique().tolist())
unique_snp_ra_list = set(snp_atac_ra.name_snp.unique().tolist())
unique_snp_ps_list = set(snp_atac_ps.name_snp.unique().tolist())

print(len(unique_snp_ms_list))
print(len(unique_snp_ibd_list))
print(len(unique_snp_ra_list)) 
print(len(unique_snp_ps_list))
# Out:
# 816
# 1015
# 349
# 244

# %%
all_snp_df = pd.concat([snp_atac_ms,snp_atac_ibd,snp_atac_ra,snp_atac_ps])
all_snp_df = all_snp_df.drop_duplicates()
all_snp_df[['chr_start_end_atac','name_snp']].drop_duplicates()
# Out:
#            chr_start_end_atac     name_snp
# 0        chr1_2585245_2587484  rs554599679
# 1        chr1_2585245_2587484   rs60733400
# 2      chr1_10414913_10415783   rs11576384
# 3      chr1_10414913_10415783   rs34918542
# 12     chr1_32249679_32251855   rs10914539
# 20     chr1_24966275_24967222    rs7536201
# 21     chr1_24966275_24967222    rs4265380
# 22     chr1_24966275_24967222   rs11249212
# 23     chr1_24966275_24967222   rs11249213
# 24     chr1_24966275_24967222    rs7414934
# 45     chr1_64956301_64958002   rs12408934
# 46     chr1_66283586_66284279     rs575056
# 52     chr1_85275810_85277359   rs12068788
# 53     chr1_85275810_85277359   rs11161583
# 54     chr1_85275810_85277359    rs1060843
# 55     chr1_85275810_85277359   rs11161582
# 56     chr1_85275810_85277359   rs12562182
# 57     chr1_85278884_85279384    rs9887879
# 58     chr1_85278884_85279384    rs9887812
# 59     chr1_85278884_85279384   rs71582951
# 60     chr1_92503732_92505642   rs56252613
# ...

# %%
import matplotlib_venn
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib_venn import venn2, venn3

sns.set_style("ticks", {"xtick.major.size": 8, "ytick.major.size": 8})
sns.set_context("talk", font_scale=0.8)
fig = plt.gcf()
fig.set_size_inches(10,7)
venn2([unique_snp_ms_list,unique_snp_ibd_list], ('MS', 'IBD'))
#venn4([unique_snp_ms_list, unique_snp_ibd_list, unique_snp_ra_list, unique_snp_ps_list], ('MS', 'IBD', 'RA', 'Psoriasis'))
plt.suptitle('Unique SNPs that intersect with ATAC peaks for RA and Psoriasis')
plt.show()

# %%
ms_ibd_outer_merge = snp_atac_ms.merge(snp_atac_ibd, on='name_snp', how='outer')
ms_ibd_ra_outer_merge = ms_ibd_outer_merge.merge(snp_atac_ra, on='name_snp', how='outer')
ms_ibd_ra_ps_outer_merge = ms_ibd_ra_outer_merge.merge(snp_atac_ps, on='name_snp', how='outer')

ms_ibd_ra_ps_outer_merge[['ms','ibd','ra','ps']] = ms_ibd_ra_ps_outer_merge[['ms','ibd','ra','ps']].fillna(value='False')
ms_ibd_ra_ps_outer_merge.columns

ms_ibd_ra_ps_inner_merge = ms_ibd_ra_outer_merge.merge(snp_atac_ps, on='name_snp', how='inner')

ms_ibd_ra_ps_outer_merge_dedup = ms_ibd_ra_ps_outer_merge.drop_duplicates(subset='name_snp')

### co-ordinates of snps in each category

ms_ibd_ra_ps_snp_coordinates = ms_ibd_ra_ps_outer_merge_dedup[['chr_start_end_snp_ms','chr_start_end_snp_ps','chr_start_end_snp_ibd','chr_start_end_snp_ra']]
ms_ibd_ra_ps_all_snp = pd.concat([ms_ibd_ra_ps_snp_coordinates.chr_start_end_snp_ms, ms_ibd_ra_ps_snp_coordinates.chr_start_end_snp_ps, ms_ibd_ra_ps_snp_coordinates.chr_start_end_snp_ibd, ms_ibd_ra_ps_snp_coordinates.chr_start_end_snp_ra], join='inner', ignore_index=True)

ms_ibd_ra_ps_all_snp_df = pd.DataFrame(ms_ibd_ra_ps_all_snp, columns=['chr_start_end'])
ms_ibd_ra_ps_all_snp_df = ms_ibd_ra_ps_all_snp_df.dropna()

ms_ibd_ra_ps_all_snp_df[['chr','start','end']] = ms_ibd_ra_ps_all_snp_df.chr_start_end.str.split("_",expand=True)
ms_ibd_ra_ps_all_snp_df = ms_ibd_ra_ps_all_snp_df.drop(columns=['chr_start_end'])
#ms_ibd_ra_ps_all_snp_df.to_csv('/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/ms_ibd_ra_ps_snp_coordinates.bed', sep='\t', index=False, header=None)

# %%
ms_ibd_ra_ps_outer_merge
# Out:
#         chr_start_end_atac_ms       chr_start_end_gene_ms  \
# 0        chr1_2585245_2587484    chr1_2184459.0_2213720.0
# 1        chr1_2585245_2587484    chr1_2184459.0_2213720.0
# 2        chr1_2585245_2587484    chr1_2585489.0_2591469.0
# 3        chr1_2585245_2587484    chr1_2585489.0_2591469.0
# 4        chr1_2585245_2587484    chr1_2184459.0_2213720.0
# 5        chr1_2585245_2587484    chr1_2184459.0_2213720.0
# 6        chr1_2585245_2587484    chr1_2585489.0_2591469.0
# 7        chr1_2585245_2587484    chr1_2585489.0_2591469.0
# 8      chr1_10414913_10415783    chr1_9946316.0_9947636.0
# 9      chr1_10414913_10415783    chr1_9922111.0_9944407.0
# 10     chr1_10414913_10415783    chr1_9941921.0_9949974.0
# 11     chr1_10414913_10415783    chr1_9942426.0_9985501.0
# 12     chr1_10414913_10415783  chr1_10209803.0_10381603.0
# 13     chr1_10414913_10415783  chr1_10397590.0_10420511.0
# 14     chr1_10414913_10415783    chr1_9946316.0_9947636.0
# ...

# %%
len(ms_ibd_ra_ps_outer_merge.name_snp.unique().tolist())
# Out:
# 2171

# %%
# Out:
#         chr_start_end_atac_ms       chr_start_end_gene_ms  \
# 0        chr1_2585245_2587484    chr1_2184459.0_2213720.0
# 4        chr1_2585245_2587484    chr1_2184459.0_2213720.0
# 8      chr1_10414913_10415783    chr1_9946316.0_9947636.0
# 14     chr1_10414913_10415783    chr1_9946316.0_9947636.0
# 20     chr1_32249679_32251855  chr1_12165941.0_12167038.0
# 29     chr1_24966275_24967222  chr1_23549137.0_23551915.0
# 34     chr1_24966275_24967222  chr1_23549137.0_23551915.0
# 59     chr1_24966275_24967222  chr1_23549137.0_23551915.0
# 84     chr1_24966275_24967222  chr1_23549137.0_23551915.0
# 109    chr1_24966275_24967222  chr1_23549137.0_23551915.0
# 134    chr1_64956301_64958002  chr1_67306362.0_67397090.0
# 136    chr1_66283586_66284279  chr1_65791512.0_66374579.0
# 143    chr1_85275810_85277359  chr1_85649415.0_85709433.0
# 146    chr1_85275810_85277359  chr1_85649415.0_85709433.0
# 149    chr1_85275810_85277359  chr1_85649415.0_85709433.0
# ...

# %%
ms_ibd_ra_ps_inner_merge.shape
# Out:
# (924, 29)

# %%
annot_dict = {"True":1,"False":0}
def annotate(df):
    col_sum = annot_dict[df.ms] + annot_dict[df.ra] + annot_dict[df.ibd] + annot_dict[df.ps]
    return col_sum

ms_ibd_ra_ps_outer_merge_dedup['ms_ibd_ra_ps'] = ms_ibd_ra_ps_outer_merge_dedup.apply(annotate, axis=1)
#ms_ibd_ra_ps_inner_merge['ms_ibd_ra_ps'] = ms_ibd_ra_ps_inner_merge.apply(annotate, axis=1)


ms_ibd_ra_ps_outer_merge_dedup = ms_ibd_ra_ps_outer_merge_dedup.sort_values(by='ms_ibd_ra_ps', ascending=False)
#ms_ibd_ra_ps_inner_merge = ms_ibd_ra_ps_inner_merge.sort_values(by='ms_ibd_ra_ps', ascending=False)

ms_ibd_ra_ps_outer_merge_dedup.to_csv('/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/ma_ibd_ra_ps_snp_atac_gene_data.txt', sep='\t')
# Out:
# /data/reddylab/software/miniconda3/envs/revathy_py3/lib/python3.5/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
len(ms_ibd_ra_ps_outer_merge.name_snp.unique())
# Out:
# 2171

# %%
ms_ibd_ra_ps_outer_merge[ms_ibd_ra_ps_outer_merge.ms_ibd_ra_ps==4]
# Out:
# Empty DataFrame
# Columns: [chr_start_end_atac_ms, chr_start_end_gene_ms, chr_start_end_snp_ms, gene_symbol_ms, name_snp, is_lead_snp_ms, atac_promoter_ms, ms, chr_start_end_atac_ibd, chr_start_end_gene_ibd, chr_start_end_snp_ibd, gene_symbol_ibd, is_lead_snp_ibd, atac_promoter_ibd, ibd, chr_start_end_atac_ra, chr_start_end_gene_ra, chr_start_end_snp_ra, gene_symbol_ra, is_lead_snp_ra, atac_promoter_ra, ra, chr_start_end_atac_ps, chr_start_end_gene_ps, chr_start_end_snp_ps, gene_symbol_ps, is_lead_snp_ps, atac_promoter_ps, ps, ms_ibd_ra_ps]
# Index: []
#
# [0 rows x 30 columns]

# %%
uniq_ps_snps_in_table = ms_ibd_ra_ps_inner_merge.name_snp.unique().tolist()

ms_ibd_ra_ps_inner_merge_uniq = ms_ibd_ra_ps_inner_merge[ms_ibd_ra_ps_inner_merge.name_snp.isin(uniq_ps_snps_in_table)]
ms_ibd_ra_ps_inner_merge_uniq

# %%
# !wc -l /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/ma_ibd_ra_ps_snp_atac_gene_data.txt
# Out:
# 14903 /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/ma_ibd_ra_ps_snp_atac_gene_data.txt

# %%
intr3 = ms_ibd_ra_ps_outer_merge[ms_ibd_ra_ps_outer_merge.ms_ibd_ra_ps==3]
intr3[intr3.ps=='True']
# Out:
# Empty DataFrame
# Columns: [chr_start_end_atac_ms, chr_start_end_gene_ms, chr_start_end_snp_ms, gene_symbol_ms, name_snp, is_lead_snp_ms, atac_promoter_ms, ms, chr_start_end_atac_ibd, chr_start_end_gene_ibd, chr_start_end_snp_ibd, gene_symbol_ibd, is_lead_snp_ibd, atac_promoter_ibd, ibd, chr_start_end_atac_ra, chr_start_end_gene_ra, chr_start_end_snp_ra, gene_symbol_ra, is_lead_snp_ra, atac_promoter_ra, ra, chr_start_end_atac_ps, chr_start_end_gene_ps, chr_start_end_snp_ps, gene_symbol_ps, is_lead_snp_ps, atac_promoter_ps, ps, ms_ibd_ra_ps]
# Index: []
#
# [0 rows x 30 columns]

# %%
ms_ibd_ra_outer_merge.sort_values(by=['chr_start_end_atac_ms', 'chr_start_end_gene_ms',
       'chr_start_end_snp_ms', 'chr_start_end_atac_ibd',
       'chr_start_end_gene_ibd', 'chr_start_end_snp_ibd', 'chr_start_end_atac_ra',
       'chr_start_end_gene_ra', 'chr_start_end_snp_ra'] , na_position='last')

# %%
ms_ibd_ra_outer_merge.columns
# Out:
# Index(['chr_start_end_atac_ms', 'chr_start_end_gene_ms',
#        'chr_start_end_snp_ms', 'gene_symbol_ms', 'name_snp', 'is_lead_snp_ms',
#        'atac_promoter_ms', 'ms', 'chr_start_end_atac_ibd',
#        'chr_start_end_gene_ibd', 'chr_start_end_snp_ibd', 'gene_symbol_ibd',
#        'is_lead_snp_ibd', 'atac_promoter_ibd', 'ibd', 'chr_start_end_atac_ra',
#        'chr_start_end_gene_ra', 'chr_start_end_snp_ra', 'gene_symbol_ra',
#        'is_lead_snp_ra', 'atac_promoter_ra', 'ra'],
#       dtype='object')

# %%
snp_atac_ibd.columns
# Out:
# Index(['chrom_anc_at', 'start_anc_at', 'end_anc_at', 'chrom_atac',
#        'start_atac', 'end_atac', 'name_atac', 'name_anc', 'anc_pos_at',
#        'chrom_anc_ge', 'start_anc_ge', 'end_anc_ge', 'chrom_gene',
#        'start_gene', 'end_gene', 'name_gene', 'strand_gene', 'anc_pos_ge',
#        'score', 'chr_snp', 'start_snp', 'end_snp', 'name_snp', 'score_gene',
#        'gene_symbol', 'gene_type', 'atac_promoter', 'is_lead_snp', 'is_looped',
#        'description', 'Th1_cytokine_capture', 'Th1_standard',
#        'Th17_cytokine_capture', 'Th17_standard'],
#       dtype='object')

# %%
snp_atac_ms.columns
# Out:
# Index(['chrom_anc_at', 'start_anc_at', 'end_anc_at', 'chrom_atac',
#        'start_atac', 'end_atac', 'name_atac', 'name_anc', 'anc_pos_at',
#        'chrom_anc_ge', 'start_anc_ge', 'end_anc_ge', 'chrom_gene',
#        'start_gene', 'end_gene', 'name_gene', 'strand_gene', 'anc_pos_ge',
#        'score', 'chr_snp', 'start_snp', 'end_snp', 'name_snp', 'score_gene',
#        'gene_symbol', 'gene_type', 'atac_promoter', 'is_lead_snp', 'is_looped',
#        'description', 'Th1_cytokine_capture', 'Th1_standard',
#        'Th17_cytokine_capture', 'Th17_standard', 'logFC_MSvControl',
#        'PVal_MSvControl', 'FDR_MSvControl'],
#       dtype='object')

# %%
snp_atac_ibd.name_atac.head()
# Out:
# 0    chr1.2545952.2549272
# 1    chr1.2545952.2549272
# 2    chr1.2545952.2549272
# 3    chr1.2545952.2549272
# 4    chr1.2545952.2549272
# Name: name_atac, dtype: object

# %% [markdown]
# name_atac -> chr_start_end_atac
# chrom_gene, start_gene, end_gene -> chr_start_end_gene
# name_gene
# gene_symbol
# chr_snp, start_snp, end_snp -> chr_start_end_snp
# name_snp
# atac_promoter
# is_lead_snp
# ms_ibd_ra

# %% [markdown]
# ### bedtools Closest to identify any overlapping SNPs in the 300bp window

# %%
# !head /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/ms_ibd_ra_ps_snp_coordinates.bed
# Out:
# chr1	2585382	2585391
# chr1	2585341	2585342
# chr1	10415062	10415063
# chr1	10415089	10415102
# chr1	32250039	32250040
# chr1	24966592	24966593
# chr1	24966864	24966865
# chr1	24966709	24966710
# chr1	24966745	24966746
# chr1	24966724	24966725

# %%
# !wc -l /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/ms_ibd_ra_ps_snp_coordinates.bed
# Out:
# 2424 /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/ms_ibd_ra_ps_snp_coordinates.bed

# %%
# %%bash
# cat /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/ms_ibd_ra_ps_snp_coordinates.bed \
# | awk -vOFS="\t" '{print $1,$2,$3,$1"_"$2"_"$3}' \
# | sort -k1,1 -k2,2n \
# > /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/ms_ibd_ra_ps_snp_coordinates.sorted.bed

# %%
# %%bash
# bedtools closest \
#   -io \
#   -D a \
#   -a /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/ms_ibd_ra_ps_snp_coordinates.sorted.bed \
#   -b /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/ms_ibd_ra_ps_snp_coordinates.sorted.bed \
# > /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/ms_ibd_ra_ps_snp_coordinates_with_distance.sorted.bed

# %%
# %%bash
# sbatch -p all \
#     --mem 64G \
#     <<'EOF'
# #!/bin/bash
# bedtools makewindows \
# -g /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/ms_ibd_ra_ps_snp_coordinates.sorted.bed \
# -w 300 \
# > /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/ms_ibd_ra_ps_snp_coordinates_windows.sorted.bed
#
# EOF
# Out:
# Submitted batch job 26772529

# %%
# !head /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/ms_ibd_ra_ps_snp_coordinates_windows.sorted.bed
# Out:
# chr1	0	300
# chr1	300	600
# chr1	600	900
# chr1	900	1200
# chr1	1200	1500
# chr1	1500	1800
# chr1	1800	2100
# chr1	2100	2400
# chr1	2400	2700
# chr1	2700	3000

# %%
# %%bash
# bedtools intersect \
# -a /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/ms_ibd_ra_ps_snp_coordinates.sorted.bed \
# -b /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/ms_ibd_ra_ps_snp_coordinates_windows.sorted.bed \
# -c \
# | head

# %%
import pandas as pd
import numpy as np

snp_with_distance = pd.read_csv('/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/ms_ibd_ra_ps_snp_coordinates_with_distance.sorted.bed', sep='\t', 
                               names=['chr_1','start_1','end_1','chr_start_end_1','chr_2','start_2','end_2','chr_start_end_2','distance'])
#snp_with_distance = snp_with_distance[['chr_start_end_1','chr_start_end_2','distance']]
#snp_with_distance

snp_with_coordinates = snp_with_distance[['chr_1','start_1','end_1','chr_start_end_1']]
snp_with_coordinates = snp_with_coordinates.drop_duplicates(subset=['chr_start_end_1'])

levels = list(set(snp_with_distance['chr_1']))
start_index={}
for level in levels:
    start = snp_with_distance.loc[snp_with_distance['chr_1']==level, 'start_1'].iloc[0]
    start_index[level] = start
    
    
start_index_df = pd.DataFrame(list(start_index.items()),columns=['chr_1', 'start_index'])

snp_with_coordinates_start_index = snp_with_coordinates.merge(start_index_df, on='chr_1', how='outer')
snp_with_coordinates_start_index['diff'] = snp_with_coordinates_start_index['start_1'] - snp_with_coordinates_start_index['start_index']
# snp_with_coordinates_start_index.head()
snp_with_coordinates_start_index['diff'] = snp_with_coordinates_start_index['diff']//300

snp_with_coordinates_start_index['start'] = snp_with_coordinates_start_index['start_index'] + (snp_with_coordinates_start_index['diff']*300)
snp_with_coordinates_start_index['keystr'] = snp_with_coordinates_start_index['chr_1'].astype('str') + '_' + snp_with_coordinates_start_index['start'].astype('str')+'_'+(snp_with_coordinates_start_index['start']+300).astype('str')
snp_windows = snp_with_coordinates_start_index.groupby(['keystr']).size().reset_index(name='count')

snp_window_count = snp_with_coordinates_start_index.merge(snp_windows, on='keystr',how='outer')
snp_window_count
# test = snp_windows[snp_windows['count']>1]
# Out:
#      chr_1    start_1      end_1           chr_start_end_1  start_index  \
# 0     chr1    1308515    1308516      chr1_1308515_1308516      1308515
# 1     chr1    2547071    2547072      chr1_2547071_2547072      1308515
# 2     chr1    2548543    2548544      chr1_2548543_2548544      1308515
# 3     chr1    2556223    2556224      chr1_2556223_2556224      1308515
# 4     chr1    2556326    2556327      chr1_2556326_2556327      1308515
# 5     chr1    2556713    2556714      chr1_2556713_2556714      1308515
# 6     chr1    2557168    2557169      chr1_2557168_2557169      1308515
# 7     chr1    2585341    2585342      chr1_2585341_2585342      1308515
# 8     chr1    2585382    2585383      chr1_2585382_2585383      1308515
# 9     chr1    2585382    2585391      chr1_2585382_2585391      1308515
# 10    chr1    2642638    2642639      chr1_2642638_2642639      1308515
# 11    chr1    2652812    2652813      chr1_2652812_2652813      1308515
# ...

# %%
import matplotlib.pyplot as plt

test[test['count']==18]
# Out:
#                       keystr  count
# 1426  chr6_32622567_32622867     18

# %%
snp_window_count[snp_window_count['keystr']=='chr6_32622567_32622867']
# Out:
#      chr_1   start_1     end_1         chr_start_end_1  start_index    diff  \
# 1739  chr6  32622585  32622586  chr6_32622585_32622586       528567  106980
# 1740  chr6  32622585  32622587  chr6_32622585_32622587       528567  106980
# 1741  chr6  32622586  32622587  chr6_32622586_32622587       528567  106980
# 1742  chr6  32622603  32622604  chr6_32622603_32622604       528567  106980
# 1743  chr6  32622615  32622616  chr6_32622615_32622616       528567  106980
# 1744  chr6  32622650  32622651  chr6_32622650_32622651       528567  106980
# 1745  chr6  32622658  32622659  chr6_32622658_32622659       528567  106980
# 1746  chr6  32622659  32622660  chr6_32622659_32622660       528567  106980
# 1747  chr6  32622685  32622686  chr6_32622685_32622686       528567  106980
# 1748  chr6  32622705  32622706  chr6_32622705_32622706       528567  106980
# 1749  chr6  32622812  32622813  chr6_32622812_32622813       528567  106980
# ...

# %% [markdown]
# ### Trace ancestry in the GWAS SNPs

# %% [markdown]
# GWAS SNPS from each category:
# * MS: `/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/snp_data/source_snps/ebi_gwas_ms.csv`
# * RA: `/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/snp_data/source_snps_ibd/ebi_gwas_ra.csv`
# * IBD: `/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/snp_data/source_snps_ibd/ebi_gwas_ibd.csv`
# * Psoriasis: `/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/snp_data/source_snps_psoriasis/ebi_gwas_ps.csv`

# %%
# !wc -l /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/snp_data/source_snps/ebi_gwas_ms.csv
# !wc -l /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/snp_data/source_snps_ibd/ebi_gwas_ra.csv
# !wc -l /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/snp_data/source_snps_ibd/ebi_gwas_ibd.csv
# !wc -l /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/snp_data/source_snps_psoriasis/ebi_gwas_ps.csv
# Out:
# 663 /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/snp_data/source_snps/ebi_gwas_ms.csv
# 747 /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/snp_data/source_snps_ibd/ebi_gwas_ra.csv
# 1434 /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/snp_data/source_snps_ibd/ebi_gwas_ibd.csv
# 458 /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/snp_data/source_snps_psoriasis/ebi_gwas_ps.csv

# %%
import pandas as pd

gwas_ms = pd.read_csv('/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/snp_data/source_snps/ebi_gwas_ms.csv', sep=',', engine='python')
gwas_ibd = pd.read_csv('/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/snp_data/source_snps_ibd/ebi_gwas_ibd.csv', sep=',', engine='python')
gwas_ra = pd.read_csv('/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/snp_data/source_snps_ibd/ebi_gwas_ra.csv', sep=',', engine='python')
gwas_ps = pd.read_csv('/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/snp_data/source_snps_psoriasis/ebi_gwas_ps.csv', sep=',', engine='python')

gwas_ms_subset = gwas_ms[['INITIAL SAMPLE SIZE','REPLICATION SAMPLE SIZE','SNPS']]
gwas_ibd_subset = gwas_ibd[['INITIAL SAMPLE SIZE','REPLICATION SAMPLE SIZE','SNPS']]
gwas_ra_subset = gwas_ra[['INITIAL SAMPLE SIZE','REPLICATION SAMPLE SIZE','SNPS']]
gwas_ps_subset = gwas_ps[['INITIAL SAMPLE SIZE','REPLICATION SAMPLE SIZE','SNPS']]

# gwas_ms_subset.to_csv('/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/snp_data/source_snps/ebi_gwas_snp_ms_subset.txt', sep='\t', index=False)
# gwas_ibd_subset.to_csv('/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/snp_data/source_snps/ebi_gwas_snp_ibd_subset.txt', sep='\t', index=False)
# gwas_ra_subset.to_csv('/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/snp_data/source_snps/ebi_gwas_snp_ra_subset.txt', sep='\t', index=False)
# gwas_ps_subset.to_csv('/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/snp_data/source_snps/ebi_gwas_snp_ps_subset.txt', sep='\t', index=False)

print(len(gwas_ms_subset['SNPS'].unique()))
print(len(gwas_ibd_subset['SNPS'].unique()))
print(len(gwas_ra_subset['SNPS'].unique()))
print(len(gwas_ps_subset['SNPS'].unique()))
# Out:
# 616
# 665
# 341
# 362

# %%
616+665+341+362
# Out:
# 1984

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

ancestry_files = {
    'MS':'/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/snp_data/source_snps/ebi_gwas_snp_ms_subset_correct.txt',
    'IBD':'/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/snp_data/source_snps/ebi_gwas_snp_ibd_subset_correct.txt',
    'RA':'/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/snp_data/source_snps/ebi_gwas_snp_ra_subset_correct.txt',
    'PS':'/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/snp_data/source_snps/ebi_gwas_snp_ps_subset_correct.txt'
}

for disease, file in ancestry_files.items():
    ancestry = pd.read_csv(file, sep='\t')
    ancestry_count = ancestry.groupby(['ANCESTRY'])['SNPS'].count()
    ax = ancestry_count.plot(kind='bar', figsize=(6, 5), fontsize=10)
    ax.set_alpha(0.8)
    ax.set_title("Ancestry and number of SNPS in %s"% disease, fontsize=15)
    ax.set_ylabel("Count", fontsize=10)
    sns.despine()
    plt.show()
    print(ancestry_count)
# Out:
# ANCESTRY
# European             301
# European, unknown    333
# Finland                2
# German                16
# Sardinian              7
# Name: SNPS, dtype: int64
# ANCESTRY
# African American       6
# Ashkenazi Jewish      17
# European             936
# European, unknown    334
# French Canadian        3
# Japanese              29
# Korean                47
# North Indian           5
# Polish                36
# Southern European      7
# Name: SNPS, dtype: int64
# ANCESTRY
# African American                                        190
# African admixed Arab, non-African admixed Arab            4
# African admixed Arab, non-African admixed Arab, Arab      4
# European                                                244
# European, East Asian                                    181
# Han Chinese                                              15
# Japanese                                                 21
# Korean                                                    6
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



ps = pd.read_csv('/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/snp_data/source_snps/ebi_gwas_snp_ps_subset_correct.txt', sep='\t')
ps.groupby(['ANCESTRY']).nunique()
# ps = ps.groupby(['ANCESTRY'])['SNPS'].count()
# ax = ps.plot(kind='bar', figsize=(6, 5), fontsize=10)
# ax.set_alpha(0.8)
# ax.set_title("Ancestry and number of SNPS in PS", fontsize=15)
# ax.set_ylabel("Count", fontsize=10)
# sns.despine()
# plt.show()
# print(ps)
# Out:
#                    PUBMEDID  SNPS  ANCESTRY  CATEGORY
# ANCESTRY
# Egyptian                  1     6         1         1
# European                  5    29         1         1
# European                  5   133         1         1
# European, Chinese         1    41         1         1
# Han Chinese               2    37         1         1
# Japanese                  1     2         1         1

# %% [markdown]
# ### Concatenate all the gwas data from all sub categories to make it a single table

# %%
import pandas as pd

gwas_snps_all = pd.read_csv('/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/snp_data/source_snps/gwas_snps_ancestry_disorder.txt', sep='\t')

## european ancestry snp list
gwas_snps_european = gwas_snps_all[(gwas_snps_all.ANCESTRY=='EUR') | (gwas_snps_all.ANCESTRY=='EUR ')]
european_snp_list = gwas_snps_european.SNPS.unique().tolist()
with open('/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/snp_data/source_snps/european_snp_list.txt', "w") as f:
    for snp in european_snp_list:
        f.write("%s\n" % snp)

## east asian ancestry snp_list
gwas_snps_eastasian = gwas_snps_all[gwas_snps_all.ANCESTRY=='EAS']
eastasian_snp_list = gwas_snps_eastasian.SNPS.unique().tolist()
with open('/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/snp_data/source_snps/eastasian_snp_list.txt', "w") as f:
    for snp in eastasian_snp_list:
        f.write("%s\n" % snp)

## african ancestry snp_list
gwas_snps_african = gwas_snps_all[gwas_snps_all.ANCESTRY=='ASW']
african_snp_list = gwas_snps_african.SNPS.unique().tolist()
with open('/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/snp_data/source_snps/african_snp_list.txt', "w") as f:
    for snp in african_snp_list:
        f.write("%s\n" % snp)

## south asian ancestry snp_list
gwas_snps_southasian = gwas_snps_all[gwas_snps_all.ANCESTRY=='SAS']
southasian_snp_list = gwas_snps_southasian.SNPS.unique().tolist()
with open('/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/snp_data/source_snps/southasian_snp_list.txt', "w") as f:
    for snp in southasian_snp_list:
        f.write("%s\n" % snp)

# %%
gwas_snps_all.ANCESTRY.unique()
# Out:
# array(['EUR', 'ASW', 'EUR ', 'EAS', 'SAS'], dtype=object)

# %% [markdown]
# ### Concatenate LD expanded list from all the disorders (not categorized by ancestry)

# %% [markdown]
# * MS: `/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/snp_data/ld_expansion/ensembl_ldlink_snps_r2_0.8.deduplicated.bed`
#
# * IBD: `/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/snp_data/ld_expansion_ibd/ibd_ld_snps_r2_0.8.bed`
#
# * RA: `/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/snp_data/ld_expansion_ra/ra_ld_snps_r2_0.8_new.bed`
#
# * PS: `/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/snp_data/ld_expansion_psoriasis/ps_ld_snps_r2_0.8_new.bed`

# %%
# %%bash
# wc -l /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/snp_data/ld_expansion/ensembl_ldlink_snps_r2_0.8.deduplicated.bed
# wc -l /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/snp_data/ld_expansion_ibd/ibd_ld_snps_r2_0.8.bed
# wc -l /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/snp_data/ld_expansion_ra/ra_ld_snps_r2_0.8_new.bed
# wc -l /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/snp_data/ld_expansion_psoriasis/ps_ld_snps_r2_0.8_new.bed
# Out:
# 10916 /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/snp_data/ld_expansion/ensembl_ldlink_snps_r2_0.8.deduplicated.bed
# 15486 /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/snp_data/ld_expansion_ibd/ibd_ld_snps_r2_0.8.bed
# 5566 /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/snp_data/ld_expansion_ra/ra_ld_snps_r2_0.8_new.bed
# 3840 /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/snp_data/ld_expansion_psoriasis/ps_ld_snps_r2_0.8_new.bed

# %%
import pandas as pd

ms_ld = pd.read_csv('/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/snp_data/ld_expansion/ensembl_ldlink_snps_r2_0.8.deduplicated.bed', sep='\t', names=['chr','start','end','snp_id'])
ibd_ld = pd.read_csv('/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/snp_data/ld_expansion_ibd/ibd_ld_snps_r2_0.8.bed', sep='\t', names=['chr','start','end','snp_id'])
ra_ld = pd.read_csv('/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/snp_data/ld_expansion_ra/ra_ld_snps_r2_0.8_new.bed', sep='\t', names=['chr','start','end','snp_id'])
ps_ld = pd.read_csv('/data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data/snp_data/ld_expansion_psoriasis/ps_ld_snps_r2_0.8_new.bed', sep='\t', names=['chr','start','end','snp_id'])

all_ld_df = pd.concat([ms_ld,ibd_ld,ra_ld,ps_ld])
len(all_ld_df.snp_id.unique())
# Out:
# 32871

# %%
# !wc -l /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/snp_data/ancestry/ld_snps_european.txt
# Out:
# 51712 /data/reddylab/Revathy/collabs/Maria/human-th-ms_new/data_v1/snp_data/ancestry/ld_snps_european.txt

# %%
10916+15486+5566+3840
# Out:
# 35808
