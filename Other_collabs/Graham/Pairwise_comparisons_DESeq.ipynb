# %% [markdown]
# ## Model1
# #### Model1:  ~ Compound + TNF + Compound:TNF
#
# Libraries to include:<br>
# A549_AZD2906_RNAseq<br>
# A549_AZD9567_RNAseq<br>
# A549_CORT108297_RNAseq<br>
# A549_CpdA_RNAseq<br>
# A549_dex_RNAseq<br>
# A549_DMSO_RNAseq<br>
# A549_GW87085_RNAseq<br>
# A549_hydrocortisone_RNAseq<br>
# A549_mapracorat_RNAseq<br>
# A549_RU489_RNAseq<br>
# A549_ZK216348_RNAseq<br>
# A549_TNF_AZD2906_RNAseq<br>
# A549_TNF_AZD9567_RNAseq<br>
# A549_TNF_CORT108297_RNAseq<br>
# A549_TNF_CpdA_RNAseq<br>
# A549_TNF_dex_RNAseq<br>
# A549_TNF_DMSO_RNAseq<br>
# A549_TNF_GW87085_RNAseq<br>
# A549_TNF_hydrocortisone_RNAseq<br>
# A549_TNF_mapracorat_RNAseq<br>
# A549_TNF_RU489_RNAseq<br>
# A549_TNF_ZK216348_RNAseq

# %%
# %%bash
# cd /data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb
# ls *.featurecounts.*
# Out:
# A549_AZD2906_RNAseq_rep1.star2.featurecounts.counts.txt
# A549_AZD2906_RNAseq_rep2.star2.featurecounts.counts.txt
# A549_AZD9567_RNAseq_rep1.star2.featurecounts.counts.txt
# A549_AZD9567_RNAseq_rep3.star2.featurecounts.counts.txt
# A549_CORT108297_RNAseq_rep1.star2.featurecounts.counts.txt
# A549_CORT108297_RNAseq_rep2.star2.featurecounts.counts.txt
# A549_CORT108297_RNAseq_rep3.star2.featurecounts.counts.txt
# A549_CpdA_RNAseq_rep1.star2.featurecounts.counts.txt
# A549_CpdA_RNAseq_rep2.star2.featurecounts.counts.txt
# A549_CpdA_RNAseq_rep3.star2.featurecounts.counts.txt
# A549_dex_RNAseq_rep1.star2.featurecounts.counts.txt
# A549_dex_RNAseq_rep2.star2.featurecounts.counts.txt
# A549_dex_RNAseq_rep3.star2.featurecounts.counts.txt
# A549_DMSO_RNAseq_rep1.star2.featurecounts.counts.txt
# A549_DMSO_RNAseq_rep2.star2.featurecounts.counts.txt
# A549_DMSO_RNAseq_rep3.star2.featurecounts.counts.txt
# A549_GW87085_RNAseq_rep1.star2.featurecounts.counts.txt
# ...

# %%
# %%bash
# mkdir -p /data/reddylab/Revathy/collabs/Graham/20220328/deseq/counts
# mkdir -p /data/reddylab/Revathy/collabs/Graham/20220328/deseq/model1
# mkdir -p /data/reddylab/Revathy/collabs/Graham/20220328/deseq/model2

# %%
import pandas as pd

files = [
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_AZD2906_RNAseq_rep1.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_AZD2906_RNAseq_rep2.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_AZD9567_RNAseq_rep1.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_AZD9567_RNAseq_rep3.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_CORT108297_RNAseq_rep1.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_CORT108297_RNAseq_rep2.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_CORT108297_RNAseq_rep3.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_CpdA_RNAseq_rep1.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_CpdA_RNAseq_rep2.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_CpdA_RNAseq_rep3.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_dex_RNAseq_rep1.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_dex_RNAseq_rep2.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_dex_RNAseq_rep3.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_DMSO_RNAseq_rep1.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_DMSO_RNAseq_rep2.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_DMSO_RNAseq_rep3.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_GW87085_RNAseq_rep1.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_GW87085_RNAseq_rep2.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_GW87085_RNAseq_rep3.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_hydrocortisone_RNAseq_rep1.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_hydrocortisone_RNAseq_rep2.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_hydrocortisone_RNAseq_rep3.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_mapracorat_RNAseq_rep1.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_mapracorat_RNAseq_rep2.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_mapracorat_RNAseq_rep3.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_RU489_RNAseq_rep1.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_RU489_RNAseq_rep2.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_RU489_RNAseq_rep3.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_ZK216348_RNAseq_rep1.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_ZK216348_RNAseq_rep2.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_ZK216348_RNAseq_rep3.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_AZD2906_RNAseq_rep1.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_AZD2906_RNAseq_rep2.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_AZD2906_RNAseq_rep3.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_AZD9567_RNAseq_rep1.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_AZD9567_RNAseq_rep2.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_AZD9567_RNAseq_rep3.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_CORT108297_RNAseq_rep1.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_CORT108297_RNAseq_rep2.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_CORT108297_RNAseq_rep3.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_CpdA_RNAseq_rep1.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_CpdA_RNAseq_rep2.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_CpdA_RNAseq_rep3.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_dex_RNAseq_rep1.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_dex_RNAseq_rep2.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_dex_RNAseq_rep3.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_DMSO_RNAseq_rep1.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_DMSO_RNAseq_rep2.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_DMSO_RNAseq_rep3.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_GW87085_RNAseq_rep1.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_GW87085_RNAseq_rep2.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_GW87085_RNAseq_rep3.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_hydrocortisone_RNAseq_rep1.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_hydrocortisone_RNAseq_rep2.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_hydrocortisone_RNAseq_rep3.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_mapracorat_RNAseq_rep1.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_mapracorat_RNAseq_rep2.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_mapracorat_RNAseq_rep3.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_RU489_RNAseq_rep1.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_RU489_RNAseq_rep2.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_RU489_RNAseq_rep3.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_ZK216348_RNAseq_rep1.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_ZK216348_RNAseq_rep2.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_ZK216348_RNAseq_rep3.star2.featurecounts.counts.txt'
]

def clean_count_column(s):
    rep=s.split('/')[-1].split('.')[0].replace('_RNAseq','').split('_')[-1]
    name="_".join(s.split('/')[-1].split('.')[0].replace('_RNAseq','').split('_')[:-1])
    col_name=".".join([name,rep])
    return col_name

df = None
for file in files:
    df_tmp = pd.read_csv(file, sep='\t',skiprows=1)
    df_tmp.columns = df_tmp.columns[:-1].tolist() + [clean_count_column(file)]
    if df is None:
        df = df_tmp.loc[:, ['Geneid','Chr', 'Start', 'End'] + [df_tmp.columns[-1]]]
    else:
        df = df.join(df_tmp.loc[:, df_tmp.columns[-1]], how='right')

count_columns = ["rep" in c for c in df.columns]
df.loc[:, count_columns] = df.loc[:, count_columns].astype(dtype='int')
df.drop(columns=['Chr','Start','End']).to_csv('/data/reddylab/Revathy/collabs/Graham/20220328/deseq/counts/A549_compounds_TNF_model1.counts.txt', sep='\t', index=False)

# %%
df.columns
# Out:
# Index(['Geneid', 'Chr', 'Start', 'End', 'A549_AZD2906.rep1',
#        'A549_AZD2906.rep2', 'A549_AZD9567.rep1', 'A549_AZD9567.rep3',
#        'A549_CORT108297.rep1', 'A549_CORT108297.rep2', 'A549_CORT108297.rep3',
#        'A549_CpdA.rep1', 'A549_CpdA.rep2', 'A549_CpdA.rep3', 'A549_dex.rep1',
#        'A549_dex.rep2', 'A549_dex.rep3', 'A549_DMSO.rep1', 'A549_DMSO.rep2',
#        'A549_DMSO.rep3', 'A549_GW87085.rep1', 'A549_GW87085.rep2',
#        'A549_GW87085.rep3', 'A549_hydrocortisone.rep1',
#        'A549_hydrocortisone.rep2', 'A549_hydrocortisone.rep3',
#        'A549_mapracorat.rep1', 'A549_mapracorat.rep2', 'A549_mapracorat.rep3',
#        'A549_RU489.rep1', 'A549_RU489.rep2', 'A549_RU489.rep3',
#        'A549_ZK216348.rep1', 'A549_ZK216348.rep2', 'A549_ZK216348.rep3',
#        'A549_TNF_AZD2906.rep1', 'A549_TNF_AZD2906.rep2',
#        'A549_TNF_AZD2906.rep3', 'A549_TNF_AZD9567.rep1',
#        'A549_TNF_AZD9567.rep2', 'A549_TNF_AZD9567.rep3',
# ...

# %%
# !mkdir -p /data/reddylab/Revathy/collabs/Graham/20220328/deseq/model1/plots/

# %%
# %%writefile /data/reddylab/Revathy/scripts/Graham_DESeq2.R
# #!/usr/bin/env Rscript
#
# suppressPackageStartupMessages(library(DESeq2))
# suppressPackageStartupMessages(library(ggplot2))
# suppressPackageStartupMessages(library(matrixStats))
# suppressPackageStartupMessages(library(dplyr))
# suppressPackageStartupMessages(library(RUVSeq))
# suppressPackageStartupMessages(library(EDASeq))
# suppressPackageStartupMessages(library(tidyverse))
# suppressPackageStartupMessages(library(RColorBrewer))
# suppressPackageStartupMessages(library("argparse"))
#
# # Rewrite DESeq2 plotPCA function to specify which PC to plot
# plotPCA_ = function(object, intgroup="condition", ntop=500, returnData=FALSE, pcX=1, pcY=2, ignoreReps=FALSE)
# {
#   # calculate the variance for each gene
#   rv <- rowVars(assay(object))
#
#   # select the ntop genes by variance
#   select <- order(rv, decreasing=TRUE)[seq_len(min(ntop, length(rv)))]
#
#   # perform a PCA on the data in assay(x) for the selected genes
#   pca <- prcomp(t(assay(object)[select,]))
#
#   # the contribution to the total variance for each component
#   percentVar <- pca$sdev^2 / sum( pca$sdev^2 )
#
#   if (!all(intgroup %in% names(colData(object)))) {
#     stop("the argument 'intgroup' should specify columns of colData(dds)")
#   }
#
#   intgroup.df <- as.data.frame(colData(object)[, intgroup, drop=FALSE])
#
#   # add the intgroup factors together to create a new grouping factor
#   group <- if (length(intgroup) > 1) {
#     factor(apply( intgroup.df, 1, paste, collapse=":"))
#   } else {
#     colData(object)[[intgroup]]
#   }
#
#   if (returnData) {
#     attr(d, "percentVar") <- c(percentVar[pcX], percentVar[pcY])
#     return(d)
#   }
#   rep <- colData(object)[['rep']]
# #   rep <- row.names(colData(dds))
#   if (!ignoreReps){
#       # Add replicate info
# #       rep <- colData(object)[['rep']]
#
#         # assembly the data for the plot
#       d <- data.frame(PCX=pca$x[,pcX], PCY=pca$x[,pcY], group=group, rep=rep, intgroup.df, name=colnames(object))
#
#       ggplot(data=d, aes_string(x="PCX", y="PCY", color="group", shape="rep")) + geom_point(size=3) +
#         xlab(paste0("PC", pcX, ": ",round(percentVar[pcX] * 100),"% variance")) +
#           ylab(paste0("PC", pcY, ": ",round(percentVar[pcY] * 100),"% variance")) +
#       scale_shape_manual(values=seq(0,15))
#   } else {
# #       batch <- as.factor(colData(object)[['batch']])
#         # assembly the data for the plot
#       d <- data.frame(PCX=pca$x[,pcX], PCY=pca$x[,pcY], group=group, intgroup.df, name=colnames(object))
#
#       ggplot(data=d, aes_string(x="PCX", y="PCY", color="group")) +
#           geom_point(size=3) +
#           geom_text(aes(label=rep),hjust=0, vjust=0) +
#           xlab(paste0("PC", pcX, ": ",round(percentVar[pcX] * 100),"% variance")) +
#           ylab(paste0("PC", pcY, ": ",round(percentVar[pcY] * 100),"% variance")) +
#       scale_shape_manual(values=seq(0,15))
#   }
# #     + coord_fixed()
# }
#
# # create parser object
#
# parser <- ArgumentParser()
#
# parser$add_argument("--counts", nargs="+", help="Countdata for all the samples")
# parser$add_argument("--contrast", nargs="+", help="Contrast matrix indicating all the contrasts between the given samples")
# parser$add_argument("--outdir", nargs="+", help="Path to output directory where all results will be saved")
#
# args <- parser$parse_args()
#
# count <- args$counts
# contrast <- args$contrast
# outdir <- args$outdir
# model_name <- gsub("^.*/", "", outdir)
#
# ### countData
#
# countData <- read.csv(count, sep='\t')
# rownames(countData) <- countData[,1]
# countData[,1] <- NULL
#
#
# ### colData
#
# col1_colData <- as.vector(colnames(countData))
# cond_colData <- gsub('(.*)\\..*', '\\1', col1_colData)
# rep_colData <- gsub('.*\\.(.*)','\\1',col1_colData)
# colData <- data.frame(condition = cond_colData,
#                       rep = rep_colData, stringsAsFactors = TRUE)
# rownames(colData) <- col1_colData
#
#
# ### contrast_matrix
#
# contrast_matrix <- read.csv(contrast, sep='\t')
# control <- as.character(contrast_matrix$Treatment2)
# base_control <- unique(control)
# base_control
#
# ## DESeq
#
# dds <- DESeqDataSetFromMatrix(countData = countData,
#                                  colData = colData,
#                                  design = ~ condition + rep)
# dds <- dds[ rowSums(fpm(dds, robust = FALSE)>=2) > 10, ]
#
#
# for (i in 1:length(base_control)){
#     dds$condition <- relevel(dds$condition, ref = base_control[i])
#     dds <- estimateSizeFactors(dds)
#     dds <- estimateDispersions(dds, fitType='local')
#     dds <- nbinomWaldTest(dds)
#
#     coeff <- coef(dds)
#
#     treatment <- as.vector(contrast_matrix$Treatment1[contrast_matrix$Treatment2==base_control[i]])
# #     print(treatment)
#
#     for (j in 1:length(treatment)){
#         result <- results(dds, contrast = c('condition',treatment[j],base_control[i]), alpha = 0.05, independentFiltering=F)
#         result <- result[order(result$padj),]
#         result_logFC <- result[(abs(result$log2FoldChange))>1,]
#
#
#         pdf(paste0(outdir, '/plots/', treatment[j], '_vs_', base_control[i], '.MA_plot.filtered_log2FC.pdf'), width=6, height=6)
#         DESeq2::plotMA(result_logFC, main=paste0('MA plot for ', treatment[j], '_vs_', base_control[i]), ylim = c(-8,8))
#         dev.off()
#
#         pdf(paste0(outdir, '/plots/', treatment[j], '_vs_', base_control[i], '.MA_plot.pdf'), width=6, height=6)
#         DESeq2::plotMA(result, main=paste0('MA plot for ', treatment[j], '_vs_', base_control[i]), ylim = c(-8,8))
#         dev.off()
#
#         write.table(result, file=paste0(outdir, '/', treatment[j], '_vs_', base_control[i],'.txt'),
#                 quote=FALSE, row.names=TRUE, sep='\t')
#         write.table(result_logFC, file=paste0(outdir, '/', treatment[j], '_vs_', base_control[i],'.filtered_log2FC.txt'),
#                 quote=FALSE, row.names=TRUE, sep='\t')
#
#         }
#
#     write.table(coeff, file=paste0(outdir, '/',base_control[i],'.beta_values.txt'),
#                 quote=FALSE, row.names=TRUE, sep='\t')
#
# }
# save.image(paste0(outdir, '/', model_name, '.RData'))
# Out:
# Overwriting /data/reddylab/Revathy/scripts/Graham_DESeq2.R

# %%
# %%bash
# source /data/reddylab/software/miniconda3/bin/activate alex_py3
# sbatch -p all \
#     --mem 64G \
#     -o /data/reddylab/Revathy/collabs/Graham/20220328/deseq/logs/model1_deseq.out \
#     <<'EOF'
# #!/bin/bash
# Rscript /data/reddylab/Revathy/scripts/Graham_DESeq2.R \
#      --counts /data/reddylab/Revathy/collabs/Graham/20220328/deseq/counts/A549_compounds_TNF_model1.counts.txt \
#      --contrast /data/reddylab/Revathy/collabs/Graham/20220328/20220404_deseq_rnaseq_model1_contrasts.txt \
#      --outdir /data/reddylab/Revathy/collabs/Graham/20220328/deseq/model1
# EOF
# Out:
# Submitted batch job 28224323

# %%
# %%bash
# source /data/reddylab/software/miniconda3/bin/activate alex_py3
# sbatch -p all \
#     --mem 64G \
#     -o /data/reddylab/Revathy/collabs/Graham/20220328/deseq/logs/model1_deseq_dex_contrasts.out \
#     <<'EOF'
# #!/bin/bash
# Rscript /data/reddylab/Revathy/scripts/Graham_DESeq2.R \
#      --counts /data/reddylab/Revathy/collabs/Graham/20220328/deseq/counts/A549_compounds_TNF_model1.counts.txt \
#      --contrast /data/reddylab/Revathy/collabs/Graham/20220328/20220404_deseq_rnaseq_model1_dex_contrasts.txt \
#      --outdir /data/reddylab/Revathy/collabs/Graham/20220328/deseq/model1
# EOF
# Out:
# Submitted batch job 28361190

# %% [markdown]
# ### Model1 variation with the interaction term

# %%
# %%writefile /data/reddylab/Revathy/scripts/Graham_DESeq2_model1_interaction.R
# #!/usr/bin/env Rscript
#
# suppressPackageStartupMessages(library(DESeq2))
# suppressPackageStartupMessages(library(ggplot2))
# suppressPackageStartupMessages(library(matrixStats))
# suppressPackageStartupMessages(library(dplyr))
# suppressPackageStartupMessages(library(RUVSeq))
# suppressPackageStartupMessages(library(EDASeq))
# suppressPackageStartupMessages(library(tidyverse))
# suppressPackageStartupMessages(library(RColorBrewer))
# suppressPackageStartupMessages(library("argparse"))
#
# # Rewrite DESeq2 plotPCA function to specify which PC to plot
# plotPCA_ = function(object, intgroup="condition", ntop=500, returnData=FALSE, pcX=1, pcY=2, ignoreReps=FALSE)
# {
#   # calculate the variance for each gene
#   rv <- rowVars(assay(object))
#
#   # select the ntop genes by variance
#   select <- order(rv, decreasing=TRUE)[seq_len(min(ntop, length(rv)))]
#
#   # perform a PCA on the data in assay(x) for the selected genes
#   pca <- prcomp(t(assay(object)[select,]))
#
#   # the contribution to the total variance for each component
#   percentVar <- pca$sdev^2 / sum( pca$sdev^2 )
#
#   if (!all(intgroup %in% names(colData(object)))) {
#     stop("the argument 'intgroup' should specify columns of colData(dds)")
#   }
#
#   intgroup.df <- as.data.frame(colData(object)[, intgroup, drop=FALSE])
#
#   # add the intgroup factors together to create a new grouping factor
#   group <- if (length(intgroup) > 1) {
#     factor(apply( intgroup.df, 1, paste, collapse=":"))
#   } else {
#     colData(object)[[intgroup]]
#   }
#
#   if (returnData) {
#     attr(d, "percentVar") <- c(percentVar[pcX], percentVar[pcY])
#     return(d)
#   }
#   rep <- colData(object)[['rep']]
# #   rep <- row.names(colData(dds))
#   if (!ignoreReps){
#       # Add replicate info
# #       rep <- colData(object)[['rep']]
#
#         # assembly the data for the plot
#       d <- data.frame(PCX=pca$x[,pcX], PCY=pca$x[,pcY], group=group, rep=rep, intgroup.df, name=colnames(object))
#
#       ggplot(data=d, aes_string(x="PCX", y="PCY", color="group", shape="rep")) + geom_point(size=3) +
#         xlab(paste0("PC", pcX, ": ",round(percentVar[pcX] * 100),"% variance")) +
#           ylab(paste0("PC", pcY, ": ",round(percentVar[pcY] * 100),"% variance")) +
#       scale_shape_manual(values=seq(0,15))
#   } else {
# #       batch <- as.factor(colData(object)[['batch']])
#         # assembly the data for the plot
#       d <- data.frame(PCX=pca$x[,pcX], PCY=pca$x[,pcY], group=group, intgroup.df, name=colnames(object))
#
#       ggplot(data=d, aes_string(x="PCX", y="PCY", color="group")) +
#           geom_point(size=3) +
#           geom_text(aes(label=rep),hjust=0, vjust=0) +
#           xlab(paste0("PC", pcX, ": ",round(percentVar[pcX] * 100),"% variance")) +
#           ylab(paste0("PC", pcY, ": ",round(percentVar[pcY] * 100),"% variance")) +
#       scale_shape_manual(values=seq(0,15))
#   }
# #     + coord_fixed()
# }
#
# parser <- ArgumentParser()
#
# parser$add_argument("--counts", nargs="+", help="Countdata for all the samples")
# parser$add_argument("--outdir", nargs="+", help="Path to output directory where all results will be saved")
#
# args <- parser$parse_args()
#
# count <- args$counts
# outdir <- args$outdir
#
#
# countData <- read.csv(count, sep='\t')
# rownames(countData) <- countData[,1]
# countData[,1] <- NULL
#
# col1_colData <- as.vector(colnames(countData))
# cond_colData <- gsub('(.*)\\..*', '\\1', col1_colData)
# comp_colData <- gsub('.*_(.*)', '\\1', cond_colData)
# treat_colData <- c(rep('no',31), rep('yes',33))
#
# colData <- data.frame(compound = comp_colData, treatment = treat_colData,
#                       stringsAsFactors = TRUE)
#
# rownames(colData) <- col1_colData
#
# dds <- DESeqDataSetFromMatrix(countData = countData,
#                                  colData = colData,
#                                  design = ~ treatment+compound+treatment:compound)
#
# dds$compound <- relevel(dds$compound, ref = 'dex')
# dds <- dds[ rowSums(fpm(dds, robust = FALSE)>=2) > 10, ]
# dds <- estimateSizeFactors(dds)
# dds <- estimateDispersions(dds, fitType='local')
# dds <- nbinomWaldTest(dds)
#
# # vsd <- tryCatch({
# #     vst(dds, blind=FALSE)
# # }, error = function(e){
# #     varianceStabilizingTransformation(dds, blind=FALSE)
# # })
#
# # pdf(paste0(outdir, '/plots/model1_interaction.pca.1_vs_2.pdf'), width=5, height=5)
# # plotPCA_(vsd, intgroup=c('compound'), ntop=500, pcX=1, pcY=2)
# # dev.off()
# # # Create PCA plot for the second and third PCs
# # pdf(paste0(outdir, '/plots/model1_interaction.pca.2_vs_3.pdf'), width=5, height=5)
# # plotPCA_(vsd, intgroup=c('compound'), ntop=500, pcX=2, pcY=3)
# # dev.off()
# # # Create PCA plot for the third and fourth PCs
# # pdf(paste0(outdir, '/plots/model1_interaction.pca.3_vs_4.pdf'), width=5, height=5)
# # plotPCA_(vsd, intgroup=c('compound'), ntop=500, pcX=3, pcY=4)
# # dev.off()
#
# coeff <- coef(dds)
#
# write.table(coeff, file=paste0(outdir, '/model1_interaction.beta_values.txt'),
#             quote=FALSE, row.names=TRUE, sep='\t')
#
# contrast_names <- grep('treatmentyes.', resultsNames(dds), value=TRUE)
#
# for (i in 1:length(contrast_names)){
#     result <- results(dds, name=(contrast_names[i]), alpha = 0.05)
#     result <- result[order(result$padj),]
#     result_logFC <- result[(abs(result$log2FoldChange))>1,]
#
#
#     pdf(paste0(outdir, '/plots/', contrast_names[i], '.MA_plot.filtered_log2FC.pdf'), width=6, height=6)
#     DESeq2::plotMA(result_logFC, main=paste0('MA plot for ', contrast_names[i]), ylim = c(-8,8))
#     dev.off()
#
#     pdf(paste0(outdir, '/plots/', contrast_names[i], '.MA_plot.pdf'), width=6, height=6)
#     DESeq2::plotMA(result, main=paste0('MA plot for ', contrast_names[i]), ylim = c(-8,8))
#     dev.off()
#
#     write.table(result, file=paste0(outdir, '/', contrast_names[i],'.txt'),
#                 quote=FALSE, row.names=TRUE, sep='\t')
#     write.table(result_logFC, file=paste0(outdir, '/', contrast_names[i],'.filtered_log2FC.txt'),
#                 quote=FALSE, row.names=TRUE, sep='\t')
# }
#
# save.image(paste0(outdir, '/model1_interaction.RData'))
# Out:
# Overwriting /data/reddylab/Revathy/scripts/Graham_DESeq2_model1_interaction.R

# %%
# %%bash
# mkdir -p /data/reddylab/Revathy/collabs/Graham/20220328/deseq/model1_interaction
# mkdir -p /data/reddylab/Revathy/collabs/Graham/20220328/deseq/model1_interaction/plots
# source /data/reddylab/software/miniconda3/bin/activate alex_py3
# sbatch -p all \
#     --mem 64G \
#     -o /data/reddylab/Revathy/collabs/Graham/20220328/deseq/logs/model1_interaction_deseq.out \
#     <<'EOF'
# #!/bin/bash
# Rscript /data/reddylab/Revathy/scripts/Graham_DESeq2_model1_interaction.R \
#      --counts /data/reddylab/Revathy/collabs/Graham/20220328/deseq/counts/A549_compounds_TNF_model1.counts.txt \
#      --outdir /data/reddylab/Revathy/collabs/Graham/20220328/deseq/model1_interaction
# EOF
# Out:
# Submitted batch job 28229246

# %%
import pandas as pd

beta = pd.read_csv('/data/reddylab/Revathy/collabs/Graham/20220328/deseq/model1_interaction/model1_interaction.beta_values.txt', sep='\t')
beta.shape
# Out:
# (12873, 22)

# %% [markdown]
# # Model 2

# %%
# %%bash
# ls /data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/*A549_TNF_CpdA_RNAseq*.featurecounts*
# Out:
# /data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_CpdA_RNAseq_rep1.star2.featurecounts.counts.txt
# /data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_CpdA_RNAseq_rep2.star2.featurecounts.counts.txt
# /data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_CpdA_RNAseq_rep3.star2.featurecounts.counts.txt

# %%
import pandas as pd

files = [
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_DMSO_RNAseq_rep1.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_DMSO_RNAseq_rep2.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_DMSO_RNAseq_rep3.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_DMSO_RNAseq_rep1.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_DMSO_RNAseq_rep2.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_DMSO_RNAseq_rep3.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_dex_RNAseq_rep1.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_dex_RNAseq_rep2.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_dex_RNAseq_rep3.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_dex_RNAseq_rep1.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_dex_RNAseq_rep2.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_dex_RNAseq_rep3.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_CORT108297_RNAseq_rep1.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_CORT108297_RNAseq_rep2.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_CORT108297_RNAseq_rep3.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_CORT108297_RNAseq_rep1.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_CORT108297_RNAseq_rep2.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_CORT108297_RNAseq_rep3.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_pretreatCORT108297_dex_RNAseq_rep1.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_pretreatCORT108297_dex_RNAseq_rep2.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_pretreatCORT108297_dex_RNAseq_rep3.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_pretreatCORT108297_dex_RNAseq_rep1.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_pretreatCORT108297_dex_RNAseq_rep2.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_pretreatCpdA_dex_RNAseq_rep1.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_pretreatCpdA_dex_RNAseq_rep2.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_pretreatCpdA_dex_RNAseq_rep3.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_CpdA_RNAseq_rep1.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_CpdA_RNAseq_rep2.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_CpdA_RNAseq_rep3.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_CpdA_RNAseq_rep1.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_CpdA_RNAseq_rep2.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_CpdA_RNAseq_rep3.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_pretreatCpdA_dex_RNAseq_rep1.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_pretreatCpdA_dex_RNAseq_rep2.star2.featurecounts.counts.txt',
'/data/reddylab/Revathy/collabs/Graham/20220328/processing/rna_seq/20220401_GDJ_multistim_rnaseq-pe-revstranded-with-sjdb/A549_TNF_pretreatCpdA_dex_RNAseq_rep3.star2.featurecounts.counts.txt'
]

def clean_count_column(s):
    rep=s.split('/')[-1].split('.')[0].replace('_RNAseq','').split('_')[-1]
    name="_".join(s.split('/')[-1].split('.')[0].replace('_RNAseq','').split('_')[:-1])
    col_name=".".join([name,rep])
    return col_name

df = None
for file in files:
    df_tmp = pd.read_csv(file, sep='\t',skiprows=1)
    df_tmp.columns = df_tmp.columns[:-1].tolist() + [clean_count_column(file)]
    if df is None:
        df = df_tmp.loc[:, ['Geneid','Chr', 'Start', 'End'] + [df_tmp.columns[-1]]]
    else:
        df = df.join(df_tmp.loc[:, df_tmp.columns[-1]], how='right')

count_columns = ["rep" in c for c in df.columns]
df.loc[:, count_columns] = df.loc[:, count_columns].astype(dtype='int')
df.drop(columns=['Chr','Start','End']).to_csv('/data/reddylab/Revathy/collabs/Graham/20220328/deseq/counts/A549_compounds_TNF_pretreated_model2.counts.txt', sep='\t', index=False)

# %%
# %%bash
# source /data/reddylab/software/miniconda3/bin/activate alex_py3
# mkdir -p /data/reddylab/Revathy/collabs/Graham/20220328/deseq/model2/plots
# sbatch -p all \
#     --mem 64G \
#     -o /data/reddylab/Revathy/collabs/Graham/20220328/deseq/logs/model2_deseq.out \
#     <<'EOF'
# #!/bin/bash
# Rscript /data/reddylab/Revathy/scripts/Graham_DESeq2.R \
#      --counts /data/reddylab/Revathy/collabs/Graham/20220328/deseq/counts/A549_compounds_TNF_pretreated_model2.counts.txt \
#      --contrast /data/reddylab/Revathy/collabs/Graham/20220328/20220404_deseq_rnaseq_model2_contrasts.txt \
#      --outdir /data/reddylab/Revathy/collabs/Graham/20220328/deseq/model2
# EOF
# Out:
# Submitted batch job 28087570

# %%
# !cat /data/reddylab/Revathy/collabs/Graham/20220328/20220404_deseq_rnaseq_model2_contrasts.txt
# Out:
# Treatment1	Treatment2
# A549_TNF_pretreatCpdA_dex	A549_DMSO
# A549_TNF_pretreatCORT108297_dex	A549_DMSO
# A549_TNF_pretreatCpdA_dex	A549_TNF_DMSO
# A549_TNF_pretreatCORT108297_dex	A549_TNF_DMSO
# A549_TNF_pretreatCpdA_dex	A549_CpdA
# A549_TNF_pretreatCpdA_dex	A549_TNF_CpdA
# A549_TNF_pretreatCpdA_dex	A549_dex
# A549_TNF_pretreatCpdA_dex	A549_TNF_dex
# A549_TNF_pretreatCORT108297_dex	A549_CORT108297
# A549_TNF_pretreatCORT108297_dex	A549_TNF_CORT108297
# A549_TNF_pretreatCpdA_dex	A549_dex
# A549_TNF_pretreatCpdA_dex	A549_TNF_dex

# %%
# %%writefile /data/reddylab/Revathy/collabs/Graham/20220328/20220404_deseq_rnaseq_model2_contrasts_v1.txt
# Treatment1	Treatment2
# A549_pretreatCpdA_dex	A549_dex
# A549_pretreatCORT108297_dex	A549_dex
# Out:
# Writing /data/reddylab/Revathy/collabs/Graham/20220328/20220404_deseq_rnaseq_model2_contrasts_v1.txt

# %%
# %%bash
# source /data/reddylab/software/miniconda3/bin/activate alex_py3
# mkdir -p /data/reddylab/Revathy/collabs/Graham/20220328/deseq/model2/plots
# sbatch -p all \
#     --mem 64G \
#     -o /data/reddylab/Revathy/collabs/Graham/20220328/deseq/logs/model2_deseq_v1.out \
#     <<'EOF'
# #!/bin/bash
# Rscript /data/reddylab/Revathy/scripts/Graham_DESeq2.R \
#      --counts /data/reddylab/Revathy/collabs/Graham/20220328/deseq/counts/A549_compounds_TNF_pretreated_model2.counts.txt \
#      --contrast /data/reddylab/Revathy/collabs/Graham/20220328/20220404_deseq_rnaseq_model2_contrasts_v1.txt \
#      --outdir /data/reddylab/Revathy/collabs/Graham/20220328/deseq/model2
# EOF
# Out:
# Submitted batch job 28423635
